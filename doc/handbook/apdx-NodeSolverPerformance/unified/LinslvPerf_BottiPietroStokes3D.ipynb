// %% [markdown]
// # Linear Solver Performance: 3D Stokes manufactured Solution after Botti and Di Pietro
// ### Part 1, Benchmark Setup and Execution

// %% [markdown]
// This benchmark was proposed in a work:
//
//  "p‑Multilevel Preconditioners for HHO Discretizations of the Stokes Equations with Static Condensation"
//  by L. Botti and D. Di Pietro (https://doi.org/10.1007/s42967-021-00142-5)
//
// It is used to assess DG as well as HDG methods, the latter beeing the main focus of the paper, the former only for reference.
// The exact solution to the stationary Stokes equation is
// $$
// u_1 =  2 \sin(\pi x)), \\
// u_2 =  -\pi y \cos(\pi x), \\
// u_3 =  -\pi z \cos(\pi x), \\
//   p =  \sin(\pi y) \cos(\pi y) \sin(\pi z).
// $$
// This velocity field is divergence-free, i.e. it fulfills the continuity equation.
// To fulfill also momentum balance, a right-hand-side
// $$
// g_1 =                      -2 \pi^2  \sin(\pi x), \\
// g_2 =    \left( -2 \pi \cos(\pi y)^2  + \pi \right) \sin(\pi z) + \pi^3  y \cos(\pi x), \\
// g_3 =   \pi \left( \cos(\pi x) \pi^2  z - \sin(\pi y) \cos(\pi y) \cos(\pi z) \right)
// $$
// The domain is set as $ \Omega = (0,1)^3 $.
// This manufactured solution is also used as a boundary condition on three sides;
// On one side, a Neumann boundary condition is enforced. It is not mentioned which side this is.
//
//
// ### Note
//
// This example can be found in the source code repository as as `LinslvPerf_BottiPietroStokes3D.ipynb`.
// One can directly load this into Jupyter to interactively work with the following code examples.
//
// Note: First, BoSSS has to be loaded into the Jupyter kernel. Note:
// In the following line, the reference to `BoSSSpad.dll` is required.
// One must either set `#r "BoSSSpad.dll"` to something which is appropirate for the current computer
// (e.g. `C:\Program Files (x86)\FDY\BoSSS\bin\Release\net5.0\BoSSSpad.dll` if working with the binary distribution),
// or, if one is working with the source code, one must compile `BoSSSpad`
// and put it side-by-side to this worksheet file
// (from the original location in the repository, one can use the scripts `getbossspad.sh`, resp. `getbossspad.bat`).

// %%
Console.WriteLine("Execution Date/time is " + DateTime.Now);
// Out:
// Execution Date/time is 10/17/2024 11:16:37 AM

// %%
System.Security.Principal.WindowsIdentity.GetCurrent().Name
// Out:
// FDY\toprak

// %%
//#r "C:\Users\toprak\Documents\BoSSS-code\public\src\L4-application\BoSSSpad\bin\Release\net6.0\BoSSSpad.dll"
//#r "C:\Users\jenkinsci\Documents\BoSSS-NET5\public\src\L4-application\BoSSSpad\bin\Debug\net5.0\BoSSSpad.dll"
#r "BoSSSpad.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using BoSSS.Application.XNSFE_Solver;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

// %%
string PROJECT_NAME = System.Environment.GetEnvironmentVariable("LinSlvPerfTest") ?? "LinslvPerfSer"; // this allows to modify the project name for testing purposes
var myBatch = ExecutionQueues[4];
wmg.Init(PROJECT_NAME,myBatch);
wmg.SetNameBasedSessionJobControlCorrelation();
wmg.AllJobs
// Out:
// Project name is set to 'LinSlvPerfExpTest'.
// Opening existing database '\\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest'.

// %%
wmg.Sessions
// Out:
// #0: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p5_exp_Kcycle_schwarzSkipPreSmootherWithComments	10/17/2024 11:08:32 AM	fb8b371d...
// #1: LinSlvPerfExpTest	BottiPietroStokes2D-J65536_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithComments	10/17/2024 11:09:30 AM	6b74ca9c...
// #2: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p2_exp_Kcycle_schwarzNormalWithComments	10/17/2024 11:11:32 AM	5ab9e729...
// #3: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p3_exp_Kcycle_schwarzNormalWithComments	10/17/2024 11:12:17 AM	a36be1d8...
// #4: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p3_exp_Kcycle_schwarzSkipPreSmootherWithComments	10/17/2024 11:08:03 AM	b5986ee6...
// #5: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p5_exp_Kcycle_schwarzNormalWithComments*	10/17/2024 11:13:26 AM	8050d510...
// #6: LinSlvPerfExpTest	BottiPietroStokes2D-J65536_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments	10/17/2024 11:07:15 AM	456f51b6...
// #7: LinSlvPerfExpTest	BottiPietroStokes2D-J65536_p3_exp_Kcycle_schwarzNormalWithComments*	10/17/2024 11:12:55 AM	310a6eb0...
// #8: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p5_exp_Kcycle_schwarzNormalWithComments*	10/17/2024 11:13:09 AM	81f3e0c5...
// #9: LinSlvPerfExpTest	BottiPietroStokes2D-J147456_p2_exp_Kcycle_schwarzNormalWithComments*	10/17/2024 11:12:04 AM	0b75c3ae...
// #10: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p2_exp_Kcycle_schwarzNormalWithComments	10/17/2024 11:11:17 AM	9a0e5cc5...
// #11: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p3_exp_Kcycle_schwarzNormalWithComments*	10/17/2024 11:12:35 AM	6b63c130...
// #12: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithComments	10/17/2024 11:09:16 AM	ccdb4d74...
// #13: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithComments	10/17/2024 11:09:59 AM	abd92484...
// #14: LinSlvPerfExpTest	BottiPietroStokes2D-J65536_p2_exp_Kcycle_schwarzNormalWithComments*	10/17/2024 11:11:48 AM	b40c9cb9...
// #15: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithComments*	10/17/2024 11:11:04 AM	1d7b5f71...
// #16: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithComments*	10/17/2024 11:10:50 AM	aba93241...
// #17: LinSlvPerfExpTest	BottiPietroStokes2D-J65536_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithComments*	10/17/2024 11:10:33 AM	0543b455...
// #18: LinSlvPerfExpTest	BottiPietroStokes2D-J147456_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithComments*	10/17/2024 11:09:45 AM	fc7361e6...
// #19: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithComments*	10/17/2024 11:10:16 AM	fe7ed830...
// #20: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithComments	10/17/2024 11:09:01 AM	6057adc5...
// #21: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments	10/17/2024 11:07:03 AM	ace6f8d3...
// #22: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p3_exp_Kcycle_schwarzSkipPreSmootherWithComments	10/17/2024 11:07:46 AM	e5808b0d...
// #23: LinSlvPerfExpTest	BottiPietroStokes2D-J36864_p5_exp_Kcycle_schwarzSkipPreSmootherWithComments*	10/17/2024 11:08:47 AM	9258ccd3...
// #24: LinSlvPerfExpTest	BottiPietroStokes2D-J65536_p3_exp_Kcycle_schwarzSkipPreSmootherWithComments*	10/17/2024 11:08:16 AM	ddad5bb8...
// #25: LinSlvPerfExpTest	BottiPietroStokes2D-J147456_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments*	10/17/2024 11:07:33 AM	e3660a0e...
// #26: LinSlvPerfExpTest	BottiPietroStokes2D-J16384_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments	10/17/2024 11:06:44 AM	c957dbd2...

// %%
/*
// extract the control object to reproduce specific simulation on local workstation
string dest = @"C:\Users\flori\Documents\BoSSS-kummer\public\src\L4-application\XNSE_Solver\bin\Release\net5.0\BenchControls";
foreach(var s in wmg.Sessions) {
    string name = s.Name;
    Console.Write(name + ": ");
    try {
        var ctrl = s.GetControl();
        var txt = ctrl.Serialize();
        
        string DestPath = System.IO.Path.Combine(dest, name + ".obj");
        System.IO.File.WriteAllText(DestPath, txt);
        
        Console.WriteLine("written");
    } catch(Exception e) {
        Console.WriteLine(e.Message);
    }
}
*/

// %%
//wmg.DefaultDatabase.Grids.ForEach(s => s.Delete(true));

// %% [markdown]
// ## Utility definitions

// %%
static class Utils {
    // DOF per cell for one variable
    public static int Np(int p) {
        //return (p*p + 3*p + 2)/2; // 2D 
        return (p*p*p + 6*p*p + 11*p + 6)/6; // 3D
    }    
    
    /*
    //Non-equidistant nodes
    public static double[] SinLinSpacing(double l, double r, double a, int n) {
        double[] linnodes = GenericBlas.Linspace(-Math.PI * 0.5, Math.PI * 0.5, n);
        double[] linnodes2 = GenericBlas.Linspace(-1, 1, n);
        double[] nodes = new double[n];

        for (int i = 0; i < n; i++)
            //nodes[i] = linnodes2[i] * (1 - a) + (1.0 - Math.Sin(linnodes[i])) * a;
            nodes[i] = linnodes2[i] * (1 - a) + Math.Sin(linnodes[i])*a;

        for (int i = 0; i < n; i++)
            nodes[i] = nodes[i] * (r - l)*0.5 + l;
        return nodes;
    }
    */
}

// %% [markdown]
// ## Init grids and save to database

// %%
int[] Resolutions_3D = new int[] { 8, 16, 24, 32, 48, 64 };

IGridInfo[] grids = new IGridInfo[Resolutions_3D.Length];
for(int cnt = 0; cnt < Resolutions_3D.Length; cnt++) {
    int Res = Resolutions_3D[cnt];    
    
    double[] xNodes = GenericBlas.Linspace(0, +1, Res + 1);
    double[] yNodes = GenericBlas.Linspace(0, +1, Res + 1);
    double[] zNodes = GenericBlas.Linspace(0, +1, Res + 1);
    int J = (xNodes.Length - 1)*(yNodes.Length - 1)*(zNodes.Length - 1);
    
    string GridName = string.Format(wmg.CurrentProject + "-Stokes3D_J" + J);
    
    grids[cnt] = wmg.Grids.SingleOrDefault(grd => grd.Name.Contains(GridName)); // check if an appropriate grid is already present in the database
    if(grids[cnt] == null){
        Console.WriteLine("Creating grid with " + J + " cells.");
        
        GridCommons g;
        g      = Grid3D.Cartesian3DGrid(xNodes, yNodes, zNodes);
        g.Name = GridName;
        
        g.DefineEdgeTags(delegate (double[] X) {
            double x = X[0];
            if(Math.Abs(x - (0.0)) < 1e-8)
                return "pressure_outlet";
            return "wall"; 
        });
      
        g = wmg.SaveGrid(g);  
        grids[cnt] = g;
    } else {
        Console.WriteLine("Found Grid: " + grids[cnt]);
        if(grids[cnt].NumberOfCells != J)
            throw new Exception("J mismatch");
        
        if(grids[cnt].SpatialDimension != 3)
            throw new Exception("D mismatch");
    }
}
// Out:
// Opening existing database 'X:\work\LinSlvPerfExpTest'.
// Opening existing database 'W:\work\scratch\mt64qocy\LinSlvPerfExpTest'.
// Opening existing database '\\dc3\userspace\toprak\BoSSS-Convergence\LinSlvPerfExpTest'.
// Opening existing database '\\dc3\userspace\toprak\BoSSS-ConvergenceFinal\LinSlvPerfExpTest'.
// Opening existing database '\\dc3\userspace\toprak\BoSSS-ConvSteadyFinal\LinSlvPerfExpTest'.
// Opening existing database 'C:\localBatch\LinSlvPerfExpTest'.
// Found Grid: { Guid = f1ae0a5f-4aa5-4a6e-a8c0-c318a9dedea3; Name = LinSlvPerfExpTest-Stokes3D_J512; Cell Count = 512; Dim = 3 }
// Found Grid: { Guid = 5a6cc981-2a56-4546-9d19-bcec516cc597; Name = LinSlvPerfExpTest-Stokes3D_J4096; Cell Count = 4096; Dim = 3 }
// Found Grid: { Guid = a4d222e0-d676-45c4-936d-d2cf721941ad; Name = LinSlvPerfExpTest-Stokes3D_J13824; Cell Count = 13824; Dim = 3 }
// Found Grid: { Guid = 3ac198c8-94aa-444e-8bd5-3eb983533929; Name = LinSlvPerfExpTest-Stokes3D_J32768; Cell Count = 32768; Dim = 3 }
// Found Grid: { Guid = 0ec81f90-7e79-4806-aa91-8f225b111171; Name = LinSlvPerfExpTest-Stokes3D_J110592; Cell Count = 110592; Dim = 3 }
// Found Grid: { Guid = 9ebc34ad-249e-42f1-bb0f-fedbea591327; Name = LinSlvPerfExpTest-Stokes3D_J262144; Cell Count = 262144; Dim = 3 }

// %%
grids
// Out:
// #0: { Guid = f1ae0a5f-4aa5-4a6e-a8c0-c318a9dedea3; Name = LinSlvPerfExpTest-Stokes3D_J512; Cell Count = 512; Dim = 3 }
// #1: { Guid = 5a6cc981-2a56-4546-9d19-bcec516cc597; Name = LinSlvPerfExpTest-Stokes3D_J4096; Cell Count = 4096; Dim = 3 }
// #2: { Guid = a4d222e0-d676-45c4-936d-d2cf721941ad; Name = LinSlvPerfExpTest-Stokes3D_J13824; Cell Count = 13824; Dim = 3 }
// #3: { Guid = 3ac198c8-94aa-444e-8bd5-3eb983533929; Name = LinSlvPerfExpTest-Stokes3D_J32768; Cell Count = 32768; Dim = 3 }
// #4: { Guid = 0ec81f90-7e79-4806-aa91-8f225b111171; Name = LinSlvPerfExpTest-Stokes3D_J110592; Cell Count = 110592; Dim = 3 }
// #5: { Guid = 9ebc34ad-249e-42f1-bb0f-fedbea591327; Name = LinSlvPerfExpTest-Stokes3D_J262144; Cell Count = 262144; Dim = 3 }

// %%
//PlotGrid("g2304",grids[4]);

// %%
wmg.DefaultDatabase
// Out:
// { Session Count = 27; Grid Count = 11; Path = \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest }

// %% [markdown]
// ## Setup Control Object for a Solver Run

// %%
// - - - - - - - - - - - - - - - - - - -
// Initial Values & Boundary conditions
// - - - - - - - - - - - - - - - - - - -

// %%
using BoSSS.Application.XNSE_Solver;
using BoSSS.Solution.LevelSetTools;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.XNSECommon;
using BoSSS.Solution.Timestepping;
using BoSSS.Solution.XdgTimestepping ;

// %% [markdown]
// ### Boundary Conditions and Exact Solution
//
// Note that the 3D-example given by Botti and Di Pietro is only a manufactured solution, i.e. it fulfills the continuity, but not the momentum equation;
// Hence, some non-zero right-hand-side for the momentum is required.

// %%
var VelocityX = new Formula("(X) => 2.0*Math.Sin(Math.PI*X[0])");

// %%
var VelocityY = new Formula("(X) => -Math.PI*X[1]*Math.Cos(Math.PI*X[0])");

// %%
var VelocityZ = new Formula("(X) =>  -Math.PI*X[2]*Math.Cos(Math.PI*X[0])");

// %%
var Pressure = new Formula("(X) => Math.Sin(Math.PI*X[1])*Math.Cos(Math.PI*X[1])*Math.Sin(Math.PI*X[2])");

// %%
var RhsX = new Formula("(X) => -(2*Math.PI.Pow2()*Math.Sin(Math.PI*X[0]) + Math.PI*Math.Cos(Math.PI*X[0])*Math.Cos(Math.PI*X[1])*Math.Sin(Math.PI*X[2]))");

// %%
var RhsY = new Formula("(X) => -(-Math.PI*(Math.Cos(Math.PI*X[0])*Math.PI.Pow2()*X[1] + Math.Sin(Math.PI*X[0])*Math.Sin(Math.PI*X[1])*Math.Sin(Math.PI*X[2])))");

// %%
var RhsZ = new Formula("(X) => -(-Math.PI*(Math.Cos(Math.PI*X[0])*Math.PI.Pow2()*X[2] - Math.Cos(Math.PI*X[1])*Math.Cos(Math.PI*X[2])*Math.Sin(Math.PI*X[0])))");

// %%
NUnit.Framework.Assert.Less((VelocityX.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (1.618033989)).Abs(), 1.0e-9, 
     "x-Velocity expression differs from reference value");
NUnit.Framework.Assert.Less((VelocityY.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (-0.5539745491)).Abs(), 1.0e-9, 
     "y-Velocity expression differs from reference value");
NUnit.Framework.Assert.Less((VelocityZ.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (-1.292607281)).Abs(), 1.0e-9, 
     "z-Velocity expression differs from reference value");
NUnit.Framework.Assert.Less((Pressure.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (0.3847104420)).Abs(), 1.0e-9, 
     "pressure expression differs from reference value");
NUnit.Framework.Assert.Less((RhsX.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (-16.84745722)).Abs(), 1.0e-8, 
     "Rhs of x-Momentum expression differs from reference value");
NUnit.Framework.Assert.Less((RhsY.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (+7.131009654)).Abs(), 1.0e-8, 
     "Rhs of y-Momentum expression differs from reference value");
NUnit.Framework.Assert.Less((RhsZ.Evaluate(new double[] { 0.3, 0.3, 0.7 }, 0) - (+13.63562436)).Abs(), 1.0e-8, 
     "Rhs of z-Momentum expression differs from reference value");

// %% [markdown]
// ### Setup of Parameter Study

// %% [markdown]
// Polynomial degrees to test:

// %%
int[] PolyDegS = new int[] {2, 3, 5};

// %% [markdown]
// Solvers which we want to instrument:

// %%
// Solvers which we want to instrument:
LinearSolverCode[] solver_nameS = new LinearSolverCode[] {
    // LinearSolverCode.direct_pardiso,
    // LinearSolverCode.exp_gmres_levelpmg,
    LinearSolverCode.exp_Kcycle_schwarz,
    // LinearSolverCode.pMultigrid
};

// %% [markdown]
// Maximum Dof for one calculation (we skip fine grids for higher polynomial orders):

// %%
int GetMaxAllowedDOF(LinearSolverCode code) {
    switch(code) {
        case LinearSolverCode.direct_pardiso:
        case LinearSolverCode.direct_mumps:
        case LinearSolverCode.pMultigrid:
        return 700000; // 0.7 Million for direct solvers and p-MG at maximum            
    
        default: 
        return 5000000; // Up to 5 Million for iterative solvers
    }
}

// %%
enum Cases {
SkipPreSmoother,
NonSerialPreSmoother,
Normal
}

// %%
OrthoMGSchwarzConfig GetPreSmoother(OrthoMGSchwarzConfig config, Cases caseType) {
    switch(caseType) {
        case Cases.SkipPreSmoother:
            config.SkipPreSmoother = true;
            config.NonSerialPreSmoother = false;
            break;
        case Cases.NonSerialPreSmoother:
            config.NonSerialPreSmoother = true;
            config.SkipPreSmoother = false;
            break;
        case Cases.Normal:
        default:
            config.NonSerialPreSmoother = false;
            config.SkipPreSmoother = false;
            break;
    }
    return config; // Up to 3 Million for iterative solvers
}

// %% [markdown]
// Loop over all combinations of parameters and define a control object for each combo:

// %%
using BoSSS.Solution.XNSECommon;
using BoSSS.Foundation.XDG;

// %%
List<XNSE_Control> controls = new List<XNSE_Control>();
controls.Clear();
foreach(Cases mycase in Enum.GetValues(typeof(Cases))) {
foreach(LinearSolverCode solver in solver_nameS) {
foreach(int k in PolyDegS) {
foreach(IGridInfo grd in grids) {

    int Np_V = Utils.Np(k);
    int Np_p = Utils.Np(k-1);
    int J    = grd.NumberOfCells;
    int DOF  = Np_V*3 + Np_p;
    if(J*DOF >  GetMaxAllowedDOF(solver))
        continue;
    if(solver == LinearSolverCode.pMultigrid && k <= 2)
        continue; // p-multigrid cannot really work with only two p-levels
    if(solver == LinearSolverCode.exp_gmres_levelpmg && k > 3)
        continue; // two-grid is ineffective for higher polynomial degrees
    if(k >= 5 && J >= 13824) // 09oct23: calculation lasts more than four hours
        continue;

    // Control Instance, grid, DG degree, etc.
    // =======================================
    
    XNSE_Control C = new XNSE_Control();
    controls.Add(C);
       
    string caseName = string.Format("BottiPietroStokes3D-J{0}_p{1}_{2}", J, k, solver);
    Console.WriteLine("setting up: " + caseName);
    C.SessionName        = caseName;
    
    C.SetGrid(grd);
    C.savetodb = true;
    C.SetDGdegree(k);
    
    // Phys. Parameters
    // ================
    
    C.PhysicalParameters.rho_A             = 1; // not relevant, since density is not present in steady-state Stokes.
    C.PhysicalParameters.rho_B             = 1; // not relevant, since density is not present in steady-state Stokes.
    C.PhysicalParameters.mu_A              = 1; // dimensionless
    C.PhysicalParameters.mu_B              = 1; // dimensionless
    C.PhysicalParameters.Sigma             = 0; // not relevant, since single phase
    C.PhysicalParameters.IncludeConvection = false;
    C.PhysicalParameters.Material          = true;
    
    // Boundary Conditions
    // ===================
    C.AddBoundaryValue("wall", "VelocityX", VelocityX);
    C.AddBoundaryValue("wall", "VelocityY", VelocityY);
    C.AddBoundaryValue("wall", "VelocityZ", VelocityZ);
    
    // RHS of the manufactured solution
    // ================================

    C.AddInitialValue("VolumeForceX", RhsX);
    C.AddInitialValue("VolumeForceY", RhsY);
    C.AddInitialValue("VolumeForceZ", RhsZ);

   
    // Solver Stuff
    // ============
    
    //C.VelocityBlockPrecondMode         = MultigridOperator.Mode.SymPart_DiagBlockEquilib;
    
    C.LinearSolver           = solver.GetConfig();
    if(C.LinearSolver is IterativeSolverConfig isc) {
        isc.ConvergenceCriterion = 1e-8;
    }
    if(C.LinearSolver is OrthoMGSchwarzConfig OMGconfig){
        C.LinearSolver = GetPreSmoother(OMGconfig, mycase);
        C.SessionName +=  mycase;
        C.Tags.Add(mycase.ToString());
    }    
    C.LevelSet_ConvergenceCriterion     = 1e-6;
    C.NoOfMultigridLevels = 100;
    C.TracingNamespaces = "BoSSS.Solution";

    // Timestepping / Instationary
    // ===========================

    C.TimesteppingMode             = AppControl._TimesteppingMode.Steady;
}
}
}
}
// Out:
// setting up: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarz
// setting up: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarz

// %% [markdown]
// Total number of simulations:

// %%
controls.Count
// Out:
// <div class="dni-plaintext"><pre>33</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
// Basic checks on the multigrid configuration
foreach(var ctrl in controls) {
    NUnit.Framework.Assert.Greater(ctrl.NoOfMultigridLevels, 1, "More than 1 multigrid level must be set");
    if(ctrl.LinearSolver is OrthoMGSchwarzConfig osc)
        NUnit.Framework.Assert.Greater(osc.NoOfMultigridLevels, 1, "More than 1 multigrid level must be set");
}

// %%
//string path = @"C:\Users\kummer\Documents\BoSSS-kummer\public\src\L4-application\XNSE_Solver\bin\release\net5.0\Stokes3D";
//foreach(var ctrl in controls) {
//    ctrl.savetodb = false;
//    ctrl.SaveToFile(System.IO.Path.Combine(path, "control-" + ctrl.SessionName + ".obj"));
//}

// %% [markdown]
// ## Launch Jobs

// %% [markdown]
// Use the default queue defined on this machine:

// %%
foreach(var ctrl in controls) {
    Console.WriteLine(" Submitting: " + ctrl.SessionName); 
    ctrl.SessionName += "WithCommentss";
    var j = ctrl.CreateJob();
    j.RetryCount = 1;
    j.NumberOfThreads = 1;         
    j.Activate(myBatch);
    //ctrl.RunBatch();
}
// Out:
//  Submitting: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_111928.697387
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_111943.949436
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_111959.131389
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112014.526584
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112030.267178
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112046.406963
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112101.776025
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112117.716577
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112133.215776
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112148.282018
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzSkipPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzSkipPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112205.656476
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112224.093146
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112239.563628
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112257.411144
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112312.433287
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112327.497641
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112345.828214
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112401.342569
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112417.020992
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112432.694763
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112448.616968
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNonSerialPreSmoother
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112504.118634
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112519.531214
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112535.036268
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112551.099370
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112607.248102
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112623.231702
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112639.551351
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112655.702422
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112711.892132
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112727.219705
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112744.308460
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.
//  Submitting: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNormal
// Deployments so far (0): ;
// Success: 0
// job submit count: 0
// unable to determine job status - unknown
// Deploying job BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNormalWithCommentss ...
// Deploying executables and additional files ...
// Deployment directory: \\dc3\userspace\toprak\BoSSS-ConditionFinal\LinSlvPerfExpTest-XNSE_Solver2024Oct17_112800.219227
// copied 43 files.
//    written file: control.obj
//    copied 'win\amd64' runtime.
// deployment finished.

// %%
wmg.AllJobs
// Out:
// #0: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #1: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #2: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #3: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #4: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #5: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #6: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #7: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #8: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #9: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #10: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzSkipPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #11: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #12: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #13: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #14: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #15: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #16: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #17: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #18: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #19: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #20: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #21: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNonSerialPreSmootherWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #22: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #23: BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p2_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #24: BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J13824_p2_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #25: BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J32768_p2_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #26: BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J110592_p2_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #27: BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p3_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #28: BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p3_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #29: BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J13824_p3_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #30: BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J32768_p3_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #31: BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J512_p5_exp_Kcycle_schwarzNormalWithCommentss: FinishedSuccessful (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)
// #32: BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)	BottiPietroStokes3D-J4096_p5_exp_Kcycle_schwarzNormalWithCommentss: InProgress (MS HPC client  q4-BoSSS-ConditionFinal @DC3, @\\dc3\userspace\toprak\BoSSS-ConditionFinal)

// %%
//foreach(var j in wmg.AllJobs.Values) {
//    j.DeleteOldDeploymentsAndSessions();
//}

// %% [markdown]
// ### Wait for Completion and Check Job Status

// %%
wmg.BlockUntilAllJobsTerminate(3600*24*2); // wait at maximum two days for the jobs to finish

// %%
wmg.AllJobs
// Out:
// unable to determine job status - unknown
// unable to determine job status - unknown
// unable to determine job status - unknown
// unable to determine job status - unknown
// unable to determine job status - unknown
// unable to determine job status - unknown
// #0: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmoother: Unknown (SlurmClient q0-Lichtenberg user storage : mt64qocy@lcluster18.hrz.tu-darmstadt.de, Slurm account: special00006)	BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmoother: Unknown (SlurmClient q0-Lichtenberg user storage : mt64qocy@lcluster18.hrz.tu-darmstadt.de, Slurm account: special00006)
// #1: BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments: Unknown (SlurmClient q0-Lichtenberg user storage : mt64qocy@lcluster18.hrz.tu-darmstadt.de, Slurm account: special00006)	BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments: Unknown (SlurmClient q0-Lichtenberg user storage : mt64qocy@lcluster18.hrz.tu-darmstadt.de, Slurm account: special00006)

// %%
wmg.Sessions.Where(sess => sess.Name.StartsWith("BottiPietroStokes3D-J"))

// %%
var NoSuccess = controls.Select(ctrl => ctrl.GetJob()).Where(job => job.Status != JobStatus.FinishedSuccessful).ToArray();
NoSuccess
// Out:
// unable to determine job status - unknown
// unable to determine job status - unknown
// System.ApplicationException: Unable to find a 1:1 correlation between control object and jobs: matching jobs BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmoother: Unknown (SlurmClient q0-Lichtenberg user storage : mt64qocy@lcluster18.hrz.tu-darmstadt.de, Slurm account: special00006), BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarzSkipPreSmootherWithComments: Unknown (SlurmClient q0-Lichtenberg user storage : mt64qocy@lcluster18.hrz.tu-darmstadt.de, Slurm account: special00006);
//
//    at BoSSS.Application.BoSSSpad.AppControlExtensions.GetJob(AppControl ctrl) in C:\Users\toprak\Documents\BoSSS-code\public\src\L4-application\BoSSSpad\AppControlExtensions.cs:line 276
//
//    at Submission#90.<>c.<<Initialize>>b__0_0(XNSE_Control ctrl)
//
//    at System.Linq.Enumerable.SelectListIterator`2.MoveNext()
//
//    at System.Linq.Enumerable.WhereEnumerableIterator`1.ToArray()
//
//    at Submission#90.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %%
// In the case of some failed job, print the directory name for further inspection:
foreach(var fail in NoSuccess) {
    Console.WriteLine(fail + ":  @" + ((fail.LatestDeployment?.DeploymentDirectory?.FullName) ?? " no deployment directory"));
    //Console.WriteLine(fail.Stderr);
    //Console.WriteLine();
    //Console.WriteLine("***************************");
    //Console.WriteLine("***************************");
    //Console.WriteLine();
}
// Out:
// System.NullReferenceException: Object reference not set to an instance of an object.
//
//    at Submission#91.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %%
/*
string PathOffset = @"C:\Users\jenkinsci\Desktop\LinSlvPerfFail-20apr22";
foreach(var fail in NoSuccess) {
    var C = fail.GetControl();
    C.savetodb = false;
    C.SaveToFile(System.IO.Path.Combine(PathOffset, fail.Name + ".obj"));
    
    string Stdout = fail.Stdout;
    System.IO.File.WriteAllText(System.IO.Path.Combine(PathOffset, fail.Name + "-stdout.txt"), Stdout);
    
    string Stderr = fail.Stderr;
    System.IO.File.WriteAllText(System.IO.Path.Combine(PathOffset, fail.Name + "-stderr.txt"), Stderr);
}
*/

// %%
var FailedSessions = wmg.Sessions.Where(Si => Si.Name.Contains("BottiPietroStokes3D") && Si.SuccessfulTermination == false);
FailedSessions

// %%
//FailedSessions.Select(si => (si, si.GetSessionDirectory(), si.DeployPath))

// %% [markdown]
// #### Asserting Success:

// %% [markdown]
// Remark: since this is currently (19 Aug. 2022) work-in-progress, we allow for some jobs to fail; At this intermediate milestone, I want to record (by the means of tests) what is already working. Thereby, I hope I won't break the working cases while trying to fix the failing ones.

// %%
//foreach(var si in FailedSessions)
//   si.Delete(true);

// %%
var prelim_allowedFails = new[] {
    "BottiPietroStokes3D-J512_p2_exp_Kcycle_schwarz",
    "BottiPietroStokes3D-J*_p*_pMultigrid",
    "BottiPietroStokes3D-J13824_p3_exp_gmres_levelpmg",
    "BottiPietroStokes3D-J4096_p3_exp_gmres_levelpmg",
    "BottiPietroStokes3D-J32768_p2_exp_gmres_levelpmg",
    "BottiPietroStokes3D-J32768_p3_exp_gmres_levelpmg",
    "BottiPietroStokes3D-J512_p5_direct_pardiso",
    "BottiPietroStokes3D-J13824_p2_direct_pardiso",
    "BottiPietroStokes3D-J4096_p3_direct_pardiso"
 };

// %%
bool FailAllowed(string name) {
    foreach(string s in prelim_allowedFails) {
        if(s.WildcardMatch(name))
            return true;
    }
    return false;
}

// %%
NoSuccess.Where(job => !FailAllowed(job.Name))
// Out:
// System.ArgumentNullException: Value cannot be null. (Parameter 'source')
//
//    at System.Linq.ThrowHelper.ThrowArgumentNullException(ExceptionArgument argument)
//
//    at System.Linq.Enumerable.Where[TSource](IEnumerable`1 source, Func`2 predicate)
//
//    at Submission#98.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %%
NUnit.Framework.Assert.Zero(NoSuccess.Where(job => !FailAllowed(job.Name)).Count(), "Some Jobs Failed");
// Out:
// System.ArgumentNullException: Value cannot be null. (Parameter 'source')
//
//    at System.Linq.ThrowHelper.ThrowArgumentNullException(ExceptionArgument argument)
//
//    at System.Linq.Enumerable.Where[TSource](IEnumerable`1 source, Func`2 predicate)
//
//    at Submission#99.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %%
NUnit.Framework.Assert.Zero(FailedSessions.Where(s => !FailAllowed(s.Name)).Count(), "Some Sessions did not terminate successfully.");
