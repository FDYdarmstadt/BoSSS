// %%
// #r "BoSSSpad.dll"
#r "./binaries/BoSSSpad.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Solution.LevelSetTools;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

// %%
#r "./binaries/LsTest.dll"
using BoSSS.Application.LsTest;

// %%
var db = BoSSSshell.OpenDatabase(@"P:/cluster/Leveque3D");

// %%
var sessions = db.Sessions;
sessions.ForEach((i,s) => display(String.Format("{0} : {1} - {2}", i, s.Name, s.ID.ToString()).ToString()));
// Out:
// 0 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - 3e242741-618c-479c-8471-fab8341d5df3
// 1 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - b5317b90-5289-4780-a1b2-3a42b314f0c1
// 2 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - c3b578f9-0df5-421b-82ac-ece86c5fc553
// 3 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - fafe6060-2782-4d86-8021-17f026a0592d
// 4 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - 8321d20a-9b57-4e18-8982-145d120186f5
// 5 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - 152c5537-f714-477d-9159-262b641bf263
// 6 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - fcb66d56-871c-41f0-bbcf-efdc063ed9c8
// 7 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - 0806d3c9-9a66-443c-8501-2315018f8a99
// 8 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - 1630ebb3-84c9-459f-a8d2-5eeed5215ed5
// 9 : SwirlingFlow3D_H_p2_H1_EvoPrescribedVelocity - 10b19de3-aa87-4aed-b4a0-4f77b8b15e65
// ...

// %%
var s2e = sessions.Pick(36, 21, 0);
SessionExportInstruction E;

// %%
E = s2e.Pick(0).Timesteps.Where((t,i) => t.TimeStepNumber.MajorNumber % 10 == 0).Export();
E.FieldNames = new List<string> {"Phi", "PhiDG"};
E.To(@"P:\cluster\Leveque3D\PrescribedVelocity_H25_P2").WithSupersampling(2).Do();

// %%
E = s2e.Pick(1).Timesteps.Skip(1).Where((t,i) => t.TimeStepNumber.MajorNumber % 10 == 0).Export();
E.FieldNames = new List<string> {"Phi", "PhiDG"};
E.To(@"P:\cluster\Leveque3D\PrescribedVelocity_H25_P2").WithSupersampling(2).Do();

// %%
E = s2e.Pick(2).Timesteps.Skip(1).Where((t,i) => t.TimeStepNumber.MajorNumber % 10 == 0).Export();
E.FieldNames = new List<string> {"Phi", "PhiDG"};
E.To(@"P:\cluster\Leveque3D\PrescribedVelocity_H25_P2").WithSupersampling(2).Do();
