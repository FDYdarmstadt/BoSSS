# %%
#r "./../../../../../public/src/L4-application/BoSSSpad/bin/Release/net6.0/BoSSSpad.dll"
using System;
using System.Threading;
using System.Diagnostics;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Solution;
using BoSSS.Application.XNSE_Solver;
using BoSSS.Application.BoSSSpad;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.IO;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Control;
using BoSSS.Solution.XNSECommon;
using BoSSS.Solution.NSECommon;
using BoSSS.Solution.LoadBalancing;
using BoSSS.Solution.LevelSetTools;
using BoSSS.Solution.XdgTimestepping;
using BoSSS.Solution.Utils;
using System.IO;
using BoSSS.Application.XNSE_Solver.PhysicalBasedTestcases;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
using MomentFittingVariants = BoSSS.Foundation.XDG.XQuadFactoryHelper.MomentFittingVariants;
Init();

# %%
//defaults
string dbname = System.Environment.GetEnvironmentVariable("DATABASE_NAME");
string buildname = System.Environment.GetEnvironmentVariable("JOB_NAME");
buildname = String.IsNullOrEmpty(buildname)? "Popcorn2D" : buildname; //Popcorn2D  VanishingSphere2D
dbname = String.IsNullOrEmpty(dbname)? "condStudyBDF3" : dbname; //Collison´2
string table_name = String.Concat(buildname, "_", dbname);

# %%
using BoSSS.Solution.Gnuplot;

# %%
//ExecutionQueues
var myBatch = ExecutionQueues[4];
string WFlowName = table_name;
BoSSS.Application.BoSSSpad.BoSSSshell.WorkflowMgm.Init(WFlowName,myBatch);
BoSSS.Application.BoSSSpad.BoSSSshell.WorkflowMgm.SetNameBasedSessionJobControlCorrelation();
var myDB = BoSSS.Application.BoSSSpad.BoSSSshell.WorkflowMgm.DefaultDatabase; 
myDB
# Out:
# { Session Count = 73; Grid Count = 4; Path = \\dc3\userspace\toprak\BoSSS-ConditionFinal\Popcorn2D_condStudyBDF3 }

# %%
myDB.Sessions.Where(s => s.SuccessfulTermination == true)
# Out:
# #0: Popcorn2D_condStudyBDF3	SolverFalse_J1024_k2_Re1000_agg0.5_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	9/16/2024 11:39:05 AM	18a9bc43...
# #1: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k3_Re1000_agg0.4_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:47:43 AM	37dd8ac6...
# #2: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k3_Re1000_agg0.5_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:48:02 AM	04a2be37...
# #3: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k3_Re1000_agg0.3_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:47:21 AM	11b63800...
# #4: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k3_Re1000_agg0.1_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:44:59 AM	0af63d27...
# #5: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:44:28 AM	934d2da3...
# #6: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k3_Re1000_agg0.2_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:46:25 AM	c1718334...
# #7: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k2_Re1000_agg0.5_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:44:09 AM	c4deac85...
# #8: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k2_Re1000_agg0.4_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:44:07 AM	0d3b8b4e...
# #9: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k2_Re1000_agg0.3_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:14:29 AM	3e26bf2f...
# #10: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k2_Re1000_agg0.1_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:14:01 AM	6d285952...
# #11: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k2_Re1000_agg0.2_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:14:19 AM	c324f141...
# #12: Popcorn2D_condStudyBDF3	SolverFalse_J16384_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:13:45 AM	643320a6...
# #13: Popcorn2D_condStudyBDF3	SolverFalse_J256_k1_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 10:58:10 AM	2fcde315...
# #14: Popcorn2D_condStudyBDF3	SolverFalse_J256_k1_Re1000_agg0.1_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 10:59:05 AM	b294c7e1...
# #15: Popcorn2D_condStudyBDF3	SolverFalse_J256_k1_Re1000_agg0.2_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:00:19 AM	c3c01078...
# #16: Popcorn2D_condStudyBDF3	SolverFalse_J4096_k3_Re1000_agg0.5_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:11:54 AM	dc62da78...
# #17: Popcorn2D_condStudyBDF3	SolverFalse_J4096_k3_Re1000_agg0.1_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:10:52 AM	7fbf8985...
# #18: Popcorn2D_condStudyBDF3	SolverFalse_J4096_k3_Re1000_agg0.3_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:11:22 AM	fe7c5525...
# #19: Popcorn2D_condStudyBDF3	SolverFalse_J4096_k3_Re1000_agg0.2_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1	8/19/2024 11:11:09 AM	1cd8ffea...
# #20: Popcorn2D_condStudyBDF3	SolverFalse_J4096_
k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# Session: 101924d6-c1e5-4def-a1d1-22835def3f38
# Session: b86ceeb0-3285-4130-9078-df3a1cffe716
# Session: 311348bc-d482-459a-aebd-c11ac389a8f0
# Session: c05cf708-97dd-4477-8413-b5a54568c7cd
# Session: d535f1ac-dcab-46fa-9a35-022e6213969a
# Session: ea935919-0117-4212-a6bf-21673a4a4728
# Session: de42c228-f8e1-4aea-ba15-5f8cf814244e
# Session: 3f7a9e76-57ac-4ab8-92d3-add8e893218b
# Session: f825b5a2-be60-4327-a41c-86f485f112bd
# Session: 33dcca00-b14d-44d8-8a52-e0aaa29953f9
# Session: 09cbd1ff-512f-4783-9ec4-8f6e04e0f149
# Session: 95908b69-026b-4187-95e5-1a65709ddf59
# Session: 67f8f708-a685-4051-ac7e-9edd0caddfdd
# Session: 15d35c9b-fb9e-44d2-b4a4-1086061e004f
# The value 'Infinity' could not be converted to a double for line 2 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 18 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 22 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 38 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 42 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 58 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 78 at column 3 in session SolverFalse_J4096_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# Session: 721cd663-85b8-4ac1-855a-abc08809b499
# Session: c9045525-1573-4a4f-ac5a-97c8d4065a3d
# Session: 55509bea-7ea2-4e06-881e-d76213b389b1
# Session: 1f9683ed-7303-4b84-9986-4756c93cbc09
# Session: a79dad25-0725-4f35-a9b5-4553716a638e
# Session: 864b1b96-33bd-44a7-84a3-44cc08831030
# Session: 53cef0c6-85f4-448e-b113-f320ccab4149
# Session: 7c908117-9c8a-40e5-bb63-0a3c85e060e6
# Session: 0ef747c2-320d-46bf-a375-70b347352e61
# The value 'Infinity' could not be converted to a double for line 2 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 18 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 22 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 38 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 42 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 58 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 62 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 78 at column 3 in session SolverFalse_J1024_k2_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# Session: ed65cd68-92e7-4812-a13d-93e3eda24911
# Session: da2fc71a-dcfc-4a24-aad6-7b8166d8f6a5
# Session: e9066956-8b4a-4281-84b0-34536aedfd97
# Session: beb523df-55b7-4c1e-87f1-44bfdf42d348
# Session: a222f85f-5793-4f6f-9177-23206448fd40
# Session: eea39e93-60ca-4537-b0ae-72a97695b0ff
# Session: 5105592f-611a-4564-a1bd-c990e69e45a5
# Session: e588c141-98b1-436d-a800-2316b817477c
# Session: 78767dde-2205-4180-8eaf-ce8e8b1635ba
# Session: 054dfe06-3d7e-40e8-872b-102900ec2a74
# Session: b9e8c61a-8126-42fb-a235-a22bcb1d22fc
# Session: 29199bda-971d-4fb7-8a5b-d07faea54aec
# Session: 7ee825d1-c674-42c9-abf8-b9dec623e607
# Session: d66bd482-d295-48a2-8203-d5a17f13d258
# Session: c53b145d-fb72-4c78-8e0f-4a5b4cff19d9
# Session: c06cd096-7dd7-401d-a668-af77bc947322
# The value 'Infinity' could not be converted to a double for line 2 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 3 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 8 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 12 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 17 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 32 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 43 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 52 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 58 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 62 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 68 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# The value 'Infinity' could not be converted to a double for line 72 at column 3 in session SolverFalse_J256_k3_Re1000_agg0_ti0.000atZ_r0.6_AMRFalse_LBFalse_W9.99_NSE_dRdt0.00_condStudyFix_ct1.
# Session: daef6991-b545-4581-802f-e75f770d2959
# Session: 3dd62081-aad7-4be3-9819-e1649d1c4d5a
# Session: 5362a337-4f60-4981-a1b1-99b0dc669141
# Session: 9e4791ee-efe2-4cc6-ab3e-83a18b37ee72
# Session: 66d150bb-597c-4d9a-8561-17d5c3a85657
# Session: 0f5a493b-a6f3-437b-94bd-24c95fb51877
# Session: beafcc52-c74d-40d2-a13b-75f0b229a6dc
# Session: 318e4451-d7ac-49e2-bd9c-62485d85bf2e
# Session: 02968940-5504-4418-b3ba-ccb9c6a4e43a

# %%
var Tab = BoSSSshell.WorkflowMgm.SessionTable;

# %%
var Tab2 = Tab.ExtractColumns( "AgglomerationThreshold", "DGdegree:Velocity*","Grid:hMin","Grid:NoOfCells" ,"MassMtxCondNo", "TotCondNo-Vars0.1.2");
Tab2.SaveToFile(table_name + $"_condSummary.json");
Tab2.Print()
# Out:
#     AgglomerationThreshold DGdegree:Velocity* Grid:hMin Grid:NoOfCells MassMtxCondNo     TotCondNo-Vars0.1.2
# 0:  0.5                    2                  0.0625    1024           347014.3389827836 1124.085167863416
# 1:  0.4                    3                  0.015625  16384          26803652.39147243 12719.4866350516
# 2:  0.5                    3                  0.015625  16384          20036778.80525523 11081.61529786546
# 3:  0.3                    3                  0.015625  16384          41822620.30573832 16451.97586403205
# 4:  0.1                    3                  0.015625  16384          356943245.8709114 20949.78397012053
# 5:  0                      3                  0.015625  16384          356003744081.9747 5.337077798267193E+25
# 6:  0.2                    3                  0.015625  16384          90873677.66285762 19928.01662547001
# 7:  0.5                    2                  0.015625  16384          4426300.957168679 7555.666330512669
# 8:  0.4                    2                  0.015625  16384          5981214.92553284  7898.228007240976
# 9:  0.3                    2                  0.015625  16384          9468587.683210257 7918.833211789118
# 10: 0.1                    2                  0.015625  16384          74128006.48644815 9345.45980570795
# 11: 0.2                    2                  0.015625  16384          19724303.73601324 9328.05345388762
# 12: 0                      2                  0.015625  16384          176637698129999.4 8.580436200756621E+20
# 13: 0                      1                  0.125     256            51308705.61248821 436.1903106669443
# 14: 0.1                    1                  0.125     256            192865.8675900416 421.3275493698112
# 15: 0.2                    1                  0.125     256            76281.15636689767 381.0300554328234
# 16: 0.5                    3                  0.03125   4096           5184920.865480311 4404.663090049226
# 17: 0.1                    3                  0.03125   4096           70370357.96219946 10943.38412644906
# 18: 0.3                    3                  0.03125   4096           10768069.45133516 4946.577209397376
# 19: 0.2                    3                  0.03125   4096           21578801.45767379 7733.730780834856
# 20: 0.4                    3                  0.03125   4096           6898013.838361658 4826.700856422503
# 21: 0                      3                  0.03125   4096           20278780067046.09 2.984458753352113E+21
# 22: 0.1                    3                  0.0625    1024           20687408.83518548 4646.174436554729
# 64: 0.3                    1                  0.0625    1024           93077.30360708844 924.2715311504678
# 65: 0.2                    1                  0.0625    1024           163907.2950259955 944.183683274422
# 66: 0.1                    1                  0.0625    1024           406721.421844132  986.8468549234103
# 67: 0                      1                  0.0625    1024           259442476834.1865 991.0258532056233
# 68: 0.3                    2                  0.125     256            265165.0436331641 694.1167852827424
# 69: 0.4                    2                  0.125     256            158491.1646898692 676.8243163632892
# 70: 0.2                    2                  0.125     256            426422.0382044547 706.7519289447698
# 71: 0.5                    2                  0.125     256            112963.9386864596 666.3848026840158

# %%
using BoSSS.Solution.Gnuplot;
using System.Linq;

// arrange line color and types
var allColors = Enum.GetValues(typeof(LineColors)).Cast<LineColors>().ToArray();
var allPointTypes = Enum.GetValues(typeof(PointTypes)).Cast<PointTypes>().ToArray();
PointTypes[] myPointTypes = new PointTypes[]{ PointTypes.Diamond, PointTypes.Box,  PointTypes.LowerTriangle,PointTypes.OpenLowerTriangle };

// arrange mesh size and column names
double[] meshes = new double[]{256, 1024, 4096, 16384};

# %%
string varName = "MassMtxCondNo";

Plot2Ddata[,] PlotTable = new Plot2Ddata[2, 2];
int ind = 0;
for (int iCol = 0; iCol < 2; iCol++) {
    for (int iRow = 0; iRow < 2; iRow++) {     
        // Filter data
        var Tab2 = Tab.ExtractColumns( "AgglomerationThreshold", "DGdegree:Velocity*","Grid:hMin","Grid:NoOfCells" ,varName);
        
        // Find the correct mesh resolution for each subfigure
        Tab2 = Tab2.ExtractRows((iRow,RowEntries)=> 
                Convert.ToDouble(RowEntries["Grid:NoOfCells"]) == meshes[ind]
            );

        // Sort in ascending order of AgglomerationThreshold
        System.Data.DataView view = Tab2.DefaultView;
        view.Sort = "DGdegree:Velocity* ASC"; 
        Tab2 = view.ToTable();

        var plot = Tab2.ToPlot("AgglomerationThreshold", varName,  "DGdegree:Velocity*");

        for (int i = 0; i < plot.dataGroups.Length; i++){
            var dataGroup = plot.dataGroups[i];
            dataGroup.Format.LineColor = allColors[i % allColors.Length];
            dataGroup.Format.PointType = myPointTypes[i % myPointTypes.Length];
        }      

        // Plot details
        plot.LogY = true;
        plot.Title = "Grid:NoOfCells=" + meshes[ind]; 
        plot.TitleFont = 20;
        plot.Xlabel = "AggThreshold";  
        plot.Ylabel = varName;  
        plot.SavePgfplotsFile($"{varName}_{meshes[ind]}.tex");
        PlotTable[iCol, iRow] = plot;

        ind++;
    }
}

# %%
PlotTable.PlotNow()
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="800" height="600"
#  viewBox="0 0 800 600"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="800" height="600" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,239.5 L76.5,239.5 M346.1,239.5 L337.1,239.5  '/>	<g transform="translate(59.2,245.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,231.9 L72.0,231.9 M346.1,231.9 L341.6,231.9 M67.5,221.7 L72.0,221.7 M346.1,221.7 L341.6,221.7
# 		M67.5,216.6 L72.0,216.6 M346.1,216.6 L341.6,216.6 M67.5,214.1 L76.5,214.1 M346.1,214.1 L337.1,214.1
# 		 '/>	<g transform="translate(59.2,220.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">5</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,206.5 L72.0,206.5 M346.1,206.5 L341.6,206.5 M67.5,196.3 L72.0,196.3 M346.1,196.3 L341.6,196.3
# 		M67.5,191.2 L72.0,191.2 M346.1,191.2 L341.6,191.2 M67.5,188.7 L76.5,188.7 M346.1,188.7 L337.1,188.7
# 		 '/>	<g transform="translate(59.2,194.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,181.1 L72.0,181.1 M346.1,181.1 L341.6,181.1 M67.5,170.9 L72.0,170.9 M346.1,170.9 L341.6,170.9
# 		M67.5,165.8 L72.0,165.8 M346.1,165.8 L341.6,165.8 M67.5,163.3 L76.5,163.3 M346.1,163.3 L337.1,163.3
# 		 '/>	<g transform="translate(59.2,169.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">7</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,155.7 L72.0,155.7 M346.1,155.7 L341.6,155.7 M67.5,145.5 L72.0,145.5 M346.1,145.5 L341.6,145.5
# 		M67.5,140.4 L72.0,140.4 M346.1,140.4 L341.6,140.4 M67.5,137.9 L76.5,137.9 M346.1,137.9 L337.1,137.9
# 		 '/>	<g transform="translate(59.2,143.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,130.3 L72.0,130.3 M346.1,130.3 L341.6,130.3 M67.5,120.1 L72.0,120.1 M346.1,120.1 L341.6,120.1
# 		M67.5,115.0 L72.0,115.0 M346.1,115.0 L341.6,115.0 M67.5,112.5 L76.5,112.5 M346.1,112.5 L337.1,112.5
# 		 '/>	<g transform="translate(59.2,118.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">9</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,104.9 L72.0,104.9 M346.1,104.9 L341.6,104.9 M67.5,94.7 L72.0,94.7 M346.1,94.7 L341.6,94.7
# 		M67.5,89.6 L72.0,89.6 M346.1,89.6 L341.6,89.6 M67.5,87.1 L76.5,87.1 M346.1,87.1 L337.1,87.1
# 		 '/>	<g transform="translate(59.2,93.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">10</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,239.5 L67.5,230.5 M67.5,87.1 L67.5,96.1  '/>	<g transform="translate(67.5,262.0)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M123.2,239.5 L123.2,230.5 M123.2,87.1 L123.2,96.1  '/>	<g transform="translate(123.2,262.0)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0.1</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M178.9,239.5 L178.9,230.5 M178.9,87.1 L178.9,96.1  '/>	<g transform="translate(178.9,262.0)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0.2</tspan></text>
# 	</g>
# </g>
# <

# %%
PlotTable.SaveToGIF(varName + ".png");
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe

# %%
string varName = "TotCondNo-Vars0.1.2";

Plot2Ddata[,] PlotTable = new Plot2Ddata[2, 2];
int ind = 0;
for (int iCol = 0; iCol < 2; iCol++) {
    for (int iRow = 0; iRow < 2; iRow++) {     
        // Filter data
        var Tab2 = Tab.ExtractColumns( "AgglomerationThreshold", "DGdegree:Velocity*","Grid:hMin","Grid:NoOfCells" ,varName);
        
        // Find the correct mesh resolution for each subfigure
        Tab2 = Tab2.ExtractRows((iRow,RowEntries)=> 
                Convert.ToDouble(RowEntries["Grid:NoOfCells"]) == meshes[ind]
            );

        // Sort in ascending order of AgglomerationThreshold
        System.Data.DataView view = Tab2.DefaultView;
        view.Sort = "DGdegree:Velocity* ASC"; 
        Tab2 = view.ToTable();
        
        var plot = Tab2.ToPlot("AgglomerationThreshold", varName,  "DGdegree:Velocity*");

        for (int i = 0; i < plot.dataGroups.Length; i++){
            var dataGroup = plot.dataGroups[i];
            dataGroup.Format.LineColor = allColors[i % allColors.Length];
            dataGroup.Format.PointType = myPointTypes[i % myPointTypes.Length];
        }      

        // Plot details
        plot.LogY = true;
        plot.Title = "Grid:NoOfCells=" + meshes[ind]; 
        plot.TitleFont = 20;
        plot.Xlabel = "AggThreshold";  
        plot.Ylabel = varName;  
        plot.SavePgfplotsFile($"{varName}_{meshes[ind]}.tex");
        PlotTable[iCol, iRow] = plot;

        ind++;
    }
}

# %%
PlotTable.PlotNow()
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="800" height="600"
#  viewBox="0 0 800 600"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="800" height="600" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,239.5 L76.5,239.5 M346.1,239.5 L337.1,239.5  '/>	<g transform="translate(59.2,245.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,231.0 L72.0,231.0 M346.1,231.0 L341.6,231.0 M67.5,222.6 L76.5,222.6 M346.1,222.6 L337.1,222.6
# 		 '/>	<g transform="translate(59.2,228.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,214.1 L72.0,214.1 M346.1,214.1 L341.6,214.1 M67.5,205.6 L76.5,205.6 M346.1,205.6 L337.1,205.6
# 		 '/>	<g transform="translate(59.2,211.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,197.2 L72.0,197.2 M346.1,197.2 L341.6,197.2 M67.5,188.7 L76.5,188.7 M346.1,188.7 L337.1,188.7
# 		 '/>	<g transform="translate(59.2,194.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,180.2 L72.0,180.2 M346.1,180.2 L341.6,180.2 M67.5,171.8 L76.5,171.8 M346.1,171.8 L337.1,171.8
# 		 '/>	<g transform="translate(59.2,177.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">10</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,163.3 L72.0,163.3 M346.1,163.3 L341.6,163.3 M67.5,154.8 L76.5,154.8 M346.1,154.8 L337.1,154.8
# 		 '/>	<g transform="translate(59.2,160.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">12</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,146.4 L72.0,146.4 M346.1,146.4 L341.6,146.4 M67.5,137.9 L76.5,137.9 M346.1,137.9 L337.1,137.9
# 		 '/>	<g transform="translate(59.2,143.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">14</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,129.4 L72.0,129.4 M346.1,129.4 L341.6,129.4 M67.5,121.0 L76.5,121.0 M346.1,121.0 L337.1,121.0
# 		 '/>	<g transform="translate(59.2,127.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">16</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,112.5 L72.0,112.5 M346.1,112.5 L341.6,112.5 M67.5,104.0 L76.5,104.0 M346.1,104.0 L337.1,104.0
# 		 '/>	<g transform="translate(59.2,110.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">18</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M67.5,95.6 L72.0,95.6 M346.1,95.6 L341.6,95.6 M67.5,87.1 L76.5,87.1 M346.1,87.1 L337.1,87.1
# 		 '/>	<g transform="translate(59.2,93.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">20</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'

# %%
PlotTable.SaveToGIF(varName + ".png");
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
