// %%
#r "D:/rieckmann/BoSSS/BoSSS-Repos/BoSSS-InterfaceSlip/public/src/L4-application/BoSSSpad/bin/Release/net6.0/BoSSSpad.dll"
using System;
using System.Data;
using System.Collections.Generic;
using System.Linq;
using System.IO;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using BoSSS.Application.XNSFE_Solver;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
using System.Diagnostics;
using Microsoft.AspNetCore.Html;
using System.Text.RegularExpressions;

Init();
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-26152.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://130.83.248.161:1001/", "http://172.28.16.1:1001/", "http://127.0.0.1:1001/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '26152.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>

// %%
string proj = "SlipConvergence_Droplet";
BoSSSshell.WorkflowMgm.Init(proj);
BoSSSshell.WorkflowMgm.SetNameBasedSessionJobControlCorrelation();
// Out:
// Project name is set to 'SlipConvergence_Droplet'.
// Default Execution queue is chosen for the database.
// Opening existing database '\\dc3\backup\rieckmann\cluster\databases\SlipConvergence_Droplet'.

// %%
//BoSSSshell.WorkflowMgm.Sessions.ElementAt(5).GetSessionDirectory()

// %%
var sessions = BoSSSshell.WorkflowMgm.Sessions;
sessions.ForEach(s => display(s));
// Out:
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:22	f635de0b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:41:05	ece2c8ae...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	feea6663...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:47	7b431d59...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:55	114a90d3...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:32:00	e3a1c479...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:29:02	10f33401...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:24	bcd998ad...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	ca59ecfc...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:24	fa6b8b33...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:39:47	4785eb33...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:14	5a64abc7...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	eb697122...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:39	350dbfcc...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:55	cb3e1be4...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	bcc563ba...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:36	3dab864a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	e7ed0334...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:41:05	ec4df405...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:38:08	97f948d3...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:47	81bc1497...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:24	d86829d7...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:34:53	11939ca7...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:32:00	09bddd53...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:33:54	4d7a5205...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:46	662c01bd...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:28	a521520b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:47	07ec3117...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:20	dbc656fd...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	8b9d4840...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	cf57c902...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:39:47	2efe630d...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:07	6599b49c...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:19	329fc962...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	99fa83c5...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	ca72a070...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	b262cca3...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:14	7d424a83...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:40:42	b2451873...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:11	14ae74e2...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:38:04	9a61cb9b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:39:31	19b007ae...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:32	36abac1f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:40:42	77e4d1ca...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:40	c7f7a71a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:38	b2779e10...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:40:24	577d8dc0...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	ae3ff832...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:34:40	b5a1c17e...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:24	a21783ca...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:39:16	98e99a79...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:36	cd4f318d...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:39:47	ba390571...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:39:15	65db687c...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:33:53	c17b6cfc...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:37:33	f9b5c621...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:38:43	a3279c36...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	6bb7f787...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:35:52	c401d146...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	d551aaae...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:30	4a12883a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:37:23	d6cd21f1...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:37:10	d05b200a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:37:09	f43aa1b6...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:15	a68e367a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:29	869b8052...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:36:28	395db458...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:31:24	4cba2b67...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:35:33	166be17f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:18	5d8293ac...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:34:38	a97e3ec0...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:45	d8f5627e...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:14	03511102...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:35:21	47b969b2...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:35:06	bdd5c0a2...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:34:38	398aceaf...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:12	a8c50b7a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:34:33	19998196...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:15	2f3da87f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:13	3e17bf44...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:34:24	679589f8...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:45	950b7450...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:34:12	551110f7...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:02	3019ca37...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:32:43	c8f13664...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:33:53	f86ea8b3...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	5790aa17...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:39	0825ab50...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:20	686cedaf...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:32:33	89840da1...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:24	14bde78e...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	acb56439...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	de184019...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	94aafeaa...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	870b9938...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:32:32	27686d83...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:31:18	7df7e568...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:32:32	734fcdbc...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:32	42930b7e...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:14	715c50c3...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:31:01	c7665812...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:37	dabb9722...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:38	a577cf5a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:45	5a27015f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:31:01	1a9cb2e5...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	b8c71118...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:27	d25ed57f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	5e97ee0e...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	c2168a5b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:00	fefcc19a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:30:20	ccca5a01...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:02	e9200b8f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:26	3131228a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:39	e27a2f45...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:29:58	10f712ab...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:44	769e9c0b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:29:56	482c9a7a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:24	f70ffd67...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:38	b7d635d8...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:27	cbcb8a9a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	f77f43da...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:19	6d54c438...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	ab5e2132...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	fdafe506...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:02	875abf7d...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:38	51806c94...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	941f4844...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:19	1f5cfa10...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	a376486b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:02	f60b987b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:44	59c0dc59...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:29:02	e38d4e02...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	50134a9d...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:19	bf3343e8...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:24	1f85655b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:40	8ad06604...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	fab7aa5b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:32	f233c901...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	ea27dfe3...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:31	6840e6bf...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:24	09d0298f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	819eea3e...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	b8d0b409...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	017b324f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	71c5cdeb...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	8e17e5b7...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:18	38090d6a...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:23	6366af80...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	1d82b468...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	30a29505...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	169a9936...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	7e787b89...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	101e5ad6...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	d8473a3b...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	7aa19a00...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:27:59	289f3971...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	817d3917...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	6b4fb365...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	828a6c78...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	4ca82102...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue	01/25/2024 12:27:59	5cf6d40f...
// SlipConvergence_Droplet	SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue	01/25/2024 12:28:00	9ee17eca...

// %%
public static Dictionary<string, Plot2Ddata> ExtractConvergenceH(IEnumerable<ISessionInfo> filteredsessions){

    Dictionary<string, Plot2Ddata> ret = new Dictionary<string, Plot2Ddata>();
    
    // ITimestepInfo[] timesteps = filteredsessions.Select(s => s.Timesteps.Last()).ToArray();
    // string[] fields = timesteps.First().Fields.Select(f => f.Identification).ToArray();
    string[] fields = new string[] {"Pressure", "VelocityX", "VelocityY", "Temperature"};
    
    foreach(var field in fields){
        Plot2Ddata errDat = filteredsessions.ToEstimatedGridConvergenceData(field, normType: NormType.L2_embedded); 
        ret.Add(field, errDat);
    } 
    
    return ret;
}

public static Dictionary<string, List<ISessionInfo>> ExtractSessionsByName(IEnumerable<ISessionInfo> sessions){
    
    Dictionary<string, List<ISessionInfo>> filteredsessions = new Dictionary<string, List<ISessionInfo>>();
    
    foreach(var sess in sessions){
        var key = Regex.Split(sess.Name , ".*meshStudy_[0-9]+_P[0-9]?_",RegexOptions.IgnoreCase).Last();
        
        if(!filteredsessions.ContainsKey(key)){
            filteredsessions[key] = new List<ISessionInfo>();
        }
        filteredsessions[key].Add(sess);
    }
    
    return filteredsessions;
}

public static IEnumerable<ISessionInfo> ExtractSessions(IEnumerable<ISessionInfo> sessions, int k, double theta, double ls, double q, double sigma, bool recoil, bool convection){
    var filteredsessions = sessions.Where(s => 
        Convert.ToDouble(s.KeysAndQueries["id:wallfriction"]) == 0.0 &&
        Convert.ToDouble(s.KeysAndQueries["id:theta"]) == Math.Round(theta, 4) &&
        Convert.ToDouble(s.KeysAndQueries["id:interfacesliplength"]) == ls &&
        Convert.ToDouble(s.KeysAndQueries["id:heatflux"]) == q &&
        Convert.ToDouble(s.KeysAndQueries["id:sigma"]) == sigma &&
        Convert.ToBoolean(s.KeysAndQueries["id:recoil"]) == recoil &&
        Convert.ToBoolean(s.KeysAndQueries["id:convection"]) == convection && 
        (k > 0 ? (Convert.ToInt32(s.KeysAndQueries["id:degree"]) == k) : true)
    ).ToArray();
    
    Console.WriteLine(filteredsessions.Count());
    
    return filteredsessions;
}

// %% [markdown]
// ### StaticDropletOnWall Sessions bis mesh5, Kontaktwinkel 80°

// %%
using System.Data;

// %%
// Testcase setup
double[] thetaS            = (new double[] {80}).Select(x => x/180.0 * Math.PI).ToArray();
double[] lsS               = new double[] {0.0, 0.1, double.PositiveInfinity};
double[] qS                = new double[] {0.0, 0.1, 0.5};
double[] sigmaS                = new double[] {0.1};
bool[] recoilS = new bool[] {true}; // recoil pressure
bool[] convectionS = new bool[] {true}; // convection

DataTable table = new DataTable("ConvergenceData");
DataColumn column;
DataRow row;

column = new DataColumn();
column.DataType = System.Type.GetType("System.String");
column.ColumnName = "Study";
column.ReadOnly = true;
column.Unique = true;
table.Columns.Add(column);

column = new DataColumn();
column.DataType = typeof(List<ISessionInfo>);
column.ColumnName = "Sessions";
column.ReadOnly = false;
column.Unique = false;
table.Columns.Add(column);

var filteredsessions = ExtractSessionsByName(sessions);

foreach(var kvp in filteredsessions){
    row = table.NewRow();
    row["Study"] = kvp.Key;
    row["Sessions"] = kvp.Value;
    table.Rows.Add(row);
}

// //BERECHNUNG
// Dictionary<(double, double, double, double, bool, bool), Dictionary<string, Plot2Ddata>> ConvergenceData = new Dictionary<(double theta, double ls, double q, double sigma, bool recoil, bool convection), Dictionary<string, Plot2Ddata>>();

// foreach(double theta in thetaS){
//     foreach(double ls in lsS){
//         foreach(double q in qS){
//             foreach(double sigma in sigmaS){
//                 foreach(bool recoil in recoilS){
//                     foreach(bool convection in convectionS){
//                         ConvergenceData.Add((theta: theta, ls: ls, q: q, sigma: sigma, recoil: recoil, convection: convection), ExtractConvergenceH(sessions, 0, theta, ls, q, sigma, recoil, convection));
//                     }
//                 }
//             }
//         }
//     }
// }

// %%
table.Print()
// Out:
//    Study                                              Sessions
// 0: WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue     System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 1: WF0.00_CA1.40_SLInfinity_HF0.50_ST0.10_RTrue_CTrue System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 2: WF0.00_CA1.40_SL0.00_HF0.00_ST0.10_RTrue_CTrue     System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 3: WF0.00_CA1.40_SL0.10_HF0.10_ST0.10_RTrue_CTrue     System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 4: WF0.00_CA1.40_SLInfinity_HF0.10_ST0.10_RTrue_CTrue System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 5: WF0.00_CA1.40_SL0.10_HF0.50_ST0.10_RTrue_CTrue     System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 6: WF0.00_CA1.40_SL0.10_HF0.00_ST0.10_RTrue_CTrue     System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 7: WF0.00_CA1.40_SLInfinity_HF0.00_ST0.10_RTrue_CTrue System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// 8: WF0.00_CA1.40_SL0.00_HF0.10_ST0.10_RTrue_CTrue     System.Collections.Generic.List`1[BoSSS.Foundation.IO.ISessionInfo]
// warning CS1701: Assuming assembly reference 'System.Data.Common, Version=6.0.0.0, Culture=neutral, PublicKeyToken=b03f5f7f11d50a3a' used by 'BoSSSpad' matches identity 'System.Data.Common, Version=7.0.0.0, Culture=neutral, PublicKeyToken=b03f5f7f11d50a3a' of 'System.Data.Common', you may need to supply runtime policy

// %%
var study2export = table.Rows[0];
var study = (string)study2export["Study"];
var studysessions = (List<ISessionInfo>)study2export["Sessions"];    
var studypath = Path.GetFullPath(Path.Join(".", study));    

studysessions.ForEach(s => s.Timesteps.Last().Export().To(Path.GetFullPath(Path.Join(studypath, s.Name))).WithShadowFields().WithSupersampling(2).Do());
// Out:
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_128_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_128_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_64_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_128_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_64_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_32_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_64_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_32_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_16_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_32_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_8_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_16_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_16_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_4_P4_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_8_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_8_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_4_P3_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue
// Starting export process... Data will be written to the directory: D:\rieckmann\BoSSS\BoSSS-Repos\BoSSS-InterfaceSlip\public\examples\SlipConvergence\WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue\SlipDropletOnWall_meshStudy_4_P2_WF0.00_CA1.40_SL0.00_HF0.50_ST0.10_RTrue_CTrue

// %%
var studysessionsdirs = Directory.GetDirectories(studypath);

foreach(var dir in studysessionsdirs){
        
    var subdir = dir.Split('\\').Last();
    var degree = Regex.Match(subdir, "P[0-9]{1}").Value;
    var mesh = Regex.Match(subdir, "meshStudy_[0-9]+").Value;
    
    if(degree == subdir)
        continue;
        
    if(!Directory.Exists(Path.Join(studypath, degree))){
        Directory.CreateDirectory(Path.Join(studypath, degree));
    }    
    
    File.Copy(Path.Join(dir, "state_1.plt"), Path.Join(studypath, degree, mesh) + ".plt");

}

// %%
foreach(var data in ConvergenceData){
    
    Console.WriteLine(data.Key.ToString());    
    
    var dats = data.Value;
    
    foreach(string field in dats.Keys){
        Console.WriteLine(field);
        var regression = dats[field].Regression();
        foreach(var kvp in regression){
            Console.WriteLine($"{kvp.Key} : {kvp.Value}");
        }
    }
    
    
    Console.WriteLine();
}
// Out:
// (1.3962634015954636, 0, 0, 0.1, True, True)
// Pressure
// 3 : 1.818907010089899
// 2 : 1.5327827208437947
// 1 : 1.631355281917946
// VelocityX
// 4 : 2.4931715578346543
// 3 : 2.831047621890816
// 2 : 2.6136771608545013
// VelocityY
// 4 : 2.5173940425702925
// 3 : 2.9040467746056517
// 2 : 2.666836700607372
// Temperature
// 4 : -4.911577581967
// 3 : -0.005709908305781184
// 2 : 0.17172463486747763
//
// (1.3962634015954636, 0, 0.1, 0.1, True, True)
// Pressure
// 3 : 0.009288562025511192
// 2 : 0.019968703843792297
// 1 : 0.15492242650515137
// VelocityX
// 4 : 0.9070979313204869
// 3 : 0.9949142071143867
// 2 : 1.0120651780416645
// VelocityY
// 4 : 0.8104852484216237
// 3 : 0.8829224986521031
// 2 : 0.9709639393170529
// Temperature
// 4 : 2.1983697368803616
// 3 : 2.167139087288776
// 2 : 2.101165149358982
//
// (1.3962634015954636, 0, 0.5, 0.1, True, True)
// Pressure
// 3 : 0.016433873096096334
// 2 : 0.032823047480824256
// 1 : 0.05010626319869824
// VelocityX
// 4 : 0.9446942307373557
// 3 : 0.9250783372528297
// 2 : 0.7170453102981834
// VelocityY
// 4 : 0.8653884673225131
// 3 : 0.9099347973809381
// 2 : 0.7021573048207372
// Temperature
// 4 : 2.19835821669261
// 3 : 2.167126288421599
// 2 : 2.101148803894298
//
// (1.3962634015954636, 0.1, 0, 0.1, True, True)
// Pressure
// 3 : 1.495990104365729
// 2 : 1.4758628678626873
// 1 : 1.5958111928068806
// VelocityX
// 4 : 2.3686980430389073
// 3 : 2.845902886653256
// 2 : 2.7951139245353316
// VelocityY
// 4 : 2.402550138383134
// 3 : 2.931604003384823
// 2 : 2.7426609905098807
// Temperature
// 4 : -1.8951358603082065
// 3 : 0.8003758327047614
// 2 : 1.9391904671032794
//
// (1.3962634015954636, 0.1, 0.1, 0.1, True, True)
// Pressure
// 3 : 0.19062631341246122
// 2 : 0.15809839904825704
// 1 : 0.5353588988412937
// VelocityX
// 4 : 1.1547307918755367
// 3 : 1.2433018131154119
// 2 : 1.1500295308209074
// VelocityY
// 4 : 1.1827213653944937
// 3 : 1.264793837665103
// 2 : 1.1615555019092927
// Temperature
// 4 : 2.198370432570126
// 3 : 2.167140355419958
// 2 : 2.1011658236336914
//
// (1.3962634015954636, 0.1, 0.5, 0.1, True, True)
// Pressure
// 3 : 0.17986951966487544
// 2 : 0.16682573174775178
// 1 : 0.29256787365912745
// VelocityX
// 4 : 1.1076032690756723
// 3 : 1.085503846912302
// 2 : 0.8407775408852749
// VelocityY
// 4 : 1.103390555697569
// 3 : 1.0641371805190438
// 2 : 0.8373009522861555
// Temperature
// 4 : 2.1983623690489678
// 3 : 2.1671339573780806
// 2 : 2.1011477778905823
//
// (1.3962634015954636, Infinity, 0, 0.1, True, True)
// Pressure
// 3 : 1.04103416553191
// 2 : 1.2061691129787364
// 1 : 1.4880325651636817
// VelocityX
// 4 : 2.03591963739327
// 3 : 2.4320103100723562
// 2 : 2.328961646649293
// VelocityY
// 4 : 2.1266206037301907
// 3 : 2.498775048861414
// 2 : 2.347468405634378
// Temperature
// 4 : -1.618244340830739
// 3 : -0.022707955425707478
// 2 : 2.0375782227683614
//
// (1.3962634015954636, Infinity, 0.1, 0.1, True, True)
// Pressure
// 3 : 0.18338593914187068
// 2 : 0.17147954586933797
// 1 : 0.43767831148478703
// VelocityX
// 4 : 1.2361955552559278
// 3 : 1.2760230691358545
// 2 : 1.0916332433054985
// VelocityY
// 4 : 1.275671035034194
// 3 : 1.3138829553425742
// 2 : 1.090318524989088
// Temperature
// 4 : 2.198370141296774
// 3 : 2.1671408187970655
// 2 : 2.101165768130847
//
// (1.3962634015954636, Infinity, 0.5, 0.1, True, True)
// Pressure
// 3 : 0.17262896858206428
// 2 : 0.10998647777310357
// 1 : 0.2045533921460482
// VelocityX
// 4 : 1.1960971196711832
// 3 : 1.1357943937459618
// 2 : 0.8954488787699943
// VelocityY
// 4 : 1.2089436835853078
// 3 : 1.134993940881974
// 2 : 0.7719968272697068
// Temperature
// 4 : 2.1983628277448184
// 3 : 2.1671367878529204
// 2 : 2.10114840751158

// %%
ConvergenceData.First().Value.First().Value.Regression()
// Out:
// <table><thead><tr><th><i>index</i></th><th>Key</th><th>Value</th></tr></thead><tbody><tr><td>0</td><td>3</td><td>1.818907010089899</td></tr><tr><td>1</td><td>2</td><td>1.5327827208437947</td></tr><tr><td>2</td><td>1</td><td>1.631355281917946</td></tr></tbody></table><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// ### Druckkonvergenz für mesh5

// %%
//Hier wird das Netz 5 als Referenz verwendet

var p5a = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5b = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5c = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 

var p5d = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5e = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5f = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 


var p5g = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5h = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5i = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 


var p5j = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5k = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5l = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 

var p5m = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5n = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5o = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 


var p5p = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5q = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
var p5r = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 



// var p5j = cA80_beta5_cAstat80_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
// var p5k = cA80_beta0_cAstat80_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
// var p5l = cA80_beta0_cAstat80_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 

// var p5m = cA80_beta5_cAstat120_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
// var p5n = cA80_beta5_cAstat120_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
// var p5o = cA80_beta0_cAstat120_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded); 
// var p5p = cA80_beta0_cAstat120_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("Pressure", normType: NormType.L2_embedded);

// %%
p5a.Regression()
// Out:
// <table><thead><tr><th><i>index</i></th><th>Key</th><th>Value</th></tr></thead><tbody><tr><td>0</td><td>3</td><td>2.2897273896874317</td></tr><tr><td>1</td><td>2</td><td>2.290616950354391</td></tr><tr><td>2</td><td>1</td><td>1.5387876648613337</td></tr></tbody></table>

// %%
//Struct Vorlage für das Objekt
struct pstruct{
    public BoSSS.Solution.Gnuplot.Plot2Ddata x;
    public string filename;
    public pstruct(BoSSS.Solution.Gnuplot.Plot2Ddata x,string filename){
        this.x =x;
        this.filename = filename;
    }
}


var p5_array = new List<pstruct>();
 
var p5aa = new pstruct(p5a,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5");
var p5bb = new pstruct(p5b,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5");
var p5cc = new pstruct(p5c,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5");

var p5dd = new pstruct(p5d,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5");
var p5ee = new pstruct(p5e,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5");
var p5ff = new pstruct(p5f,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5");

var p5gg = new pstruct(p5g,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5");
var p5hh = new pstruct(p5h,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5");
var p5ii = new pstruct(p5i,"Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5");


var p5jj = new pstruct(p5j,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5");
var p5kk = new pstruct(p5k,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5");
var p5ll = new pstruct(p5l,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5");

var p5mm = new pstruct(p5m,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5");
var p5nn = new pstruct(p5n,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5");
var p5oo = new pstruct(p5o,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5");

var p5pp = new pstruct(p5p,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5");
var p5qq = new pstruct(p5q,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5");
var p5rr = new pstruct(p5r,"Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5");


p5_array.Add(p5aa);
p5_array.Add(p5bb);
p5_array.Add(p5cc);

p5_array.Add(p5dd);
p5_array.Add(p5ee);
p5_array.Add(p5ff);

p5_array.Add(p5gg);
p5_array.Add(p5hh);
p5_array.Add(p5ii);


p5_array.Add(p5jj);
p5_array.Add(p5kk);
p5_array.Add(p5ll);

p5_array.Add(p5mm);
p5_array.Add(p5nn);
p5_array.Add(p5oo);

p5_array.Add(p5pp);
p5_array.Add(p5qq);
p5_array.Add(p5rr);



foreach(pstruct item in p5_array) {
    
    var regression = item.x.Regression();  
    
    item.x.SaveToSVG(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Druck_p5\"+item.filename+".svg");
    item.x.SaveToTextFile(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Druck_p5\"+item.filename+".txt");
    item.x.SavePgfplotsFile(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Druck_p5\"+item.filename+".tex");
    item.x.SaveTextFileToPublish(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Druck_p5\"+item.filename+"Regression.txt");
   
    Console.WriteLine(item.filename);
   
    foreach(var regr in regression){
        Console.WriteLine("Key: "+regr.Key+"  |  Wert: "+regr.Value);
        //Console.WriteLine(regr.Value);
    }
}
// Out:
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 2.2897273896874317
// Key: 2  |  Wert: 2.290616950354391
// Key: 1  |  Wert: 1.5387876648613337
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 2.263441565647223
// Key: 2  |  Wert: 2.2749467658291316
// Key: 1  |  Wert: 1.5260260170754818
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 1.961851664063075
// Key: 2  |  Wert: 2.132483690857294
// Key: 1  |  Wert: 1.4715583911483126
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.06057753252842357
// Key: 2  |  Wert: 0.32654382021624423
// Key: 1  |  Wert: 0.8121031959435168
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.46295582761823834
// Key: 2  |  Wert: 0.8256048609544734
// Key: 1  |  Wert: 1.302787719486828
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.4510587177751953
// Key: 2  |  Wert: 0.8594384841811266
// Key: 1  |  Wert: 1.2411982346061605
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.023335842376312525
// Key: 2  |  Wert: 0.08072873489355849
// Key: 1  |  Wert: 0.24681520339195145
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.23162543084668463
// Key: 2  |  Wert: 0.30390044451065257
// Key: 1  |  Wert: 0.7720299110308286
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.20647657716257578
// Key: 2  |  Wert: 0.2827804146920404
// Key: 1  |  Wert: 0.6934073010998549
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 3.362949669796757
// Key: 2  |  Wert: 2.650765126774986
// Key: 1  |  Wert: 1.4273944888254444
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 3.424202911087599
// Key: 2  |  Wert: 2.6837412892319112
// Key: 1  |  Wert: 1.4195933303276702
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 3.50521960169278
// Key: 2  |  Wert: 2.682000197552807
// Key: 1  |  Wert: 1.4153936224203312
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.4037701433233244
// Key: 2  |  Wert: 0.853109419488287
// Key: 1  |  Wert: 0.9837564520482268
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.4535574960227447
// Key: 2  |  Wert: 0.9663918314596104
// Key: 1  |  Wert: 1.0764881790968543
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.4567737222229468
// Key: 2  |  Wert: 0.9748985149833322
// Key: 1  |  Wert: 1.0848441162005005
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.21089848760488358
// Key: 2  |  Wert: 0.3437183137058672
// Key: 1  |  Wert: 0.3816105882124966
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.22688887004076846
// Key: 2  |  Wert: 0.43167690584654056
// Key: 1  |  Wert: 0.49546838101599944
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Druckkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 3  |  Wert: 0.22216458094486277
// Key: 2  |  Wert: 0.4424452163049855
// Key: 1  |  Wert: 0.5078409543434254

// %% [markdown]
// ### Temperaturkonvergenz für mesh5

// %%
var t5a = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5b = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5c = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 

var t5d = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5e = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5f = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 

var t5g = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5h = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5i = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 


var t5j = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5k = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5l = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 

var t5m = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5n = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5o = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 

var t5p = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5q = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded); 
var t5r = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("Temperature", normType: NormType.L2_embedded);

// %%
t5a.Regression()
// Out:
// <table><thead><tr><th><i>index</i></th><th>Key</th><th>Value</th></tr></thead><tbody><tr><td>0</td><td>4</td><td>-2.2235995994302166E-06</td></tr><tr><td>1</td><td>3</td><td>0.0006258521218778849</td></tr><tr><td>2</td><td>2</td><td>-0.03546911424661851</td></tr></tbody></table>

// %%
//Struct Vorlage für das Objekt
struct tstruct{
    public BoSSS.Solution.Gnuplot.Plot2Ddata x;
    public string filename;
    public tstruct(BoSSS.Solution.Gnuplot.Plot2Ddata x,string filename){
        this.x =x;
        this.filename = filename;
    }
}


var t5_array = new List<tstruct>();
 
var t5aa = new tstruct(t5a,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5");
var t5bb = new tstruct(t5b,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5");
var t5cc = new tstruct(t5c,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5");

var t5dd = new tstruct(t5d,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5");
var t5ee = new tstruct(t5e,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5");
var t5ff = new tstruct(t5f,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5");

var t5gg = new tstruct(t5g,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5");
var t5hh = new tstruct(t5h,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5");
var t5ii = new tstruct(t5i,"Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5");


var t5jj = new tstruct(t5j,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5");
var t5kk = new tstruct(t5k,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5");
var t5ll = new tstruct(t5l,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5");

var t5mm = new tstruct(t5m,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5");
var t5nn = new tstruct(t5n,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5");
var t5oo = new tstruct(t5o,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5");

var t5pp = new tstruct(t5p,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5");
var t5qq = new tstruct(t5q,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5");
var t5rr = new tstruct(t5r,"Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5");



t5_array.Add(t5aa);
t5_array.Add(t5bb);
t5_array.Add(t5cc);

t5_array.Add(t5dd);
t5_array.Add(t5ee);
t5_array.Add(t5ff);

t5_array.Add(t5gg);
t5_array.Add(t5hh);
t5_array.Add(t5ii);



t5_array.Add(t5jj);
t5_array.Add(t5kk);
t5_array.Add(t5ll);

t5_array.Add(t5mm);
t5_array.Add(t5nn);
t5_array.Add(t5oo);

t5_array.Add(t5pp);
t5_array.Add(t5qq);
t5_array.Add(t5rr);


foreach(tstruct item in t5_array) {
    
    var regression = item.x.Regression();  
    
    item.x.SaveToSVG(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Temperatur_t5\"+item.filename+".svg");
    item.x.SaveToTextFile(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Temperatur_t5\"+item.filename+".txt");
    item.x.SavePgfplotsFile(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Temperatur_t5\"+item.filename+".tex");
    item.x.SaveTextFileToPublish(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Temperatur_t5\"+item.filename+"Regression.txt");
   
    Console.WriteLine(item.filename);
   
    foreach(var regr in regression){
        Console.WriteLine("Key: "+regr.Key+"  |  Wert: "+regr.Value);
        //Console.WriteLine(regr.Value);
    }
}
// Out:
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: -2.2235995994302166E-06
// Key: 3  |  Wert: 0.0006258521218778849
// Key: 2  |  Wert: -0.03546911424661851
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 3.528598469349781E-06
// Key: 3  |  Wert: -0.09188539438166611
// Key: 2  |  Wert: -0.005356701216517724
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: -0.2808679704235681
// Key: 3  |  Wert: -0.007327668197486056
// Key: 2  |  Wert: 0.0021174744497969495
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.1971152367157547
// Key: 3  |  Wert: 2.16528769406056
// Key: 2  |  Wert: 2.100497868010531
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.191285871084664
// Key: 3  |  Wert: 2.1652877032308417
// Key: 2  |  Wert: 2.1004978679023223
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.1970827602170258
// Key: 3  |  Wert: 2.165287701618238
// Key: 2  |  Wert: 2.1004978680964586
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.197482198053863
// Key: 3  |  Wert: 2.165287698562999
// Key: 2  |  Wert: 2.1004978678477446
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.196590641349971
// Key: 3  |  Wert: 2.165287704117675
// Key: 2  |  Wert: 2.100497868179669
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.196939289599425
// Key: 3  |  Wert: 2.165287704458549
// Key: 2  |  Wert: 2.10049786820423
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: -1.4887898182003068
// Key: 3  |  Wert: 5.394182704820995E-05
// Key: 2  |  Wert: -0.27179760293846744
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: -0.7709502622116071
// Key: 3  |  Wert: 0.0003654120482958594
// Key: 2  |  Wert: -0.012485424455368953
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: -0.9821702091470895
// Key: 3  |  Wert: -0.11437164455586364
// Key: 2  |  Wert: -0.020875225408051343
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.0209269326640795
// Key: 3  |  Wert: 2.0101861656683297
// Key: 2  |  Wert: 2.023072224417015
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.020926396153965
// Key: 3  |  Wert: 2.0101861674317645
// Key: 2  |  Wert: 2.0230722244099155
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.020923472198408
// Key: 3  |  Wert: 2.010186165412716
// Key: 2  |  Wert: 2.023072224423969
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.0209276169466217
// Key: 3  |  Wert: 2.0101861659876703
// Key: 2  |  Wert: 2.0230722244182253
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.020924753346628
// Key: 3  |  Wert: 2.010186166747184
// Key: 2  |  Wert: 2.023072224415493
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Temperaturkonvergenz_StaticDropletOnWall_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4  |  Wert: 2.020924812858991
// Key: 3  |  Wert: 2.0101861658757665
// Key: 2  |  Wert: 2.023072224421419

// %% [markdown]
// ### Geschwindigkeitskonvergenz für mesh5

// %%
var ux5a = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5a = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5b = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded);
var uy5b = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5c = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5c = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);



var ux5d = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded);
var uy5d = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded); 

var ux5e = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5e = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5f = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5f = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);



var ux5g = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5g = cA80_beta0_cAstat80_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5h = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5h = cA80_beta0_cAstat80_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5i = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5i = cA80_beta0_cAstat80_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);






var ux5j = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5j = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q0_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5k = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded);
var uy5k = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q0_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5l = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5l = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q0_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);



var ux5m = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded);
var uy5m = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded); 

var ux5n = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5n = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5o = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5o = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);



var ux5p = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5p = cA90_beta0_cAstat90_roh_A1_roh_B01_ls0_q05_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5q = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5q = cA90_beta0_cAstat90_roh_A1_roh_B01_ls01_q05_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

var ux5r = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
var uy5r = cA90_beta0_cAstat90_roh_A1_roh_B01_lsINF_q05_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);




// var ux5j = cA80_beta5_cAstat80_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded);
// var uy5j = cA80_beta5_cAstat80_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);


// var ux5k = cA80_beta0_cAstat80_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
// var uy5k = cA80_beta0_cAstat80_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

// var ux5l = cA80_beta0_cAstat80_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded);
// var uy5l = cA80_beta0_cAstat80_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded); 


// var ux5m = cA80_beta5_cAstat120_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
// var uy5m = cA80_beta5_cAstat120_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

// var ux5n = cA80_beta5_cAstat120_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
// var uy5n = cA80_beta5_cAstat120_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

// var ux5o = cA80_beta0_cAstat120_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
// var uy5o = cA80_beta0_cAstat120_roh_A1_roh_B1_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

// var ux5p = cA80_beta0_cAstat120_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityX", normType: NormType.L2_embedded); 
// var uy5p = cA80_beta0_cAstat120_roh_A1_roh_B01_mesh5.ToEstimatedGridConvergenceData("VelocityY", normType: NormType.L2_embedded);

// %%
ux5j.Regression()
// Out:
// <table><thead><tr><th><i>index</i></th><th>Key</th><th>Value</th></tr></thead><tbody><tr><td>0</td><td>4</td><td>3.9607498484283803</td></tr><tr><td>1</td><td>3</td><td>3.6231157127700895</td></tr><tr><td>2</td><td>2</td><td>2.3013475462030586</td></tr></tbody></table>

// %%
struct ustruct {
    public BoSSS.Solution.Gnuplot.Plot2Ddata x;
    public BoSSS.Solution.Gnuplot.Plot2Ddata y;
    public string filename;
    
    public ustruct(BoSSS.Solution.Gnuplot.Plot2Ddata x, BoSSS.Solution.Gnuplot.Plot2Ddata y, string filename) {
        this.x          = x;
        this.y          = y;
        this.filename   = filename;
    }
}

var u5_array = new List<ustruct>();


var u5a = new ustruct(ux5a, uy5a, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5");
var u5b = new ustruct(ux5b, uy5b, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5");
var u5c = new ustruct(ux5c, uy5c, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5");

var u5d = new ustruct(ux5d, uy5d, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5");
var u5e = new ustruct(ux5e, uy5e, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5");
var u5f = new ustruct(ux5f, uy5f, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5");

var u5g = new ustruct(ux5g, uy5g, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5");
var u5h = new ustruct(ux5h, uy5h, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5");
var u5i = new ustruct(ux5i, uy5i, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5");



var u5j = new ustruct(ux5j, uy5j, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5");
var u5k = new ustruct(ux5k, uy5k, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5");
var u5l = new ustruct(ux5l, uy5l, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5");

var u5m = new ustruct(ux5m, uy5m, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5");
var u5n = new ustruct(ux5n, uy5n, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5");
var u5o = new ustruct(ux5o, uy5o, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5");

var u5p = new ustruct(ux5p, uy5p, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5");
var u5q = new ustruct(ux5q, uy5q, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5");
var u5r = new ustruct(ux5r, uy5r, "Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5");


// var u5j = new pstruct(ux5j, uy5j, "Geschwindigkeitskonvergenz_80Deg_beta5_cAstat80_roh_A1_roh_B0.1_ConvStudy2_k1-k4_mesh5");
// var u5k = new pstruct(ux5k, uy5k, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B1_ConvStudy2_k1-k4_mesh5");
// var u5l = new pstruct(ux5l, uy5l, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ConvStudy2_k1-k4_mesh5");

// var u5m = new pstruct(ux5m, uy5m, "Geschwindigkeitskonvergenz_80Deg_beta5_cAstat120_roh_A1_roh_B1_ConvStudy2_k1-k4_mesh5");
// var u5n = new pstruct(ux5n, uy5n, "Geschwindigkeitskonvergenz_80Deg_beta5_cAstat120_roh_A1_roh_B0.1_ConvStudy2_k1-k4_mesh5");
// var u5o = new pstruct(ux5o, uy5o, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat120_roh_A1_roh_B1_ConvStudy2_k1-k4_mesh5");
// var u5p = new pstruct(ux5p, uy5p, "Geschwindigkeitskonvergenz_80Deg_beta0_cAstat120_roh_A1_roh_B0.1_ConvStudy2_k1-k4_mesh5");



u5_array.Add(u5a);
u5_array.Add(u5b);
u5_array.Add(u5c);

u5_array.Add(u5d);
u5_array.Add(u5e);
u5_array.Add(u5f);

u5_array.Add(u5g);
u5_array.Add(u5h);
u5_array.Add(u5i);


u5_array.Add(u5j);
u5_array.Add(u5k);
u5_array.Add(u5l);

u5_array.Add(u5m);
u5_array.Add(u5n);
u5_array.Add(u5o);

u5_array.Add(u5p);
u5_array.Add(u5q);
u5_array.Add(u5r);

// u5_array.Add(u5j);
// u5_array.Add(u5k);
// u5_array.Add(u5l);

// u5_array.Add(u5m);
// u5_array.Add(u5n);
// u5_array.Add(u5o);
// u5_array.Add(u5p);

foreach(ustruct item in u5_array) {
    var u_temp = item.x;
   
    for(int i = 0; i < u_temp.dataGroups[0].Values.Length; i++) {
        u_temp.dataGroups[0].Values[i] = Math.Sqrt(Math.Pow(item.x.dataGroups[0].Values[i], 2) + Math.Pow(item.y.dataGroups[0].Values[i], 2));
    }

    var regression = u_temp.Regression();

    u_temp.SaveToSVG(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Geschwindigkeit_u5\"+item.filename+".svg");
    u_temp.SaveToTextFile(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Geschwindigkeit_u5\"+item.filename+".txt");
    u_temp.SavePgfplotsFile(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Geschwindigkeit_u5\"+item.filename+".tex");
    u_temp.SaveTextFileToPublish(@"P:\Bachelorthesis_Pasic\Kickoff\BoSSS\DropletOnSlipWall\03_Auswertung\Verdampfung\Geschwindigkeit_u5\"+item.filename+"Regression.txt");
    
    Console.WriteLine(item.filename);
   
    foreach(var regr in regression) {
        Console.WriteLine("Key: " + regr.Key + " | Wert: " + regr.Value);
    }
}
// Out:
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 3.336866348076088
// Key: 3 | Wert: 3.2007525937207246
// Key: 2 | Wert: 2.098457934066288
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 3.6296871067154832
// Key: 3 | Wert: 3.295137126180835
// Key: 2 | Wert: 2.1065829025881935
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 2.9205613204451835
// Key: 3 | Wert: 3.1411019568689826
// Key: 2 | Wert: 2.1745314790095636
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.167950794034305
// Key: 3 | Wert: 1.5212560355375886
// Key: 2 | Wert: 1.8113862601454975
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.5728486750690038
// Key: 3 | Wert: 1.8004959918920294
// Key: 2 | Wert: 1.9527987825401707
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.509211866454533
// Key: 3 | Wert: 1.742205571477381
// Key: 2 | Wert: 1.9767406505678897
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 0.9442593646939273
// Key: 3 | Wert: 1.0995152522676752
// Key: 2 | Wert: 1.176588286191765
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.2104551299417254
// Key: 3 | Wert: 1.2899355990217465
// Key: 2 | Wert: 1.2898299617407702
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_80Deg_beta0_cAstat80_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.1986435650628127
// Key: 3 | Wert: 1.277500758466597
// Key: 2 | Wert: 1.3010403927919523
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 3.999043580674534
// Key: 3 | Wert: 3.6231157127700895
// Key: 2 | Wert: 2.3013475462030586
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 4.365301337403496
// Key: 3 | Wert: 3.6777965807801425
// Key: 2 | Wert: 2.3166225278835353
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.0_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 3.9591898318448053
// Key: 3 | Wert: 3.789533406932629
// Key: 2 | Wert: 2.3695517161575474
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.5011536967619334
// Key: 3 | Wert: 1.9524020608570443
// Key: 2 | Wert: 2.0446001747754714
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.5286311215994073
// Key: 3 | Wert: 1.973092944031208
// Key: 2 | Wert: 2.056618268880353
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.1_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.4923998476671967
// Key: 3 | Wert: 2.002952060644874
// Key: 2 | Wert: 2.0860985085224475
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.0_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.168150432023244
// Key: 3 | Wert: 1.4096210445141664
// Key: 2 | Wert: 1.518004673331828
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_ls0.1_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.1929053865322532
// Key: 3 | Wert: 1.4235565795305818
// Key: 2 | Wert: 1.5489048105575052
// Using gnuplot: C:\Program Files\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
// Warning: Handling of logarithms still unclear in 'SaveToTextFile', Raw Data Written
// Geschwindigkeitskonvergenz_90Deg_beta0_cAstat90_roh_A1_roh_B0.1_lsINF_q-0.5_ConvStudy2_k1-k4_mesh5
// Key: 4 | Wert: 1.172060725098621
// Key: 3 | Wert: 1.4107372778887302
// Key: 2 | Wert: 1.561660381440392
