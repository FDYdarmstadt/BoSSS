# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\BUIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using BUIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %%
var date = DateTime.Now.ToString("ddMMyyyy");
date
# Out:
# 02042024

# %% [markdown]
# open a database

# %%
string dbPath = @"BUIDT_db_" + date ;
var database = OpenOrCreateDatabase(dbPath);

# %% [markdown]
# ## Curved Shock Burgers

# %%
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pCSB = new BUIDTMain();
var CCSB = BUIDTHardCodedControl.AccShock(
dbPath: dbPath,
MaxIterations: 100,
dgDegree: 3,
numOfCellsX: 10,
numOfCellsY: 10,
OptiNumOfCellsX: 10,
OptiNumOfCellsY: 10,
linearization: Linearization.FD,
agg: 0.4,
optiLevelSetType: OptiLevelSetType.SplineLevelSet,
getLevelSet: GetLevelSet.FromFunction,
applyReInit: true,
solverRunType: SolverRunType.PContinuation
) ;
CCSB.ProjectName= "CSB";
pCSB.Init(CCSB);
pCSB.RunSolverMode();
# Out:
# rm;
# Session ID: 197712fc-cd2d-4974-b6ae-6239dbbbcc2a, DB path: 'BUIDT_db_02042024'
# Session directory 'BUIDT_db_02042024\sessions\197712fc-cd2d-4974-b6ae-6239dbbbcc2a'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
#
#
# *****************************************************************************************
# *  X   X   DDD   GGG   -   III  SSS  TTTTT  *
# *   X X    D  D G      -    I  S      T     *
# *    X     D  D G  GG  -    I   SSS   T     *      XDG Implicit Shock Tracking Solver
# *   X X    D  D G   G  -    I      S  T     *
# *  X   X   DDD   GGG   -   III  SSS   T     *
# *****************************************************************************************
# *
# *  solver:                             BUIDT.BUIDTMain
# *  project:                            CSB
# *  session:                            BurgersIDT
# *  optimization problem:               FullEnRes
# *  merit function:                     L2Merit
# *  level set type:                     SplineLevelSet
# *  solver type:                        PContinuation
# *  f_phi type:                         None
# *  globalization strategy:             LineSearch
# *  initial value from:                 FromFunctionPerSpecies
# *
# ******************************* Params ************************************************
# *  Solution Degree:                    3
# *  OptiLevelSet Degree:                3
# *  Level Set Degree:                   3
# *  Level Set Two Degree:               1
# *  Max Iterations:                     200
# *  Agglomeration Threshold:            0.4
# *  Regularization Params:
# *    Gamma Max:                        1
# *    Gamma Min:                        1E-06
# *    Gamma Start:                      1
# *  Globalization Params:
# *    Alpha Min:                        1E-08
# *    Alpha Start:                      1
# *    Mu Start:                         1
# *    Mu Max:                           1000000
# *    Mu Omega:                         1.2
# *    Mu Rho:                           0.95
# *  Level Set penalty Params:
# *    Kappa Xi:                         10
# *    Kappa M:                          100
# *    Kappa Min:                        1E-10
# *    Kappa v:                          0.5
# *  Reinitialization Params:
# *    Apply ReiInit:                    True
# *    c1:                               -0.2
# *    c2:                               0.01
# *    c3:                               0.01
# *  Adaptive Regularization Params:
# *    L:                                1
# *    sigma_1:                          0.01
# *    sigma_2:                          0.1
# *    tauGamma:                         1.5
# Initial Value : l2: |r|= 0E+00, |f_err|=0E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 1802.4326415477608, 1366.2606381541666
# alpha, M, predM  0.5, 750.7519942165181, 1366.2609407747605
# l2: ||R0||= 7.8847783E+00, f_err=2.652779E+01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.06E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 206.19131366756696, 473.43990128168696
# l2: ||R0||= 5.4288022E+00, f_err=1.567605E+01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.53E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 112.34006352600923, 234.37269093603703
# l2: ||R0||= 3.9156685E+00, f_err=9.136524E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.8E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 37.558736587722635, 93.92033690060259
# l2: ||R0||= 1.9191612E+00, f_err=6.844154E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.37E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 14.4544179308955, 33.5890971579468
# l2: ||R0||= 9.1680058E-01, f_err=4.793612E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.23E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 15.866838813209863, 18.894639202730065
# l2: ||R0||= 1.1744334E+00, f_err=4.467521E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.01E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 15.27014100586495, 14.30311164921984
# alpha, M, predM  0.5, 11.774152964976196, 14.303281645864717
# l2: ||R0||= 7.8852729E-01, f_err=4.230538E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.58E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 11.541241960139134, 16.872752628736677
# l2: ||R0||= 1.9616225E-01, f_err=4.499299E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.24E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 13.263041933849085, 11.522434640304779
# alpha, M, predM  0.5, 11.373291785255839, 11.52243402334132
# l2: ||R0||= 1.7588215E-01, f_err=4.498333E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.14E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 10.868626302213524, 11.35856522439304
# l2: ||R0||= 6.8289454E-02, f_err=4.557807E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.06E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 13.358077379890016, 10.869734580451052
# alpha, M, predM  0.5, 11.284593092745816, 10.869793962601152
# alpha, M, predM  0.25, 10.741640692083092, 10.869823653676203
# l2: ||R0||= 8.34486E-02, f_err=4.505854E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.07E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 10.739716926667425, 10.728510163620726
# alpha, M, predM  0.5, 10.545275574735344, 10.728482744590307
# l2: ||R0||= 5.2190063E-02, f_err=4.51317E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.92E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 13.155834805075957, 10.554056829722828
# alpha, M, predM  0.5, 11.305652307111677, 10.554096557743541
# alpha, M, predM  0.25, 10.829836363488369, 10.554116421753896
# alpha, M, predM  0.125, 10.623651396024654, 10.554126353759075
# alpha, M, predM  0.0625, 10.546395190929614, 10.554131319761664
# l2: ||R0||= 5.5750079E-02, f_err=4.505859E+00, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.09E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 10.795561830073881, 10.538973361514158
# alpha, M, predM  0.5, 10.572552078199871, 10.538954407069644
# alpha, M, predM  0.25, 10.493802007906902, 10.53894492984739
# l2: ||R0||= 4.6802997E-02, f_err=4.509645E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.95E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 13.057772986790226, 10.498270819854138
# alpha, M, predM  0.5, 11.262175501571901, 10.498308536312964
# alpha, M, predM  0.25, 10.808103567418753, 10.498327394542375
# alpha, M, predM  0.125, 10.615760981565439, 10.49833682365708
# alpha, M, predM  0.0625, 10.531766940659004, 10.498341538214435
# alpha, M, predM  0.03125, 10.494635772793895, 10.498343895493111
# l2: ||R0||= 4.8568734E-02, f_err=4.506061E+00, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.05E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 10.873589246975168, 10.487097434947811
# alpha, M, predM  0.5, 10.622810818819671, 10.487081463007604
# alpha, M, predM  0.25, 10.523166658805422, 10.487073477037498
# alpha, M, predM  0.125, 10.47728701415733, 10.487069484052446
# l2: ||R0||= 4.5678214E-02, f_err=4.508312E+00, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 6.89E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 13.357160526542943, 10.487048675799512
# alpha, M, predM  0.5, 11.36135816597518, 10.487090130697498
# alpha, M, predM  0.25, 10.86347081169183, 10.48711085814649
# alpha, M, predM  0.125, 10.647749057931893, 10.487121221870987
# alpha, M, predM  0.0625, 10.548634213864611, 10.487126403733235
# alpha, M, predM  0.03125, 10.501697898567201, 10.487128994664358
# alpha, M, predM  0.015625, 10.479124892044652, 10.48713029012992
# l2: ||R0||= 4.6174577E-02, f_err=4.505752E+00, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 7.11E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 10.83418816073771, 10.470552323824496
# alpha, M, predM  0.5, 10.618183447334639, 10.470536547092214
# alpha, M, predM  0.25, 10.521943214110577, 10.470528658726073
# alpha, M, predM  0.125, 10.485816690880174, 10.470524714543004
# alpha, M, predM  0.0625, 10.470645122770728, 10.470522742451468
# alpha, M, predM  0.03125, 10.463269236533636, 10.4705217564057
# l2: ||R0||= 4.5102489E-02, f_err=4.50579E+00, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 6.92E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 10.824357406162086, 10.46138713219428
# alpha, M, predM  0.5, 10.619415628682834, 10.461371861828338
# alpha, M, predM  0.25, 10.536777907900447, 10.461364226645369
# alpha, M, predM  0.125, 10.497044286567952, 10.461360409053883
# alpha, M, predM  0.0625, 10.477588601102523, 10.46135850025814
# alpha, M, predM  0.03125, 10.467965520523842, 10.461357545860269
# alpha, M, predM  0.015625, 10.464333612790867, 10.461357068661334
# alpha, M, predM  0.0078125, 10.462782076764862, 10.461356830061865
# alpha, M, predM  0.00390625, 10.462009979790126, 10.461356710762132
# alpha, M, predM  0.001953125, 10.461624848475163, 10.461356651112265
# alpha, M, predM  0.0009765625, 10.461432512036097, 10.461356621287331
# alpha, M, predM  0.00048828125, 10.46133640111176, 10.461356606374864
# l2: ||R0||= 4.5091455E-02, f_err=4.505802E+00, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 6.88E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 13.348179009566348, 10.470692642903133
# alpha, M, predM  0.5, 11.318883334849602, 10.470731217378269
# alpha, M, predM  0.25, 10.845633614712682, 10.470750504615838
# alpha, M, predM  0.125, 10.642013987703903, 10.470760148234623
# alpha, M, predM  0.0625, 10.551127862014905, 10.470764970044014
# alpha, M, predM  0.03125, 10.509332865085852, 10.470767380948711
# alpha, M, predM  0.015625, 10.48955695764296, 10.470768586401059
# alpha, M, predM  0.0078125, 10.479982687518564, 10.470769189127232
# alpha, M, predM  0.00390625, 10.475279244703039, 10.47076949049032
# alpha, M, predM  0.001953125, 10.472949164956889, 10.470769641171863
# alpha, M, predM  0.0009765625, 10.471789629314946, 10.470769716512635
# alpha, M, predM  0.00048828125, 10.471211249536406, 10.47076975418302
# alpha, M, predM  0.000244140625, 10.470922408172235, 10.470769773018214
# alpha, M, predM  0.0001220703125, 10.470778074811843, 10.470769782435811
# alpha, M, predM  6.103515625E-05, 10.470705929985861, 10.470769787144608
# l2: ||R0||= 4.50905E-02, f_err=4.505789E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 7.09E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 0 to 1              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 5.2781315E+00, f_err=2.143041E+01, f_phi=0E+00,
#  current DGdegree=1, min It.:15, MaxReInit:20, ReInitTol:-0.2, TermN:8, tALNR:1.005
#
# ################################################################################################
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 1233.8670929472173, 564.3574939344509
# alpha, M, predM  0.5, 238.0589678055952, 564.3618838493471
# l2: ||R0||= 3.3241282E+00, f_err=7.381782E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.34E+01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 80.15880467771827, 134.54005784803937
# l2: ||R0||= 2.9784351E+00, f_err=6.884009E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.9E+01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
# Reinitialized Cells:(32 R) ,
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 131.9557633086903, 93.36039991216937
# alpha, M, predM  0.5, 85.39960402121201, 93.35843603152757
# l2: ||R0||= 2.665594E+00, f_err=6.766565E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.34E+01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 358.69765614661316, 38.14600189042404
# alpha, M, predM  0.5, 32.512778794875274, 38.14729759000656
# l2: ||R0||= 2.729363E+00, f_err=5.813056E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.72E+00, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 4.411471368789237, 25.700830669517977
# l2: ||R0||= 9.4261229E-01, f_err=2.228786E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.05E+00, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
# Reinitialized Cells:(95 R) ,
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 0.235705521195563, 2.296512178048099
# l2: ||R0||= 2.0113506E-01, f_err=5.991161E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.8E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
# Reinitialized Cells:(95 R) ,
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 6.645329103422649, 0.24425467235454623
# alpha, M, predM  0.5, 4.900928946935403, 0.2442639156492398
# alpha, M, predM  0.25, 0.17211605864084625, 0.2442685372965866
# l2: ||R0||= 1.5673797E-01, f_err=5.001764E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 7.032373163481876, 0.16993068986799786
# alpha, M, predM  0.5, 5.394896444494, 0.16993503991877318
# alpha, M, predM  0.25, 4.74240317773159, 0.1699372149441608
# alpha, M, predM  0.125, 0.14869865650921607, 0.16993830245685465
# l2: ||R0||= 1.3754656E-01, f_err=4.676306E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.86E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 7.462525985731943, 0.1503313914038289
# alpha, M, predM  0.5, 5.7058212615309785, 0.15033462468893502
# alpha, M, predM  0.25, 5.027006242577495, 0.15033624133148807
# alpha, M, predM  0.125, 4.729137623394764, 0.1503370496527646
# alpha, M, predM  0.0625, 4.5893335113920095, 0.15033745381340285
# alpha, M, predM  0.03125, 0.14589838222474927, 0.15033765589372197
# l2: ||R0||= 1.33723E-01, f_err=4.642738E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 2.85E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 7.872458643967109, 0.1453355537178882
# alpha, M, predM  0.5, 5.86096636405525, 0.1453385895098484
# alpha, M, predM  0.25, 5.127202679160026, 0.14534010740582848
# alpha, M, predM  0.125, 4.807178210324377, 0.14534086635381854
# alpha, M, predM  0.0625, 4.657412557916006, 0.14534124582781355
# alpha, M, predM  0.03125, 4.584939667688415, 0.14534143556481108
# alpha, M, predM  0.015625, 0.14326787863256985, 0.14534153043330983
# l2: ||R0||= 1.3169454E-01, f_err=4.610232E-01, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.81E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 8.532085161723339, 0.1437730432845203
# alpha, M, predM  0.5, 6.060521389321971, 0.14377597511489978
# alpha, M, predM  0.25, 5.237876500400221, 0.14377744103008952
# alpha, M, predM  0.125, 4.881291670669546, 0.1437781739876844
# alpha, M, predM  0.0625, 4.715073094880419, 0.14377854046648184
# alpha, M, predM  0.03125, 4.634813338311737, 0.14377872370588055
# alpha, M, predM  0.015625, 4.59537237881929, 0.1437788153255799
# alpha, M, predM  0.0078125, 4.575812956791728, 0.14377886113542956
# alpha, M, predM  0.00390625, 0.1432572667124839, 0.1437788840403544
# l2: ||R0||= 1.3118027E-01, f_err=4.602087E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 2.85E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 8.75143909598247, 0.1438822794548522
# alpha, M, predM  0.5, 6.122871896203928, 0.14388516421924308
# alpha, M, predM  0.25, 5.274613559621358, 0.14388660660143848
# alpha, M, predM  0.125, 4.908130174522497, 0.1438873277925362
# alpha, M, predM  0.0625, 4.737556098102538, 0.14388768838808505
# alpha, M, predM  0.03125, 4.655254282553326, 0.14388786868585948
# alpha, M, predM  0.015625, 4.614825965340537, 0.1438879588347467
# alpha, M, predM  0.0078125, 4.594783838202514, 0.14388800390919032
# alpha, M, predM  0.00390625, 4.584804676063857, 0.1438880264464121
# alpha, M, predM  0.001953125, 0.14362706129065844, 0.143888037715023
# l2: ||R0||= 1.309241E-01, f_err=4.598026E-01, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.9E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 8.90666234898156, 0.14406687518596295
# alpha, M, predM  0.5, 6.164708217321566, 0.14406973291280986
# alpha, M, predM  0.25, 5.298482237085979, 0.1440711617762333
# alpha, M, predM  0.125, 4.925104299282197, 0.14407187620794504
# alpha, M, predM  0.0625, 4.7515085049051535, 0.1440722334238009
# alpha, M, predM  0.03125, 4.667792711047314, 0.14407241203172885
# alpha, M, predM  0.015625, 4.626680125999217, 0.1440725013356928
# alpha, M, predM  0.0078125, 4.6063046388465425, 0.1440725459876748
# alpha, M, predM  0.00390625, 4.596158554589864, 0.14407256831366577
# alpha, M, predM  0.001953125, 4.5910967958436855, 0.14407257947666127
# alpha, M, predM  0.0009765625, 4.588568732080427, 0.14407258505815904
# alpha, M, predM  0.00048828125, 0.14400722525685467, 0.1440725878489079
# l2: ||R0||= 1.3086017E-01, f_err=4.597012E-01, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.93E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 9.010936483367814, 0.14431178132265332
# alpha, M, predM  0.5, 6.1910607583679305, 0.1443146267712487
# alpha, M, predM  0.25, 5.312614266292424, 0.14431604949554638
# alpha, M, predM  0.125, 4.934582464034734, 0.1443167608576952
# alpha, M, predM  0.0625, 4.758956153450478, 0.14431711653876964
# alpha, M, predM  0.03125, 4.674292312286509, 0.14431729437930685
# alpha, M, predM  0.015625, 4.632721585768412, 0.14431738329957547
# alpha, M, predM  0.0078125, 4.61212189884527, 0.14431742775970977
# alpha, M, predM  0.00390625, 4.601864105614556, 0.1443174499897769
# alpha, M, predM  0.001953125, 4.596746727594365, 0.14431746110481047
# alpha, M, predM  0.0009765625, 4.594190912813428, 0.14431746666232728
# alpha, M, predM  0.00048828125, 4.592913723304371, 0.14431746944108567
# alpha, M, predM  0.000244140625, 4.592275307935787, 0.14431747083046487
# alpha, M, predM  0.0001220703125, 0.14430108848713658, 0.14431747152515445
# l2: ||R0||= 1.308442E-01, f_err=4.596758E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 2.95E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 9.081825509493243, 0.14450780799513488
# alpha, M, predM  0.5, 6.208431932562051, 0.1445106466426947
# alpha, M, predM  0.25, 5.321674924340615, 0.14451206596647462
# alpha, M, predM  0.125, 4.940490696015979, 0.14451277562836456
# alpha, M, predM  0.0625, 4.763492051808006, 0.14451313045930952
# alpha, M, predM  0.03125, 4.678188188150732, 0.14451330787478203
# alpha, M, predM  0.015625, 4.6363083819617295, 0.14451339658251827
# alpha, M, predM  0.0078125, 4.6155571961300135, 0.14451344093638638
# alpha, M, predM  0.00390625, 4.605224059880429, 0.14451346311332045
# alpha, M, predM  0.001953125, 4.600069171847949, 0.14451347420178748
# alpha, M, predM  0.0009765625, 4.597494642308253, 0.144513479746021
# alpha, M, predM  0.00048828125, 4.59620810546571, 0.14451348251813775
# alpha, M, predM  0.000244140625, 4.595565018939931, 0.14451348390419613
# alpha, M, predM  0.0001220703125, 4.595243521140149, 0.14451348459722532
# alpha, M, predM  6.103515625E-05, 4.595082783604638, 0.14451348494373992
# alpha, M, predM  3.0517578125E-05, 4.595002417677828, 0.14451348511699721
# alpha, M, predM  1.52587890625E-05, 4.594962235424615, 0.14451348520362586
# alpha, M, predM  7.62939453125E-06, 4.594942144475586, 0.1445134852469402
# alpha, M, predM  3.814697265625E-06, 4.594932099045453, 0.14451348526859736
# alpha, M, predM  1.9073486328125E-06, 0.14451322875561284, 0.14451348527942592
# l2: ||R0||= 1.3084395E-01, f_err=4.596754E-01, f_phi=0E+00, Alpha = 1.91E-06, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 2.97E-01, QuadOrder=6
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 1 to 2              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 1.9634435E+00, f_err=3.074213E+00, f_phi=0E+00,
#  current DGdegree=2, min It.:10, MaxReInit:5, ReInitTol:0, TermN:8, tALNR:1.001
#
# ################################################################################################
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 272.9752772177356, 38.08113608709587
# alpha, M, predM  0.5, 112.39796109107866, 38.0798253893025
# alpha, M, predM  0.25, 12.408781580938097, 38.07917004040581
# l2: ||R0||= 6.6755634E-01, f_err=1.462167E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.7E+01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 0.242033546369953, 1.3294901966380017
# l2: ||R0||= 1.8035513E-01, f_err=6.563195E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.48E-01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.38:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         5771.701155779657
#     L2 Norm of Solution:    0.2443870885276671
#     L2 Norm of Residual:    0.037987788461905876
#     Relative Residual norm: 1.6681417544177098E-10
#     Matrix Inf norm:        227725181.9954959
# alpha, M, predM  1, 4.583463969158738, 0.2458774039343825
# alpha, M, predM  0.5, 0.06719731644821782, 0.24589653079457055
# l2: ||R0||= 8.8512167E-02, f_err=3.231417E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.69E-01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 4.713031180317775, 0.040197878184886175
# alpha, M, predM  0.5, 4.293958084143398, 0.04020056245386737
# alpha, M, predM  0.25, 4.103967732914659, 0.04020190458835797
# alpha, M, predM  0.125, 4.013807304792713, 0.04020257565560326
# alpha, M, predM  0.0625, 3.969265285325957, 0.040202911189225914
# alpha, M, predM  0.03125, 0.03816182519839749, 0.04020307895603724
# l2: ||R0||= 7.0056926E-02, f_err=2.509819E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.51E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 4.890023307054881, 0.037258734654731326
# alpha, M, predM  0.5, 4.37060080288631, 0.03726135119262821
# alpha, M, predM  0.25, 4.13877652204075, 0.03726265946157665
# alpha, M, predM  0.125, 4.029345086251903, 0.037263313596050875
# alpha, M, predM  0.0625, 3.9755872007442528, 0.03726364066328798
# alpha, M, predM  0.03125, 3.949074852664496, 0.03726380419690654
# alpha, M, predM  0.015625, 0.036278298633257273, 0.03726388596371582
# l2: ||R0||= 6.8967761E-02, f_err=2.473862E-01, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 8.23E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.41:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         476.06090294301885
#     L2 Norm of Solution:    0.11655677990164491
#     L2 Norm of Residual:    0.1153895711070373
#     Relative Residual norm: 3.1275494814994516E-09
#     Matrix Inf norm:        36894562.91246772
# alpha, M, predM  1, 5.067575471930246, 0.035435040895362924
# alpha, M, predM  0.5, 4.440397474728441, 0.03543764905588922
# alpha, M, predM  0.25, 4.165907891689831, 0.03543895313615236
# alpha, M, predM  0.125, 4.037134919235232, 0.03543960517628393
# alpha, M, predM  0.0625, 3.9742970872226415, 0.03543993119634972
# alpha, M, predM  0.03125, 3.9433128667083315, 0.03544009420638261
# alpha, M, predM  0.015625, 3.9279549996228975, 0.03544017571139906
# alpha, M, predM  0.0078125, 3.920369343524364, 0.035440216463907284
# alpha, M, predM  0.00390625, 3.9165850939981772, 0.03544023684016139
# alpha, M, predM  0.001953125, 3.914695115260513, 0.03544024702828845
# alpha, M, predM  0.0009765625, 0.03537991140556425, 0.03544025212235198
# l2: ||R0||= 6.8900432E-02, f_err=2.471612E-01, f_phi=0E+00, Alpha = 9.77E-04, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 7.02E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 5.218537809788003, 0.03465911036986166
# alpha, M, predM  0.5, 4.490988204606644, 0.034661777917382466
# alpha, M, predM  0.25, 4.178969381253049, 0.03466311169114286
# alpha, M, predM  0.125, 4.033581461844324, 0.034663778578023066
# alpha, M, predM  0.0625, 3.9628851818506545, 0.03466411202146316
# alpha, M, predM  0.03125, 3.9281142294204594, 0.034664278743183216
# alpha, M, predM  0.015625, 3.91088680547043, 0.034664362104043236
# alpha, M, predM  0.0078125, 3.9023713476949444, 0.034664403784473254
# alpha, M, predM  0.00390625, 3.8981238948004977, 0.03466442462468826
# alpha, M, predM  0.001953125, 3.8960027376433186, 0.03466443504479576
# alpha, M, predM  0.0009765625, 3.8949428014313336, 0.034664440254849514
# alpha, M, predM  0.00048828125, 3.894412993922942, 0.03466444285987639
# alpha, M, predM  0.000244140625, 3.8941481303189573, 0.034664444162389826
# alpha, M, predM  0.0001220703125, 3.8940157085544795, 0.03466444481364654
# alpha, M, predM  6.103515625E-05, 3.893949500181661, 0.034664445139274906
# alpha, M, predM  3.0517578125E-05, 3.8939163966225654, 0.034664445302089085
# alpha, M, predM  1.52587890625E-05, 3.893899844999926, 0.034664445383496174
# alpha, M, predM  7.62939453125E-06, 3.8938915692278515, 0.03466444542419972
# alpha, M, predM  3.814697265625E-06, 3.893887431351505, 0.03466444544455149
# alpha, M, predM  1.9073486328125E-06, 3.893885362415921, 0.034664445454727376
# alpha, M, predM  9.5367431640625E-07, 3.8938843279487028, 0.03466444545981532
# alpha, M, predM  4.76837158203125E-07, 0.034664416095955844, 0.03466444546235929
# l2: ||R0||= 6.8900399E-02, f_err=2.471611E-01, f_phi=0E+00, Alpha = 4.77E-07, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 5.98E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 0.06639034811703388, 0.04122410370879799
# alpha, M, predM  0.5, 0.035625806923031786, 0.04122617305965848
# l2: ||R0||= 6.7684517E-02, f_err=2.241893E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 1.55E-01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 0.020521035171742787, 0.056452754056493394
# l2: ||R0||= 1.9875597E-02, f_err=1.504858E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.45:
# alpha, M, predM  1, 0.02471023366692116, 0.01628307094403108
# alpha, M, predM  0.5, 0.015415179215275186, 0.016283423574827427
# l2: ||R0||= 2.6809813E-02, f_err=1.320884E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 2.5E-01, QuadOrder=8
#
# ALNR=1 <= 1.001 so we terminate/increase degree
#
# ALNR=1 <= 1.001 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 2 to 3              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 1.9945468E+00, f_err=2.681677E+00, f_phi=0E+00,
#  current DGdegree=3, min It.:10, MaxReInit:5, ReInitTol:0, TermN:8, tALNR:1.01
#
# ################################################################################################
#
#
# Starting Opt-Iter No.46:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         2854.5487293093156
#     L2 Norm of Solution:    25.01869604062617
#     L2 Norm of Residual:    0.48354255655244627
#     Relative Residual norm: 3.5250255347271195E-10
#     Matrix Inf norm:        1371741996.728198
# alpha, M, predM  1, 1262.928434110805, 41.77320059149549
# alpha, M, predM  0.5, 394.71399673563235, 41.771589234028426
# alpha, M, predM  0.25, 14.357707959808774, 41.7707835552949
# l2: ||R0||= 7.0165991E-01, f_err=1.362652E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.91E+01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.47:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         120741.99262991585
#     L2 Norm of Solution:    332.0293464837794
#     L2 Norm of Residual:    9614.936852095369
#     Relative Residual norm: 4.036986651938766E-07
#     Matrix Inf norm:        23817113310.190876
# alpha, M, predM  1, 222.25593054392536, 2.0068607531919884
# alpha, M, predM  0.5, 1.7866272927065636, 2.007004164868094
# l2: ||R0||= 5.2406908E-01, f_err=1.709699E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.2E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.48:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         86307.76079479798
#     L2 Norm of Solution:    74.08321730148874
#     L2 Norm of Residual:    6554.377602820257
#     Relative Residual norm: 9.90961317693509E-07
#     Matrix Inf norm:        6614160901.936879
# alpha, M, predM  1, 212.5005587564014, 1.6050910834299679
# alpha, M, predM  0.5, 190.92558504954948, 1.6052298147501873
# alpha, M, predM  0.25, 181.28527930476042, 1.6052991804102972
# alpha, M, predM  0.125, 1.2439989823509288, 1.605333863240352
# l2: ||R0||= 4.5836643E-01, f_err=1.495459E+00, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.74E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.49:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         74956.21344133635
#     L2 Norm of Solution:    0.9024876109258145
#     L2 Norm of Residual:    1.582211587877641
#     Relative Residual norm: 2.425314831528357E-10
#     Matrix Inf norm:        6523736907.511432
# alpha, M, predM  1, 226.4684461846639, 1.216162399880136
# alpha, M, predM  0.5, 199.6293216849478, 1.2162690770890034
# alpha, M, predM  0.25, 187.53751952868456, 1.2163224156934371
# alpha, M, predM  0.125, 181.87991321399466, 1.216349084995654
# alpha, M, predM  0.0625, 1.0747646587947526, 1.2163624196467624
# l2: ||R0||= 4.2965596E-01, f_err=1.401954E+00, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 2.14E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.50:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         69926.32599434737
#     L2 Norm of Solution:    0.8507992317484164
#     L2 Norm of Residual:    5.4300864847974735
#     Relative Residual norm: 8.401754337506137E-10
#     Matrix Inf norm:        6463038868.629033
# alpha, M, predM  1, 228.25731307816957, 1.0766463728514895
# alpha, M, predM  0.5, 202.01477267918924, 1.076739709089137
# alpha, M, predM  0.25, 190.14926459637283, 1.0767863772079609
# alpha, M, predM  0.125, 184.5563161507662, 1.0768097112673727
# alpha, M, predM  0.0625, 181.83631042629176, 1.0768213782970788
# alpha, M, predM  0.03125, 180.48958180241723, 1.0768272118119318
# alpha, M, predM  0.015625, 179.819528695753, 1.0768301285693582
# alpha, M, predM  0.0078125, 1.0608340487410797, 1.0768315869480714
# l2: ||R0||= 4.2629841E-01, f_err=1.391024E+00, f_phi=0E+00, Alpha = 7.81E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.19E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.51:
# alpha, M, predM  1, 179.51924248432806, 1.1038531783899814
# alpha, M, predM  0.5, 178.96626464504615, 1.1039426736673978
# alpha, M, predM  0.25, 179.44317530169042, 1.103987421306106
# alpha, M, predM  0.125, 179.7681648299722, 1.1040097951254602
# alpha, M, predM  0.0625, 179.94651441742317, 1.1040209820351372
# alpha, M, predM  0.03125, 1.0405062340278688, 1.1040265754899756
# l2: ||R0||= 4.1297843E-01, f_err=1.347749E+00, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 3.2E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.52:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         67233.90224637512
#     L2 Norm of Solution:    0.8379990381243735
#     L2 Norm of Residual:    2.5337942126105744
#     Relative Residual norm: 3.918260176921545E-10
#     Matrix Inf norm:        6466630846.860449
# alpha, M, predM  1, 225.92299485268728, 1.000695360325849
# alpha, M, predM  0.5, 201.12878432379165, 1.0007813113544801
# alpha, M, predM  0.25, 189.88419973857867, 1.0008242868687958
# alpha, M, predM  0.125, 184.56506283330708, 1.0008457746259534
# alpha, M, predM  0.0625, 181.9785349879397, 1.0008565185045324
# alpha, M, predM  0.03125, 180.6972648398046, 1.0008618904438218
# alpha, M, predM  0.015625, 180.05962204976322, 1.0008645764134665
# alpha, M, predM  0.0078125, 179.74154796942412, 1.0008659193982887
# alpha, M, predM  0.00390625, 179.58269766317255, 1.0008665908907
# alpha, M, predM  0.001953125, 179.5033191816691, 1.0008669266369057
# alpha, M, predM  0.0009765625, 0.9990083669092439, 1.0008670945100084
# l2: ||R0||= 4.1257511E-01, f_err=1.346437E+00, f_phi=0E+00, Alpha = 9.77E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.24E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.53:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         67163.60342547981
#     L2 Norm of Solution:    0.5482554283136092
#     L2 Norm of Residual:    3.521289015735083
#     Relative Residual norm: 5.446057821382054E-10
#     Matrix Inf norm:        6465757675.047013
# alpha, M, predM  1, 224.94433599634232, 0.9994367742057226
# alpha, M, predM  0.5, 200.70985773670523, 0.9995225196242413
# alpha, M, predM  0.25, 189.71067966146484, 0.9995653923335006
# alpha, M, predM  0.125, 184.5059362174778, 0.9995868286881302
# alpha, M, predM  0.0625, 181.97405243100158, 0.9995975468654451
# alpha, M, predM  0.03125, 180.71966774547087, 0.9996029059541025
# alpha, M, predM  0.015625, 180.09535894887597, 0.9996055854984311
# alpha, M, predM  0.0078125, 179.78392475195093, 0.9996069252705956
# alpha, M, predM  0.00390625, 179.62838761799458, 0.9996075951566777
# alpha, M, predM  0.001953125, 179.55066403139733, 0.9996079300997188
# alpha, M, predM  0.0009765625, 179.51181348184625, 0.9996080975712394
# alpha, M, predM  0.00048828125, 179.4923910178506, 0.9996081813069996
# alpha, M, predM  0.000244140625, 0.9991441467215231, 0.9996082231748797
# l2: ||R0||= 4.1247439E-01, f_err=1.346109E+00, f_phi=0E+00, Alpha = 2.44E-04, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.26E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.54:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         67146.07885745495
#     L2 Norm of Solution:    16.494239596343757
#     L2 Norm of Residual:    286.9769540711374
#     Relative Residual norm: 4.4385575637558045E-08
#     Matrix Inf norm:        6465545392.82136
# alpha, M, predM  1, 224.24444893065828, 0.9993877849260545
# alpha, M, predM  0.5, 200.3990278762949, 0.9994734642529645
# alpha, M, predM  0.25, 189.57102433877057, 0.9995163039164193
# alpha, M, predM  0.125, 184.44638696958015, 0.9995377237481469
# alpha, M, predM  0.0625, 181.9527550384908, 0.9995484336640106
# alpha, M, predM  0.03125, 180.71719999666777, 0.9995537886219424
# alpha, M, predM  0.015625, 180.10223222782406, 0.9995564661009083
# alpha, M, predM  0.0078125, 179.79545014320325, 0.9995578048403914
# alpha, M, predM  0.00390625, 179.64223447087718, 0.9995584742101328
# alpha, M, predM  0.001953125, 179.56567046720846, 0.9995588088950036
# alpha, M, predM  0.0009765625, 179.5273994222381, 0.999558976237439
# alpha, M, predM  0.00048828125, 179.50826663881597, 0.9995590599086566
# alpha, M, predM  0.000244140625, 179.4987009318464, 0.9995591017442654
# alpha, M, predM  0.0001220703125, 179.49391824955046, 0.9995591226620699
# alpha, M, predM  6.103515625E-05, 0.9994431374474358, 0.9995591331209721
# l2: ||R0||= 4.1244921E-01, f_err=1.346027E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 2.27E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.55:
# alpha, M, predM  1, 194.84392374406494, 1.0244949773721
# alpha, M, predM  0.5, 186.56455526607905, 1.0245792675262904
# alpha, M, predM  0.25, 183.08552037120688, 1.0246214126033855
# alpha, M, predM  0.125, 181.46641880098684, 1.0246424851419331
# alpha, M, predM  0.0625, 180.6705004011732, 1.024653021411207
# alpha, M, predM  0.03125, 180.27602184931152, 1.0246582895458438
# alpha, M, predM  0.015625, 180.07964815676198, 1.0246609236131623
# alpha, M, predM  0.0078125, 179.98167770249864, 1.0246622406468215
# alpha, M, predM  0.00390625, 179.93274657287466, 1.0246628991636513
# alpha, M, predM  0.001953125, 179.90829453238516, 1.024663228422066
# alpha, M, predM  0.0009765625, 179.89607189321165, 1.0246633930512734
# alpha, M, predM  0.00048828125, 179.88996141888677, 1.024663475365877
# alpha, M, predM  0.000244140625, 179.88690639305239, 1.024663516523179
# alpha, M, predM  0.0001220703125, 179.88537893294898, 1.0246635371018298
# alpha, M, predM  6.103515625E-05, 1.0245461695308675, 1.0246635473911554
# l2: ||R0||= 4.1242404E-01, f_err=1.345945E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 2.88E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
#
# ALNR=1 <= 1.01 so we terminate/increase degree

# %% [markdown]
# the resulting residual plot shows respective residuals corresponding to the polynomial degrees

# %%
pCSB.GetResPlot().ToGnuplot().SaveToSVG("resplotCSB.svg",xRes:1200,yRes:500);
pCSB.GetResPlot().ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,411.8 L50.1,411.8 M1150.1,411.8 L1145.6,411.8 M45.6,393.9 L50.1,393.9 M1150.1,393.9 L1145.6,393.9
# 		M45.6,381.2 L50.1,381.2 M1150.1,381.2 L1145.6,381.2 M45.6,371.4 L50.1,371.4 M1150.1,371.4 L1145.6,371.4
# 		M45.6,363.4 L50.1,363.4 M1150.1,363.4 L1145.6,363.4 M45.6,356.6 L50.1,356.6 M1150.1,356.6 L1145.6,356.6
# 		M45.6,350.7 L50.1,350.7 M1150.1,350.7 L1145.6,350.7 M45.6,345.5 L50.1,345.5 M1150.1,345.5 L1145.6,345.5
# 		M45.6,340.8 L54.6,340.8 M1150.1,340.8 L1141.1,340.8  '/>	<g transform="translate(37.3,346.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,310.2 L50.1,310.2 M1150.1,310.2 L1145.6,310.2 M45.6,292.4 L50.1,292.4 M1150.1,292.4 L1145.6,292.4
# 		M45.6,279.7 L50.1,279.7 M1150.1,279.7 L1145.6,279.7 M45.6,269.8 L50.1,269.8 M1150.1,269.8 L1145.6,269.8
# 		M45.6,261.8 L50.1,261.8 M1150.1,261.8 L1145.6,261.8 M45.6,255.0 L50.1,255.0 M1150.1,255.0 L1145.6,255.0
# 		M45.6,249.1 L50.1,249.1 M1150.1,249.1 L1145.6,249.1 M45.6,243.9 L50.1,243.9 M1150.1,243.9 L1145.6,243.9
# 		M45.6,239.2 L54.6,239.2 M1150.1,239.2 L1141.1,239.2  '/>	<g transform="translate(37.3,245.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,208.7 L50.1,208.7 M1150.1,208.7 L1145.6,208.7 M45.6,190.8 L50.1,190.8 M1150.1,190.8 L1145.6,190.8
# 		M45.6,178.1 L50.1,178.1 M1150.1,178.1 L1145.6,178.1 M45.6,168.3 L50.1,168.3 M1150.1,168.3 L1145.6,168.3
# 		M45.6,160.2 L50.1,160.2 M1150.1,160.2 L1145.6,160.2 M45.6,153.4 L50.1,153.4 M1150.1,153.4 L1145.6,153.4
# 		M45.6,147.5 L50.1,147.5 M1150.1,147.5 L1145.6,147.5 M45.6,142.3 L50.1,142.3 M1150.1,142.3 L1145.6,142.3
# 		M45.6,137.7 L54.6,137.7 M1150.1,137.7 L1141.1,137.7  '/>	<g transform="translate(37.3,143.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,107.1 L50.1,107.1 M1150.1,107.1 L1145.6,107.1 M45.6,89.2 L50.1,89.2 M1150.1,89.2 L1145.6,89.2
# 		M45.6,76.5 L50.1,76.5 M1150.1,76.5 L1145.6,76.5 M45.6,66.7 L50.1,66.7 M1150.1,66.7 L1145.6,66.7
# 		M45.6,58.6 L50.1,58.6 M1150.1,58.6 L1145.6,58.6 M45.6,51.8 L50.1,51.8 M1150.1,51.8 L1145.6,51.8
# 		M45.6,45.9 L50.1,45.9 M1150.1,45.9 L1145.6,45.9 M45.6,40.7 L50.1,40.7 M1150.1,40.7 L1145.6,40.7
# 		M45.6,36.1 L54.6,36.1 M1150.1,36.1 L1141.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M229.7,442.4 L229.7,433.4 M229.7,36.1 L229.7,45.1  '/>	<g transform="translate(229.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M413.8,442.4 L413.8,433.4 M413.8,36.1 L413.8,45.1  '/>	<g transform="translate(413.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M597.9,442.4 L597.9,433.4 M597.9,36.1 L597.9,45.1  '/>	<g transform="translat

# %% [markdown]
# Resplot using the highest degree

# %%
var siCSB= database.Sessions.Pick(0);
pCSB.GetUniformResPlot(siCSB).ToGnuplot().SaveToSVG("resplotCSBUniorm.svg",xRes:1200,yRes:500);
pCSB.GetUniformResPlot(siCSB).ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,417.9 L50.1,417.9 M1150.1,417.9 L1145.6,417.9 M45.6,385.6 L50.1,385.6 M1150.1,385.6 L1145.6,385.6
# 		M45.6,369.0 L50.1,369.0 M1150.1,369.0 L1145.6,369.0 M45.6,361.1 L54.6,361.1 M1150.1,361.1 L1141.1,361.1
# 		 '/>	<g transform="translate(37.3,367.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,336.7 L50.1,336.7 M1150.1,336.7 L1145.6,336.7 M45.6,304.3 L50.1,304.3 M1150.1,304.3 L1145.6,304.3
# 		M45.6,287.8 L50.1,287.8 M1150.1,287.8 L1145.6,287.8 M45.6,279.9 L54.6,279.9 M1150.1,279.9 L1141.1,279.9
# 		 '/>	<g transform="translate(37.3,285.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,255.4 L50.1,255.4 M1150.1,255.4 L1145.6,255.4 M45.6,223.1 L50.1,223.1 M1150.1,223.1 L1145.6,223.1
# 		M45.6,206.5 L50.1,206.5 M1150.1,206.5 L1145.6,206.5 M45.6,198.6 L54.6,198.6 M1150.1,198.6 L1141.1,198.6
# 		 '/>	<g transform="translate(37.3,204.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,174.2 L50.1,174.2 M1150.1,174.2 L1145.6,174.2 M45.6,141.8 L50.1,141.8 M1150.1,141.8 L1145.6,141.8
# 		M45.6,125.2 L50.1,125.2 M1150.1,125.2 L1145.6,125.2 M45.6,117.4 L54.6,117.4 M1150.1,117.4 L1141.1,117.4
# 		 '/>	<g transform="translate(37.3,123.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,92.9 L50.1,92.9 M1150.1,92.9 L1145.6,92.9 M45.6,60.6 L50.1,60.6 M1150.1,60.6 L1145.6,60.6
# 		M45.6,44.0 L50.1,44.0 M1150.1,44.0 L1145.6,44.0 M45.6,36.1 L54.6,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M229.7,442.4 L229.7,433.4 M229.7,36.1 L229.7,45.1  '/>	<g transform="translate(229.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M413.8,442.4 L413.8,433.4 M413.8,36.1 L413.8,45.1  '/>	<g transform="translate(413.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M597.9,442.4 L597.9,433.4 M597.9,36.1 L597.9,45.1  '/>	<g transform="translate(597.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 30</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M781.9,442.4 L781.9,433.4 M781.9,36.1 L781.9,45.1  '/>	<g transform="tran

# %% [markdown]
# plot shadowfields

# %%
pCSB.PlotShadowFields(siCSB);
