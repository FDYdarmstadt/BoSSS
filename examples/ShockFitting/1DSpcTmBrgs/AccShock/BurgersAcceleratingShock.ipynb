# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\BUIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using BUIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %%
string dbPath = @"BUIDT_db";
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Opening existing database 'BUIDT_db'.

# %% [markdown]
# ## Curved Shock Burgers

# %%
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pCSB = new BUIDTMain();
var CCSB = BUIDTHardCodedControl.AccShock(
dbPath: dbPath,
MaxIterations: 100,
dgDegree: 3,
numOfCellsX: 10,
numOfCellsY: 10,
OptiNumOfCellsX: 10,
OptiNumOfCellsY: 10,
linearization: Linearization.FD,
agg: 0.4,
optiLevelSetType: OptiLevelSetType.SplineLevelSet,
getLevelSet: GetLevelSet.FromFunction,
applyReInit: true,
solverRunType: SolverRunType.PContinuation
) ;
CCSB.GetInitialValue = GetInitialValue.FromP0Timestepping;
CCSB.ProjectName= "CSB";
pCSB.Init(CCSB);
pCSB.RunSolverMode();
# Out:
# rm CSB_SP_0.plt CSB_SP_1.plt CSB_SP_10.plt CSB_SP_11.plt CSB_SP_12.plt CSB_SP_13.plt CSB_SP_14.plt CSB_SP_15.plt CSB_SP_16.plt CSB_SP_17.plt CSB_SP_18.plt CSB_SP_19.plt CSB_SP_2.plt CSB_SP_20.plt CSB_SP_21.plt CSB_SP_22.plt CSB_SP_23.plt CSB_SP_24.plt CSB_SP_25.plt CSB_SP_26.plt CSB_SP_27.plt CSB_SP_28.plt CSB_SP_29.plt CSB_SP_3.plt CSB_SP_30.plt CSB_SP_31.plt CSB_SP_32.plt CSB_SP_33.plt CSB_SP_34.plt CSB_SP_35.plt CSB_SP_36.plt CSB_SP_37.plt CSB_SP_38.plt CSB_SP_39.plt CSB_SP_4.plt CSB_SP_40.plt CSB_SP_41.plt CSB_SP_42.plt CSB_SP_43.plt CSB_SP_44.plt CSB_SP_45.plt CSB_SP_46.plt CSB_SP_47.plt CSB_SP_48.plt CSB_SP_49.plt CSB_SP_5.plt CSB_SP_50.plt CSB_SP_51.plt CSB_SP_52.plt CSB_SP_53.plt CSB_SP_54.plt CSB_SP_55.plt CSB_SP_6.plt CSB_SP_7.plt CSB_SP_8.plt CSB_SP_9.plt;
# Session ID: ec4dac56-83cd-48c2-bc20-798e7ea6a003, DB path: 'BUIDT_db'
# Session directory 'BUIDT_db\sessions\ec4dac56-83cd-48c2-bc20-798e7ea6a003'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
#
#
# *****************************************************************************************
# *  X   X   DDD   GGG   -   III  SSS  TTTTT  *
# *   X X    D  D G      -    I  S      T     *
# *    X     D  D G  GG  -    I   SSS   T     *      XDG Implicit Shock Tracking Solver
# *   X X    D  D G   G  -    I      S  T     *
# *  X   X   DDD   GGG   -   III  SSS   T     *
# *****************************************************************************************
# *
# *  solver:                             BUIDT.BUIDTMain
# *  project:                            CSB
# *  session:                            BurgersIDT
# *  optimization problem:               FullEnRes
# *  merit function:                     L2Merit
# *  level set type:                     SplineLevelSet
# *  solver type:                        PContinuation
# *  f_phi type:                         None
# *  globalization strategy:             LineSearch
# *  initial value from:                 FromP0Timestepping
# *
# ******************************* Params ************************************************
# *  Solution Degree:                    3
# *  OptiLevelSet Degree:                3
# *  Level Set Degree:                   3
# *  Level Set Two Degree:               1
# *  Max Iterations:                     200
# *  Agglomeration Threshold:            0.4
# *  Regularization Params:
# *    Gamma Max:                        1
# *    Gamma Min:                        1E-06
# *    Gamma Start:                      1
# *  Globalization Params:
# *    Alpha Min:                        1E-08
# *    Alpha Start:                      1
# *    Mu Start:                         1
# *    Mu Max:                           1000000
# *    Mu Omega:                         1.2
# *    Mu Rho:                           0.95
# *  Level Set penalty Params:
# *    Kappa Xi:                         10
# *    Kappa M:                          100
# *    Kappa Min:                        1E-10
# *    Kappa v:                          0.5
# *  Reinitialization Params:
# *    Apply ReiInit:                    True
# *    c1:                               -0.2
# *    c2:                               0.01
# *    c3:                               0.01
# *  Adaptive Regularization Params:
# *    L:                                1
# *    sigma_1:                          0.01
# *    sigma_2:                          0.1
# *    tauGamma:                         1.5
# It 0: ||r||=27.428032675331682, ||du||=0.028490184661622155, ||nu|| = 11.895953384747518, dt=0.001
# It 1: ||r||=27.41500288482289, ||du||=0.0056942523790599175, ||nu|| = 0.19963100605778125, dt=0.0002
# It 2: ||r||=27.412327271564962, ||du||=0.0011386963700437043, ||nu|| = 0.033269637751847436, dt=4E-05
# It 3: ||r||=27.40690824796374, ||du||=0.002276771203374798, ||nu|| = 0.0643484767456808, dt=8E-05
# It 4: ||r||=27.401398097880257, ||du||=0.002276142708349483, ||nu|| = 0.06041238924710756, dt=8E-05
# It 5: ||r||=27.39579690590502, ||du||=0.0022755072622780456, ||nu|| = 0.05692729105864842, dt=8E-05
# It 6: ||r||=27.390104759294186, ||du||=0.0022748648726323858, ||nu|| = 0.05381984241939573, dt=8E-05
# It 7: ||r||=27.384321747962723, ||du||=0.002274215547089223, ||nu|| = 0.05103178795654787, dt=8E-05
# It 8: ||r||=27.378447964477537, ||du||=0.002273559293529567, ||nu|| = 0.0485162681851978, dt=8E-05
# It 9: ||r||=27.366431100710948, ||du||=0.0045444529889251215, ||nu|| = 0.09239757181894229, dt=0.00016
# It 10: ||r||=27.354052422035327, ||du||=0.004541732182421079, ||nu|| = 0.0844479464885256, dt=0.00016
# It 11: ||r||=27.341312767229606, ||du||=0.004538956308721732, ||nu|| = 0.0777464507950741, dt=0.00016
# It 12: ||r||=27.32821301676552, ||du||=0.004536125515429128, ||nu|| = 0.07202032943238025, dt=0.00016
# It 13: ||r||=27.314754092569647, ||du||=0.004533239956536943, ||nu|| = 0.06707090606650991, dt=0.00016
# It 14: ||r||=27.300936957781417, ||du||=0.004530299792394077, ||nu|| = 0.06275003303903053, dt=0.00016
# It 15: ||r||=27.286762616507364, ||du||=0.004527305189667642, ||nu|| = 0.05894498818207152, dt=0.00016
# It 16: ||r||=27.272232113571302, ||du||=0.0045242563213052, ||nu|| = 0.055568483322295026, dt=0.00016
# It 17: ||r||=27.25734653426098, ||du||=0.004521153366496496, ||nu|| = 0.05255187384995369, dt=0.00016
# It 18: ||r||=27.242107004070807, ||du||=0.004517996510634432, ||nu|| = 0.049840433522830956, dt=0.00016
# It 19: ||r||=27.21058476509671, ||du||=0.009023052271901514, ||nu|| = 0.09461006049320497, dt=0.00032
# It 20: ||r||=27.177662308217258, ||du||=0.009009685420938099, ||nu|| = 0.08611744327366387, dt=0.00032
# It 21: ||r||=27.14335010351896, ||du||=0.008995895885229466, ||nu|| = 0.0789936443645269, dt=0.00032
# It 22: ||r||=27.10765923637325, ||du||=0.008981687271597575, ||nu|| = 0.07293160651598074, dt=0.00032
# It 23: ||r||=27.070601398328833, ||du||=0.00896706337404578, ||nu|| = 0.06770973298573342, dt=0.00032
# It 24: ||r||=27.032188877807624, ||du||=0.00895202817090246, ||nu|| = 0.06316409005536881, dt=0.00032
# It 25: ||r||=26.99243455061245, ||du||=0.008936585821900466, ||nu|| = 0.05917079675335378, dt=0.00032
# It 26: ||r||=26.951351870253557, ||du||=0.008920740665195014, ||nu|| = 0.055634496876478895, dt=0.00032
# It 27: ||r||=26.908954856614546, ||du||=0.00890449721381967, ||nu|| = 0.052480595864719946, dt=0.00032
# It 28: ||r||=26.865258081837563, ||du||=0.00888786015120364, ||nu|| = 0.04964990211345356, dt=0.00032
# It 29: ||r||=26.774121790357615, ||du||=0.017706943656669985, ||nu|| = 0.0937729052578793, dt=0.00064
# It 30: ||r||=26.677987283436497, ||du||=0.01763514655014188, ||nu|| = 0.0849549518297806, dt=0.00064
# It 31: ||r||=26.576990500544436, ||du||=0.01756041581734597, ||nu|| = 0.07756785911514932, dt=0.00064
# It 32: ||r||=26.471275196622063, ||du||=0.0174828431165458, ||nu|| = 0.07128688376707512, dt=0.00064
# It 33: ||r||=26.36099258361614, ||du||=0.017402524705796833, ||nu|| = 0.06587873933694377, dt=0.00064
# It 34: ||r||=26.246300964413752, ||du||=0.017319561213855778, ||nu|| = 0.06117151923432648, dt=0.00064
# It 35: ||r||=26.127365359663695, ||du||=0.01723405740629914, ||nu|| = 0.057035756548836546, dt=0.00064
# It 36: ||r||=26.004357127912435, ||du||=0.017146121947162335, ||nu|| = 0.053372089358815954, dt=0.00064
# It 37: ||r||=25.87745357942313, ||du||=0.017055867156373226, ||nu|| = 0.05010299152160221, dt=0.00064
# It 38: ||r||=25.746837583991198, ||du||=0.016963408763217093, ||nu|| = 0.04716708705229155, dt=0.00064
# It 39: ||r||=25.476032896103387, ||du||=0.03354600037461557, ||nu|| = 0.08797610452405275, dt=0.00128
# It 40: ||r||=25.192800701725474, ||du||=0.03315060404840216, ||nu|| = 0.07888374795481426, dt=0.00128
# It 41: ||r||=24.898751564902526, ||du||=0.03274265829800071, ||nu|| = 0.07125211663066336, dt=0.00128
# It 42: ||r||=24.595542770678684, ||du||=0.03232424897029498, ||nu|| = 0.06475093220949293, dt=0.00128
# It 43: ||r||=24.284864697756444, ||du||=0.031897500862108526, ||nu|| = 0.05914328527428047, dt=0.00128
# It 44: ||r||=23.968426927050572, ||du||=0.031464560255611854, ||nu|| = 0.054254799907878924, dt=0.00128
# It 45: ||r||=23.64794410361414, ||du||=0.031027577164707124, ||nu|| = 0.04995425803035997, dt=0.00128
# It 46: ||r||=23.006798178377778, ||du||=0.060314696621135686, ||nu|| = 0.08950422739477684, dt=0.00256
# It 47: ||r||=22.369501912727415, ||du||=0.058591756769111505, ||nu|| = 0.07702134538772862, dt=0.00256
# It 48: ||r||=21.74804719712367, ||du||=0.05691622261479276, ||nu|| = 0.06684405476575536, dt=0.00256
# It 49: ||r||=21.153122173409816, ||du||=0.055314655626251596, ||nu|| = 0.05839946650231412, dt=0.00256
# It 50: ||r||=20.593716901386546, ||du||=0.0538093162810307, ||nu|| = 0.05276058227502784, dt=0.00256
# It 51: ||r||=20.076792264716293, ||du||=0.05241735083333061, ||nu|| = 0.04786918660541364, dt=0.00256
# It 52: ||r||=19.19768033431876, ||du||=0.10008891364127316, ||nu|| = 0.08279414268253991, dt=0.00512
# It 53: ||r||=18.500739659324097, ||du||=0.09630129010771461, ||nu|| = 0.06943826732920597, dt=0.00512
# It 54: ||r||=17.96363786763652, ||du||=0.0933564117872993, ||nu|| = 0.06530643510401844, dt=0.00512
# It 55: ||r||=17.54586126613329, ||du||=0.0910484062161206, ||nu|| = 0.0618147409926098, dt=0.00512
# It 56: ||r||=17.202389034321488, ||du||=0.089149352869526, ||nu|| = 0.061492653734691274, dt=0.00512
# It 57: ||r||=16.89541749413255, ||du||=0.08746800965531504, ||nu|| = 0.06033043781766541, dt=0.00512
# It 58: ||r||=16.60128153239838, ||du||=0.08588448643325816, ||nu|| = 0.05842445465394363, dt=0.00512
# It 59: ||r||=16.31213751105465, ||du||=0.08435848100016244, ||nu|| = 0.05589459972910973, dt=0.00512
# It 60: ||r||=16.033303305699924, ||du||=0.08291546902839197, ||nu|| = 0.05304809804901585, dt=0.00512
# It 61: ||r||=15.777885513911126, ||du||=0.08161913185944258, ||nu|| = 0.05080948066877518, dt=0.00512
# It 62: ||r||=15.560352735738515, ||du||=0.08053859675611307, ||nu|| = 0.04815415596414694, dt=0.00512
# It 63: ||r||=15.22401695108439, ||du||=0.15779328642371437, ||nu|| = 0.08495388097475826, dt=0.01024
# It 64: ||r||=14.995840935838585, ||du||=0.15552398002796497, ||nu|| = 0.07853639489928477, dt=0.01024
# It 65: ||r||=14.776166461555096, ||du||=0.15327435129612582, ||nu|| = 0.08426647085744998, dt=0.01024
# It 66: ||r||=14.49418205308156, ||du||=0.1503843485674174, ||nu|| = 0.08612563054142461, dt=0.01024
# It 67: ||r||=14.161760292515257, ||du||=0.14705837613764494, ||nu|| = 0.08385089068869954, dt=0.01024
# It 68: ||r||=13.843171837115387, ||du||=0.14400040709024822, ||nu|| = 0.07874367914643388, dt=0.01024
# It 69: ||r||=13.574485570619133, ||du||=0.14151428865792023, ||nu|| = 0.07173867645141623, dt=0.01024
# It 70: ||r||=13.350427019579389, ||du||=0.13952260708798989, ||nu|| = 0.06984660817716266, dt=0.01024
# It 71: ||r||=13.132805632734916, ||du||=0.13761967485627805, ||nu|| = 0.07520422279111225, dt=0.01024
# It 72: ||r||=12.900280739886238, ||du||=0.13562213338915907, ||nu|| = 0.07714134065330698, dt=0.01024
# It 73: ||r||=12.670570599440504, ||du||=0.13381189725902473, ||nu|| = 0.07583989570593384, dt=0.01024
# It 74: ||r||=12.473980654275021, ||du||=0.13256320056722787, ||nu|| = 0.07186538182985623, dt=0.01024
# It 75: ||r||=12.323276391038094, ||du||=0.13200918594088623, ||nu|| = 0.06640130437111895, dt=0.01024
# It 76: ||r||=12.197792716758954, ||du||=0.13184168811504043, ||nu|| = 0.06924240588301818, dt=0.01024
# It 77: ||r||=12.066466282598476, ||du||=0.1315956085916895, ||nu|| = 0.07351067397607634, dt=0.01024
# It 78: ||r||=11.919324223073565, ||du||=0.13109334779391457, ||nu|| = 0.07464401674142306, dt=0.01024
# It 79: ||r||=11.772894543426439, ||du||=0.13047400747884025, ||nu|| = 0.07287747713414007, dt=0.01024
# It 80: ||r||=11.650252704107649, ||du||=0.1299904548862171, ||nu|| = 0.07326912219508651, dt=0.01024
# It 81: ||r||=11.555108723108734, ||du||=0.1296984369214712, ||nu|| = 0.0720292214417851, dt=0.01024
# It 82: ||r||=11.470035768440477, ||du||=0.12943694017992738, ||nu|| = 0.06929672072559474, dt=0.01024
# It 83: ||r||=11.375207184641162, ||du||=0.12899649946471106, ||nu|| = 0.07277736208385346, dt=0.01024
# It 84: ||r||=11.269093192898328, ||du||=0.12834369384826302, ||nu|| = 0.07328102452098248, dt=0.01024
# It 85: ||r||=11.168560148964021, ||du||=0.12763888279258048, ||nu|| = 0.07703437016032798, dt=0.01024
# It 86: ||r||=11.090917975634122, ||du||=0.12706917175803617, ||nu|| = 0.07841522108538457, dt=0.01024
# It 87: ||r||=11.036144328238874, ||du||=0.12665970965765846, ||nu|| = 0.07743054949480309, dt=0.01024
# It 88: ||r||=10.988015217073425, ||du||=0.1262640977822781, ||nu|| = 0.07446145797099216, dt=0.01024
# It 89: ||r||=10.93173361188269, ||du||=0.12572777461914242, ||nu|| = 0.0736314245911288, dt=0.01024
# It 90: ||r||=10.86927731710159, ||du||=0.12504982036809534, ||nu|| = 0.07994084784086077, dt=0.01024
# It 91: ||r||=10.787846208011096, ||du||=0.12358351371123051, ||nu|| = 0.08322112683282441, dt=0.01024
# It 92: ||r||=10.703145982994917, ||du||=0.12166814230901066, ||nu|| = 0.08303161875294938, dt=0.01024
# It 93: ||r||=10.661743024926308, ||du||=0.12056888713169864, ||nu|| = 0.07989232305396565, dt=0.01024
# It 94: ||r||=10.637479304006801, ||du||=0.11983576042690215, ||nu|| = 0.07453701692888846, dt=0.01024
# It 95: ||r||=10.539271496989851, ||du||=0.11781755948212327, ||nu|| = 0.08099250832760067, dt=0.01024
# It 96: ||r||=10.444127687668875, ||du||=0.11592810033085688, ||nu|| = 0.08441254405479598, dt=0.01024
# It 97: ||r||=10.38839551115418, ||du||=0.1146858866818354, ||nu|| = 0.08423220656814981, dt=0.01024
# It 98: ||r||=10.371005191957769, ||du||=0.11399787374559166, ||nu|| = 0.08099668459493956, dt=0.01024
# It 99: ||r||=10.32549426705163, ||du||=0.11301026363669457, ||nu|| = 0.07361038942054322, dt=0.01024
# It 100: ||r||=10.206548051935416, ||du||=0.11142099788562858, ||nu|| = 0.07958263455807332, dt=0.01024
# It 101: ||r||=10.08298046765491, ||du||=0.11048872298526613, ||nu|| = 0.08363000184442801, dt=0.01024
# It 102: ||r||=9.945727299133488, ||du||=0.11010352856034689, ||nu|| = 0.08404552876190187, dt=0.01024
# It 103: ||r||=9.801858935311495, ||du||=0.11021486296778327, ||nu|| = 0.08129916053509684, dt=0.01024
# It 104: ||r||=9.569448743975087, ||du||=0.10958565749915311, ||nu|| = 0.08522119651109442, dt=0.01024
# It 105: ||r||=9.274330130789155, ||du||=0.10831390351567863, ||nu|| = 0.09503007921625437, dt=0.01024
# It 106: ||r||=8.962504473203866, ||du||=0.10677746636191446, ||nu|| = 0.10059960512581673, dt=0.01024
# It 107: ||r||=8.900109290093658, ||du||=0.02130314843937674, ||nu|| = 0.02032357775595574, dt=0.0020480000000000003
# It 108: ||r||=8.763285875215738, ||du||=0.042312748753142525, ||nu|| = 0.04113974506495453, dt=0.004096000000000001
# It 109: ||r||=8.3942999315537, ||du||=0.08165366504533643, ||nu|| = 0.07728189748989248, dt=0.008192000000000001
# It 110: ||r||=7.929099159327962, ||du||=0.07724849622251166, ||nu|| = 0.06586754759058544, dt=0.008192000000000001
# It 111: ||r||=7.427485797059, ||du||=0.07302535922819434, ||nu|| = 0.059321641681493044, dt=0.008192000000000001
# It 112: ||r||=6.906594435272715, ||du||=0.06905150613282449, ||nu|| = 0.054498639791677975, dt=0.008192000000000001
# It 113: ||r||=6.382895835906125, ||du||=0.06526964388558307, ||nu|| = 0.04928329013853534, dt=0.008192000000000001
# It 114: ||r||=5.418249856762655, ||du||=0.11610352523030601, ||nu|| = 0.10195046539432792, dt=0.016384000000000003
# It 115: ||r||=5.222648214016557, ||du||=0.022603207629051617, ||nu|| = 0.020732095264400993, dt=0.0032768000000000007
# It 116: ||r||=4.853975155395972, ||du||=0.04274198048331287, ||nu|| = 0.04190525220834203, dt=0.0065536000000000014
# It 117: ||r||=4.207571418577157, ||du||=0.07581598362877343, ||nu|| = 0.08035995883401668, dt=0.013107200000000003
# It 118: ||r||=3.664997906977942, ||du||=0.06656261111905551, ||nu|| = 0.07297555415051801, dt=0.013107200000000003
# It 119: ||r||=3.224743850139891, ||du||=0.058160683953073465, ||nu|| = 0.06385115330314597, dt=0.013107200000000003
# It 120: ||r||=2.8718176858847984, ||du||=0.05083992302101122, ||nu|| = 0.054548314367483565, dt=0.013107200000000003
# It 121: ||r||=2.585389157284443, ||du||=0.044619656147681645, ||nu|| = 0.045962268567224046, dt=0.013107200000000003
# It 122: ||r||=2.158829479914347, ||du||=0.07116080186867361, ||nu|| = 0.07282307694154, dt=0.026214400000000006
# It 123: ||r||=1.813134360388451, ||du||=0.05745550117552251, ||nu|| = 0.06398884197914498, dt=0.026214400000000006
# It 124: ||r||=1.5244540313167125, ||du||=0.04687572608683585, ||nu|| = 0.053975600354726455, dt=0.026214400000000006
# It 125: ||r||=1.2870971460968785, ||du||=0.03867502409737268, ||nu|| = 0.044510059385232024, dt=0.026214400000000006
# It 126: ||r||=0.9568097402465032, ||du||=0.05594086358319403, ||nu|| = 0.061823536894861385, dt=0.05242880000000001
# It 127: ||r||=0.717610772074591, ||du||=0.041124875119873464, ||nu|| = 0.04285621883487168, dt=0.05242880000000001
# It 128: ||r||=0.4324559149293656, ||du||=0.04858581937626488, ||nu|| = 0.05317127089302128, dt=0.10485760000000002
# It 129: ||r||=0.2579566626620061, ||du||=0.028616862905643897, ||nu|| = 0.03307707077717564, dt=0.10485760000000002
# It 130: ||r||=0.10899784728457125, ||du||=0.023970463596874873, ||nu|| = 0.027805091353258052, dt=0.20971520000000005
# It 131: ||r||=0.04242146478389372, ||du||=0.01924929192376916, ||nu|| = 0.021332286926447303, dt=0.4194304000000001
# Info: Newton solver - between Cauchy point and Newton step (delta = 0.03900831161127941)
# Info: Newton solver - between Cauchy point and Newton step (delta = 0.019504155805639706)
# Info: Newton solver - between Cauchy point and Newton step (delta = 0.019504155805639706)
# Info: Newton solver - between Cauchy point and Newton step (delta = 0.009752077902819853)
# It 132: ||r||=0.07325984713637085, ||du||=0.0658563666484107, ||nu|| = 0.09174583389959824, dt=0.8388608000000002
# Info: Newton solver - between Cauchy point and Newton step (delta = 0.03512322246524391)
# Info: Newton solver - between Cauchy point and Newton step (delta = 0.017561611232621954)
# It 133: ||r||=0.08428931751983118, ||du||=0.07353580762706631, ||nu|| = 0.10811998146317178, dt=0.8388608000000002
# It 134: ||r||=0.0847303452207338, ||du||=0.014812951761295835, ||nu|| = 0.021711535519661727, dt=0.16777216000000006
# It 135: ||r||=0.07628040748743872, ||du||=0.027010949248872845, ||nu|| = 0.0386719115721728, dt=0.3355443200000001
# It 136: ||r||=0.051691332666217296, ||du||=0.03754612446298176, ||nu|| = 0.05108386262334057, dt=0.6710886400000002
# It 137: ||r||=0.030488875054140926, ||du||=0.022782289179298063, ||nu|| = 0.02914231539855665, dt=0.6710886400000002
# It 138: ||r||=0.010671320592342059, ||du||=0.01630780932296509, ||nu|| = 0.019742311081819175, dt=1.3421772800000005
# It 139: ||r||=0.0019857488565388597, ||du||=0.0061494956548444925, ||nu|| = 0.007178002501789906, dt=2.684354560000001
# It 140: ||r||=0.00018966792175666492, ||du||=0.0011807060825104216, ||nu|| = 0.0013560460766282607, dt=5.368709120000002
# It 141: ||r||=9.251193786767545E-06, ||du||=0.00011532784538920793, ||nu|| = 0.00013179890967646615, dt=10.737418240000004
# It 142: ||r||=2.2942426335489572E-07, ||du||=5.7214489884416136E-06, ||nu|| = 6.531068652617746E-06, dt=21.474836480000008
# It 143: ||r||=2.8753290866448228E-09, ||du||=1.4341634721452682E-07, ||nu|| = 1.6367444699919015E-07, dt=42.949672960000015
# It 144: ||r||=1.8124795810695323E-11, ||du||=1.8081162733701699E-09, ||nu|| = 2.063444351727931E-09, dt=85.89934592000003
# It 145: ||r||=5.686648947412494E-14, ||du||=1.1432118526179657E-11, ||nu|| = 1.3046277021662903E-11, dt=171.79869184000006
# ...Finished
# Initial Value : l2: |r|= 5.9850542E-14, |f_err|=2.3341687E+01, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 749.3631395562088, 272.3723574758804
# alpha, M, predM  0.5, 223.97058627542458, 272.3947622285609
# l2: ||R0||= 4.802325E+00, f_err=1.713836E+01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.61E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 671.1192612533931, 434.8957243328429
# alpha, M, predM  0.5, 447.8910616601461, 434.89325850308336
# alpha, M, predM  0.25, 369.13082569357334, 434.8920255882035
# l2: ||R0||= 4.1306014E+00, f_err=2.328636E+01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.37E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 215.63049858547288, 378.4117427419976
# l2: ||R0||= 4.5830034E+00, f_err=1.305152E+01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.85E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 47.192992496925, 198.47658649918856
# l2: ||R0||= 2.0656512E+00, f_err=6.605802E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.23E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 31.687156739556446, 29.79580404013385
# alpha, M, predM  0.5, 24.813076253557483, 29.796922346782363
# l2: ||R0||= 2.0970619E+00, f_err=5.542173E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.51E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 22.379553062391455, 31.318305818966422
# l2: ||R0||= 1.3968748E+00, f_err=5.407322E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.56E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 17.185516415637114, 14.060585427490043
# alpha, M, predM  0.5, 7.938013029090855, 14.061279832295375
# l2: ||R0||= 7.0922602E-01, f_err=3.658038E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.76E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 49.48361125270198, 7.34637511105572
# alpha, M, predM  0.5, 15.65297213946618, 7.346648569653482
# alpha, M, predM  0.25, 13.424378087457354, 7.346785298952362
# alpha, M, predM  0.125, 12.84551104177147, 7.346853663601803
# alpha, M, predM  0.0625, 12.611016788895899, 7.346887845926523
# alpha, M, predM  0.03125, 12.50560801132081, 7.346904937088883
# alpha, M, predM  0.015625, 7.23100475711405, 7.346913482670063
# l2: ||R0||= 6.904734E-01, f_err=3.539544E+00, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.4E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 54.64076164540483, 7.1959990963769815
# alpha, M, predM  0.5, 16.009650686837244, 7.196271674410013
# alpha, M, predM  0.25, 13.470189753694038, 7.1964079634265286
# alpha, M, predM  0.125, 12.870395120107952, 7.196476107934787
# alpha, M, predM  0.0625, 12.61603128901644, 7.196510180188915
# alpha, M, predM  0.03125, 12.499726836572535, 7.19652721631598
# alpha, M, predM  0.015625, 12.4443218555362, 7.196535734379513
# alpha, M, predM  0.0078125, 7.139433143202841, 7.196539993411278
# l2: ||R0||= 6.8506535E-01, f_err=3.525444E+00, f_phi=0E+00, Alpha = 7.81E-03, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 1.35E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 59.47976692999243, 7.157276144045266
# alpha, M, predM  0.5, 16.48072104117441, 7.157554436319892
# alpha, M, predM  0.25, 13.530683380827835, 7.157693582457205
# alpha, M, predM  0.125, 12.92077201030318, 7.157763155525862
# alpha, M, predM  0.0625, 12.655093958084521, 7.157797942060189
# alpha, M, predM  0.03125, 12.532630022910933, 7.157815335327354
# alpha, M, predM  0.015625, 12.474056009529248, 7.157824031960936
# alpha, M, predM  0.0078125, 12.445450047332182, 7.157828380277727
# alpha, M, predM  0.00390625, 7.1290405737070435, 7.1578305544361225
# l2: ||R0||= 6.8288552E-01, f_err=3.528941E+00, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 1.32E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 61.97066661978774, 7.115188318807177
# alpha, M, predM  0.5, 16.727863367541683, 7.115467241215335
# alpha, M, predM  0.25, 13.538082699876835, 7.115606702419414
# alpha, M, predM  0.125, 12.9241017277227, 7.115676433021454
# alpha, M, predM  0.0625, 12.6516901555008, 7.1157112983224735
# alpha, M, predM  0.03125, 12.525295374697142, 7.115728730972983
# alpha, M, predM  0.015625, 12.464651318153093, 7.115737447298238
# alpha, M, predM  0.0078125, 12.434988594306041, 7.115741805460866
# alpha, M, predM  0.00390625, 12.420324570715355, 7.1157439845421795
# alpha, M, predM  0.001953125, 7.1013804971350645, 7.115745074082836
# l2: ||R0||= 6.8155103E-01, f_err=3.52536E+00, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 1.3E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 64.22031884136484, 7.092604825850878
# alpha, M, predM  0.5, 16.935728130768027, 7.092885231570453
# alpha, M, predM  0.25, 13.54554245408136, 7.093025434430241
# alpha, M, predM  0.125, 12.927321179609118, 7.093095535860135
# alpha, M, predM  0.0625, 12.649538593232421, 7.093130586575081
# alpha, M, predM  0.03125, 12.520023442471988, 7.093148111932555
# alpha, M, predM  0.015625, 12.4577477880389, 7.093156874611292
# alpha, M, predM  0.0078125, 12.427255383925374, 7.09316125595066
# alpha, M, predM  0.00390625, 12.412173541570052, 7.093163446620345
# alpha, M, predM  0.001953125, 12.40467407865271, 7.093164541955186
# alpha, M, predM  0.0009765625, 12.400934757353905, 7.093165089622608
# alpha, M, predM  0.00048828125, 12.399067704915888, 7.093165363456318
# alpha, M, predM  0.000244140625, 12.398134831456897, 7.093165500373173
# alpha, M, predM  0.0001220703125, 12.397668558005732, 7.093165568831601
# alpha, M, predM  6.103515625E-05, 12.397435462110696, 7.093165603060815
# alpha, M, predM  3.0517578125E-05, 7.092940836826843, 7.093165620175422
# l2: ||R0||= 6.8153023E-01, f_err=3.525304E+00, f_phi=0E+00, Alpha = 3.05E-05, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 1.29E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 66.00078619369101, 7.087265704006966
# alpha, M, predM  0.5, 17.081184199219596, 7.087547983058772
# alpha, M, predM  0.25, 13.546439598547117, 7.087689122584674
# alpha, M, predM  0.125, 12.925361831286624, 7.087759692347626
# alpha, M, predM  0.0625, 12.644049423736956, 7.087794977229102
# alpha, M, predM  0.03125, 12.512458627578612, 7.087812619669839
# alpha, M, predM  0.015625, 12.449106343537183, 7.087821440890208
# alpha, M, predM  0.0078125, 12.418069378269395, 7.0878258515003925
# alpha, M, predM  0.00390625, 12.402714124744762, 7.087828056805485
# alpha, M, predM  0.001953125, 12.395077727368136, 7.087829159458031
# alpha, M, predM  0.0009765625, 12.391269888335097, 7.0878297107843045
# alpha, M, predM  0.00048828125, 12.389368565242606, 7.08782998644744
# alpha, M, predM  0.000244140625, 12.388418553614363, 7.087830124279009
# alpha, M, predM  0.0001220703125, 12.387943710381137, 7.087830193194793
# alpha, M, predM  6.103515625E-05, 12.387706329422347, 7.0878302276526854
# alpha, M, predM  3.0517578125E-05, 12.387587649109095, 7.087830244881631
# alpha, M, predM  1.52587890625E-05, 7.087717446836935, 7.087830253496104
# l2: ||R0||= 6.8151983E-01, f_err=3.525276E+00, f_phi=0E+00, Alpha = 1.53E-05, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 1.28E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 67.45997127403538, 7.083790503707331
# alpha, M, predM  0.5, 17.201536448137876, 7.084074214616019
# alpha, M, predM  0.25, 13.550002345916562, 7.084216070070363
# alpha, M, predM  0.125, 12.925614250333561, 7.084286997797536
# alpha, M, predM  0.0625, 12.641214253111011, 7.084322461661121
# alpha, M, predM  0.03125, 12.507856094529439, 7.084340193592914
# alpha, M, predM  0.015625, 12.443599424911291, 7.084349059558811
# alpha, M, predM  0.0078125, 12.412108128171331, 7.0843534925417595
# alpha, M, predM  0.00390625, 12.396525556223818, 7.084355709033233
# alpha, M, predM  0.001953125, 12.388775509335476, 7.08435681727897
# alpha, M, predM  0.0009765625, 12.384910853962564, 7.084357371401839
# alpha, M, predM  0.00048828125, 12.382981125553508, 7.084357648463273
# alpha, M, predM  0.000244140625, 12.382016912074059, 7.08435778699399
# alpha, M, predM  0.0001220703125, 12.381534968128664, 7.0843578562593486
# alpha, M, predM  6.103515625E-05, 12.381294036868683, 7.084357890892028
# alpha, M, predM  3.0517578125E-05, 12.381173581418679, 7.084357908208368
# alpha, M, predM  1.52587890625E-05, 12.3811133562389, 7.084357916866537
# alpha, M, predM  7.62939453125E-06, 12.381083244285259, 7.084357921195623
# alpha, M, predM  3.814697265625E-06, 12.3810681884676, 7.084357923360165
# alpha, M, predM  1.9073486328125E-06, 12.381060660598477, 7.084357924442436
# alpha, M, predM  9.5367431640625E-07, 7.08435085368349, 7.084357924983571
# l2: ||R0||= 6.8151918E-01, f_err=3.525274E+00, f_phi=0E+00, Alpha = 9.54E-07, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 1.28E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 68.63685160946703, 7.081602694267633
# alpha, M, predM  0.5, 17.299236465385828, 7.081887498019361
# alpha, M, predM  0.25, 13.554735406520281, 7.0820298998952245
# alpha, M, predM  0.125, 12.927002038776772, 7.082101100833156
# alpha, M, predM  0.0625, 12.63997537426593, 7.082136701302122
# alpha, M, predM  0.03125, 12.505146658668687, 7.082154501536605
# alpha, M, predM  0.015625, 12.440146033178044, 7.082163401653847
# alpha, M, predM  0.0078125, 12.408283184648502, 7.082167851712467
# alpha, M, predM  0.00390625, 12.392515272408216, 7.082170076741778
# alpha, M, predM  0.001953125, 12.384672705696879, 7.0821711892564325
# alpha, M, predM  0.0009765625, 12.380761833189595, 7.082171745513761
# alpha, M, predM  0.00048828125, 12.378809007558319, 7.082172023642424
# alpha, M, predM  0.000244140625, 12.377833248385262, 7.082172162706756
# alpha, M, predM  0.0001220703125, 12.377345532332713, 7.082172232238922
# alpha, M, predM  6.103515625E-05, 12.377101715205383, 7.082172267005005
# alpha, M, predM  3.0517578125E-05, 12.376979816868321, 7.082172284388046
# alpha, M, predM  1.52587890625E-05, 12.376918870256665, 7.082172293079568
# alpha, M, predM  7.62939453125E-06, 12.376888397590113, 7.082172297425328
# alpha, M, predM  3.814697265625E-06, 12.376873161416698, 7.0821722995982075
# alpha, M, predM  1.9073486328125E-06, 12.37686554336991, 7.082172300684648
# alpha, M, predM  9.5367431640625E-07, 12.376861734356511, 7.082172301227868
# alpha, M, predM  4.76837158203125E-07, 12.376859829852304, 7.082172301499478
# alpha, M, predM  2.384185791015625E-07, 7.082170529638579, 7.082172301635283
# l2: ||R0||= 6.8151902E-01, f_err=3.525274E+00, f_phi=0E+00, Alpha = 2.38E-07, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.27E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 69.56137653660608, 7.080196755804165
# alpha, M, predM  0.5, 17.376443039339033, 7.080482378324911
# alpha, M, predM  0.25, 13.559746578460153, 7.080625189585284
# alpha, M, predM  0.125, 12.928817793208424, 7.08069659521547
# alpha, M, predM  0.0625, 12.639639956272207, 7.080732298030564
# alpha, M, predM  0.03125, 12.503626928293793, 7.08075014943811
# alpha, M, predM  0.015625, 12.43803235497306, 7.080759075141883
# alpha, M, predM  0.0078125, 12.405874217234881, 7.080763537993771
# alpha, M, predM  0.00390625, 12.389959353902476, 7.080765769419713
# alpha, M, predM  0.001953125, 12.382043519440789, 7.080766885132685
# alpha, M, predM  0.0009765625, 12.378096069333623, 7.080767442989171
# alpha, M, predM  0.00048828125, 12.376124969513434, 7.080767721917414
# alpha, M, predM  0.000244140625, 12.375140076966668, 7.080767861381536
# alpha, M, predM  0.0001220703125, 12.374647795165952, 7.080767931113596
# alpha, M, predM  6.103515625E-05, 12.374401695400204, 7.080767965979627
# alpha, M, predM  3.0517578125E-05, 12.374278655803035, 7.080767983412642
# alpha, M, predM  1.52587890625E-05, 12.374217138576167, 7.080767992129149
# alpha, M, predM  7.62939453125E-06, 12.374186380605634, 7.080767996487403
# alpha, M, predM  3.814697265625E-06, 12.374171001781132, 7.08076799866653
# alpha, M, predM  1.9073486328125E-06, 12.374163312409053, 7.080767999756094
# alpha, M, predM  9.5367431640625E-07, 12.37415946773305, 7.080768000300875
# alpha, M, predM  4.76837158203125E-07, 12.374157545397573, 7.080768000573266
# alpha, M, predM  2.384185791015625E-07, 12.374156584230446, 7.080768000709462
# alpha, M, predM  1.1920928955078125E-07, 12.374156103647072, 7.080768000777559
# alpha, M, predM  5.960464477539063E-08, 7.08076755700376, 7.080768000811608
# l2: ||R0||= 6.8151897E-01, f_err=3.525274E+00, f_phi=0E+00, Alpha = 5.96E-08, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 1.27E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 7.059016954801672, 8.22964115554576
# l2: ||R0||= 5.6924947E-01, f_err=3.27875E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 2.96E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 8.798959248564886, 7.253594698111861
# alpha, M, predM  0.5, 6.105717198305069, 7.253812025109669
# l2: ||R0||= 4.4348946E-01, f_err=3.198425E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 2.23E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 113.9897380528211, 5.584793896905285
# alpha, M, predM  0.5, 19.449484863439917, 5.584991255930629
# alpha, M, predM  0.25, 13.464459039868878, 5.585089935443301
# alpha, M, predM  0.125, 12.283258815133427, 5.585139275199637
# alpha, M, predM  0.0625, 11.899595004758321, 5.585163945077805
# alpha, M, predM  0.03125, 11.736621484224912, 5.5851762800168885
# alpha, M, predM  0.015625, 11.661776588834911, 5.585182447486431
# alpha, M, predM  0.0078125, 11.625952635436862, 5.585185531221202
# alpha, M, predM  0.00390625, 11.608433020824725, 5.585187073088587
# alpha, M, predM  0.001953125, 11.599770427860154, 5.58518784402228
# alpha, M, predM  0.0009765625, 11.595463327453981, 5.585188229489127
# alpha, M, predM  0.00048828125, 11.593315812958709, 5.58518842222255
# alpha, M, predM  0.000244140625, 11.592243562982192, 5.585188518589261
# alpha, M, predM  0.0001220703125, 11.591707814605225, 5.585188566772617
# alpha, M, predM  6.103515625E-05, 11.59144003454378, 5.585188590864295
# alpha, M, predM  3.0517578125E-05, 11.5913061680416, 5.585188602910134
# alpha, M, predM  1.52587890625E-05, 11.591239240672275, 5.585188608933054
# alpha, M, predM  7.62939453125E-06, 11.59120577845794, 5.585188611944513
# alpha, M, predM  3.814697265625E-06, 11.5911890477184, 5.585188613450243
# alpha, M, predM  1.9073486328125E-06, 11.591180682440498, 5.5851886142031075
# alpha, M, predM  9.5367431640625E-07, 11.591176499824547, 5.585188614579541
# alpha, M, predM  4.76837158203125E-07, 11.591174408522305, 5.585188614767756
# alpha, M, predM  2.384185791015625E-07, 11.5911733628726, 5.585188614861865
# alpha, M, predM  1.1920928955078125E-07, 11.591172840048118, 5.585188614908919
# alpha, M, predM  5.960464477539063E-08, 5.585188323235611, 5.585188614932446
# l2: ||R0||= 4.3740936E-01, f_err=3.195451E+00, f_phi=0E+00, Alpha = 5.96E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.1E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 8.89087869246644, 6.25126611102762
# alpha, M, predM  0.5, 6.388838923716996, 6.251283825618563
# alpha, M, predM  0.25, 6.094797228046469, 6.251292682914033
# l2: ||R0||= 4.1872541E-01, f_err=3.161611E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 2.62E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.015990985839108 > 1.005 so we continue
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 5.593401002837706, 6.1776090135581825
# l2: ||R0||= 2.7584485E-01, f_err=3.103616E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 2.82E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0186603921344075 > 1.005 so we continue
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 10.036215564355086, 5.531614589956659
# alpha, M, predM  0.5, 5.937656960048024, 5.531633764670068
# alpha, M, predM  0.25, 5.31338539215201, 5.531643352026772
# l2: ||R0||= 2.4418244E-01, f_err=3.062042E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 2.56E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0205999715242269 > 1.005 so we continue
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 5.161140726050457, 5.412655154843104
# l2: ||R0||= 1.570171E-01, f_err=3.064381E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.97E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0205999670162116 > 1.005 so we continue
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 6.3709242148072684, 5.154845410221615
# alpha, M, predM  0.5, 5.367516128924009, 5.154853478987918
# alpha, M, predM  0.25, 5.176061441846818, 5.15485751337107
# alpha, M, predM  0.125, 5.113548815183627, 5.1548595305626455
# l2: ||R0||= 1.9984824E-01, f_err=3.032717E+00, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.58E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0112401752404787 > 1.005 so we continue
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 5.470461871409082, 5.050819121450342
# alpha, M, predM  0.5, 5.058068980173645, 5.050807785853628
# alpha, M, predM  0.25, 4.997451791612885, 5.050802118055272
# l2: ||R0||= 1.4160067E-01, f_err=3.039693E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.67E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0076524675823424 > 1.005 so we continue
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 8.439291998707358, 4.993274353269548
# alpha, M, predM  0.5, 5.738762059259009, 4.9932832590735625
# alpha, M, predM  0.25, 5.0344142831002445, 4.99328771197557
# alpha, M, predM  0.125, 4.963376445719879, 4.993289938426573
# l2: ||R0||= 1.4063804E-01, f_err=3.030673E+00, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.64E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0076158013521732 > 1.005 so we continue
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 5.155767870244778, 5.000139135991219
# alpha, M, predM  0.5, 4.988149294707554, 5.000119700223488
# l2: ||R0||= 1.2711118E-01, f_err=3.039653E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.9E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.0060867743322666 > 1.005 so we continue
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 75.06726472813506, 4.762247182278953
# alpha, M, predM  0.5, 18.512784778439837, 4.762414000054771
# alpha, M, predM  0.25, 13.022640218083355, 4.7624974089426795
# alpha, M, predM  0.125, 11.721752303777325, 4.762539113386634
# alpha, M, predM  0.0625, 11.321022855897509, 4.76255996560861
# alpha, M, predM  0.03125, 11.171735485080264, 4.762570391719599
# alpha, M, predM  0.015625, 11.102341234408897, 4.762575604775094
# alpha, M, predM  0.0078125, 11.06898864523569, 4.7625782113028405
# alpha, M, predM  0.00390625, 11.052645165592828, 4.762579514566714
# alpha, M, predM  0.001953125, 11.044556218822358, 4.762580166198651
# alpha, M, predM  0.0009765625, 11.040532392627801, 4.76258049201462
# alpha, M, predM  0.00048828125, 11.03854395805563, 4.762580654922604
# alpha, M, predM  0.000244140625, 11.037573979022484, 4.762580736376596
# alpha, M, predM  0.0001220703125, 11.037089295401152, 4.762580777103592
# alpha, M, predM  6.103515625E-05, 11.036847030050719, 4.7625807974670895
# alpha, M, predM  3.0517578125E-05, 11.036725916488894, 4.762580807648839
# alpha, M, predM  1.52587890625E-05, 11.036665364486105, 4.762580812739714
# alpha, M, predM  7.62939453125E-06, 11.036635089679207, 4.76258081528515
# alpha, M, predM  3.814697265625E-06, 11.036619952574412, 4.762580816557869
# alpha, M, predM  1.9073486328125E-06, 11.036612384096658, 4.7625808171942285
# alpha, M, predM  9.5367431640625E-07, 11.036608599876443, 4.762580817512409
# alpha, M, predM  4.76837158203125E-07, 11.036606707770988, 4.762580817671498
# alpha, M, predM  2.384185791015625E-07, 11.036605761719445, 4.762580817751043
# alpha, M, predM  1.1920928955078125E-07, 11.036605288693933, 4.762580817790815
# alpha, M, predM  5.960464477539063E-08, 4.762580601940859, 4.762580817810702
# l2: ||R0||= 1.2711118E-01, f_err=3.039653E+00, f_phi=0E+00, Alpha = 5.96E-08, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 1.12E+00, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1.0034172962886243 <= 1.005 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 0 to 1              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 3.6190596E+00, f_err=6.650164E+00, f_phi=0E+00,
#  current DGdegree=1, min It.:15, MaxReInit:20, ReInitTol:-0.2, TermN:8, tALNR:1.005
#
# ################################################################################################
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 109.0470452677099, 43.7743152799399
# alpha, M, predM  0.5, 17.09773493963029, 43.77531099354145
# l2: ||R0||= 1.8635155E+00, f_err=3.447488E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.99E+00, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 0.8560663472706866, 12.448742024755436
# l2: ||R0||= 2.5894161E-01, f_err=7.698021E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.16E+00, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 0.2020242443362268, 0.36695408898606097
# l2: ||R0||= 2.2417547E-01, f_err=5.306956E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.73E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
# Reinitialized Cells:(95 R) ,
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 7.229351480378232, 0.2122309588427621
# alpha, M, predM  0.5, 5.195375450370056, 0.21223644332989336
# alpha, M, predM  0.25, 0.15111629513244423, 0.212239185573459
# l2: ||R0||= 1.7086086E-01, f_err=4.50632E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.9E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 8.810163792936518, 0.14868805160402493
# alpha, M, predM  0.5, 6.010387934037138, 0.14869004518998008
# alpha, M, predM  0.25, 5.1346811076884356, 0.14869104198295766
# alpha, M, predM  0.125, 4.75177791193683, 0.14869154037944643
# alpha, M, predM  0.0625, 0.14171142589208413, 0.14869178957769083
# l2: ||R0||= 1.6219555E-01, f_err=4.370096E-01, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.85E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 9.509099802896019, 0.1419438316455451
# alpha, M, predM  0.5, 6.26590970334065, 0.14194557793922133
# alpha, M, predM  0.25, 5.338856524812114, 0.14194645108605947
# alpha, M, predM  0.125, 4.939155528372066, 0.14194688765947852
# alpha, M, predM  0.0625, 4.752919996461254, 0.14194710594618803
# alpha, M, predM  0.03125, 4.663052822951342, 0.1419472150895428
# alpha, M, predM  0.015625, 4.6189151864358, 0.1419472696612202
# alpha, M, predM  0.0078125, 0.14094725908087866, 0.14194729694705888
# l2: ||R0||= 1.6092452E-01, f_err=4.355518E-01, f_phi=0E+00, Alpha = 7.81E-03, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 2.86E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 10.357484766297215, 0.14024776370141434
# alpha, M, predM  0.5, 6.426400766342293, 0.14024954831170408
# alpha, M, predM  0.25, 5.411731816370834, 0.14025044061684896
# alpha, M, predM  0.125, 4.979645617102313, 0.1402508867694214
# alpha, M, predM  0.0625, 4.779395407366999, 0.14025110984570763
# alpha, M, predM  0.03125, 4.682998037249294, 0.14025122138385074
# alpha, M, predM  0.015625, 4.635718546744562, 0.1402512771529223
# alpha, M, predM  0.0078125, 4.61230112716713, 0.14025130503745808
# alpha, M, predM  0.00390625, 0.13975681791165087, 0.14025131897972595
# l2: ||R0||= 1.6029484E-01, f_err=4.348237E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.82E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 11.04032657984156, 0.13926349943658828
# alpha, M, predM  0.5, 6.543208632835767, 0.13926532140125886
# alpha, M, predM  0.25, 5.461822639920937, 0.13926623238359412
# alpha, M, predM  0.125, 5.005324523878775, 0.13926668787476176
# alpha, M, predM  0.0625, 4.794706677166032, 0.1392669156203456
# alpha, M, predM  0.03125, 4.693504861791763, 0.1392670294931375
# alpha, M, predM  0.015625, 4.64391818843388, 0.13926708642953345
# alpha, M, predM  0.0078125, 4.619369736101113, 0.13926711489773144
# alpha, M, predM  0.00390625, 4.607156203463516, 0.13926712913183042
# alpha, M, predM  0.001953125, 0.13902111921125, 0.1392671362488799
# l2: ||R0||= 1.5998147E-01, f_err=4.344588E-01, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 2.79E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 11.557085387338978, 0.13867792299886822
# alpha, M, predM  0.5, 6.625828077089966, 0.13867977581954558
# alpha, M, predM  0.25, 5.495371996607159, 0.13868070222988424
# alpha, M, predM  0.125, 5.021537210005505, 0.13868116543505357
# alpha, M, predM  0.0625, 4.803507720036171, 0.13868139703763824
# alpha, M, predM  0.03125, 4.698887500059775, 0.13868151283893057
# alpha, M, predM  0.015625, 4.647657976609937, 0.13868157073957674
# alpha, M, predM  0.0078125, 4.622306240898637, 0.13868159968989982
# alpha, M, predM  0.00390625, 4.609695176250047, 0.13868161416506136
# alpha, M, predM  0.001953125, 4.603405778969567, 0.13868162140264212
# alpha, M, predM  0.0009765625, 4.600265105892095, 0.13868162502143253
# alpha, M, predM  0.00048828125, 0.1386202601807301, 0.13868162683082771
# l2: ||R0||= 1.5990334E-01, f_err=4.343673E-01, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.77E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 11.928826961872627, 0.13838717781669913
# alpha, M, predM  0.5, 6.6813753974882095, 0.13838905693323672
# alpha, M, predM  0.25, 5.516170956815893, 0.13838999649150552
# alpha, M, predM  0.125, 5.0302026214121245, 0.13839046627063992
# alpha, M, predM  0.0625, 4.8070214275173475, 0.13839070116020713
# alpha, M, predM  0.03125, 4.700033115850809, 0.13839081860499072
# alpha, M, predM  0.015625, 4.647667704945194, 0.1383908773273825
# alpha, M, predM  0.0078125, 4.621760775916997, 0.13839090668857842
# ...
# alpha, M, predM  0.015625, 4.022955900994123, 0.034343741566266295
# alpha, M, predM  0.0078125, 4.011693578214251, 0.03434377516403711
# alpha, M, predM  0.00390625, 4.006077747601967, 0.03434379196292252
# alpha, M, predM  0.001953125, 4.003273658056696, 0.03434380036236522
# alpha, M, predM  0.0009765625, 4.001872568870137, 0.03434380456208657
# alpha, M, predM  0.00048828125, 4.0011722630676, 0.03434380666194725
# alpha, M, predM  0.000244140625, 4.000822169850581, 0.03434380771187759
# alpha, M, predM  0.0001220703125, 4.000647138161694, 0.03434380823684276
# alpha, M, predM  6.103515625E-05, 4.000559626046964, 0.03434380849932534
# alpha, M, predM  3.0517578125E-05, 4.000515870921973, 0.03434380863056663
# alpha, M, predM  1.52587890625E-05, 0.034342910462332045, 0.03434380869618728
# l2: ||R0||= 6.7692434E-02, f_err=2.29825E-01, f_phi=0E+00, Alpha = 1.53E-05, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 1.17E-01, QuadOrder=8
#
# ALNR=1 <= 1.001 so we terminate/increase degree
# ALNR=1.0947859102535522 > 1.001 so we continue
#
#
# Starting Opt-Iter No.62:
# alpha, M, predM  1, 5.9044800965921125, 0.034411064919531394
# alpha, M, predM  0.5, 4.820127664657747, 0.03441321646729764
# alpha, M, predM  0.25, 4.386350891909003, 0.03441429224118076
# alpha, M, predM  0.125, 4.18879631873521, 0.03441483012812232
# alpha, M, predM  0.0625, 4.094306684402619, 0.034415099071593104
# alpha, M, predM  0.03125, 4.04808867247333, 0.03441523354332849
# alpha, M, predM  0.015625, 4.025231889005143, 0.03441530077919619
# alpha, M, predM  0.0078125, 4.013866049331179, 0.034415334397130036
# alpha, M, predM  0.00390625, 4.00819870797479, 0.034415351206096956
# alpha, M, predM  0.001953125, 4.00536892468475, 0.03441535961058042
# alpha, M, predM  0.0009765625, 4.003955003995837, 0.034415363812822154
# alpha, M, predM  0.00048828125, 4.00324828627987, 0.034415365913943015
# alpha, M, predM  0.000244140625, 4.00289498806518, 0.03441536696450345
# alpha, M, predM  0.0001220703125, 4.002718354117092, 0.03441536748978367
# alpha, M, predM  6.103515625E-05, 4.00263004093253, 0.03441536775242377
# alpha, M, predM  3.0517578125E-05, 4.002585885287579, 0.03441536788374383
# alpha, M, predM  1.52587890625E-05, 4.002563807701968, 0.034415367949403856
# alpha, M, predM  7.62939453125E-06, 0.034414917561874966, 0.034415367982233866
# l2: ||R0||= 6.7691918E-02, f_err=2.298233E-01, f_phi=0E+00, Alpha = 7.63E-06, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 1.18E-01, QuadOrder=8
#
# ALNR=1 <= 1.001 so we terminate/increase degree
# ALNR=1.094786963380402 > 1.001 so we continue
#
#
# Starting Opt-Iter No.63:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         309.21241503172337
#     L2 Norm of Solution:    0.1345969136147965
#     L2 Norm of Residual:    0.0035629378509280077
#     Relative Residual norm: 3.249046890437289E-10
#     Matrix Inf norm:        10966101.663274156
# alpha, M, predM  1, 5.921497063162604, 0.03445991265615123
# alpha, M, predM  0.5, 4.827138646974889, 0.0344620650753011
# alpha, M, predM  0.25, 4.390227578480655, 0.034463141284876035
# alpha, M, predM  0.125, 4.191370250427902, 0.0344636793896635
# alpha, M, predM  0.0625, 4.096280513039122, 0.03446394844205723
# alpha, M, predM  0.03125, 4.049774061249797, 0.034464082968254095
# alpha, M, predM  0.015625, 4.026775840180679, 0.03446415023135253
# alpha, M, predM  0.0078125, 4.015339963345059, 0.034464183862901746
# alpha, M, predM  0.00390625, 4.009637772141041, 0.03446420067867636
# alpha, M, predM  0.001953125, 4.006790605905292, 0.03446420908656366
# alpha, M, predM  0.0009765625, 4.005368004212576, 0.03446421329050731
# alpha, M, predM  0.00048828125, 4.004656948608697, 0.03446421539247914
# alpha, M, predM  0.000244140625, 4.00430148210326, 0.03446421644346505
# alpha, M, predM  0.0001220703125, 4.004123764172935, 0.03446421696895801
# alpha, M, predM  6.103515625E-05, 4.004034909038058, 0.03446421723170449
# alpha, M, predM  3.0517578125E-05, 4.003990482428241, 0.034464217363077726
# alpha, M, predM  1.52587890625E-05, 4.0039682693627725, 0.03446421742876434
# alpha, M, predM  7.62939453125E-06, 4.00395716288975, 0.03446421746160765
# alpha, M, predM  3.814697265625E-06, 0.03446399182489767, 0.03446421747802931
# l2: ||R0||= 6.769166E-02, f_err=2.298225E-01, f_phi=0E+00, Alpha = 3.81E-06, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 1.19E-01, QuadOrder=8
#
# ALNR=1 <= 1.001 so we terminate/increase degree
#
# ALNR=1.000689689259338 <= 1.001 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 2 to 3              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 1.9984374E+00, f_err=2.722946E+00, f_phi=0E+00,
#  current DGdegree=3, min It.:10, MaxReInit:5, ReInitTol:-0.2, TermN:8, tALNR:1.01
#
# ################################################################################################
#
#
# Starting Opt-Iter No.64:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         10021.556511806664
#     L2 Norm of Solution:    13.210674489779608
#     L2 Norm of Residual:    2.768261099260579
#     Relative Residual norm: 2.0093135891934704E-09
#     Matrix Inf norm:        1377714814.725235
# alpha, M, predM  1, 1118.3724280152162, 28.10693665103374
# alpha, M, predM  0.5, 331.18854224148504, 28.106036424578118
# alpha, M, predM  0.25, 6.954587898620399, 28.105586311350304
# l2: ||R0||= 5.2872267E-01, f_err=9.996785E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.22E+01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.65:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         215693.976366625
#     L2 Norm of Solution:    1.4277163947966083
#     L2 Norm of Residual:    4.715233696736733
#     Relative Residual norm: 1.0694712336787179E-10
#     Matrix Inf norm:        44089392479.66015
# alpha, M, predM  1, 4.153511028575534, 2.915038070789118
# alpha, M, predM  0.5, 3.9017621025784246, 2.9151495616827683
# alpha, M, predM  0.25, 3.312893171492541, 2.9152053071295936
# alpha, M, predM  0.125, 3.092262864143614, 2.915233179853006
# alpha, M, predM  0.0625, 2.9984403785032208, 2.915247116214712
# alpha, M, predM  0.03125, 2.9555299733220908, 2.915254084395565
# alpha, M, predM  0.015625, 2.935067488832582, 2.915257568485992
# alpha, M, predM  0.0078125, 2.925082433013949, 2.915259310531205
# alpha, M, predM  0.00390625, 2.9201513197026667, 2.915260181553812
# alpha, M, predM  0.001953125, 2.91770109329739, 2.915260617065115
# alpha, M, predM  0.0009765625, 2.916479800080474, 2.9152608348207667
# alpha, M, predM  0.00048828125, 2.915870108154659, 2.9152609436985926
# alpha, M, predM  0.000244140625, 2.915565500830982, 2.9152609981375055
# alpha, M, predM  0.0001220703125, 2.9154132568209423, 2.915261025356962
# alpha, M, predM  6.103515625E-05, 2.915337149725546, 2.9152610389666904
# alpha, M, predM  3.0517578125E-05, 2.915299099908953, 2.915261045771554
# alpha, M, predM  1.52587890625E-05, 2.915280075929937, 2.9152610491739863
# alpha, M, predM  7.62939453125E-06, 2.9152705641774084, 2.9152610508752024
# alpha, M, predM  3.814697265625E-06, 2.9152658083528293, 2.9152610517258104
# alpha, M, predM  1.9073486328125E-06, 2.9152634304586695, 2.9152610521511146
# alpha, M, predM  9.5367431640625E-07, 2.9152622415203684, 2.9152610523637663
# alpha, M, predM  4.76837158203125E-07, 2.9152616470475805, 2.9152610524700924
# alpha, M, predM  2.384185791015625E-07, 2.915261349810076, 2.9152610525232556
# alpha, M, predM  1.1920928955078125E-07, 2.915261201193791, 2.915261052549837
# alpha, M, predM  5.960464477539063E-08, 2.9152611268825854, 2.9152610525631277
# alpha, M, predM  2.9802322387695312E-08, 2.9152610897285394, 2.915261052569773
# alpha, M, predM  1.4901161193847656E-08, 2.915261071157826, 2.9152610525730958
# l2: ||R0||= 6.9721239E-01, f_err=2.141386E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.93E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.66:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         301787.7714022798
#     L2 Norm of Solution:    0.8274818243574349
#     L2 Norm of Residual:    90.69405313835227
#     Relative Residual norm: 2.0743249025197413E-09
#     Matrix Inf norm:        43722202355.17764
# alpha, M, predM  1, 0.3389497704836499, 2.4544834647091283
# l2: ||R0||= 2.1635996E-01, f_err=7.597738E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 2.33E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.67:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         31585.868960129115
#     L2 Norm of Solution:    7.239983825578948
#     L2 Norm of Residual:    513.0511423906793
#     Relative Residual norm: 6.895832455863028E-08
#     Matrix Inf norm:        7440017513.106325
# alpha, M, predM  1, 180.42321445283272, 0.35466870262489775
# alpha, M, predM  0.5, 0.09615432385788741, 0.35469427773058076
# l2: ||R0||= 1.031307E-01, f_err=3.595855E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.05E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.68:
# alpha, M, predM  1, 0.006382569558099715, 0.08061139092562106
# l2: ||R0||= 1.9221709E-02, f_err=8.253131E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 1.55E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.69:
# alpha, M, predM  1, 0.0015501858048294207, 0.006483410924894937
# l2: ||R0||= 7.1288944E-03, f_err=2.858724E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 1.6E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.70:
# alpha, M, predM  1, 0.002908210719936271, 0.0015528766918847519
# alpha, M, predM  0.5, 0.0015401593238898498, 0.0015528365834101758
# l2: ||R0||= 6.7547352E-03, f_err=3.020034E-02, f_phi=0E+00, Alpha = 5E-01, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 1.6E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.71:
# alpha, M, predM  1, 0.000727940573712788, 0.0015119395568573004
# l2: ||R0||= 2.6959708E-03, f_err=2.476007E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 1.56E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.72:
# alpha, M, predM  1, 0.0022676282861812183, 0.0007322663782087299
# alpha, M, predM  0.5, 0.0010989365639168889, 0.0007322488400236891
# alpha, M, predM  0.25, 0.0007229523313740182, 0.0007322400709311687
# l2: ||R0||= 2.6565717E-03, f_err=2.463626E-02, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 1.58E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.73:
# alpha, M, predM  1, 0.0006112603666137465, 0.0007429270760127464
# l2: ||R0||= 1.8344559E-03, f_err=2.48125E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 1.65E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
# ALNR=1.547323456041307 > 1.01 so we continue
#
#
# Starting Opt-Iter No.74:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         135.74231950414742
#     L2 Norm of Solution:    1.0072234822007282
#     L2 Norm of Residual:    18.861462114505574
#     Relative Residual norm: 5.509061809351636E-10
#     Matrix Inf norm:        34237158280.722553
# alpha, M, predM  1, 291.45811966968216, 0.000569649213701136
# alpha, M, predM  0.5, 218.58211493137122, 0.0005696419466200383
# alpha, M, predM  0.25, 188.59846956338328, 0.0005696383130794894
# alpha, M, predM  0.125, 175.01874993589274, 0.0005696364963092151
# alpha, M, predM  0.0625, 0.0005471524406582067, 0.0005696355879240778
# l2: ||R0||= 1.7262885E-03, f_err=2.452692E-02, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.43E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
# ALNR=1.5479603181733654 > 1.01 so we continue
#
#
# Starting Opt-Iter No.75:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         130.16802660293845
#     L2 Norm of Solution:    0.40789456145637365
#     L2 Norm of Residual:    14.373228439926395
#     Relative Residual norm: 4.32292578156942E-10
#     Matrix Inf norm:        33248843876.07565
# alpha, M, predM  1, 361.74381133524713, 0.0005397428866009853
# alpha, M, predM  0.5, 248.98365927179793, 0.0005397366689082918
# alpha, M, predM  0.25, 205.29474584014648, 0.000539733560061945
# alpha, M, predM  0.125, 186.11176249176916, 0.0005397320056387717
# alpha, M, predM  0.0625, 177.12908407995633, 0.0005397312284271849
# alpha, M, predM  0.03125, 0.000529062041005703, 0.0005397308398213917
# l2: ||R0||= 1.6746397E-03, f_err=2.438301E-02, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 1.38E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
# ALNR=1.2938506077822256 > 1.01 so we continue
#
#
# Starting Opt-Iter No.76:
# alpha, M, predM  1, 0.0012831539683105582, 0.0005567714937267159
# alpha, M, predM  0.5, 0.0007859577541844791, 0.0005567615223382945
# alpha, M, predM  0.25, 0.0006048142750276063, 0.0005567565366440837
# alpha, M, predM  0.125, 0.0005444592651129194, 0.0005567540437969783
# l2: ||R0||= 1.6502266E-03, f_err=2.403148E-02, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 1.55E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
# ALNR=1.02636908309692 > 1.01 so we continue
#
#
# Starting Opt-Iter No.77:
# alpha, M, predM  1, 0.000938423802859287, 0.0005482786513815205
# alpha, M, predM  0.5, 0.0006024894788699837, 0.0005482662007078513
# alpha, M, predM  0.25, 0.0005334985443723585, 0.0005482599753710166
# l2: ||R0||= 1.5687957E-03, f_err=2.395019E-02, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 1.57E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
# ALNR=1.0268539589502697 > 1.01 so we continue
#
#
# Starting Opt-Iter No.78:
# alpha, M, predM  1, 0.002667458537086679, 0.0005503503824357493
# alpha, M, predM  0.5, 0.001206612936359772, 0.0005503362810201469
# alpha, M, predM  0.25, 0.0007079553713892999, 0.0005503292303123457
# alpha, M, predM  0.125, 0.0005942607405238998, 0.0005503257049584452
# alpha, M, predM  0.0625, 0.000558860220554677, 0.0005503239422814948
# alpha, M, predM  0.03125, 0.000548492755911646, 0.0005503230609430198
# l2: ||R0||= 1.5516314E-03, f_err=2.399415E-02, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 1.68E-01, QuadOrder=10
#
# ALNR=1 <= 1.01 so we terminate/increase degree
#
# ALNR=1.004772484964493 <= 1.01 so we terminate/increase degree

# %% [markdown]
# the resulting residual plot shows respective residuals corresponding to the polynomial degrees

# %%
pCSB.GetResPlot().ToGnuplot().SaveToSVG("resplotCSB.svg",xRes:1200,yRes:500);
pCSB.GetResPlot().ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L62.9,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(45.6,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-14</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,417.0 L58.4,417.0 M1150.1,417.0 L1145.6,417.0 M53.9,391.6 L62.9,391.6 M1150.1,391.6 L1141.1,391.6
# 		 '/>	<g transform="translate(45.6,397.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-12</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,366.2 L58.4,366.2 M1150.1,366.2 L1145.6,366.2 M53.9,340.8 L62.9,340.8 M1150.1,340.8 L1141.1,340.8
# 		 '/>	<g transform="translate(45.6,346.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-10</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,315.4 L58.4,315.4 M1150.1,315.4 L1145.6,315.4 M53.9,290.0 L62.9,290.0 M1150.1,290.0 L1141.1,290.0
# 		 '/>	<g transform="translate(45.6,296.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,264.6 L58.4,264.6 M1150.1,264.6 L1145.6,264.6 M53.9,239.2 L62.9,239.2 M1150.1,239.2 L1141.1,239.2
# 		 '/>	<g transform="translate(45.6,245.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,213.9 L58.4,213.9 M1150.1,213.9 L1145.6,213.9 M53.9,188.5 L62.9,188.5 M1150.1,188.5 L1141.1,188.5
# 		 '/>	<g transform="translate(45.6,194.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,163.1 L58.4,163.1 M1150.1,163.1 L1145.6,163.1 M53.9,137.7 L62.9,137.7 M1150.1,137.7 L1141.1,137.7
# 		 '/>	<g transform="translate(45.6,143.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,112.3 L58.4,112.3 M1150.1,112.3 L1145.6,112.3 M53.9,86.9 L62.9,86.9 M1150.1,86.9 L1141.1,86.9
# 		 '/>	<g transform="translate(45.6,92.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,61.5 L58.4,61.5 M1150.1,61.5 L1145.6,61.5 M53.9,36.1 L62.9,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(45.6,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L53.9,433.4 M53.9,36.1 L53.9,45.1  '/>	<g transform="translate(53.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M190.9,442.4 L190.9,433.4 M190.9,36.1 L190.9,45.1  '/>	<g transform="translate(190.9,464.9)" stroke="none" fill="black"

# %% [markdown]
# Resplot using the highest degree

# %%
var siCSB= database.Sessions.Pick(0);
pCSB.GetUniformResPlot(siCSB).ToGnuplot().SaveToSVG("resplotCSBUniorm.svg",xRes:1200,yRes:500);
pCSB.GetUniformResPlot(siCSB).ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,422.0 L50.1,422.0 M1150.1,422.0 L1145.6,422.0 M45.6,395.1 L50.1,395.1 M1150.1,395.1 L1145.6,395.1
# 		M45.6,381.2 L50.1,381.2 M1150.1,381.2 L1145.6,381.2 M45.6,374.7 L54.6,374.7 M1150.1,374.7 L1141.1,374.7
# 		 '/>	<g transform="translate(37.3,380.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,354.3 L50.1,354.3 M1150.1,354.3 L1145.6,354.3 M45.6,327.4 L50.1,327.4 M1150.1,327.4 L1145.6,327.4
# 		M45.6,313.5 L50.1,313.5 M1150.1,313.5 L1145.6,313.5 M45.6,307.0 L54.6,307.0 M1150.1,307.0 L1141.1,307.0
# 		 '/>	<g transform="translate(37.3,313.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,286.6 L50.1,286.6 M1150.1,286.6 L1145.6,286.6 M45.6,259.6 L50.1,259.6 M1150.1,259.6 L1145.6,259.6
# 		M45.6,245.8 L50.1,245.8 M1150.1,245.8 L1145.6,245.8 M45.6,239.3 L54.6,239.3 M1150.1,239.3 L1141.1,239.3
# 		 '/>	<g transform="translate(37.3,245.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,218.9 L50.1,218.9 M1150.1,218.9 L1145.6,218.9 M45.6,191.9 L50.1,191.9 M1150.1,191.9 L1145.6,191.9
# 		M45.6,178.1 L50.1,178.1 M1150.1,178.1 L1145.6,178.1 M45.6,171.5 L54.6,171.5 M1150.1,171.5 L1141.1,171.5
# 		 '/>	<g transform="translate(37.3,177.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,151.1 L50.1,151.1 M1150.1,151.1 L1145.6,151.1 M45.6,124.2 L50.1,124.2 M1150.1,124.2 L1145.6,124.2
# 		M45.6,110.4 L50.1,110.4 M1150.1,110.4 L1145.6,110.4 M45.6,103.8 L54.6,103.8 M1150.1,103.8 L1141.1,103.8
# 		 '/>	<g transform="translate(37.3,109.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,83.4 L50.1,83.4 M1150.1,83.4 L1145.6,83.4 M45.6,56.5 L50.1,56.5 M1150.1,56.5 L1145.6,56.5
# 		M45.6,42.7 L50.1,42.7 M1150.1,42.7 L1145.6,42.7 M45.6,36.1 L54.6,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M183.7,442.4 L183.7,433.4 M183.7,36.1 L183.7,45.1  '/>	<g transform="translate(183.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M321.7,442.4 L321.7,433.4 M321.7,36.1 L321.7,45.1  '/>	<g transform="translate(321.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan fon

# %% [markdown]
# plot shadowfields

# %%
pCSB.PlotShadowFields(siCSB);
