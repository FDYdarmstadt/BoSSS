# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\SAIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using SAIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %% [markdown]
# # Run Simulation

# %%
var date = DateTime.Now.ToString("ddMMyyyy");
date
# Out:
# 06122023

# %% [markdown]
# open a database

# %%
string dbPath = @"SAIDT_db_" + date ;
var database = OpenOrCreateDatabase(dbPath);

# %%
Dictionary<string,int> DOFS = new Dictionary<string,int>();

# %% [markdown]
# ## SinglePhaseField

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SinglePhaseField,
                    LSDegree: 3
                    );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SinglePhaseField",pSAIDT.LsTBO.DOFLocal);
# Out:
# rm;
# Session ID: 02be8bd3-db10-4788-8fcc-d1a41279051a, DB path: 'SAIDT_db_04102023'
# Session directory 'SAIDT_db_04102023\sessions\02be8bd3-db10-4788-8fcc-d1a41279051a'.
# Initial Value : l2: |r|= 1.6007811E+00, |f_err|=3.0923292E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 3.954149001100444, 5.802586765683451
# l2: ||R0||= 9.5548297E-01, f_err=2.690491E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.33E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 0.8140060357842365, 4.411320021694308
# l2: ||R0||= 1.6303931E-01, f_err=1.257716E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.74E+00, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 0.2303869839107234, 0.44338655630670376
# l2: ||R0||= 4.5084477E-02, f_err=6.781476E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.38E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 0.23558755652914823, 0.23041957382731013
# alpha, M, predM  0.5, 0.2260806156809149, 0.23041957382731013
# l2: ||R0||= 2.439944E-02, f_err=6.722206E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 4.71E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.22705028649600661, 0.22607676610720265
# alpha, M, predM  0.5, 0.2237968090960095, 0.22607676610720265
# l2: ||R0||= 1.1982567E-02, f_err=6.689748E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 4.62E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 0.2221315396265369, 0.22379650293571693
# l2: ||R0||= 9.482418E-04, f_err=6.665303E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.22197586108923986, 0.22213150892226965
# l2: ||R0||= 4.3775337E-05, f_err=6.66297E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.2219724877296134, 0.22197586044044335
# l2: ||R0||= 2.5256955E-06, f_err=6.66292E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.2219722907062943, 0.22197248768249686
# l2: ||R0||= 1.833495E-07, f_err=6.662917E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.22197226335659878, 0.22197229070024718
# l2: ||R0||= 7.427589E-08, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.22197226089247907, 0.22197226335574902
# l2: ||R0||= 1.8114135E-09, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.2219722602872255, 0.22197226089228522
# l2: ||R0||= 3.4203013E-09, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.221972260192996, 0.2219722602871814
# l2: ||R0||= 3.9041743E-10, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.2219722601654669, 0.2219722601929839
# l2: ||R0||= 4.2108873E-11, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.22197226015690127, 0.22197226016546354
# l2: ||R0||= 5.7978799E-11, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.22197226015555077, 0.22197226015690055
# l2: ||R0||= 2.3727012E-11, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.22197226015498997, 0.22197226015555052
# l2: ||R0||= 3.2216708E-11, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.22197226015518282, 0.22197226015498983
# alpha, M, predM  0.5, 0.22197226015477878, 0.22197226015498983
# l2: ||R0||= 3.3121402E-11, f_err=6.662916E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.22197226015425447, 0.22197226015477872
# l2: ||R0||= 1.6421996E-11, f_err=6.662916E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 4.63E-01, QuadOrder=2
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1,
3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,239.2 L58.4,239.2 M550.1,239.2 L545.6,239.2 M53.9,210.2 L62.9,210.2 M550.1,210.2 L541.1,210.2
# 		 '/>	<g transform="translate(45.6,216.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,181.2 L58.4,181.2 M550.1,181.2 L545.6,181.2 M53.9,152.2 L62.9,152.2 M550.1,152.2 L541.1,152.2
# 		 '/>	<g transform="translate(45.6,158.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,123.2 L58.4,123.2 M550.1,123.2 L545.6,123.2 M53.9,94.1 L62.9,94.1 M550.1,94.1 L541.1,94.1
# 		 '/>	<g transform="translate(45.6,100.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,65.1 L58.4,65.1 M550.1,65.1 L545.6,65.1 M53.9,36.1 L62.9,36.1 M550.1,36.1 L541.1,36.1
# 		 '/>	<g transform="translate(45.6,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L53.9,433.4 M53.9,36.1 L53.9,45.1  '/>	<g transform="translate(53.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M136.6,442.4 L136.6,433.4 M136.6,36.1 L136.6,45.1  '/>	<g transform="translate(136.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M219.3,442.4 L219.3,433.4 M219.3,36.1 L219.3,45.1  '/>	<g transform="translate(219.3,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;

# %% [markdown]
# ## Spline level set

# %%
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SplineLevelSet,
                    LSDegree: 3,
                    isFarConfig:true
                    );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SplineLevelSet",pSAIDT.LevelSetOpti.GetLength());
# Out:
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Session ID: 10d56b55-61a4-4817-aee5-7155aa23c20b, DB path: 'SAIDT_db_04102023'
# Session directory 'SAIDT_db_04102023\sessions\10d56b55-61a4-4817-aee5-7155aa23c20b'.
# Initial Value : l2: |r|= 1.4635787E+00, |f_err|=2.8278013E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 4.145875153897125, 7.046028827600281
# l2: ||R0||= 1.0325765E+00, f_err=2.331855E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.68E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 1.3416548458307012, 7.171877903467249
# l2: ||R0||= 3.9663809E-01, f_err=1.577581E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.24E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 5.516718138839279, 1.5784017688014735
# alpha, M, predM  0.5, 1.661115556058192, 1.5784017688014735
# alpha, M, predM  0.25, 1.0697209270453032, 1.5784017688014735
# l2: ||R0||= 3.0123417E-01, f_err=1.429894E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.05E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 1.2134769729127293, 1.066490812708037
# alpha, M, predM  0.5, 0.7269658172728931, 1.066490812708037
# l2: ||R0||= 1.4623599E-01, f_err=1.193622E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.37E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 1.16943378840201, 0.724726365977343
# alpha, M, predM  0.5, 0.8572508345534481, 0.724726365977343
# alpha, M, predM  0.25, 0.6163354014571821, 0.724726365977343
# l2: ||R0||= 2.3633035E-01, f_err=1.080593E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.16E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 0.5434191987327377, 0.5752840432892545
# l2: ||R0||= 1.8141152E-01, f_err=1.022102E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.28E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 1.523775699560087, 0.4711220130158025
# alpha, M, predM  0.5, 0.6358271041801621, 0.4711220130158025
# alpha, M, predM  0.25, 0.5456013434038348, 0.4711220130158025
# alpha, M, predM  0.125, 0.41566324389543735, 0.4711220130158025
# l2: ||R0||= 9.2529078E-02, f_err=9.061254E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.2E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.4757422020593662, 0.41545410838068436
# alpha, M, predM  0.5, 0.3916865701137903, 0.41545410838068436
# l2: ||R0||= 2.4488506E-01, f_err=8.448632E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.16E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.43520714950674627, 0.35675509174787756
# alpha, M, predM  0.5, 0.18309485377620666, 0.35675509174787756
# l2: ||R0||= 1.6580477E-01, f_err=5.919372E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.75E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.40844225675627727, 0.21237498215268175
# alpha, M, predM  0.5, 0.1751013237395376, 0.21237498215268175
# l2: ||R0||= 1.4485516E-01, f_err=5.766363E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.43E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.06484175361789112, 0.1518179552883461
# l2: ||R0||= 5.898477E-02, f_err=3.565895E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.26E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.049661625447330514, 0.06420162770471986
# l2: ||R0||= 7.2297196E-02, f_err=3.121301E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.63E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.036021333868528044, 0.026967355790658447
# alpha, M, predM  0.5, 0.0319934586850367, 0.026967355790658447
# alpha, M, predM  0.25, 0.022403316585727605, 0.026967355790658447
# l2: ||R0||= 5.7466039E-02, f_err=2.08839E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.61E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.03491800877438447, 0.022400086223591367
# alpha, M, predM  0.5, 0.031725522219085395, 0.022400086223591367
# alpha, M, predM  0.25, 0.03165368073031521, 0.022400086223591367
# alpha, M, predM  0.125, 0.021063123853209794, 0.022400086223591367
# l2: ||R0||= 5.0293685E-02, f_err=2.030165E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.6E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.03492633563841549, 0.021055944427338467
# alpha, M, predM  0.5, 0.03174478584944022, 0.021055944427338467
# alpha, M, predM  0.25, 0.03147534083702046, 0.021055944427338467
# alpha, M, predM  0.125, 0.031638975277813446, 0.021055944427338467
# alpha, M, predM  0.0625, 0.03181333728628675, 0.021055944427338467
# alpha, M, predM  0.03125, 0.020762725540382058, 0.021055944427338467
# l2: ||R0||= 4.872249E-02, f_err=2.016992E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.55E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.0328062155955287, 0.02071823849092254
# alpha, M, predM  0.5, 0.030623860251290158, 0.02071823849092254
# alpha, M, predM  0.25, 0.03075371518536216, 0.02071823849092254
# alpha, M, predM  0.125, 0.03115112220797795, 0.02071823849092254
# alpha, M, predM  0.0625, 0.03141243887880996, 0.02071823849092254
# alpha, M, predM  0.03125, 0.031586195961703915, 0.02071823849092254
# alpha, M, predM  0.015625, 0.02052918482020765, 0.02071823849092254
# l2: ||R0||= 4.796124E-02, f_err=2.00812E-01, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu =
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 2.1014117138775497E-13, 1.1660949032866392E-11
# l2: ||R0||= 1.8913701E-07, f_err=6.482918E-07, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 1.39E-06, QuadOrder=4
# ALNR=4.836489909304954 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 7.394029898940859E-16, 2.1010085133450877E-13
# l2: ||R0||= 8.1672318E-09, f_err=3.845525E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 6.31E-08, QuadOrder=4
# ALNR=8.001922998253761 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 2.3452161837231984E-17, 7.392640591564467E-16
# l2: ||R0||= 4.0506679E-09, f_err=6.848673E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 7.12E-09, QuadOrder=4
# ALNR=8.038407579587766 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 1.336646192838958E-18, 2.3448181083271026E-17
# l2: ||R0||= 8.4133025E-10, f_err=1.635021E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 1.99E-09, QuadOrder=4
# ALNR=8.571793374632225 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 1.764690360641633E-18, 1.336391781900644E-18
# alpha, M, predM  0.5, 3.0308722886849083E-19, 1.336391781900644E-18
# l2: ||R0||= 2.9951992E-10, f_err=7.785721E-10, f_phi=0E+00, Alpha = 5E-01, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 1.23E-09, QuadOrder=4
# ALNR=7.685695979117362 > 1.005 so we continue
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 3.3386853831189412E-18, 3.030432176125829E-19
# alpha, M, predM  0.5, 6.934425417609158E-19, 3.030432176125829E-19
# alpha, M, predM  0.25, 2.2237817260672286E-19, 3.030432176125829E-19
# l2: ||R0||= 1.9606113E-10, f_err=6.669006E-10, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 4.68E-10, QuadOrder=4
# ALNR=7.611830046793716 > 1.005 so we continue
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 8.662117518972264E-18, 2.223481085186379E-19
# alpha, M, predM  0.5, 1.7113697004454415E-18, 2.223481085186379E-19
# alpha, M, predM  0.25, 3.0494131893694255E-19, 2.223481085186379E-19
# alpha, M, predM  0.125, 1.2159190563945228E-19, 2.223481085186379E-19
# l2: ||R0||= 1.6252869E-10, f_err=4.931367E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 6.93E-10, QuadOrder=4
# ALNR=5.670674669708484 > 1.005 so we continue
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 3.0699870396919837E-18, 1.215743033969151E-19
# alpha, M, predM  0.5, 6.877728202716259E-19, 1.215743033969151E-19
# alpha, M, predM  0.25, 1.9240070151054584E-19, 1.215743033969151E-19
# alpha, M, predM  0.125, 1.0684130675972252E-19, 1.215743033969151E-19
# l2: ||R0||= 8.7559911E-11, f_err=4.622582E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 6.77E-04, Kappa = 1E+03, Mu = 3.76E-10, QuadOrder=4
# ALNR=5.341147314795443 > 1.005 so we continue
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 3.9055049431777785E-18, 1.068298210883E-19
# alpha, M, predM  0.5, 8.426930274995292E-19, 1.068298210883E-19
# alpha, M, predM  0.25, 1.9085662762885922E-19, 1.068298210883E-19
# alpha, M, predM  0.125, 8.62723498945668E-20, 1.068298210883E-19
# l2: ||R0||= 1.0259496E-10, f_err=4.15385E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 4.51E-04, Kappa = 1E+03, Mu = 6.19E-10, QuadOrder=4
# ALNR=2.175714225846636 > 1.005 so we continue
#
#
# Starting Opt-Iter No.41:
# alpha, M, predM  1, 4.992405281807296E-18, 8.625986081078748E-20
# alpha, M, predM  0.5, 1.083560049841412E-18, 8.625986081078748E-20
# alpha, M, predM  0.25, 2.42879089367014E-19, 8.625986081078748E-20
# alpha, M, predM  0.125, 8.591069004646454E-20, 8.625986081078748E-20
# l2: ||R0||= 4.9187267E-11, f_err=4.145134E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 3.01E-04, Kappa = 1E+03, Mu = 2.12E-10, QuadOrder=4
# ALNR=2.141980766457304 > 1.005 so we continue
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 1.269962997522587E-17, 8.589856134248004E-20
# alpha, M, predM  0.5, 2.83994432985845E-18, 8.589856134248004E-20
# alpha, M, predM  0.25, 5.820662228757825E-19, 8.589856134248004E-20
# alpha, M, predM  0.125, 1.2111496401626985E-19, 8.589856134248004E-20
# alpha, M, predM  0.0625, 5.765298783706622E-20, 8.589856134248004E-20
# l2: ||R0||= 9.071591E-11, f_err=3.395673E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 2E-04, Kappa = 1E+03, Mu = 3.76E-10, QuadOrder=4
# ALNR=1.597038022403942 > 1.005 so we continue
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 5.189486890179021E-18, 5.764384867211368E-20
# alpha, M, predM  0.5, 1.1935664205743626E-18, 5.764384867211368E-20
# alpha, M, predM  0.25, 2.8179107189981608E-19, 5.764384867211368E-20
# alpha, M, predM  0.125, 9.046781420637812E-20, 5.764384867211368E-20
# alpha, M, predM  0.0625, 5.754015978279284E-20, 5.764384867211368E-20
# l2: ||R0||= 6.0145444E-11, f_err=3.392349E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1.34E-04, Kappa = 1E+03, Mu = 1.73E-10, QuadOrder=4
# ALNR=1.3386195645472712 > 1.005 so we continue
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 5.781598492833289E-18, 5.753348475654206E-20
# alpha, M, predM  0.5, 1.3300815747291005E-18, 5.753348475654206E-20
# alpha, M, predM  0.25, 2.9912972583223773E-19, 5.753348475654206E-20
# alpha, M, predM  0.125, 8.235534364316865E-20, 5.753348475654206E-20
# alpha, M, predM  0.0625, 4.878754686882054E-20, 5.753348475654206E-20
# l2: ||R0||= 7.2442992E-11, f_err=3.123701E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.37E-10, QuadOrder=4
# ALNR=1.2632357974505193 > 1.005 so we continue
#
#
# Starting Opt-Iter No.45:
# alpha, M, predM  1, 5.717779297425855E-18, 4.87798401440528E-20
# alpha, M, predM  0.5, 1.3083102157980728E-18, 4.87798401440528E-20
# alpha, M, predM  0.25, 2.9723038642976815E-19, 4.87798401440528E-20
# alpha, M, predM  0.125, 8.599068140355974E-20, 4.87798401440528E-20
# alpha, M, predM  0.0625, 4.8756171614524796E-20, 4.87798401440528E-20
# l2: ||R0||= 4.8863024E-11, f_err=3.122697E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 1.25E-10, QuadOrder=4
# ALNR=1.2347098988262315 > 1.005 so we continue
#
#
# Starting Opt-Iter No.46:
# alpha, M, predM  1, 5.9294619699147825E-18, 4.875051583843854E-20
# alpha, M, predM  0.5, 1.3671307319602615E-18, 4.875051583843854E-20
# alpha, M, predM  0.25, 3.047777057363813E-19, 4.875051583843854E-20
# alpha, M, predM  0.125, 7.830391231063715E-20, 4.875051583843854E-20
# alpha, M, predM  0.0625, 4.1375541001303296E-20, 4.875051583843854E-20
# l2: ||R0||= 5.9047082E-11, f_err=2.876649E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.67E-10, QuadOrder=4
# ALNR=1.1123956366374563 > 1.005 so we continue
#
#
# Starting Opt-Iter No.47:
# alpha, M, predM  1, 5.504008662028702E-18, 4.1369198155148765E-20
# alpha, M, predM  0.5, 1.2547988947950972E-18, 4.1369198155148765E-20
# alpha, M, predM  0.25, 2.7952343353529376E-19, 4.1369198155148765E-20
# alpha, M, predM  0.125, 7.681161840466616E-20, 4.1369198155148765E-20
# alpha, M, predM  0.0625, 4.107635186167115E-20, 4.1369198155148765E-20
# l2: ||R0||= 4.3820687E-11, f_err=2.866229E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 1.22E-10, QuadOrder=4
# ALNR=1.1288338513325868 > 1.005 so we continue
#
#
# Starting Opt-Iter No.48:
# alpha, M, predM  1, 5.006851795911232E-18, 4.107167422782047E-20
# alpha, M, predM  0.5, 1.1541210816434963E-18, 4.107167422782047E-20
# alpha, M, predM  0.25, 2.5702638699450973E-19, 4.107167422782047E-20
# alpha, M, predM  0.125, 6.579707158380536E-20, 4.107167422782047E-20
# alpha, M, predM  0.0625, 3.456010183170092E-20, 4.107167422782047E-20
# l2: ||R0||= 5.1369121E-11, f_err=2.629072E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.18E-10, QuadOrder=4
# ALNR=1.0173861792416201 > 1.005 so we continue
#
#
# Starting Opt-Iter No.49:
# alpha, M, predM  1, 5.057644368485379E-18, 3.4554929750521566E-20
# alpha, M, predM  0.5, 1.1574152380233365E-18, 3.4554929750521566E-20
# alpha, M, predM  0.25, 2.5788679706857725E-19, 3.4554929750521566E-20
# alpha, M, predM  0.125, 6.97194305751677E-20, 3.4554929750521566E-20
# alpha, M, predM  0.0625, 3.540885757235935E-20, 3.4554929750521566E-20
# alpha, M, predM  0.03125, 3.098956957030821E-20, 3.4554929750521566E-20
# l2: ||R0||= 7.0145337E-11, f_err=2.489561E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 1.14E-10, QuadOrder=4
# ALNR=1.0173861792416201 > 1.005 so we continue
#
#
# Starting Opt-Iter No.50:
# alpha, M, predM  1, 1.5527630301051314E-18, 3.0985393782103207E-20
# alpha, M, predM  0.5, 3.825800262225098E-19, 3.0985393782103207E-20
# alpha, M, predM  0.25, 1.0984268557927668E-19, 3.0985393782103207E-20
# alpha, M, predM  0.125, 4.8618861393595614E-20, 3.0985393782103207E-20
# alpha, M, predM  0.0625, 3.512248257804422E-20, 3.0985393782103207E-20
# alpha, M, predM  0.03125, 3.217662714797418E-20, 3.0985393782103207E-20
# alpha, M, predM  0.015625, 3.1311242628702587E-20, 3.0985393782103207E-20
# alpha, M, predM  0.0078125, 3.111312463193096E-20, 3.0985393782103207E-20
# alpha, M, predM  0.00390625, 3.100575354955753E-20, 3.0985393782103207E-20
# alpha, M, predM  0.001953125, 3.099372580537051E-20, 3.0985393782103207E-20
# alpha, M, predM  0.0009765625, 3.0991294258742284E-20, 3.0985393782103207E-20
9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M153.1,442.4 L153.1,433.4 M153.1,36.1 L153.1,45.1  '/>	<g transform="translate(153.1,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M252.4,442.4 L252.4,433.4 M252.4,36.1 L252.4,45.1  '/>	<g transform="translate(252.4,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width=

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;

# %% [markdown]
# ## SpecFemField

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SpecFemField,
                    LSDegree: 3,
                    isFarConfig:true
                    );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SpecFemField",pSAIDT.LevelSetOpti.GetLength());
# Out:
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_31.plt ScalarAdvection_SP_32.plt ScalarAdvection_SP_33.plt ScalarAdvection_SP_34.plt ScalarAdvection_SP_35.plt ScalarAdvection_SP_36.plt ScalarAdvection_SP_37.plt ScalarAdvection_SP_38.plt ScalarAdvection_SP_39.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_40.plt ScalarAdvection_SP_41.plt ScalarAdvection_SP_42.plt ScalarAdvection_SP_43.plt ScalarAdvection_SP_44.plt ScalarAdvection_SP_45.plt ScalarAdvection_SP_46.plt ScalarAdvection_SP_47.plt ScalarAdvection_SP_48.plt ScalarAdvection_SP_49.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_50.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Session ID: 0fd90d8d-5d14-4f94-a8ef-48686821996c, DB path: 'SAIDT_db_04102023'
# Session directory 'SAIDT_db_04102023\sessions\0fd90d8d-5d14-4f94-a8ef-48686821996c'.
# Initial Value : l2: |r|= 1.450267E+00, |f_err|=2.8254358E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 1.6783580482850935, 7.071826827905927
# l2: ||R0||= 5.9838335E-01, f_err=1.547809E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.68E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 0.6170231601597577, 1.4419922522945694
# l2: ||R0||= 1.5696288E-01, f_err=1.095377E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.39E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 0.6699707387806422, 0.6323346175876795
# alpha, M, predM  0.5, 0.6197564816349617, 0.6323346175876795
# l2: ||R0||= 9.1566837E-02, f_err=1.107299E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.6E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 0.5574653914965378, 0.6214273746780403
# l2: ||R0||= 1.2867008E-01, f_err=1.042033E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.76E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.6911188224141649, 1.1596104909033034
# l2: ||R0||= 3.390737E-01, f_err=1.104849E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.41E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 0.544872209544016, 0.5364011872288866
# alpha, M, predM  0.5, 0.4691159070001909, 0.5364011872288866
# l2: ||R0||= 6.1018903E-02, f_err=9.654835E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.63E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.29638558518562996, 0.46816959615064396
# l2: ||R0||= 5.8409875E-02, f_err=7.673905E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.14E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.7250640267141035, 0.28957750313163577
# alpha, M, predM  0.5, 0.37056109687041794, 0.28957750313163577
# alpha, M, predM  0.25, 0.2927612264663332, 0.28957750313163577
# alpha, M, predM  0.125, 0.2782147780481391, 0.28957750313163577
# l2: ||R0||= 7.6327631E-02, f_err=7.425654E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.63E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.2083543316510373, 0.2783229791026934
# l2: ||R0||= 1.7615648E-01, f_err=6.232845E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.1E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.378493000469357, 0.19971517493129826
# alpha, M, predM  0.5, 0.21843173498703586, 0.19971517493129826
# alpha, M, predM  0.25, 0.1906529161839398, 0.19971517493129826
# l2: ||R0||= 1.7025528E-01, f_err=6.056837E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.99E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.1359258773462559, 0.19407420248633694
# l2: ||R0||= 1.0021801E-01, f_err=5.142553E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.36E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.2787923354922234, 0.13357048660332488
# alpha, M, predM  0.5, 0.12682595172876973, 0.13357048660332488
# l2: ||R0||= 1.1765544E-01, f_err=4.978361E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.2E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.1723586521269651, 0.12885046977196235
# alpha, M, predM  0.5, 0.09773557788654738, 0.12885046977196235
# l2: ||R0||= 7.6332588E-02, f_err=4.373915E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.14E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.1799441573335823, 0.09812137696372593
# alpha, M, predM  0.5, 0.1671836884447104, 0.09812137696372593
# alpha, M, predM  0.25, 0.09176369307728434, 0.09812137696372593
# l2: ||R0||= 5.9037627E-02, f_err=4.249393E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.48E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.1699700648506248, 0.0918372685993863
# alpha, M, predM  0.5, 0.16520448686501663, 0.0918372685993863
# alpha, M, predM  0.25, 0.16443585242217507, 0.0918372685993863
# alpha, M, predM  0.125, 0.09020766302429428, 0.0918372685993863
# l2: ||R0||= 5.212411E-02, f_err=4.218951E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.91E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.2048850676545481, 0.08943979188199366
# alpha, M, predM  0.5, 0.10751755542937282, 0.08943979188199366
# alpha, M, predM  0.25, 0.09120024098231988, 0.08943979188199366
# alpha, M, predM  0.125, 0.08881559934226092, 0.08943979188199366
# l2: ||R0||= 5.662655E-02, f_err=4.196671E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.71E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.1512443826977595, 0.08936775440431007
# alpha, M, predM  0.5, 0.15106142907255782, 0.08936775440431007
# alpha, M, predM  0.25, 0.1543233049841546, 0.08936775440431007
# alpha, M, predM  0.125, 0.08677918603424814, 0.08936775440431007
# l2: ||R0||= 4.9791636E-02, f_err=4.141654E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.17E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.1488807593368945, 0.08676999403351816
# alpha, M, predM  0.5, 0.14819337026025262, 0.08676999403351816
# alpha, M, predM  0.25, 0.1525808184670912, 0.08676999403351816
# alpha, M, predM  0.125, 0.15359284994472047, 0.08676999403351816
# alpha, M, predM  0.0625, 0.15328450174656438, 0.08676999403351816
# alpha, M, predM  0.03125, 0.0861807944269525, 0.08676999403351816
# l2: ||R0||= 4.8308742E-02, f_err=4.128783E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.11E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.14239768965273908, 0.08613840604740976
# alpha, M, predM  0.5, 0.14342434479526087, 0.08613840604740976
# alpha, M, predM  0.25, 0.14897024401536046, 0.08613840604740976
# alpha, M, predM  0.125, 0.1520915235785655, 0.08613840604740976
# alpha, M, predM  0.0625, 0.1522123547912823, 0.08613840604740976
# alpha, M, predM  0.03125, 0.1523058103885791, 0.08613840604740976
# alpha, M, predM  0.015625, 0.15236099063379102, 0.08613840604740976
# alpha, M, predM  0.0078125, 0.0859825541587361, 0.08613840604740976
# l2: ||R0||= 4.7931966E-02, f_err=4.125298E-01, f_phi=0E+00, Alpha = 7.81E-03, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 7.77E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 0.1359932854791287, 0.08592622873181312
# alpha, M, predM  0.5, 0.1386843561168939, 0.08592622873181312
# alpha, M, predM  0.25, 0.1455906569740453, 0.08592622873181312
# alpha, M, predM  0.125, 0.1499330891236826, 0.08592622873181312
# alpha, M, predM  0.0625, 0.15061126638191363, 0.08592622873181312
# alpha, M, predM  0.03125, 0.15098913445105216, 0.08592622873181312
# alpha, M, predM  0.015625, 0.1511880525301609, 0.08592622873181312
# alpha, M, predM  0.0078125, 0.15129004856655162, 0.08592622873181312
# alpha, M, predM  0.00390625, 0.08582888759645503, 0.08592622873181312
# l2: ||R0||= 4.7744905E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 7.3E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 0.12909242819111, 0.08577016924680085
# alpha, M, predM  0.5, 0.13378352940011057, 0.08577016924680085
# alpha, M, predM  0.25, 0.1421860448618064, 0.08577016924680085
# alpha, M, predM  0.125, 0.14754936045383335, 0.08577016924680085
# alpha, M, predM  0.0625, 0.14886814138310628, 0.08577016924680085
# alpha, M, predM  0.03125, 0.1495708451714541, 0.08577016924680085
# alpha, M, predM  0.015625, 0.14993396802707193, 0.08577016924680085
# alpha, M, predM  0.0078125, 0.1501185337105267, 0.08577016924680085
# alpha, M, predM  0.00390625, 0.15021157588744702, 0.08577016924680085
# alpha, M, predM  0.001953125, 0.15025828788146983, 0.08577016924680085
# alpha, M, predM  0.0009765625, 0.1502816917412568, 0.08577016924680085
# alpha, M, predM  0.00048828125, 0.15029340565404464, 0.08577016924680085
# alpha, M, predM  0.000244140625, 0.15029926560832182, 0.08577016924680085
# alpha, M, predM  0.0001220703125, 0.15030219633520195, 0.08577016924680085
# alpha, M, predM  6.103515625E-05, 0.15030366188611097, 0.08577016924680085
# alpha, M, predM  3.0517578125E-05, 0.15030439470843715, 0.08577016924680085
# alpha, M, predM  1.52587890625E-05, 0.1503047611313187, 0.08577016924680085
# alpha, M, predM  7.62939453125E-06, 0.08577316430334272, 0.08577016924680085
# alpha, M, predM  3.814697265625E-06, 0.08577328799128303, 0.08577016924680085
# alpha, M, predM  1.9073486328125E-06, 0.08577334983551811, 0.08577016924680085
# alpha, M, predM  9.5367431640625E-07, 0.08577338075770159, 0.08577016924680085
# alpha, M, predM  4.76837158203125E-07, 0.08577339621881006, 0.08577016924680085
# alpha, M, predM  2.384185791015625E-07, 0.08577340394936842, 0.08577016924680085
# alpha, M, predM  1.1920928955078125E-07, 0.08577340781464858, 0.08577016924680085
# alpha, M, predM  5.960464477539063E-08, 0.08577340974728913, 0.08577016924680085
# alpha, M, predM  2.9802322387695312E-08, 0.08577341071360912, 0.08577016924680085
# alpha, M, predM  1.4901161193847656E-08, 0.08577341119676943, 0.08577016924680085
# l2: ||R0||= 4.7744904E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 6.81E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 0.12282103057804991, 0.08571138991237225
# alpha, M, predM  0.5, 0.12890329253020644, 0.08571138991237225
# alpha, M, predM  0.25, 0.13875161438280903, 0.08571138991237225
# alpha, M, predM  0.125, 0.1450087029256348, 0.08571138991237225
# alpha, M, predM  0.0625, 0.14704088513802438, 0.08571138991237225
# alpha, M, predM  0.03125, 0.1481131470128417, 0.08571138991237225
# alpha, M, predM  0.015625, 0.14866303972496742, 0.08571138991237225
# alpha, M, predM  0.0078125, 0.1489415141446196, 0.08571138991237225
# alpha, M, predM  0.00390625, 0.1490816454156738, 0.08571138991237225
# alpha, M, predM  0.001953125, 0.14915193614348066, 0.08571138991237225
# alpha, M, predM  0.0009765625, 0.14918713798213065, 0.08571138991237225
# alpha, M, predM  0.00048828125, 0.14920475304563965, 0.08571138991237225
# alpha, M, predM  0.000244140625, 0.14921356411664544, 0.08571138991237225
# alpha, M, predM  0.0001220703125, 0.14921797053736294, 0.08571138991237225
# alpha, M, predM  6.103515625E-05, 0.14922017396907564, 0.08571138991237225
# alpha, M, predM  3.0517578125E-05, 0.14922127574027672, 0.08571138991237225
# alpha, M, predM  1.52587890625E-05, 0.14922182663971445, 0.08571138991237225
# alpha, M, predM  7.62939453125E-06, 0.08571515255130768, 0.08571138991237225
# alpha, M, predM  3.814697265625E-06, 0.08571530793851347, 0.08571138991237225
# alpha, M, predM  1.9073486328125E-06, 0.08571538563242305, 0.08571138991237225
# alpha, M, predM  9.5367431640625E-07, 0.08571542447945481, 0.08571138991237225
# alpha, M, predM  4.76837158203125E-07, 0.08571544390298974, 0.08571138991237225
# alpha, M, predM  2.384185791015625E-07, 0.08571545361476213, 0.08571138991237225
# alpha, M, predM  1.1920928955078125E-07, 0.0857154584706493, 0.08571138991237225
# alpha, M, predM  5.960464477539063E-08, 0.08571546089859323, 0.08571138991237225
# alpha, M, predM  2.9802322387695312E-08, 0.08571546211256545, 0.08571138991237225
# alpha, M, predM  1.4901161193847656E-08, 0.08571546271955145, 0.08571138991237225
# l2: ||R0||= 4.7744904E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 6.3E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 0.12529552839887573, 0.08564945436466714
# alpha, M, predM  0.5, 0.1237674062933357, 0.08564945436466714
# alpha, M, predM  0.25, 0.13508577726768287, 0.08564945436466714
# alpha, M, predM  0.125, 0.14225034784487783, 0.08564945436466714
# alpha, M, predM  0.0625, 0.14506918055056003, 0.08564945436466714
# alpha, M, predM  0.03125, 0.14655493665861657, 0.08564945436466714
# alpha, M, predM  0.015625, 0.1473135812590933, 0.08564945436466714
# alpha, M, predM  0.0078125, 0.1476969557291144, 0.08564945436466714
# alpha, M, predM  0.00390625, 0.14788967191304084, 0.08564945436466714
# alpha, M, predM  0.001953125, 0.14798628936711425, 0.08564945436466714
# alpha, M, predM  0.0009765625, 0.14803466320902228, 0.08564945436466714
# alpha, M, predM  0.00048828125, 0.14805886644353933, 0.08564945436466714
# alpha, M, predM  0.000244140625, 0.1480709721435789, 0.08564945436466714
# alpha, M, predM  0.0001220703125, 0.1480770260148447, 0.08564945436466714
# alpha, M, predM  6.103515625E-05, 0.14808005320585835, 0.08564945436466714
# alpha, M, predM  3.0517578125E-05, 0.14808156686521898, 0.08564945436466714
# alpha, M, predM  1.52587890625E-05, 0.14808232371086363, 0.08564945436466714
# alpha, M, predM  7.62939453125E-06, 0.14808270213767744, 0.08564945436466714
# alpha, M, predM  3.814697265625E-06, 0.08565429650431684, 0.08564945436466714
# alpha, M, predM  1.9073486328125E-06, 0.08565439252328973, 0.08564945436466714
# alpha, M, predM  9.5367431640625E-07, 0.08565444053286375, 0.08564945436466714
# alpha, M, predM  4.76837158203125E-07, 0.0856544645376726, 0.08564945436466714
# alpha, M, predM  2.384185791015625E-07, 0.08565447654008258, 0.08564945436466714
# alpha, M, predM  1.1920928955078125E-07, 0.08565448254128899, 0.08564945436466714
# alpha, M, predM  5.960464477539063E-08, 0.08565448554189238, 0.08564945436466714
# alpha, M, predM  2.9802322387695312E-08, 0.08565448704219439, 0.08564945436466714
# alpha, M, predM  1.4901161193847656E-08, 0.08565448779234519, 0.08564945436466714
# l2: ||R0||= 4.7744903E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 5.77E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 0.19781986292154263, 0.08558522219652341
# alpha, M, predM  0.5, 0.1189859652536051, 0.08558522219652341
# alpha, M, predM  0.25, 0.13141411548778853, 0.08558522219652341
# alpha, M, predM  0.125, 0.13933420743869068, 0.08558522219652341
# alpha, M, predM  0.0625, 0.1429945840837439, 0.08558522219652341
# alpha, M, predM  0.03125, 0.14492483226444688, 0.08558522219652341
# alpha, M, predM  0.015625, 0.14590763766113307, 0.08558522219652341
# alpha, M, predM  0.0078125, 0.14640357222544306, 0.08558522219652341
# alpha, M, predM  0.00390625, 0.14665269035117606, 0.08558522219652341
# alpha, M, predM  0.001953125, 0.14677753961667853, 0.08558522219652341
# alpha, M, predM  0.0009765625, 0.14684003712800264, 0.08558522219652341
# alpha, M, predM  0.00048828125, 0.1468713041453368, 0.08558522219652341
# alpha, M, predM  0.000244140625, 0.1468869422247415, 0.08558522219652341
# alpha, M, predM  0.0001220703125, 0.14689476240779686, 0.08558522219652341
# alpha, M, predM  6.103515625E-05, 0.1468986727852469, 0.08558522219652341
# alpha, M, predM  3.0517578125E-05, 0.14690062804546294, 0.08558522219652341
# alpha, M, predM  1.52587890625E-05, 0.146901605693445, 0.08558522219652341
# alpha, M, predM  7.62939453125E-06, 0.1469020945219046, 0.08558522219652341
# alpha, M, predM  3.814697265625E-06, 0.08559107648267829, 0.08558522219652341
# alpha, M, predM  1.9073486328125E-06, 0.08559119257240916, 0.08558522219652341
# alpha, M, predM  9.5367431640625E-07, 0.08559125061737236, 0.08558522219652341
# alpha, M, predM  4.76837158203125E-07, 0.08559127963987838, 0.08558522219652341
# alpha, M, predM  2.384185791015625E-07, 0.08559129415113756, 0.08558522219652341
# alpha, M, predM  1.1920928955078125E-07, 0.08559130140676864, 0.08558522219652341
# alpha, M, predM  5.960464477539063E-08, 0.08559130503458456, 0.08558522219652341
# alpha, M, predM  2.9802322387695312E-08, 0.0855913068484926, 0.08558522219652341
# alpha, M, predM  1.4901161193847656E-08, 0.08559130775544668, 0.08558522219652341
# l2: ||R0||= 4.7744903E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 5.21E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 0.38842660666974077, 0.08552109100969806
# alpha, M, predM  0.5, 0.11585588395457891, 0.08552109100969806
# alpha, M, predM  0.25, 0.12767801068635592, 0.08552109100969806
# alpha, M, predM  0.125, 0.13640167293241715, 0.08552109100969806
# alpha, M, predM  0.0625, 0.14090933940488962, 0.08552109100969806
# alpha, M, predM  0.03125, 0.14329086167092053, 0.08552109100969806
# alpha, M, predM  0.015625, 0.14450108513260634, 0.08552109100969806
# alpha, M, predM  0.0078125, 0.14511112764551398, 0.08552109100969806
# alpha, M, predM  0.00390625, 0.14541739677101334, 0.08552109100969806
# alpha, M, predM  0.001953125, 0.14557084565592765, 0.08552109100969806
# alpha, M, predM  0.0009765625, 0.14564764900258886, 0.08552109100969806
# alpha, M, predM  0.00048828125, 0.14568607044428142, 0.08552109100969806
# alpha, M, predM  0.000244140625, 0.1457052861126236, 0.08552109100969806
# alpha, M, predM  0.0001220703125, 0.14571489518435154, 0.08552109100969806
# alpha, M, predM  6.103515625E-05, 0.14571970002969062, 0.08552109100969806
# alpha, M, predM  3.0517578125E-05, 0.14572210252973966, 0.08552109100969806
# alpha, M, predM  1.52587890625E-05, 0.14572330379911028, 0.08552109100969806
# alpha, M, predM  7.62939453125E-06, 0.14572390443863245, 0.08552109100969806
# alpha, M, predM  3.814697265625E-06, 0.08552798474198739, 0.08552109100969806
# alpha, M, predM  1.9073486328125E-06, 0.08552812144384062, 0.08552109100969806
# alpha, M, predM  9.5367431640625E-07, 0.08552818979487345, 0.08552109100969806
# alpha, M, predM  4.76837158203125E-07, 0.08552822397041616, 0.08552109100969806
# alpha, M, predM  2.384185791015625E-07, 0.08552824105819407, 0.08552109100969806
# alpha, M, predM  1.1920928955078125E-07, 0.08552824960208456, 0.08552109100969806
# alpha, M, predM  5.960464477539063E-08, 0.08552825387403054, 0.08552109100969806
# alpha, M, predM  2.9802322387695312E-08, 0.08552825601000337, 0.08552109100969806
# alpha, M, predM  1.4901161193847656E-08, 0.08552825707798979, 0.08552109100969806
# l2: ||R0||= 4.7744902E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 4.66E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 1.2300469631437734, 0.08546049762561547
# alpha, M, predM  0.5, 0.11657681766521917, 0.08546049762561547
# alpha, M, predM  0.25, 0.12424663420483391, 0.08546049762561547
# alpha, M, predM  0.125, 0.13363421902651013, 0.08546049762561547
# alpha, M, predM  0.0625, 0.13893608783164907, 0.08546049762561547
# alpha, M, predM  0.03125, 0.14174576076293033, 0.08546049762561547
# alpha, M, predM  0.015625, 0.14317172375790826, 0.08546049762561547
# alpha, M, predM  0.0078125, 0.14388993972443676, 0.08546049762561547
# alpha, M, predM  0.0078125, 0.1416158454259162, 0.08534929988643823
# alpha, M, predM  0.00390625, 0.14209597067322277, 0.08534929988643823
# alpha, M, predM  0.001953125, 0.14233637644530697, 0.08534929988643823
# alpha, M, predM  0.0009765625, 0.14245666467099352, 0.08534929988643823
# alpha, M, predM  0.00048828125, 0.14251683007059154, 0.08534929988643823
# alpha, M, predM  0.000244140625, 0.14254691808654835, 0.08534929988643823
# alpha, M, predM  0.0001220703125, 0.14256196342290556, 0.08534929988643823
# alpha, M, predM  6.103515625E-05, 0.14256948642309833, 0.08534929988643823
# alpha, M, predM  3.0517578125E-05, 0.14257324800618829, 0.08534929988643823
# alpha, M, predM  1.52587890625E-05, 0.14257512881848017, 0.08534929988643823
# alpha, M, predM  7.62939453125E-06, 0.14257606922981292, 0.08534929988643823
# alpha, M, predM  3.814697265625E-06, 0.14257653943677584, 0.08534929988643823
# alpha, M, predM  1.9073486328125E-06, 0.08535960278938061, 0.08534929988643823
# alpha, M, predM  9.5367431640625E-07, 0.08535970295592975, 0.08534929988643823
# alpha, M, predM  4.76837158203125E-07, 0.0853597530392334, 0.08534929988643823
# alpha, M, predM  2.384185791015625E-07, 0.08535977808089233, 0.08534929988643823
# alpha, M, predM  1.1920928955078125E-07, 0.08535979060172369, 0.08534929988643823
# alpha, M, predM  5.960464477539063E-08, 0.08535979686213961, 0.08534929988643823
# alpha, M, predM  2.9802322387695312E-08, 0.08535979999234802, 0.08534929988643823
# alpha, M, predM  1.4901161193847656E-08, 0.08535980155745221, 0.08534929988643823
# l2: ||R0||= 4.7744901E-02, f_err=4.123034E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 3.18E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 3.5758847539337486, 0.0853495109554969
# alpha, M, predM  0.5, 0.17719319655172602, 0.0853495109554969
# alpha, M, predM  0.25, 0.1166313975468122, 0.0853495109554969
# alpha, M, predM  0.125, 0.12751648538256372, 0.0853495109554969
# alpha, M, predM  0.0625, 0.1346225510506669, 0.0853495109554969
# alpha, M, predM  0.03125, 0.13857019871077614, 0.0853495109554969
# alpha, M, predM  0.015625, 0.1405720879081038, 0.0853495109554969
# alpha, M, predM  0.0078125, 0.14157896695507946, 0.0853495109554969
# alpha, M, predM  0.00390625, 0.1420838194942463, 0.0853495109554969
# alpha, M, predM  0.001953125, 0.14233659248618338, 0.0853495109554969
# alpha, M, predM  0.0009765625, 0.1424630649923554, 0.0853495109554969
# alpha, M, predM  0.00048828125, 0.1425263226734197, 0.0853495109554969
# alpha, M, predM  0.000244140625, 0.1425579568622044, 0.0853495109554969
# alpha, M, predM  0.0001220703125, 0.14257377529260373, 0.0853495109554969
# alpha, M, predM  6.103515625E-05, 0.14258168484167527, 0.0853495109554969
# alpha, M, predM  3.0517578125E-05, 0.14258563969966284, 0.0853495109554969
# alpha, M, predM  1.52587890625E-05, 0.14258761714951762, 0.0853495109554969
# alpha, M, predM  7.62939453125E-06, 0.14258860587966002, 0.0853495109554969
# alpha, M, predM  3.814697265625E-06, 0.1425891002460349, 0.0853495109554969
# alpha, M, predM  1.9073486328125E-06, 0.08536026654172593, 0.0853495109554969
464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M297.8,442.4 L297.8,433.4 M297.8,36.1 L297.8,45.1  '/>	<g transform="translate(297.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 15</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M381.9,442.4 L381.9,433.4 M381.9,36.1 L381.9,45.1  '/>	<g transform="translate(381.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M466.0,442.4 L466.0,433.4 M466.0,36.1 L466.0,45.1  '/>	<g transform="translate(466.0,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 25</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;

# %%
using System.IO;
static void AppendRowToCSV(string filePath, double[] rowData)
    {
        // Create a StreamWriter in append mode to append rows to the CSV file
        using (StreamWriter writer = new StreamWriter(filePath, true))
        {
            int cols = rowData.Length;

            // Write double values of the new row to the file
            for (int i = 0; i < cols; i++)
            {
                writer.Write(rowData[i]);

                // Add a comma after each value except for the last one in a row
                if (i < cols - 1)
                {
                    writer.Write(";");
                }
            }

            // Move to the next line after writing the row
            writer.WriteLine();
        }
    }
    static void WriteCSV(string filePath, string[] data)
    {
        // Create a StreamWriter to write to the CSV file
        using (StreamWriter writer = new StreamWriter(filePath))
        {
            int cols = data.Length;

            // Loop through the data array and write to the file
                for (int j = 0; j < cols; j++)
                {
                    // Write each cell value to the file
                    writer.Write(data[ j]);

                    // Add a comma after each cell value except for the last one in a row
                    if (j < cols - 1)
                    {
                        writer.Write(";");
                    }
                }

                // Move to the next line after each row
                writer.WriteLine();
            
        }
    }
    static void DeleteCSVFiles()
    {
        try
        {
            // Get all CSV files in the specified directory
            string[] csvFiles = Directory.GetFiles("*.csv");

            // Delete each CSV file
            foreach (string file in csvFiles)
            {
                File.Delete(file);
                Console.WriteLine($"Deleted: {file}");
            }
        }
        catch (Exception ex)
        {
            Console.WriteLine($"Error deleting CSV files: {ex.Message}");
        }
    }

# %% [markdown]
# ## Measure wall-clock time for computation of sensitivities and residuals

# %%
using System.Diagnostics;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
DeleteCSVFiles();

int nRefs=5;
var optLsTypes=new OptiLevelSetType[] {OptiLevelSetType.SinglePhaseField,OptiLevelSetType.SplineLevelSet,OptiLevelSetType.SpecFemField};
var CellsVsRuntime_dRdPhi = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
var CellsVsRuntime_Residuals = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
var CellsVsRuntime_dRdU = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
string[] stringArray = new string[] { "nCells" }.Concat(optLsTypes.Select(x => x.ToString())).ToArray();

//Create files for results
string filePathdRdPhi = "TimeDRdPhi.csv";
string filePathdRdU = "TimedRdU.csv";
string filePathResiduals = "TimeResiduals.csv";
string filePathDOFs = "DOFs.csv";
WriteCSV(filePathdRdPhi,stringArray);
WriteCSV(filePathdRdU,stringArray);
WriteCSV(filePathResiduals,stringArray);
WriteCSV(filePathDOFs,stringArray);

for(int n =0; n< nRefs;n++){
    //counter for level set type
    int iLS=1;
    //save cell resolution
    int reso= (int) Math.Pow(2,n+1);
    CellsVsRuntime_dRdPhi[n,0]=reso*reso;
    double[] dRdPhiResults= new double[optLsTypes.Length +1];
    dRdPhiResults[0]=reso*reso;
    double[] dRdUResults=dRdPhiResults.CloneAs();
    double[] resiudalResults=dRdPhiResults.CloneAs();
    double[] DOFs=dRdPhiResults.CloneAs();
    foreach(OptiLevelSetType lstype in optLsTypes){
        var pSAIDT = new SAIDTMain();
        var CSAIDT = SAIDTHardCodedControl.StraightShock(
                            dbPath: null,
                            MaxIterations: 1,
                            dgDegree: 0,
                            numOfCellsX: reso,
                            numOfCellsY: reso,
                            OptiNumOfCellsX: reso,
                            OptiNumOfCellsY: reso,
                            agg: 0.4,
                            ImmediatePlotPeriod: -1,
                            optiLevelSetType: lstype,
                            LSDegree: 3,
                            isFarConfig:true);

        pSAIDT.Init(CSAIDT);    
        pSAIDT.InitializeEverything();
        //pSAIDT.RunSolverMode();

        //Measure time for creation of Jacobians dRdPhi
        Stopwatch stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.FD_LevelSet();
        stopwatch.Stop();
        CellsVsRuntime_dRdPhi[n,iLS] =stopwatch.ElapsedMilliseconds;
        dRdPhiResults[iLS]=stopwatch.ElapsedMilliseconds;

        //Measure time for creation of Jacobians dRdU
        stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.Oproblem.GetJacobians(pSAIDT.ConservativeFields, pSAIDT.XSpatialOperator.LinearizationHint);
        stopwatch.Stop(); 
        CellsVsRuntime_dRdU[n,iLS] =stopwatch.ElapsedMilliseconds;
        dRdUResults[iLS]=stopwatch.ElapsedMilliseconds;

        //Measure time for evaluation of the Residuals
        stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.ComputeResiduals();
        stopwatch.Stop(); Console.WriteLine("Elapsed Time: " + stopwatch.ElapsedMilliseconds + "ms");
        CellsVsRuntime_Residuals[n,iLS] =stopwatch.ElapsedMilliseconds;
        resiudalResults[iLS]=stopwatch.ElapsedMilliseconds;

        DOFs[iLS]=pSAIDT.LevelSetOpti.GetLength();

        iLS++;
    }
    // Append the new row to the existing CSV file
    AppendRowToCSV(filePathdRdPhi, dRdPhiResults);
    AppendRowToCSV(filePathdRdU, dRdUResults);
    AppendRowToCSV(filePathResiduals, resiudalResults);
    AppendRowToCSV(filePathDOFs, DOFs);
}

# %%
public PlotFormat GetFormat(int count){
    
    var allPT = new BoSSS.Solution.Gnuplot.PointTypes[] { PointTypes.Diamond, PointTypes.LowerTriangle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle,PointTypes.Diamond, PointTypes.LowerTriangle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle};
    var allC = new BoSSS.Solution.Gnuplot.LineColors[] { LineColors.Blue, LineColors.Black, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red};
    var Fmt = new PlotFormat();
    Fmt.PointSize = 0.8;
    Fmt.LineWidth = 1;    
    Fmt.Style     = Styles.LinesPoints;

    Fmt.LineColor = allC[count];
    Fmt.PointType =  allPT[count];
    return Fmt;
}

# %%
var plot = new Plot2Ddata();
var cells = CellsVsRuntime_dRdPhi.Co;
int count=0;
foreach(OptiLevelSetType lstype in optLsTypes){
    runtimes.
    plot.AddDataGroup(lstype.ToString,cells,runtimes, GetFormat(count));
    count++;
}
plot.Xlabel="number of Cells"";
plot.LogY = true;
plot.LogX = true;
plot.ShowXtics = true;
plot.ToGnuplot().PlotSVG(xRes:1200,yRes:600)
