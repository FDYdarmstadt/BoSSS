# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\SAIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using SAIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %% [markdown]
# # Run Simulation

# %%
var date = DateTime.Now.ToString("ddMMyyyy");
date
# Out:
# 22032024

# %% [markdown]
# open a database

# %%
string dbPath = @"SAIDT_db_" + date ;
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Creating database 'SAIDT_db_22032024'.

# %%
Dictionary<string,int> DOFS = new Dictionary<string,int>();

# %% [markdown]
# ## SinglePhaseField

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SinglePhaseField,
                    LSDegree: 3
                    );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SinglePhaseField",pSAIDT.LsTBO.DOFLocal);
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# rm XESFWedgeFlow_TwoLs_0.plt;
# Session ID: bd80f014-eff5-40b4-a24f-27f1cdb597b9, DB path: 'SAIDT_db_22032024'
# Session directory 'SAIDT_db_22032024\sessions\bd80f014-eff5-40b4-a24f-27f1cdb597b9'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Initial Value : l2: |r|= 1.5458527E+00, |f_err|=2.9597349E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 1.7458658464628456, 5.403534981138808
# l2: ||R0||= 6.6536702E-01, f_err=1.772104E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.94E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1448.799942310297
#     L2 Norm of Solution:    0.13068801955234102
#     L2 Norm of Residual:    0.003060021010584848
#     Relative Residual norm: 1.785701228894962E-09
#     Matrix Inf norm:        1713624.2956378923
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1448.799942310297
#     L2 Norm of Solution:    0.1306887527027411
#     L2 Norm of Residual:    0.0035164746181022164
#     Relative Residual norm: 2.052068605150826E-09
#     Matrix Inf norm:        1713624.2956378923
# alpha, M, predM  1, 5.918965645728261, 1.5807884494042295
# alpha, M, predM  0.5, 4.840864035732023, 1.5807884494042295
# alpha, M, predM  0.25, 4.4258437989179376, 1.5807884494042295
# alpha, M, predM  0.125, 3.5770494778816087, 1.5807884494042295
# alpha, M, predM  0.0625, 2.322115407129315, 1.5807884494042295
# alpha, M, predM  0.03125, 1.6155666882725068, 1.5807884494042295
# alpha, M, predM  0.015625, 1.5039839613117334, 1.5807884494042295
# l2: ||R0||= 6.4336967E-01, f_err=1.728458E+00, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 4.93E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1298.636707072156
#     L2 Norm of Solution:    0.14839257471504635
#     L2 Norm of Residual:    0.008749457382156238
#     Relative Residual norm: 6.159736262934905E-09
#     Matrix Inf norm:        1420427.2729669465
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1298.636707072156
#     L2 Norm of Solution:    0.14839237251561674
#     L2 Norm of Residual:    0.007486806239491482
#     Relative Residual norm: 5.27081279131825E-09
#     Matrix Inf norm:        1420427.2729669465
# alpha, M, predM  1, 3.3033765650463423, 1.505467886730881
# alpha, M, predM  0.5, 3.2271343978999254, 1.505467886730881
# alpha, M, predM  0.25, 3.019507697127392, 1.505467886730881
# alpha, M, predM  0.125, 3.3284332917927695, 1.505467886730881
# alpha, M, predM  0.0625, 2.6519322536842806, 1.505467886730881
# alpha, M, predM  0.03125, 2.3434910933206208, 1.505467886730881
# alpha, M, predM  0.015625, 1.740173336276417, 1.505467886730881
# alpha, M, predM  0.0078125, 1.610589713606503, 1.505467886730881
# alpha, M, predM  0.00390625, 1.5553552878380215, 1.505467886730881
# alpha, M, predM  0.001953125, 1.499407101412306, 1.505467886730881
# l2: ||R0||= 6.4179436E-01, f_err=1.724817E+00, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 5.78E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1261.431241893653
#     L2 Norm of Solution:    0.1622575658124636
#     L2 Norm of Residual:    0.00568905188187583
#     Relative Residual norm: 4.2383383047360614E-09
#     Matrix Inf norm:        1342283.5726725005
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1261.431241893653
#     L2 Norm of Solution:    0.16225711150996552
#     L2 Norm of Residual:    0.006326096507086027
#     Relative Residual norm: 4.712935951745802E-09
#     Matrix Inf norm:        1342283.5726725005
# alpha, M, predM  1, 4.951188222447828, 1.497774205861381
# alpha, M, predM  0.5, 3.6706854176164168, 1.497774205861381
# alpha, M, predM  0.25, 3.271439126036887, 1.497774205861381
# alpha, M, predM  0.125, 2.723400085588635, 1.497774205861381
# alpha, M, predM  0.0625, 2.40777327460083, 1.497774205861381
# alpha, M, predM  0.03125, 2.2951348095193107, 1.497774205861381
# alpha, M, predM  0.015625, 1.8423988864747125, 1.497774205861381
# alpha, M, predM  0.0078125, 1.6708163205443098, 1.497774205861381
# alpha, M, predM  0.00390625, 1.596053811682857, 1.497774205861381
# alpha, M, predM  0.001953125, 1.558912810194153, 1.497774205861381
# alpha, M, predM  0.0009765625, 1.6329475360610592, 1.497774205861381
# alpha, M, predM  0.00048828125, 1.4965677959794164, 1.497774205861381
# l2: ||R0||= 6.4145581E-01, f_err=1.723959E+00, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 5.13E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1248.7357959252038
#     L2 Norm of Solution:    32.72013994166999
#     L2 Norm of Residual:    8.978519352321921
#     Relative Residual norm: 6.8233207147704425E-06
#     Matrix Inf norm:        1315857.7366715476
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1248.7357959252038
#     L2 Norm of Solution:    32.71998320869955
#     L2 Norm of Residual:    7.906756860719306
#     Relative Residual norm: 6.008823477163564E-06
#     Matrix Inf norm:        1315857.7366715476
# alpha, M, predM  1, 4.507920277043148, 1.493960600212608
# alpha, M, predM  0.5, 4.56965166382025, 1.493960600212608
# alpha, M, predM  0.25, 3.5391002097462816, 1.493960600212608
# alpha, M, predM  0.125, 2.6301487656290696, 1.493960600212608
# alpha, M, predM  0.0625, 3.149572580743522, 1.493960600212608
# alpha, M, predM  0.03125, 2.439541818701561, 1.493960600212608
# alpha, M, predM  0.015625, 1.9050079599731355, 1.493960600212608
# alpha, M, predM  0.0078125, 1.7052443180853325, 1.493960600212608
# alpha, M, predM  0.00390625, 1.6135607320193568, 1.493960600212608
# alpha, M, predM  0.001953125, 1.5727057894877854, 1.493960600212608
# alpha, M, predM  0.0009765625, 1.554135178694747, 1.493960600212608
# alpha, M, predM  0.00048828125, 1.6149447385512783, 1.493960600212608
# alpha, M, predM  0.000244140625, 1.4935157229579992, 1.493960600212608
# l2: ||R0||= 6.4129295E-01, f_err=1.72354E+00, f_phi=0E+00, Alpha = 2.44E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu =
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4072217266494
#     L2 Norm of Solution:    417.66361041098946
#     L2 Norm of Residual:    11.904199902682294
#     Relative Residual norm: 9.153328916515674E-06
#     Matrix Inf norm:        1300532.2993695906
# alpha, M, predM  1, 3.553483986182136, 1.4862972459665644
# alpha, M, predM  0.5, 4.19520637432378, 1.4862972459665644
# alpha, M, predM  0.25, 3.5091486535745093, 1.4862972459665644
# alpha, M, predM  0.125, 2.8104051456240096, 1.4862972459665644
# alpha, M, predM  0.0625, 3.5929564724781855, 1.4862972459665644
# alpha, M, predM  0.03125, 2.7839937486972444, 1.4862972459665644
# alpha, M, predM  0.015625, 2.1064533287164546, 1.4862972459665644
# alpha, M, predM  0.0078125, 1.7765567867951833, 1.4862972459665644
# alpha, M, predM  0.00390625, 1.6428521466100856, 1.4862972459665644
# alpha, M, predM  0.001953125, 1.5896371461642813, 1.4862972459665644
# alpha, M, predM  0.0009765625, 1.5535378129926984, 1.4862972459665644
# alpha, M, predM  0.00048828125, 1.5537172250523752, 1.4862972459665644
# alpha, M, predM  0.000244140625, 1.592333195206096, 1.4862972459665644
# alpha, M, predM  0.0001220703125, 1.6661344058842367, 1.4862972459665644
# alpha, M, predM  6.103515625E-05, 1.9796652201339653, 1.4862972459665644
# alpha, M, predM  3.0517578125E-05, 1.486503297437386, 1.4862972459665644
# alpha, M, predM  1.52587890625E-05, 1.4865489373100331, 1.4862972459665644
# alpha, M, predM  7.62939453125E-06, 1.4865716819688095, 1.4862972459665644
# alpha, M, predM  3.814697265625E-06, 1.486583035504423, 1.4862972459665644
# alpha, M, predM  1.9073486328125E-06, 1.4865887075769795, 1.4862972459665644
# alpha, M, predM  9.5367431640625E-07, 1.4865915424398433, 1.4862972459665644
# alpha, M, predM  4.76837158203125E-07, 1.4865929595779706, 1.4862972459665644
# alpha, M, predM  2.384185791015625E-07, 1.486593668073718, 1.4862972459665644
# alpha, M, predM  1.1920928955078125E-07, 1.4865940223032583, 1.4862972459665644
# alpha, M, predM  5.960464477539063E-08, 1.4865941994134482, 1.4862972459665644
# alpha, M, predM  2.9802322387695312E-08, 1.4865942879674001, 1.4862972459665644
# alpha, M, predM  1.4901161193847656E-08, 1.4865943322440847, 1.4862972459665644
# l2: ||R0||= 6.4130789E-01, f_err=1.723602E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 5.8E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4310835964156
#     L2 Norm of Solution:    122.96646542177794
#     L2 Norm of Residual:    4.234447613365983
#     Relative Residual norm: 3.255859029348389E-06
#     Matrix Inf norm:        1300562.3324586765
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4310835964156
#     L2 Norm of Solution:    122.96643661844504
#     L2 Norm of Residual:    3.604578828109196
#     Relative Residual norm: 2.771554071764358E-06
#     Matrix Inf norm:        1300562.3324586765
# alpha, M, predM  1, 3.573222676725732, 1.4862404848642676
# alpha, M, predM  0.5, 4.226798221275061, 1.4862404848642676
# alpha, M, predM  0.25, 3.5549672618438013, 1.4862404848642676
# alpha, M, predM  0.125, 2.821745575439992, 1.4862404848642676
# alpha, M, predM  0.0625, 3.603878160301148, 1.4862404848642676
# alpha, M, predM  0.03125, 2.792841899454384, 1.4862404848642676
# alpha, M, predM  0.015625, 2.1121919437667223, 1.4862404848642676
# alpha, M, predM  0.0078125, 1.7784727154969981, 1.4862404848642676
# alpha, M, predM  0.00390625, 1.6436766475942992, 1.4862404848642676
# alpha, M, predM  0.001953125, 1.590045927049537, 1.4862404848642676
# alpha, M, predM  0.0009765625, 1.553642427951775, 1.4862404848642676
# alpha, M, predM  0.00048828125, 1.5534507996338125, 1.4862404848642676
# alpha, M, predM  0.000244140625, 1.591918071769807, 1.4862404848642676
# alpha, M, predM  0.0001220703125, 1.6652442156354141, 1.4862404848642676
# alpha, M, predM  6.103515625E-05, 1.9715422377294327, 1.4862404848642676
# alpha, M, predM  3.0517578125E-05, 1.4864465290247852, 1.4862404848642676
# alpha, M, predM  1.52587890625E-05, 1.4864921723552542, 1.4862404848642676
# alpha, M, predM  7.62939453125E-06, 1.4865149177627235, 1.4862404848642676
# alpha, M, predM  3.814697265625E-06, 1.4865262714280718, 1.4862404848642676
# alpha, M, predM  1.9073486328125E-06, 1.486531943504396, 1.4862404848642676
# alpha, M, predM  9.5367431640625E-07, 1.4865347783538836, 1.4862404848642676
# alpha, M, predM  4.76837158203125E-07, 1.4865361954815066, 1.4862404848642676
# alpha, M, predM  2.384185791015625E-07, 1.486536903971045, 1.4862404848642676
# alpha, M, predM  1.1920928955078125E-07, 1.4865372581972442, 1.4862404848642676
# alpha, M, predM  5.960464477539063E-08, 1.4865374353057033, 1.4862404848642676
# alpha, M, predM  2.9802322387695312E-08, 1.4865375238587728, 1.4862404848642676
# alpha, M, predM  1.4901161193847656E-08, 1.4865375681350128, 1.4862404848642676
# l2: ||R0||= 6.4131002E-01, f_err=1.723611E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 5.45E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4549439586767
#     L2 Norm of Solution:    97.54661545651095
#     L2 Norm of Residual:    3.945357079423584
#     Relative Residual norm: 3.0335078001424677E-06
#     Matrix Inf norm:        1300592.3634804208
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4549439586767
#     L2 Norm of Solution:    97.54660856072259
#     L2 Norm of Residual:    5.917777040402393
#     Relative Residual norm: 4.550062884089416E-06
#     Matrix Inf norm:        1300592.3634804208
# alpha, M, predM  1, 3.5983069761961364, 1.4862071727399941
# alpha, M, predM  0.5, 4.249210783225001, 1.4862071727399941
# alpha, M, predM  0.25, 3.6368181792487055, 1.4862071727399941
# alpha, M, predM  0.125, 2.8292439767376893, 1.4862071727399941
# alpha, M, predM  0.0625, 3.6111977786831555, 1.4862071727399941
# alpha, M, predM  0.03125, 2.7988000567830373, 1.4862071727399941
# alpha, M, predM  0.015625, 2.116065486212489, 1.4862071727399941
# alpha, M, predM  0.0078125, 1.779771739659501, 1.4862071727399941
# alpha, M, predM  0.00390625, 1.6442398165918184, 1.4862071727399941
# alpha, M, predM  0.001953125, 1.5903283782054962, 1.4862071727399941
# alpha, M, predM  0.0009765625, 1.5537193270491254, 1.4862071727399941
# alpha, M, predM  0.00048828125, 1.5532754517699718, 1.4862071727399941
# alpha, M, predM  0.000244140625, 1.591640274954232, 1.4862071727399941
# alpha, M, predM  0.0001220703125, 1.6646353023950182, 1.4862071727399941
# alpha, M, predM  6.103515625E-05, 1.9659426496713717, 1.4862071727399941
# alpha, M, predM  3.0517578125E-05, 1.4864132126410914, 1.4862071727399941
# alpha, M, predM  1.52587890625E-05, 1.486458858466053, 1.4862071727399941
# alpha, M, predM  7.62939453125E-06, 1.4864816044568372, 1.4862071727399941
# alpha, M, predM  3.814697265625E-06, 1.486492958248162, 1.4862071727399941
# alpha, M, predM  1.9073486328125E-06, 1.4864986303461003, 1.4862071727399941
# alpha, M, predM  9.5367431640625E-07, 1.4865014651960466, 1.4862071727399941
# alpha, M, predM  4.76837158203125E-07, 1.4865028823213167, 1.4862071727399941
# alpha, M, predM  2.384185791015625E-07, 1.486503590809031, 1.4862071727399941
# alpha, M, predM  1.1920928955078125E-07, 1.4865039450341606, 1.4862071727399941
# alpha, M, predM  5.960464477539063E-08, 1.4865041221420419, 1.4862071727399941
# alpha, M, predM  2.9802322387695312E-08, 1.4865042106948145, 1.4862071727399941
# alpha, M, predM  1.4901161193847656E-08, 1.486504254970909, 1.4862071727399941
# l2: ||R0||= 6.4131216E-01, f_err=1.72362E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 5.21E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.478803067748
#     L2 Norm of Solution:    178.502924757984
#     L2 Norm of Residual:    4.603923006416785
#     Relative Residual norm: 3.5397845173853314E-06
#     Matrix Inf norm:        1300622.3920707698
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.478803067748
#     L2 Norm of Solution:    178.5029252658765
#     L2 Norm of Residual:    6.557568988122992
#     Relative Residual norm: 5.04186997556027E-06
#     Matrix Inf norm:        1300622.3920707698
# alpha, M, predM  1, 3.616711909148113, 1.4861898201061885
# alpha, M, predM  0.5, 4.264655582363649, 1.4861898201061885
# alpha, M, predM  0.25, 3.5029782337496123, 1.4861898201061885
# alpha, M, predM  0.125, 2.83413861048692, 1.4861898201061885
# alpha, M, predM  0.0625, 3.616070388642428, 1.4861898201061885
# alpha, M, predM  0.03125, 2.802792893094236, 1.4861898201061885
# alpha, M, predM  0.015625, 2.1186738407502257, 1.4861898201061885
# alpha, M, predM  0.0078125, 1.780651353462852, 1.4861898201061885
# alpha, M, predM  0.00390625, 1.644625000086956, 1.4861898201061885
# alpha, M, predM  0.001953125, 1.5905250345784359, 1.4861898201061885
# alpha, M, predM  0.0009765625, 1.5537771454931673, 1.4861898201061885
# alpha, M, predM  0.00048828125, 1.553161325017556, 1.4861898201061885
# alpha, M, predM  0.000244140625, 1.59145450670845, 1.4861898201061885
# alpha, M, predM  0.0001220703125, 1.6642136959099045, 1.4861898201061885
# alpha, M, predM  6.103515625E-05, 1.9619507542034076, 1.4861898201061885
# alpha, M, predM  3.0517578125E-05, 1.4863958578401641, 1.4861898201061885
# alpha, M, predM  1.52587890625E-05, 1.486441505496749, 1.4861898201061885
# alpha, M, predM  7.62939453125E-06, 1.4864642519565758, 1.4861898201061885
# alpha, M, predM  3.814697265625E-06, 1.4864756058709345, 1.4861898201061885
# alpha, M, predM  1.9073486328125E-06, 1.4864812780025423, 1.4861898201061885
# alpha, M, predM  9.5367431640625E-07, 1.4864841128623658, 1.4861898201061885
# alpha, M, predM  4.76837158203125E-07, 1.486485529990833, 1.4861898201061885
# alpha, M, predM  2.384185791015625E-07, 1.4864862384797148, 1.4861898201061885
# alpha, M, predM  1.1920928955078125E-07, 1.4864865927053184, 1.4861898201061885
# alpha, M, predM  5.960464477539063E-08, 1.4864867698134125, 1.4861898201061885
# alpha, M, predM  2.9802322387695312E-08, 1.4864868583662803, 1.4861898201061885
# alpha, M, predM  1.4901161193847656E-08, 1.4864869026424214, 1.4861898201061885
# l2: ||R0||= 6.4131429E-01, f_err=1.723628E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 5.05E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5026612983254
#     L2 Norm of Solution:    101.31651167240801
#     L2 Norm of Residual:    2.4456223216914874
#     Relative Residual norm: 1.8803042894955304E-06
#     Matrix Inf norm:        1300652.4185229759
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5026612983254
#     L2 Norm of Solution:    101.31652766812556
#     L2 Norm of Residual:    2.857303866682035
#     Relative Residual norm: 2.196823552542036E-06
#     Matrix Inf norm:        1300652.4185229759
# alpha, M, predM  1, 3.632787721965801, 1.486183258050291
# alpha, M, predM  0.5, 4.276129314711485, 1.486183258050291
# alpha, M, predM  0.25, 3.5193993083326873, 1.486183258050291
# alpha, M, predM  0.125, 2.8372229395739184, 1.486183258050291
# alpha, M, predM  0.0625, 3.619276095040296, 1.486183258050291
# alpha, M, predM  0.03125, 2.8054528321787435, 1.486183258050291
# alpha, M, predM  0.015625, 2.120429193733049, 1.486183258050291
# alpha, M, predM  0.0078125, 1.781247848365368, 1.486183258050291
# alpha, M, predM  0.00390625, 1.6448900069342467, 1.486183258050291
# alpha, M, predM  0.001953125, 1.590664046879769, 1.486183258050291
# alpha, M, predM  0.0009765625, 1.5538220211520417, 1.486183258050291
# alpha, M, predM  0.00048828125, 1.5530879915174522, 1.486183258050291
# alpha, M, predM  0.000244140625, 1.5913298863332646, 1.486183258050291
# alpha, M, predM  0.0001220703125, 1.663915918093347, 1.486183258050291
# alpha, M, predM  6.103515625E-05, 1.958990420950597, 1.486183258050291
# alpha, M, predM  3.0517578125E-05, 1.4863892950414017, 1.486183258050291
# alpha, M, predM  1.52587890625E-05, 1.486434944076793, 1.486183258050291
# alpha, M, predM  7.62939453125E-06, 1.4864576909272562, 1.486183258050291
# alpha, M, predM  3.814697265625E-06, 1.486469044962391, 1.486183258050291
# alpha, M, predM  1.9073486328125E-06, 1.4864747171357668, 1.486183258050291
# alpha, M, predM  9.5367431640625E-07, 1.4864775520118259, 1.486183258050291
# alpha, M, predM  4.76837158203125E-07, 1.4864789691472466, 1.486183258050291
# alpha, M, predM  2.384185791015625E-07, 1.4864796776393108, 1.486183258050291
# alpha, M, predM  1.1920928955078125E-07, 1.4864800318664346, 1.486183258050291
# alpha, M, predM  5.960464477539063E-08, 1.4864802089752644, 1.486183258050291
# alpha, M, predM  2.9802322387695312E-08, 1.4864802975285023, 1.486183258050291
# alpha, M, predM  1.4901161193847656E-08, 1.4864803418048251, 1.486183258050291
# l2: ||R0||= 6.4131643E-01, f_err=1.723637E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 4.95E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5265198830707
#     L2 Norm of Solution:    1063.8242339775888
#     L2 Norm of Residual:    106151.65592944561
#     Relative Residual norm: 0.08161227691420994
#     Matrix Inf norm:        1300682.445620666
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5265198830707
#     L2 Norm of Solution:    610.0621021389555
#     L2 Norm of Residual:    57606.74247304553
#     Relative Residual norm: 0.04428962862303909
#     Matrix Inf norm:        1300682.445620666
# alpha, M, predM  1, 3.6519759621024903, 1.4861839603433538
# alpha, M, predM  0.5, 4.286065373968144, 1.4861839603433538
# alpha, M, predM  0.25, 3.531480977551618, 1.4861839603433538
# alpha, M, predM  0.125, 2.83899633562608, 1.4861839603433538
# alpha, M, predM  0.0625, 3.621332724712439, 1.4861839603433538
# alpha, M, predM  0.03125, 2.8072063317748475, 1.4861839603433538
# alpha, M, predM  0.015625, 2.1216121660516176, 1.4861839603433538
# alpha, M, predM  0.0078125, 1.7816543034288344, 1.4861839603433538
# alpha, M, predM  0.00390625, 1.645074501381832, 1.4861839603433538
# alpha, M, predM  0.001953125, 1.5907648285726004, 1.4861839603433538
# alpha, M, predM  0.0009765625, 1.553858244195996, 1.4861839603433538
# alpha, M, predM  0.00048828125, 1.55304146879275, 1.4861839603433538
# alpha, M, predM  0.000244140625, 1.5912453070753496, 1.4861839603433538
# alpha, M, predM  0.0001220703125, 1.6636988124024885, 1.4861839603433538
# alpha, M, predM  6.103515625E-05, 1.9566886424454744, 1.4861839603433538
# alpha, M, predM  3.0517578125E-05, 1.4863899975601031, 1.4861839603433538
# alpha, M, predM  1.52587890625E-05, 1.4864356476643692, 1.4861839603433538
# alpha, M, predM  7.62939453125E-06, 1.4864583948512604, 1.4861839603433538
# alpha, M, predM  3.814697265625E-06, 1.4864697490052055, 1.4861839603433538
# alpha, M, predM  1.9073486328125E-06, 1.4864754212256441, 1.4861839603433538
# alpha, M, predM  9.5367431640625E-07, 1.4864782561221477, 1.4861839603433538
# alpha, M, predM  4.76837158203125E-07, 1.4864796732670231, 1.4861839603433538
# alpha, M, predM  2.384185791015625E-07, 1.4864803817636225, 1.4861839603433538
# alpha, M, predM  1.1920928955078125E-07, 1.4864807359929662, 1.4861839603433538
# alpha, M, predM  5.960464477539063E-08, 1.4864809131028973, 1.4861839603433538
# alpha, M, predM  2.9802322387695312E-08, 1.4864810016566747, 1.4861839603433538
# alpha, M, predM  1.4901161193847656E-08, 1.48648104593327, 1.4861839603433538
# l2: ||R0||= 6.4131856E-01, f_err=1.723646E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 4.88E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5503790435764
#     L2 Norm of Solution:    10.371718924373399
#     L2 Norm of Residual:    0.22526613848678986
#     Relative Residual norm: 1.7318672885649464E-07
#     Matrix Inf norm:        1300712.4736067338
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5503790435764
#     L2 Norm of Solution:    10.371719803517728
#     L2 Norm of Residual:    0.32559985343195563
#     Relative Residual norm: 2.503242338632325E-07
#     Matrix Inf norm:        1300712.4736067338
# alpha, M, predM  1, 3.6969481878933106, 1.4861895460227592
# alpha, M, predM  0.5, 4.300126322338759, 1.4861895460227592
# alpha, M, predM  0.25, 3.5422429511106386, 1.4861895460227592
# alpha, M, predM  0.125, 2.8399143085234, 1.4861895460227592
# alpha, M, predM  0.0625, 3.6225739417129112, 1.4861895460227592
# alpha, M, predM  0.03125, 2.8083350603568835, 1.4861895460227592
# alpha, M, predM  0.015625, 2.1224125617935683, 1.4861895460227592
# alpha, M, predM  0.0078125, 1.7819338874046495, 1.4861895460227592
# alpha, M, predM  0.00390625, 1.6452055790942868, 1.4861895460227592
# alpha, M, predM  0.001953125, 1.5908408202433937, 1.4861895460227592
+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.75E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.8367855529752
#     L2 Norm of Solution:    32.17370937631763
#     L2 Norm of Residual:    0.2705638730480857
#     Relative Residual norm: 2.079544181656184E-07
#     Matrix Inf norm:        1301072.9727925477
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.8367855529752
#     L2 Norm of Solution:    32.17370789847915
#     L2 Norm of Residual:    0.3957726263112044
#     Relative Residual norm: 3.0418941488096627E-07
#     Matrix Inf norm:        1301072.9727925477
# alpha, M, predM  1, 9.862851121665752, 1.4863572607026783
# alpha, M, predM  0.5, 5.886484936307779, 1.4863572607026783
# alpha, M, predM  0.25, 4.31779912334699, 1.4863572607026783
# alpha, M, predM  0.125, 3.0607623041859715, 1.4863572607026783
# alpha, M, predM  0.0625, 3.67399184177865, 1.4863572607026783
# alpha, M, predM  0.03125, 2.8182647472056246, 1.4863572607026783
# alpha, M, predM  0.015625, 2.1243279247369062, 1.4863572607026783
# alpha, M, predM  0.0078125, 1.782736478313342, 1.4863572607026783
# alpha, M, predM  0.00390625, 1.6457155426368106, 1.4863572607026783
# alpha, M, predM  0.001953125, 1.5912846190218382, 1.4863572607026783
# alpha, M, predM  0.0009765625, 1.5541471792682604, 1.4863572607026783
# alpha, M, predM  0.00048828125, 1.5529745033279487, 1.4863572607026783
# alpha, M, predM  0.000244140625, 1.5909360468557536, 1.4863572607026783
# alpha, M, predM  0.0001220703125, 1.6624439329187137, 1.4863572607026783
# alpha, M, predM  6.103515625E-05, 1.939582381215539, 1.4863572607026783
# alpha, M, predM  3.0517578125E-05, 1.4865633238230498, 1.4863572607026783
# alpha, M, predM  1.52587890625E-05, 1.4866089801649431, 1.4863572607026783
# alpha, M, predM  7.62939453125E-06, 1.4866317303377408, 1.4863572607026783
# alpha, M, predM  3.814697265625E-06, 1.4866430859515831, 1.4863572607026783
# alpha, M, predM  1.9073486328125E-06, 1.4866487588937314, 1.4863572607026783
# alpha, M, predM  9.5367431640625E-07, 1.486651594149035, 1.4863572607026783
# alpha, M, predM  4.76837158203125E-07, 1.4866530114727923, 1.4863572607026783
# alpha, M, predM  2.384185791015625E-07, 1.4866537200587084, 1.4863572607026783
# alpha, M, predM  1.1920928955078125E-07, 1.486654074332672, 1.4863572607026783
# alpha, M, predM  5.960464477539063E-08, 1.486654251464906, 1.4863572607026783
# alpha, M, predM  2.9802322387695312E-08, 1.4866543400298387, 1.4863572607026783
# alpha, M, predM  1.4901161193847656E-08, 1.4866543843120101, 1.4863572607026783
# l2: ||R0||= 6.4134631E-01, f_err=1.723762E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.75E-03, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:600,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="600" height="500"
#  viewBox="0 0 600 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="600" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,381.2 L50.1,381.2 M550.1,381.2 L545.6,381.2 M45.6,345.5 L50.1,345.5 M550.1,345.5 L545.6,345.5
# 		M45.6,320.1 L50.1,320.1 M550.1,320.1 L545.6,320.1 M45.6,300.4 L50.1,300.4 M550.1,300.4 L545.6,300.4
# 		M45.6,284.3 L50.1,284.3 M550.1,284.3 L545.6,284.3 M45.6,270.7 L50.1,270.7 M550.1,270.7 L545.6,270.7
# 		M45.6,258.9 L50.1,258.9 M550.1,258.9 L545.6,258.9 M45.6,248.5 L50.1,248.5 M550.1,248.5 L545.6,248.5
# 		M45.6,239.2 L54.6,239.2 M550.1,239.2 L541.1,239.2  '/>	<g transform="translate(37.3,245.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,178.1 L50.1,178.1 M550.1,178.1 L545.6,178.1 M45.6,142.3 L50.1,142.3 M550.1,142.3 L545.6,142.3
# 		M45.6,116.9 L50.1,116.9 M550.1,116.9 L545.6,116.9 M45.6,97.3 L50.1,97.3 M550.1,97.3 L545.6,97.3
# 		M45.6,81.2 L50.1,81.2 M550.1,81.2 L545.6,81.2 M45.6,67.6 L50.1,67.6 M550.1,67.6 L545.6,67.6
# 		M45.6,55.8 L50.1,55.8 M550.1,55.8 L545.6,55.8 M45.6,45.4 L50.1,45.4 M550.1,45.4 L545.6,45.4
# 		M45.6,36.1 L54.6,36.1 M550.1,36.1 L541.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M129.7,442.4 L129.7,433.4 M129.7,36.1 L129.7,45.1  '/>	<g transform="translate(129.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M213.8,442.4 L213.8,433.4 M213.8,36.1 L213.8,45.1  '/>	<g transform="translate(213.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M297.8,442.4 L297.8,433.4 M297.8,36.1 L297.8,45.1  '/>	<g transform="translate(297.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 15</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M381.9,442.4 L381.9,433.4 M381.9,36.1 L381.9,45.1  '/>	<g transform="translate(381.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M466.0,442.4 L466.0,433.4 M466.0,36.1 L466.0,45.1  '/>	<g transform="translate(466.0,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 25</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M550.1,442.4 L550.1,433.4 M550.1,36.1 L550.1,45.1  '/>	<g transform="translate(550.1,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 30</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(558.4,446.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="start">
# 		<text><tspan font-family="Arial" > </tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M550.1,384.4 L541.1,

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;

# %% [markdown]
# ## Spline level set

# %%
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SplineLevelSet,
                    LSDegree: 3,
                    isFarConfig:true
                    );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SplineLevelSet",pSAIDT.LevelSetOpti.GetLength());
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Session ID: 5879d8bf-9926-441c-97ea-5b7286b004c2, DB path: 'SAIDT_db_22032024'
# Session directory 'SAIDT_db_22032024\sessions\5879d8bf-9926-441c-97ea-5b7286b004c2'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Initial Value : l2: |r|= 1.4635787E+00, |f_err|=2.8278013E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         222657.87182710806
#     L2 Norm of Solution:    36.85693402507989
#     L2 Norm of Residual:    143347.50947617946
#     Relative Residual norm: 1.9572204068936025E-07
#     Matrix Inf norm:        732403509442.726
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         222657.87182710806
#     L2 Norm of Solution:    36.85693402507989
#     L2 Norm of Residual:    143347.50947617946
#     Relative Residual norm: 1.9572204068936025E-07
#     Matrix Inf norm:        732403509442.726
# alpha, M, predM  1, 4.172793915844592, 7.050963838425317
# l2: ||R0||= 1.035425E+00, f_err=2.338934E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.68E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 1.3358847507860003, 7.208562944502188
# l2: ||R0||= 3.9390809E-01, f_err=1.574745E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.24E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 5.515357265735162, 1.571577515927482
# alpha, M, predM  0.5, 1.6590189937944029, 1.571577515927482
# alpha, M, predM  0.25, 1.0655689631686727, 1.571577515927482
# l2: ||R0||= 2.9957253E-01, f_err=1.427402E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.04E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 0.9779288922964557, 1.0621675010322642
# l2: ||R0||= 4.0731829E-01, f_err=1.315058E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.37E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.7953478622409045, 0.82549022293531
# l2: ||R0||= 3.7698537E-01, f_err=1.162351E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.69E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 0.4342108440213177, 0.7327439086723041
# l2: ||R0||= 2.1249691E-01, f_err=9.039431E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.14E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.3791738249127408, 0.4186333268159225
# l2: ||R0||= 3.3553646E-01, f_err=8.374689E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.06E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.18427612484468833, 0.4073809045039056
# l2: ||R0||= 2.0105252E-01, f_err=5.778825E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.56E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.04944362182475779, 0.17748291148475384
# l2: ||R0||= 8.8272809E-02, f_err=3.079248E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.22E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.0341266308413181, 0.046648311414457036
# l2: ||R0||= 4.76222E-02, f_err=2.597731E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.4E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.016172285845019077, 0.040557301036272746
# l2: ||R0||= 2.670216E-02, f_err=1.792851E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.82E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.00801372129492201, 0.016143370867684415
# l2: ||R0||= 1.8402026E-03, f_err=1.265968E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.05E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.004570447886209644, 0.007956373146879385
# l2: ||R0||= 2.1131073E-03, f_err=9.560335E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.01E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.002791271825592082, 0.004570104565941685
# l2: ||R0||= 2.7224946E-03, f_err=7.470918E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.46E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.0019033953504698723, 0.0027911761608614676
# l2: ||R0||= 1.4775844E-03, f_err=6.169647E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.54E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.001241994247704841, 0.0019032532844926468
# l2: ||R0||= 2.9778986E-03, f_err=4.98302E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.06E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.0010769816897404985, 0.0012420035360848616
# l2: ||R0||= 4.1556228E-03, f_err=4.638866E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.19E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.0007776896419156484, 0.0010768792427752066
# l2: ||R0||= 1.0363041E-03, f_err=3.943677E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.12E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.000641295875457265, 0.0007776528887259385
# l2: ||R0||= 2.8574372E-03, f_err=3.58023E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.64E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 0.00048055263706593264, 0.000641241252772932
# l2: ||R0||= 1.1778773E-03, f_err=3.09997E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.94E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 0.0003752152721159696, 0.00048053293200379395
# l2: ||R0||= 5.1743914E-04, f_err=2.73936E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.03E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 0.0002744550114516477, 0.0003751990328161155
# l2: ||R0||= 1.2856159E-03, f_err=2.342644E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 6.78E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 0.00019382808201415765, 0.00027443459391059
# l2: ||R0||= 1.7668548E-03, f_err=1.968448E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 5.68E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 0.00014223505591010946, 0.0001938090909851706
# l2: ||R0||= 7.6406429E-04, f_err=1.686538E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 4.95E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 7.447167768842382E-05, 0.0001422183411434247
# l2: ||R0||= 1.4581631E-03, f_err=1.220207E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.49E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 5.761898203153239E-05, 7.447662362191871E-05
# l2: ||R0||= 4.8633414E-04, f_err=1.073454E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 3.2E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 3.0401957268268596E-05, 5.761402997650967E-05
# l2: ||R0||= 1.0164383E-03, f_err=7.796215E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 2.22E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 1.1684068383746177E-05, 3.0395310404435706E-05
# l2: ||R0||= 2.7127615E-04, f_err=4.833951E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 1.43E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 3.82172867282907E-06, 1.1682578632764276E-05
# l2: ||R0||= 6.2037309E-04, f_err=2.764181E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 7.17E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 6.143489504957626E-07, 3.820201687544616E-06
# l2: ||R0||= 1.9435889E-04, f_err=1.108434E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 1.91E-03, QuadOrder=4
# ALNR=1.1789244006935016 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 1.6261216686562987E-07, 6.142474626290349E-07
# l2: ||R0||= 1.8292805E-04, f_err=5.70252E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.1E-03, QuadOrder=4
# ALNR=1.1878512754567443 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 8.268972704905031E-09, 1.62570449880333E-07
# l2: ||R0||= 2.2947382E-05, f_err=1.285995E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 2.3E-04, QuadOrder=4
# ALNR=2.1837985265161515 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 1.3080725056481373E-09, 8.26762162302825E-09
# l2: ||R0||= 1.9826143E-05, f_err=5.1148E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 6.82E-05, QuadOrder=4
# ALNR=2.1971517254839164 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 1.2901258590714545E-11, 1.3078894126265249E-09
# l2: ||R0||= 9.6382885E-07, f_err=5.079617E-06, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 9.78E-06, QuadOrder=4
# ALNR=4.992893215211808 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 1.300479139944607E-13, 1.290627264459619E-11
# l2: ||R0||= 8.2139834E-08, f_err=5.099959E-07, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 1.35E-06, QuadOrder=4
# ALNR=6.413069847796463 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 8.287870823600161E-16, 1.3038944118199532E-13
# l2: ||R0||= 1.475694E-08, f_err=4.071332E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 5.79E-08, QuadOrder=4
# ALNR=7.065381772241488 > 1.005 so we continue
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 6.055552938328411E-17, 9.554943450956205E-16
# l2: ||R0||= 7.4226451E-09, f_err=1.100505E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 8.3E-09, QuadOrder=4
# ALNR=7.150002988381623 > 1.005 so we continue
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 7.953767100235067E-17, 1.1429075507618862E-16
# l2: ||R0||= 8.6015367E-09, f_err=1.261251E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 1.09E-09, QuadOrder=4
# ALNR=7.1410761136183805 > 1.005 so we continue
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 8.865956034074688E-17, 1.5008860528384716E-16
# l2: ||R0||= 9.2612664E-09, f_err=1.331612E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 3.76E-10, QuadOrder=4
# ALNR=6.145128862558974 > 1.005 so we continue
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 9.098682307071634E-17, 1.6273855717727333E-16
# l2: ||R0||= 9.4044205E-09, f_err=1.348976E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 3.78E-10, QuadOrder=4
# ALNR=6.122638797004889 > 1.005 so we continue
#
#
# Starting Opt-Iter No.41:
# alpha, M, predM  1, 8.602086501060535E-17, 1.658949070300425E-16
# l2: ||R0||= 9.1606424E-09, f_err=1.311647E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 2.89E-10, QuadOrder=4
# ALNR=3.3268973072769983 > 1.005 so we continue
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 7.757818160396962E-17, 1.5917135712744866E-16
# l2: ||R0||= 8.713529E-09, f_err=1.245618E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.77E-04, Kappa = 1E+03, Mu = 2.14E-10, QuadOrder=4
# ALNR=1.7934686634669141 > 1.005 so we continue
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 6.879471153563921E-17, 1.476134556904416E-16
# l2: ||R0||= 8.2161721E-09, f_err=1.172985E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.51E-04, Kappa = 1E+03, Mu = 1.55E-10, QuadOrder=4
# ALNR=1.141156739021889 > 1.005 so we continue
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 6.13197154028168E-17, 1.35401105189034E-16
# l2: ||R0||= 7.7646741E-09, f_err=1.107427E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.01E-04, Kappa = 1E+03, Mu = 1.12E-10, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:600,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="600" height="500"
#  viewBox="0 0 600 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="600" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-9</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,401.8 L54.6,401.8 M550.1,401.8 L541.1,401.8  '/>	<g transform="translate(37.3,407.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,361.1 L54.6,361.1 M550.1,361.1 L541.1,361.1  '/>	<g transform="translate(37.3,367.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-7</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,320.5 L54.6,320.5 M550.1,320.5 L541.1,320.5  '/>	<g transform="translate(37.3,326.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,279.9 L54.6,279.9 M550.1,279.9 L541.1,279.9  '/>	<g transform="translate(37.3,285.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-5</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,239.2 L54.6,239.2 M550.1,239.2 L541.1,239.2  '/>	<g transform="translate(37.3,245.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,198.6 L54.6,198.6 M550.1,198.6 L541.1,198.6  '/>	<g transform="translate(37.3,204.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,158.0 L54.6,158.0 M550.1,158.0 L541.1,158.0  '/>	<g transform="translate(37.3,164.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,117.4 L54.6,117.4 M550.1,117.4 L541.1,117.4  '/>	<g transform="translate(37.3,123.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,76.7 L54.6,76.7 M550.1,76.7 L541.1,76.7  '/>	<g transform="translate(37.3,82.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,36.1 L54.6,36.1 M550.1,36.1 L541.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;

# %% [markdown]
# ## SpecFemField

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SpecFemField,
                    LSDegree: 3,
                    isFarConfig:true
                    );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SpecFemField",pSAIDT.LevelSetOpti.GetLength());
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_31.plt ScalarAdvection_SP_32.plt ScalarAdvection_SP_33.plt ScalarAdvection_SP_34.plt ScalarAdvection_SP_35.plt ScalarAdvection_SP_36.plt ScalarAdvection_SP_37.plt ScalarAdvection_SP_38.plt ScalarAdvection_SP_39.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_40.plt ScalarAdvection_SP_41.plt ScalarAdvection_SP_42.plt ScalarAdvection_SP_43.plt ScalarAdvection_SP_44.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Session ID: dc04ee62-71d7-42ee-b6ba-d97bdbb1f3a0, DB path: 'SAIDT_db_22032024'
# Session directory 'SAIDT_db_22032024\sessions\dc04ee62-71d7-42ee-b6ba-d97bdbb1f3a0'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Initial Value : l2: |r|= 1.448461E+00, |f_err|=2.8259626E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         123.05190702767374
#     L2 Norm of Solution:    2.4124860984455396
#     L2 Norm of Residual:    0.5667692699079714
#     Relative Residual norm: 7.736028596898637E-08
#     Matrix Inf norm:        7326359.550108029
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         123.05190702767374
#     L2 Norm of Solution:    2.4121214157695006
#     L2 Norm of Residual:    0.6189097997610035
#     Relative Residual norm: 8.447712612628703E-08
#     Matrix Inf norm:        7326359.550108029
# alpha, M, predM  1, 2.20585956014825, 7.068239285340206
# l2: ||R0||= 6.3580548E-01, f_err=1.822502E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.7E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 1.0769126277770233, 1.8868537065124016
# l2: ||R0||= 3.9584659E-01, f_err=1.40667E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.12E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 1.169158955418534, 1.1821039928159285
# l2: ||R0||= 4.448672E-01, f_err=1.430887E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.47E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 0.7966462570003043, 1.9139942274348327
# l2: ||R0||= 2.7479332E-01, f_err=1.221145E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.35E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.5928484846733725, 0.8116731253624886
# l2: ||R0||= 1.2569566E-01, f_err=1.076099E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.75E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 1.319529929399843, 0.7960116921335426
# alpha, M, predM  0.5, 0.8347754704884357, 0.7960116921335426
# alpha, M, predM  0.25, 0.7299569964170961, 0.7960116921335426
# l2: ||R0||= 1.389007E-01, f_err=1.197296E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.37E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.5178538621841846, 0.7298771221992112
# l2: ||R0||= 5.1473521E-02, f_err=1.01592E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.36E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.48595541751940047, 0.5182413217951791
# l2: ||R0||= 1.9690634E-01, f_err=9.559292E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.5E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.7357438848755151, 0.4711466306125295
# alpha, M, predM  0.5, 0.5059171868580551, 0.4711466306125295
# alpha, M, predM  0.25, 0.4437470552020465, 0.4711466306125295
# l2: ||R0||= 1.8116279E-01, f_err=9.143279E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.57E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.3963913964965738, 0.44354742558711147
# l2: ||R0||= 2.0152407E-01, f_err=8.552059E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.51E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.5298279063081954, 0.39341112946668333
# alpha, M, predM  0.5, 0.3787967117709633, 0.39341112946668333
# l2: ||R0||= 2.0467993E-01, f_err=8.368644E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.37E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.3046778307436874, 0.4034043903985158
# l2: ||R0||= 1.4958859E-01, f_err=7.597201E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.44E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.6432803252692021, 0.5128469595819131
# alpha, M, predM  0.5, 0.4872265823898311, 0.5128469595819131
# l2: ||R0||= 1.9228228E-01, f_err=9.702881E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.92E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.31879291916479807, 0.48696632909049015
# l2: ||R0||= 1.2906911E-01, f_err=7.892479E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.81E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.6043693502186829, 0.3211085425164272
# alpha, M, predM  0.5, 0.3623896570038174, 0.3211085425164272
# alpha, M, predM  0.25, 0.3090000307888161, 0.3211085425164272
# l2: ||R0||= 1.3911773E-01, f_err=7.723103E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.11E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.2973045231590447, 0.3266032555234567
# l2: ||R0||= 1.7000317E-01, f_err=7.47753E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.23E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.36439358954567486, 0.2902601047585921
# alpha, M, predM  0.5, 0.24852916073395426, 0.2902601047585921
# l2: ||R0||= 1.4641128E-01, f_err=6.932009E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.71E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.33357339388372853, 0.2523893288368209
# alpha, M, predM  0.5, 0.257121316603644, 0.2523893288368209
# alpha, M, predM  0.25, 0.2507916603878508, 0.2523893288368209
# l2: ||R0||= 1.2730091E-01, f_err=6.951476E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.13E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.26003501656742983, 0.24970284645714907
# alpha, M, predM  0.5, 0.21495180223850868, 0.24970284645714907
# l2: ||R0||= 7.4691018E-02, f_err=6.514041E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 0.2704510997034757, 0.21508796959206092
# alpha, M, predM  0.5, 0.21783586776942088, 0.21508796959206092
# alpha, M, predM  0.25, 0.21139603476012442, 0.21508796959206092
# l2: ||R0||= 7.9915073E-02, f_err=6.450426E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.05E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 0.29169333056555324, 0.21122586482528094
# alpha, M, predM  0.5, 0.2217254531580476, 0.21122586482528094
# alpha, M, predM  0.25, 0.1985097448035713, 0.21122586482528094
# l2: ||R0||= 7.2484464E-02, f_err=6.259117E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 0.3147887875579547, 0.19820574877530647
# alpha, M, predM  0.5, 0.23960261789878667, 0.19820574877530647
# alpha, M, predM  0.25, 0.21660126271421423, 0.19820574877530647
# alpha, M, predM  0.125, 0.19388339845606575, 0.19820574877530647
# l2: ||R0||= 6.5246958E-02, f_err=6.196726E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.86E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 0.27782022996249073, 0.19383767808294045
# alpha, M, predM  0.5, 0.21169056951746743, 0.19383767808294045
# alpha, M, predM  0.25, 0.1959994403095417, 0.19383767808294045
# alpha, M, predM  0.125, 0.1931388212702132, 0.19383767808294045
# l2: ||R0||= 6.753026E-02, f_err=6.183213E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.68E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 0.20109948846415643, 0.19334679866765178
# alpha, M, predM  0.5, 0.18701169309028837, 0.19334679866765178
# l2: ||R0||= 5.7005806E-02, f_err=6.090168E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.61E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 0.5007482737957049, 0.18673651692422588
# alpha, M, predM  0.5, 0.26867526773729855, 0.18673651692422588
# alpha, M, predM  0.25, 0.19121070403366278, 0.18673651692422588
# alpha, M, predM  0.125, 0.1824169419552758, 0.18673651692422588
# l2: ||R0||= 6.8564757E-02, f_err=6.008996E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.98E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 0.3168745937660251, 0.18246734351946892
# alpha, M, predM  0.5, 0.2315796953152095, 0.18246734351946892
# alpha, M, predM  0.25, 0.2025490454213812, 0.18246734351946892
# alpha, M, predM  0.125, 0.1778287669582348, 0.18246734351946892
# l2: ||R0||= 6.1549249E-02, f_err=5.937539E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.22E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 0.6184064986605781, 0.17782134558762758
# alpha, M, predM  0.5, 0.17477960258852326, 0.17782134558762758
# l2: ||R0||= 5.1644573E-02, f_err=5.893834E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.2E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 1.0682738074021965, 0.17471037059946198
# alpha, M, predM  0.5, 0.2879024729072385, 0.17471037059946198
# alpha, M, predM  0.25, 0.20254519798938692, 0.17471037059946198
# alpha, M, predM  0.125, 0.19119001684348202, 0.17471037059946198
# alpha, M, predM  0.0625, 0.1895145571277897, 0.17471037059946198
# alpha, M, predM  0.03125, 0.1710329612717973, 0.17471037059946198
# l2: ||R0||= 5.1122058E-02, f_err=5.831252E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.77E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 0.965355689881357, 0.17092194551609213
# alpha, M, predM  0.5, 0.29105970676408927, 0.17092194551609213
# alpha, M, predM  0.25, 0.20798602709050648, 0.17092194551609213
# alpha, M, predM  0.125, 0.19392048317394686, 0.17092194551609213
# alpha, M, predM  0.0625, 0.18856383050682912, 0.17092194551609213
# alpha, M, predM  0.03125, 0.1667567011038263, 0.17092194551609213
# l2: ||R0||= 4.9504451E-02, f_err=5.76014E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 7.02E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 1.067751887633452, 0.16662929898361795
# alpha, M, predM  0.5, 0.3460881429766798, 0.16662929898361795
# alpha, M, predM  0.25, 0.22220533679221555, 0.16662929898361795
# alpha, M, predM  0.125, 0.19829155022239625, 0.16662929898361795
# alpha, M, predM  0.0625, 0.19026022356132094, 0.16662929898361795
# alpha, M, predM  0.03125, 0.1880148617953998, 0.16662929898361795
# alpha, M, predM  0.015625, 0.1871988714311179, 0.16662929898361795
# alpha, M, predM  0.0078125, 0.18703948120538855, 0.16662929898361795
# alpha, M, predM  0.00390625, 0.16603360896678476, 0.16662929898361795
# l2: ||R0||= 4.9314078E-02, f_err=5.749613E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 6.11E-01, QuadOrder=5
# ALNR=1.0062016271110072 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 1.0939713056626088, 0.16597726247714575
# alpha, M, predM  0.5, 0.5427642159997343, 0.16597726247714575
# alpha, M, predM  0.25, 0.21470257841653217, 0.16597726247714575
# alpha, M, predM  0.125, 0.18981260939569822, 0.16597726247714575
# alpha, M, predM  0.0625, 0.18952139776125576, 0.16597726247714575
# alpha, M, predM  0.03125, 0.1877884852506086, 0.16597726247714575
# alpha, M, predM  0.015625, 0.18715446039897474, 0.16597726247714575
# alpha, M, predM  0.0078125, 0.1868749576483416, 0.16597726247714575
# alpha, M, predM  0.00390625, 0.1869000153453573, 0.16597726247714575
# alpha, M, predM  0.001953125, 0.18702926907363424, 0.16597726247714575
# alpha, M, predM  0.0009765625, 0.1870942374777477, 0.16597726247714575
# alpha, M, predM  0.00048828125, 0.18712719095745584, 0.16597726247714575
# alpha, M, predM  0.000244140625, 0.18714368400909367, 0.16597726247714575
# alpha, M, predM  0.0001220703125, 0.16597482565593952, 0.16597726247714575
# l2: ||R0||= 4.9308065E-02, f_err=5.749381E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 5.74E-01, QuadOrder=5
# ALNR=1.0062190482057294 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 1.3296914298861917, 0.16587586721120662
# alpha, M, predM  0.5, 0.6259413389247643, 0.16587586721120662
# alpha, M, predM  0.25, 0.36123675227522917, 0.16587586721120662
# alpha, M, predM  0.125, 0.19603705558469764, 0.16587586721120662
# alpha, M, predM  0.0625, 0.18908250573028515, 0.16587586721120662
# alpha, M, predM  0.03125, 0.1873372663380967, 0.16587586721120662
# alpha, M, predM  0.015625, 0.18682089732079016, 0.16587586721120662
# alpha, M, predM  0.0078125, 0.18661418359049867, 0.16587586721120662
# alpha, M, predM  0.00390625, 0.18658965120775453, 0.16587586721120662
# alpha, M, predM  0.001953125, 0.18677774552013207, 0.16587586721120662
# alpha, M, predM  0.0009765625, 0.1868721251222893, 0.16587586721120662
# alpha, M, predM  0.00048828125, 0.18691982243341113, 0.16587586721120662
# alpha, M, predM  0.000244140625, 0.1869436946259659, 0.16587586721120662
# alpha, M, predM  0.0001220703125, 0.18695563591727538, 0.16587586721120662
# alpha, M, predM  6.103515625E-05, 0.1658810207864086, 0.16587586721120662
# alpha, M, predM  3.0517578125E-05, 0.165885056553796, 0.16587586721120662
# alpha, M, predM  1.52587890625E-05, 0.16588707450526416, 0.16587586721120662
# alpha, M, predM  7.62939453125E-06, 0.16588808349794235, 0.16587586721120662
# alpha, M, predM  3.814697265625E-06, 0.16588858799851805, 0.16587586721120662
# alpha, M, predM  1.9073486328125E-06, 0.1658888402498647, 0.16587586721120662
# alpha, M, predM  9.5367431640625E-07, 0.16588896637580264, 0.16587586721120662
# alpha, M, predM  4.76837158203125E-07, 0.16588902943883793, 0.16587586721120662
# alpha, M, predM  2.384185791015625E-07, 0.16588906097037223, 0.16587586721120662
# alpha, M, predM  1.1920928955078125E-07, 0.16588907673614348, 0.16587586721120662
# alpha, M, predM  5.960464477539063E-08, 0.16588908461903004, 0.16587586721120662
# alpha, M, predM  2.9802322387695312E-08, 0.16588908856047352, 0.16587586721120662
# alpha, M, predM  1.4901161193847656E-08, 0.1658890905311956, 0.16587586721120662
# l2: ||R0||= 4.930807E-02, f_err=5.749381E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 5.04E-01, QuadOrder=5
# ALNR=1.0062190482057294 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 1.588408095667497, 0.1657836727611488
# alpha, M, predM  0.5, 0.7147172174654571, 0.1657836727611488
# alpha, M, predM  0.25, 0.4020803370981695, 0.1657836727611488
# alpha, M, predM  0.125, 0.19608460441646397, 0.1657836727611488
# alpha, M, predM  0.0625, 0.18300013542428517, 0.1657836727611488
# alpha, M, predM  0.03125, 0.1867628095842361, 0.1657836727611488
# alpha, M, predM  0.015625, 0.18641800044548856, 0.1657836727611488
# alpha, M, predM  0.0078125, 0.1863121134865354, 0.1657836727611488
# alpha, M, predM  0.00390625, 0.18627641531138875, 0.1657836727611488
# alpha, M, predM  0.001953125, 0.18652198882444831, 0.1657836727611488
# alpha, M, predM  0.0009765625, 0.18664753733792466, 0.1657836727611488
# alpha, M, predM  0.00048828125, 0.1867108329642554, 0.1657836727611488
# alpha, M, predM  0.000244140625, 0.18674251290933935, 0.1657836727611488
# alpha, M, predM  0.0001220703125, 0.1867583593284291, 0.1657836727611488
# alpha, M, predM  6.103515625E-05, 0.165789709821028, 0.1657836727611488
# alpha, M, predM  3.0517578125E-05, 0.16579443732775134, 0.1657836727611488
# alpha, M, predM  1.52587890625E-05, 0.16579680117490067, 0.1657836727611488
# alpha, M, predM  7.62939453125E-06, 0.165797983121923, 0.1657836727611488
# alpha, M, predM  3.814697265625E-06, 0.16579857410129606, 0.1657836727611488
# alpha, M, predM  1.9073486328125E-06, 0.16579886959244805, 0.1657836727611488
# alpha, M, predM  9.5367431640625E-07, 0.16579901733839042, 0.1657836727611488
# alpha, M, predM  4.76837158203125E-07, 0.1657990912114532, 0.1657836727611488
# alpha, M, predM  2.384185791015625E-07, 0.16579912814800754, 0.1657836727611488
# alpha, M, predM  1.1920928955078125E-07, 0.1657991466162905, 0.1657836727611488
# alpha, M, predM  5.960464477539063E-08, 0.16579915585043323, 0.1657836727611488
# alpha, M, predM  2.9802322387695312E-08, 0.16579916046750515, 0.1657836727611488
# alpha, M, predM  1.4901161193847656E-08, 0.1657991627760411, 0.1657836727611488
# l2: ||R0||= 4.9308074E-02, f_err=5.749381E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 4.3E-01, QuadOrder=5
# ALNR=1.0062190482057294 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 1.8856551021314312, 0.1657132355331895
# alpha, M, predM  0.5, 0.7981370219450743, 0.1657132355331895
# alpha, M, predM  0.25, 0.44721616299205996, 0.1657132355331895
# alpha, M, predM  0.125, 0.19546532082114745, 0.1657132355331895
# alpha, M, predM  0.0625, 0.18760648752435283, 0.1657132355331895
# alpha, M, predM  0.03125, 0.18613606884960476, 0.1657132355331895
# alpha, M, predM  0.015625, 0.18601181406054743, 0.1657132355331895
# alpha, M, predM  0.0078125, 0.18603190674328846, 0.1657132355331895
# alpha, M, predM  0.00390625, 0.18606324534622165, 0.1657132355331895
# alpha, M, predM  0.001953125, 0.18631279197499417, 0.1657132355331895
# alpha, M, predM  0.0009765625, 0.18646961997663578, 0.1657132355331895
# alpha, M, predM  0.00048828125, 0.18654854601617038, 0.1657132355331895
# alpha, M, predM  0.000244140625, 0.18658807362881924, 0.1657132355331895
# alpha, M, predM  0.0001220703125, 0.1866078451075106, 0.1657132355331895
# alpha, M, predM  6.103515625E-05, 0.1866177327655707, 0.1657132355331895
# alpha, M, predM  3.0517578125E-05, 0.1657255750056497, 0.1657132355331895
# alpha, M, predM  1.52587890625E-05, 0.1657282846809954, 0.1657132355331895
# alpha, M, predM  7.62939453125E-06, 0.16572963954819725, 0.1657132355331895
# alpha, M, predM  3.814697265625E-06, 0.16573031698918073, 0.1657132355331895
# alpha, M, predM  1.9073486328125E-06, 0.16573065571151807, 0.1657132355331895
# alpha, M, predM  9.5367431640625E-07, 0.1657308250731482, 0.1657132355331895
# alpha, M, predM  4.76837158203125E-07, 0.16573090975407834, 0.1657132355331895
# alpha, M, predM  2.384185791015625E-07, 0.1657309520945722, 0.1657132355331895
# alpha, M, predM  1.1920928955078125E-07, 0.16573097326482664, 0.1657132355331895
# alpha, M, predM  5.960464477539063E-08, 0.1657309838499554, 0.1657132355331895
# alpha, M, predM  2.9802322387695312E-08, 0.16573098914252082, 0.1657132355331895
# alpha, M, predM  1.4901161193847656E-08, 0.16573099178880313, 0.1657132355331895
# l2: ||R0||= 4.9308079E-02, f_err=5.749381E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 3.74E-01, QuadOrder=5
# ALNR=1.0062190482057294 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 3.5237239916471816, 0.16568331000243167
# alpha, M, predM  0.5, 0.899592743464464, 0.16568331000243167
# alpha, M, predM  0.25, 0.4959394976497817, 0.16568331000243167
# alpha, M, predM  0.125, 0.33084954848733045, 0.16568331000243167
# alpha, M, predM  0.0625, 0.1865683918676108, 0.16568331000243167
# alpha, M, predM  0.03125, 0.185520074471395, 0.16568331000243167
# alpha, M, predM  0.015625, 0.1856580841157396, 0.16568331000243167
# alpha, M, predM  0.0078125, 0.18582177473219663, 0.16568331000243167
# alpha, M, predM  0.00390625, 0.18592810261233605, 0.16568331000243167
# alpha, M, predM  0.001953125, 0.18619276208642163, 0.16568331000243167
# alpha, M, predM  0.0009765625, 0.1863797679715432, 0.16568331000243167
# alpha, M, predM  0.00048828125, 0.1864737443526526, 0.16568331000243167
# alpha, M, predM  0.000244140625, 0.1865208574091443, 0.16568331000243167
# alpha, M, predM  0.0001220703125, 0.1865444226577342, 0.16568331000243167
# alpha, M, predM  6.103515625E-05, 0.18655620746293236, 0.16568331000243167
# alpha, M, predM  3.0517578125E-05, 0.16569717613846066, 0.16568331000243167
# alpha, M, predM  1.52587890625E-05, 0.16570022105384208, 0.16568331000243167
# alpha, M, predM  7.62939453125E-06, 0.16570174354595507, 0.16568331000243167
# alpha, M, predM  3.814697265625E-06, 0.1657025048006175, 0.16568331000243167
# alpha, M, predM  1.9073486328125E-06, 0.16570288543010037, 0.16568331000243167
# alpha, M, predM  9.5367431640625E-07, 0.1657030757453789, 0.16568331000243167
# alpha, M, predM  4.76837158203125E-07, 0.16570317090315315, 0.16568331000243167
# alpha, M, predM  2.384185791015625E-07, 0.1657032184820738, 0.16568331000243167
# alpha, M, predM  1.1920928955078125E-07, 0.1657032422715425, 0.16568331000243167
# alpha, M, predM  5.960464477539063E-08, 0.16570325416627893, 0.16568331000243167
# alpha, M, predM  2.9802322387695312E-08, 0.16570326011364772, 0.16568331000243167
# alpha, M, predM  1.4901161193847656E-08, 0.16570326308733221, 0.16568331000243167
# l2: ||R0||= 4.9308084E-02, f_err=5.749381E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 3.51E-01, QuadOrder=5
# ALNR=1.005236907509676 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 5.4476425962802715, 0.165643767994281
# alpha, M, predM  0.5, 1.0206277097402858, 0.165643767994281
# alpha, M, predM  0.25, 0.5460129935958099, 0.165643767994281
# alpha, M, predM  0.125, 0.35916295891957273, 0.165643767994281
# alpha, M, predM  0.0625, 0.18528338011433743, 0.165643767994281
# alpha, M, predM  0.03125, 0.18483808184345368, 0.165643767994281
# alpha, M, predM  0.015625, 0.185268633087272, 0.165643767994281
# alpha, M, predM  0.0078125, 0.18558377066300477, 0.165643767994281
# alpha, M, predM  0.00390625, 0.18576903351864188, 0.165643767994281
# alpha, M, predM  0.001953125, 0.18605599264199232, 0.165643767994281
# alpha, M, predM  0.0009765625, 0.18627106797830745, 0.165643767994281
# alpha, M, predM  0.00048828125, 0.18637900838278146, 0.165643767994281
# alpha, M, predM  0.000244140625, 0.18643319012018522, 0.165643767994281
# alpha, M, predM  0.0001220703125, 0.18646029044935825, 0.165643767994281
# alpha, M, predM  6.103515625E-05, 0.18647384298008438, 0.165643767994281
# alpha, M, predM  3.0517578125E-05, 0.16565906667976346, 0.165643767994281
# alpha, M, predM  1.52587890625E-05, 0.16566242617596924, 0.165643767994281
# alpha, M, predM  7.62939453125E-06, 0.16566410596163697, 0.165643767994281
# alpha, M, predM  3.814697265625E-06, 0.1656649458638623, 0.165643767994281
# alpha, M, predM  1.9073486328125E-06, 0.16566536581732264, 0.165643767994281
# alpha, M, predM  9.5367431640625E-07, 0.16566557579463978, 0.165643767994281
# alpha, M, predM  4.76837158203125E-07, 0.16566568078344515, 0.165643767994281
# alpha, M, predM  2.384185791015625E-07, 0.16566573327788467, 0.165643767994281
# alpha, M, predM  1.1920928955078125E-07, 0.16566575952511348, 0.165643767994281
# alpha, M, predM  5.960464477539063E-08, 0.1656657726487299, 0.165643767994281
# alpha, M, predM  2.9802322387695312E-08, 0.16566577921053907, 0.165643767994281
# alpha, M, predM  1.4901161193847656E-08, 0.1656657824914436, 0.165643767994281
# l2: ||R0||= 4.9308089E-02, f_err=5.749381E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 3.2E-01, QuadOrder=5
#
# ALNR=1.000568908522689 <= 1.005 so we terminate/increase degree
#
# ALNR=1.0002673021301167 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:600,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="600" height="500"
#  viewBox="0 0 600 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="600" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,401.6 L50.1,401.6 M550.1,401.6 L545.6,401.6 M45.6,377.8 L50.1,377.8 M550.1,377.8 L545.6,377.8
# 		M45.6,360.9 L50.1,360.9 M550.1,360.9 L545.6,360.9 M45.6,347.7 L50.1,347.7 M550.1,347.7 L545.6,347.7
# 		M45.6,337.0 L50.1,337.0 M550.1,337.0 L545.6,337.0 M45.6,327.9 L50.1,327.9 M550.1,327.9 L545.6,327.9
# 		M45.6,320.1 L50.1,320.1 M550.1,320.1 L545.6,320.1 M45.6,313.2 L50.1,313.2 M550.1,313.2 L545.6,313.2
# 		M45.6,307.0 L54.6,307.0 M550.1,307.0 L541.1,307.0  '/>	<g transform="translate(37.3,313.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,266.2 L50.1,266.2 M550.1,266.2 L545.6,266.2 M45.6,242.3 L50.1,242.3 M550.1,242.3 L545.6,242.3
# 		M45.6,225.4 L50.1,225.4 M550.1,225.4 L545.6,225.4 M45.6,212.3 L50.1,212.3 M550.1,212.3 L545.6,212.3
# 		M45.6,201.6 L50.1,201.6 M550.1,201.6 L545.6,201.6 M45.6,192.5 L50.1,192.5 M550.1,192.5 L545.6,192.5
# 		M45.6,184.7 L50.1,184.7 M550.1,184.7 L545.6,184.7 M45.6,177.7 L50.1,177.7 M550.1,177.7 L545.6,177.7
# 		M45.6,171.5 L54.6,171.5 M550.1,171.5 L541.1,171.5  '/>	<g transform="translate(37.3,177.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,130.8 L50.1,130.8 M550.1,130.8 L545.6,130.8 M45.6,106.9 L50.1,106.9 M550.1,106.9 L545.6,106.9
# 		M45.6,90.0 L50.1,90.0 M550.1,90.0 L545.6,90.0 M45.6,76.9 L50.1,76.9 M550.1,76.9 L545.6,76.9
# 		M45.6,66.1 L50.1,66.1 M550.1,66.1 L545.6,66.1 M45.6,57.1 L50.1,57.1 M550.1,57.1 L545.6,57.1
# 		M45.6,49.2 L50.1,49.2 M550.1,49.2 L545.6,49.2 M45.6,42.3 L50.1,42.3 M550.1,42.3 L545.6,42.3
# 		M45.6,36.1 L54.6,36.1 M550.1,36.1 L541.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M108.7,442.4 L108.7,433.4 M108.7,36.1 L108.7,45.1  '/>	<g transform="translate(108.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M171.7,442.4 L171.7,433.4 M171.7,36.1 L171.7,45.1  '/>	<g transform="translate(171.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M234.8,442.4 L234.8,433.4 M234.8,36.1 L234.8,45.1  '/>	<g transform="translate(234.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 15</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M297.9,442.4 L297.9,433.4 M297.9,36.1 L297.9,45.1  '/>	<g transform="translate(297.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M360.9,442.4 L360.9,433.4 M360.9,36.1 L360.9,45.1  '/>	<g transform="translate(360.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 25</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;

# %%
using System.IO;
static void AppendRowToCSV(string filePath, double[] rowData)
    {
        // Create a StreamWriter in append mode to append rows to the CSV file
        using (StreamWriter writer = new StreamWriter(filePath, true))
        {
            int cols = rowData.Length;

            // Write double values of the new row to the file
            for (int i = 0; i < cols; i++)
            {
                writer.Write(rowData[i]);

                // Add a comma after each value except for the last one in a row
                if (i < cols - 1)
                {
                    writer.Write(";");
                }
            }

            // Move to the next line after writing the row
            writer.WriteLine();
        }
    }
    static void WriteCSV(string filePath, string[] data)
    {
        // Create a StreamWriter to write to the CSV file
        using (StreamWriter writer = new StreamWriter(filePath))
        {
            int cols = data.Length;

            // Loop through the data array and write to the file
                for (int j = 0; j < cols; j++)
                {
                    // Write each cell value to the file
                    writer.Write(data[ j]);

                    // Add a comma after each cell value except for the last one in a row
                    if (j < cols - 1)
                    {
                        writer.Write(";");
                    }
                }

                // Move to the next line after each row
                writer.WriteLine();
            
        }
    }
    static void DeleteCSVFiles()
    {
        try
        {
            // Get all CSV files in the specified directory
            string[] csvFiles = Directory.GetFiles("*.csv");

            // Delete each CSV file
            foreach (string file in csvFiles)
            {
                File.Delete(file);
                Console.WriteLine($"Deleted: {file}");
            }
        }
        catch (Exception ex)
        {
            Console.WriteLine($"Error deleting CSV files: {ex.Message}");
        }
    }

# %% [markdown]
# ## Measure wall-clock time for computation of sensitivities and residuals

# %%
using System.Diagnostics;
BoSSS.Solution.Application.InitMPI();
DeleteCSVFiles();

int nRefs=3;
var optLsTypes=new OptiLevelSetType[] {OptiLevelSetType.SinglePhaseField,OptiLevelSetType.SplineLevelSet,OptiLevelSetType.SpecFemField};
var CellsVsRuntime_dRdPhi = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
var CellsVsRuntime_Residuals = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
var CellsVsRuntime_dRdU = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
string[] stringArray = new string[] { "nCells" }.Concat(optLsTypes.Select(x => x.ToString())).ToArray();

//Create files for results
string filePathdRdPhi = "TimeDRdPhi.csv";
string filePathdRdU = "TimedRdU.csv";
string filePathResiduals = "TimeResiduals.csv";
string filePathDOFs = "DOFs.csv";
WriteCSV(filePathdRdPhi,stringArray);
WriteCSV(filePathdRdU,stringArray);
WriteCSV(filePathResiduals,stringArray);
WriteCSV(filePathDOFs,stringArray);

for(int n =0; n< nRefs;n++){
    //counter for level set type
    int iLS=1;
    //save cell resolution
    int reso= (int) Math.Pow(2,n+1);
    CellsVsRuntime_dRdPhi[n,0]=reso*reso;
    double[] dRdPhiResults= new double[optLsTypes.Length +1];
    dRdPhiResults[0]=reso*reso;
    double[] dRdUResults=dRdPhiResults.CloneAs();
    double[] resiudalResults=dRdPhiResults.CloneAs();
    double[] DOFs=dRdPhiResults.CloneAs();
    foreach(OptiLevelSetType lstype in optLsTypes){
        var pSAIDT = new SAIDTMain();
        var CSAIDT = SAIDTHardCodedControl.StraightShock(
                            dbPath: null,
                            MaxIterations: 1,
                            dgDegree: 0,
                            numOfCellsX: reso,
                            numOfCellsY: reso,
                            OptiNumOfCellsX: reso,
                            OptiNumOfCellsY: reso,
                            agg: 0.4,
                            ImmediatePlotPeriod: -1,
                            optiLevelSetType: lstype,
                            LSDegree: 3,
                            isFarConfig:true);

        pSAIDT.Init(CSAIDT);    
        pSAIDT.InitializeEverything();
        //pSAIDT.RunSolverMode();

        //Measure time for creation of Jacobians dRdPhi
        Stopwatch stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.FD_LevelSet();
        stopwatch.Stop();
        CellsVsRuntime_dRdPhi[n,iLS] =stopwatch.ElapsedMilliseconds;
        dRdPhiResults[iLS]=stopwatch.ElapsedMilliseconds;

        //Measure time for creation of Jacobians dRdU
        stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.Oproblem.GetJacobians(pSAIDT.ConservativeFields, pSAIDT.XSpatialOperator.LinearizationHint);
        stopwatch.Stop(); 
        CellsVsRuntime_dRdU[n,iLS] =stopwatch.ElapsedMilliseconds;
        dRdUResults[iLS]=stopwatch.ElapsedMilliseconds;

        //Measure time for evaluation of the Residuals
        stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.ComputeResiduals();
        stopwatch.Stop(); Console.WriteLine("Elapsed Time: " + stopwatch.ElapsedMilliseconds + "ms");
        CellsVsRuntime_Residuals[n,iLS] =stopwatch.ElapsedMilliseconds;
        resiudalResults[iLS]=stopwatch.ElapsedMilliseconds;

        DOFs[iLS]=pSAIDT.LevelSetOpti.GetLength();

        iLS++;
    }
    // Append the new row to the existing CSV file
    AppendRowToCSV(filePathdRdPhi, dRdPhiResults);
    AppendRowToCSV(filePathdRdU, dRdUResults);
    AppendRowToCSV(filePathResiduals, resiudalResults);
    AppendRowToCSV(filePathDOFs, DOFs);
}
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_31.plt ScalarAdvection_SP_32.plt ScalarAdvection_SP_33.plt ScalarAdvection_SP_34.plt ScalarAdvection_SP_35.plt ScalarAdvection_SP_36.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Error deleting CSV files: The filename, directory name, or volume label syntax is incorrect. : 'c:\experimental\public\examples\ShockFitting\Studies\LevelSetComparison\*.csv'
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 11ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 10ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 11ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 15ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 17ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 21ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 22ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 18ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 79ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 32ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 28ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 39ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0

# %%
public PlotFormat GetFormat(int count){
    
    var allPT = new BoSSS.Solution.Gnuplot.PointTypes[] { PointTypes.Diamond, PointTypes.LowerTriangle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle,PointTypes.Diamond, PointTypes.LowerTriangle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle};
    var allC = new BoSSS.Solution.Gnuplot.LineColors[] { LineColors.Blue, LineColors.Black, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red};
    var Fmt = new PlotFormat();
    Fmt.PointSize = 0.8;
    Fmt.LineWidth = 1;    
    Fmt.Style     = Styles.LinesPoints;

    Fmt.LineColor = allC[count];
    Fmt.PointType =  allPT[count];
    return Fmt;
}

# %%
var plot = new Plot2Ddata();
var cells = CellsVsRuntime_dRdPhi.Co;
int count=0;
foreach(OptiLevelSetType lstype in optLsTypes){
    runtimes.
    plot.AddDataGroup(lstype.ToString,cells,runtimes, GetFormat(count));
    count++;
}
plot.Xlabel="number of Cells"";
plot.LogY = true;
plot.LogX = true;
plot.ShowXtics = true;
plot.ToGnuplot().PlotSVG(xRes:1200,yRes:600)
