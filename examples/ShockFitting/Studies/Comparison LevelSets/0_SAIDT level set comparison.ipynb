# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\SAIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using SAIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %% [markdown]
# # Run Simulation

# %%
var date = DateTime.Now.ToString("ddMMyyyy");
date
# Out:
# 22032024

# %% [markdown]
# open a database

# %%
string dbPath = @"SAIDT_db_" + date ;
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Opening existing database 'SAIDT_db_22032024'.

# %%
Dictionary<string,int> DOFS = new Dictionary<string,int>();

# %% [markdown]
# ## SinglePhaseField

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SinglePhaseField,
                    LSDegree: 3
                    );
CSAIDT.SessionName="SAIDT_DGLevelSet";
CSAIDT.ProjectName="SAIDT_DGLevelSet";
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SinglePhaseField",pSAIDT.LsTBO.DOFLocal);
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# rm ScalarAdvection_0.plt;
# Session ID: edab022c-40e8-485a-82ec-f37cffc26885, DB path: 'SAIDT_db_22032024'
# Session directory 'SAIDT_db_22032024\sessions\edab022c-40e8-485a-82ec-f37cffc26885'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Initial Value : l2: |r|= 1.5458527E+00, |f_err|=2.9597349E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 1.7458689159808305, 5.403534982517511
# l2: ||R0||= 6.6536777E-01, f_err=1.772106E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.94E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1448.567311760642
#     L2 Norm of Solution:    1.2179361619966298
#     L2 Norm of Residual:    0.9509269124952915
#     Relative Residual norm: 5.549206054478878E-07
#     Matrix Inf norm:        1713626.9642173026
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1448.567311760642
#     L2 Norm of Solution:    1.217930662266754
#     L2 Norm of Residual:    0.91248991775809
#     Relative Residual norm: 5.324904059121577E-07
#     Matrix Inf norm:        1713626.9642173026
# alpha, M, predM  1, 5.9190114264786144, 1.5807908026566593
# alpha, M, predM  0.5, 4.840869041109443, 1.5807908026566593
# alpha, M, predM  0.25, 4.425844953939659, 1.5807908026566593
# alpha, M, predM  0.125, 3.5770634258374194, 1.5807908026566593
# alpha, M, predM  0.0625, 2.322138121460169, 1.5807908026566593
# alpha, M, predM  0.03125, 1.6155735067277084, 1.5807908026566593
# alpha, M, predM  0.015625, 1.503985468938589, 1.5807908026566593
# l2: ||R0||= 6.4337016E-01, f_err=1.728459E+00, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 4.93E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1298.6376484590971
#     L2 Norm of Solution:    0.2719259671431913
#     L2 Norm of Residual:    0.16048459078358077
#     Relative Residual norm: 1.1298350893575949E-07
#     Matrix Inf norm:        1420424.9124076115
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1298.6376484590971
#     L2 Norm of Solution:    0.2719260671977968
#     L2 Norm of Residual:    0.16563182313082123
#     Relative Residual norm: 1.1660723610519919E-07
#     Matrix Inf norm:        1420424.9124076115
# alpha, M, predM  1, 3.303406203585077, 1.5054698021032675
# alpha, M, predM  0.5, 3.2271478818698554, 1.5054698021032675
# alpha, M, predM  0.25, 3.019523421585581, 1.5054698021032675
# alpha, M, predM  0.125, 3.3284455058888884, 1.5054698021032675
# alpha, M, predM  0.0625, 2.6519449002132722, 1.5054698021032675
# alpha, M, predM  0.03125, 2.343509889660711, 1.5054698021032675
# alpha, M, predM  0.015625, 1.740181160221701, 1.5054698021032675
# alpha, M, predM  0.0078125, 1.610595771178058, 1.5054698021032675
# alpha, M, predM  0.00390625, 1.5553591043243329, 1.5054698021032675
# alpha, M, predM  0.001953125, 1.4994090023221958, 1.5054698021032675
# l2: ||R0||= 6.4179484E-01, f_err=1.724818E+00, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 5.78E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1261.43220911025
#     L2 Norm of Solution:    0.2120521286366443
#     L2 Norm of Residual:    0.05955343464991257
#     Relative Residual norm: 4.4367324493602236E-08
#     Matrix Inf norm:        1342281.4048320667
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1261.43220911025
#     L2 Norm of Solution:    0.21205588950779736
#     L2 Norm of Residual:    0.05821591240104843
#     Relative Residual norm: 4.337087006605135E-08
#     Matrix Inf norm:        1342281.4048320667
# alpha, M, predM  1, 4.951200778120304, 1.4977761120479665
# alpha, M, predM  0.5, 3.6707383828646774, 1.4977761120479665
# alpha, M, predM  0.25, 3.2714614290927235, 1.4977761120479665
# alpha, M, predM  0.125, 2.723419396527907, 1.4977761120479665
# alpha, M, predM  0.0625, 2.407785379135475, 1.4977761120479665
# alpha, M, predM  0.03125, 2.2951482133701306, 1.4977761120479665
# alpha, M, predM  0.015625, 1.8424077355686792, 1.4977761120479665
# alpha, M, predM  0.0078125, 1.6708234244296891, 1.4977761120479665
# alpha, M, predM  0.00390625, 1.5960597052145724, 1.4977761120479665
# alpha, M, predM  0.001953125, 1.558917401556824, 1.4977761120479665
# alpha, M, predM  0.0009765625, 1.6329090186767352, 1.4977761120479665
# alpha, M, predM  0.00048828125, 1.4965696999591336, 1.4977761120479665
# l2: ||R0||= 6.4145629E-01, f_err=1.72396E+00, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 5.13E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1248.7367438340932
#     L2 Norm of Solution:    0.1809485551443625
#     L2 Norm of Residual:    0.013478958763191927
#     Relative Residual norm: 1.0243494048873715E-08
#     Matrix Inf norm:        1315855.5761228714
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1248.7367438340932
#     L2 Norm of Solution:    0.1809415152288276
#     L2 Norm of Residual:    0.017858579621537814
#     Relative Residual norm: 1.3571838692326387E-08
#     Matrix Inf norm:        1315855.5761228714
# alpha, M, predM  1, 4.507934356528691, 1.493962487538651
# alpha, M, predM  0.5, 4.569643698433158, 1.493962487538651
# alpha, M, predM  0.25, 3.539129517697661, 1.493962487538651
# alpha, M, predM  0.125, 2.6301692138820285, 1.493962487538651
# alpha, M, predM  0.0625, 3.149591940407903, 1.493962487538651
# alpha, M, predM  0.03125, 2.4395567102869484, 1.493962487538651
# alpha, M, predM  0.015625, 1.9050178360618155, 1.493962487538651
# alpha, M, predM  0.0078125, 1.70525212494518, 1.493962487538651
# alpha, M, predM  0.00390625, 1.6135669834432385, 1.493962487538651
# alpha, M, predM  0.001953125, 1.5727114711707364, 1.493962487538651
# alpha, M, predM  0.0009765625, 1.5541378084956583, 1.493962487538651
# alpha, M, predM  0.00048828125, 1.6149178959205714, 1.493962487538651
# alpha, M, predM  0.000244140625, 1.4935176094725597, 1.493962487538651
# l2: ||R0||= 6.4129343E-01, f_err=1.723541E+00, f_phi=0E+00, Alpha = 2.44E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 4E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.264784827088
#     L2 Norm of Solution:    15.88203961578035
#     L2 Norm of Residual:    2.4147704597730137
#     Relative Residual norm: 1.8570163395724971E-06
#     Matrix Inf norm:        1300349.6029167504
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.264784827088
#     L2 Norm of Solution:    15.882098386841664
#     L2 Norm of Residual:    2.5833706931588725
#     Relative Residual norm: 1.9866739585756327E-06
#     Matrix Inf norm:        1300349.6029167504
# alpha, M, predM  1, 4.742975725342946, 1.491102508773356
# alpha, M, predM  0.5, 4.104322280386434, 1.491102508773356
# alpha, M, predM  0.25, 2.6991950211040217, 1.491102508773356
# alpha, M, predM  0.125, 2.6305025624470804, 1.491102508773356
# alpha, M, predM  0.0625, 3.3018197400810068, 1.491102508773356
# alpha, M, predM  0.03125, 2.54471334958541, 1.491102508773356
# alpha, M, predM  0.015625, 1.9761320536760947, 1.491102508773356
# alpha, M, predM  0.0078125, 1.7322132682606777, 1.491102508773356
# alpha, M, predM  0.00390625, 1.6262826694069867, 1.491102508773356
# alpha, M, predM  0.001953125, 1.583126172481388, 1.491102508773356
# alpha, M, predM  0.0009765625, 1.5548192237945333, 1.491102508773356
# alpha, M, predM  0.00048828125, 1.564554728229414, 1.491102508773356
# alpha, M, predM  0.000244140625, 1.607465821177391, 1.491102508773356
# alpha, M, predM  0.0001220703125, 1.6953772713949242, 1.491102508773356
# alpha, M, predM  6.103515625E-05, 2.435790507541485, 1.491102508773356
# alpha, M, predM  3.0517578125E-05, 1.4913091981343123, 1.491102508773356
# alpha, M, predM  1.52587890625E-05, 1.491354860433053, 1.491102508773356
# alpha, M, predM  7.62939453125E-06, 1.4913776390734717, 1.491102508773356
# alpha, M, predM  3.814697265625E-06, 1.4913890152823055, 1.491102508773356
# alpha, M, predM  1.9073486328125E-06, 1.4913947001108612, 1.491102508773356
# alpha, M, predM  9.5367431640625E-07, 1.4913975417064194, 1.491102508773356
# alpha, M, predM  4.76837158203125E-07, 1.4913989622995534, 1.491102508773356
# alpha, M, predM  2.384185791015625E-07, 1.4913996725449572, 1.491102508773356
# alpha, M, predM  1.1920928955078125E-07, 1.4914000276548727, 1.491102508773356
# alpha, M, predM  5.960464477539063E-08, 1.4914002052066317, 1.491102508773356
# alpha, M, predM  2.9802322387695312E-08, 1.4914002939817148, 1.491102508773356
# alpha, M, predM  1.4901161193847656E-08, 1.4914003383690548, 1.491102508773356
# l2: ||R0||= 6.4129556E-01, f_err=1.723549E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.96E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.2887232333776
#     L2 Norm of Solution:    22.10704551208833
#     L2 Norm of Residual:    2.7732619125449838
#     Relative Residual norm: 2.132655394945561E-06
#     Matrix Inf norm:        1300379.7608923006
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241
+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 7.07E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.3842837398304
#     L2 Norm of Solution:    47.16382075065528
#     L2 Norm of Residual:    1.5721896654342984
#     Relative Residual norm: 1.2089116219567242E-06
#     Matrix Inf norm:        1300500.0836120497
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.3842837398304
#     L2 Norm of Solution:    47.16381511103578
#     L2 Norm of Residual:    5.320059774954886
#     Relative Residual norm: 4.090780032999909E-06
#     Matrix Inf norm:        1300500.0836120497
# alpha, M, predM  1, 3.501009045867089, 1.4863899055279095
# alpha, M, predM  0.5, 4.1487749780160845, 1.4863899055279095
# alpha, M, predM  0.25, 3.4431690875624628, 1.4863899055279095
# alpha, M, predM  0.125, 2.7932195716561554, 1.4863899055279095
# alpha, M, predM  0.0625, 3.576771554988097, 1.4863899055279095
# alpha, M, predM  0.03125, 2.7389987503964255, 1.4863899055279095
# alpha, M, predM  0.015625, 2.0980058710178335, 1.4863899055279095
# alpha, M, predM  0.0078125, 1.7737517825789928, 1.4863899055279095
# alpha, M, predM  0.00390625, 1.6416461709166796, 1.4863899055279095
# alpha, M, predM  0.001953125, 1.5890508634732452, 1.4863899055279095
# alpha, M, predM  0.0009765625, 1.5533984693901102, 1.4863899055279095
# alpha, M, predM  0.00048828125, 1.5541138267885528, 1.4863899055279095
# alpha, M, predM  0.000244140625, 1.592933520006631, 1.4863899055279095
# alpha, M, predM  0.0001220703125, 1.6673563946206391, 1.4863899055279095
# alpha, M, predM  6.103515625E-05, 1.990067430822711, 1.4863899055279095
# alpha, M, predM  3.0517578125E-05, 1.4865959689487214, 1.4863899055279095
# alpha, M, predM  1.52587890625E-05, 1.48664160403962, 1.4863899055279095
# alpha, M, predM  7.62939453125E-06, 1.4866643477408426, 1.4863899055279095
# alpha, M, predM  3.814697265625E-06, 1.486675701155356, 1.4863899055279095
# alpha, M, predM  1.9073486328125E-06, 1.4866813732567037, 1.4863899055279095
# alpha, M, predM  9.5367431640625E-07, 1.4866842081562905, 1.4863899055279095
# alpha, M, predM  4.76837158203125E-07, 1.4866856253183571, 1.4863899055279095
# alpha, M, predM  2.384185791015625E-07, 1.4866863338274703, 1.4863899055279095
# alpha, M, predM  1.1920928955078125E-07, 1.4866866880640426, 1.4863899055279095
# alpha, M, predM  5.960464477539063E-08, 1.486686865177835, 1.4863899055279095
# alpha, M, predM  2.9802322387695312E-08, 1.4866869537336092, 1.4863899055279095
# alpha, M, predM  1.4901161193847656E-08, 1.486686998011214, 1.4863899055279095
# l2: ||R0||= 6.4130624E-01, f_err=1.723594E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 6.32E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4081499928745
#     L2 Norm of Solution:    23.821848616137203
#     L2 Norm of Residual:    2.607376413302609
#     Relative Residual norm: 2.0048566063152788E-06
#     Matrix Inf norm:        1300530.1252415753
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4081499928745
#     L2 Norm of Solution:    23.821831167049606
#     L2 Norm of Residual:    2.4827335424112458
#     Relative Residual norm: 1.9090165573443173E-06
#     Matrix Inf norm:        1300530.1252415753
# alpha, M, predM  1, 3.5535077650060085, 1.486299031336563
# alpha, M, predM  0.5, 4.195231042008486, 1.486299031336563
# alpha, M, predM  0.25, 3.509238850988199, 1.486299031336563
# alpha, M, predM  0.125, 2.8104394611927166, 1.486299031336563
# alpha, M, predM  0.0625, 3.5929789033417006, 1.486299031336563
# alpha, M, predM  0.03125, 2.7840144717698623, 1.486299031336563
# alpha, M, predM  0.015625, 2.106469583413197, 1.486299031336563
# alpha, M, predM  0.0078125, 1.7765659991475051, 1.486299031336563
# alpha, M, predM  0.00390625, 1.6428591691029186, 1.486299031336563
# alpha, M, predM  0.001953125, 1.5896433940538677, 1.486299031336563
# alpha, M, predM  0.0009765625, 1.5535425916214216, 1.486299031336563
# alpha, M, predM  0.00048828125, 1.5537130573685207, 1.486299031336563
# alpha, M, predM  0.000244140625, 1.5923151926810206, 1.486299031336563
# alpha, M, predM  0.0001220703125, 1.6660474737397217, 1.486299031336563
# alpha, M, predM  6.103515625E-05, 1.9780314368466922, 1.486299031336563
# alpha, M, predM  3.0517578125E-05, 1.4865050830460769, 1.486299031336563
# alpha, M, predM  1.52587890625E-05, 1.486550722980021, 1.486299031336563
# alpha, M, predM  7.62939453125E-06, 1.4865734676677682, 1.486299031336563
# alpha, M, predM  3.814697265625E-06, 1.4865848212174444, 1.486299031336563
# alpha, M, predM  1.9073486328125E-06, 1.4865904932969312, 1.486299031336563
# alpha, M, predM  9.5367431640625E-07, 1.4865933281632338, 1.486299031336563
# alpha, M, predM  4.76837158203125E-07, 1.486594745303074, 1.486299031336563
# alpha, M, predM  2.384185791015625E-07, 1.4865954537996735, 1.486299031336563
# alpha, M, predM  1.1920928955078125E-07, 1.486595808029644, 1.486299031336563
# alpha, M, predM  5.960464477539063E-08, 1.486595985140047, 1.486299031336563
# alpha, M, predM  2.9802322387695312E-08, 1.4865960736941015, 1.486299031336563
# alpha, M, predM  1.4901161193847656E-08, 1.4865961179708442, 1.486299031336563
# l2: ||R0||= 6.4130837E-01, f_err=1.723603E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 5.8E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4320122493543
#     L2 Norm of Solution:    62.593211333849325
#     L2 Norm of Residual:    4.087716680027694
#     Relative Residual norm: 3.143043135722338E-06
#     Matrix Inf norm:        1300560.158900985
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4320122493543
#     L2 Norm of Solution:    62.59320745782828
#     L2 Norm of Residual:    2.471825293149111
#     Relative Residual norm: 1.90058512574911E-06
#     Matrix Inf norm:        1300560.158900985
# alpha, M, predM  1, 3.5732452359708002, 1.4862422693140034
# alpha, M, predM  0.5, 4.226823371334903, 1.4862422693140034
# alpha, M, predM  0.25, 3.5550592764738824, 1.4862422693140034
# alpha, M, predM  0.125, 2.82177975976285, 1.4862422693140034
# alpha, M, predM  0.0625, 3.6039007076398, 1.4862422693140034
# alpha, M, predM  0.03125, 2.792862783589656, 1.4862422693140034
# alpha, M, predM  0.015625, 2.1122082993348594, 1.4862422693140034
# alpha, M, predM  0.0078125, 1.7784819673433585, 1.4862422693140034
# alpha, M, predM  0.00390625, 1.6436836930697716, 1.4862422693140034
# alpha, M, predM  0.001953125, 1.5900521864991572, 1.4862422693140034
# alpha, M, predM  0.0009765625, 1.5536472229234564, 1.4862422693140034
# alpha, M, predM  0.00048828125, 1.553446675454408, 1.4862422693140034
# alpha, M, predM  0.000244140625, 1.59190024865335, 1.4862422693140034
# alpha, M, predM  0.0001220703125, 1.665158446407155, 1.4862422693140034
# alpha, M, predM  6.103515625E-05, 1.9699835922430875, 1.4862422693140034
# alpha, M, predM  3.0517578125E-05, 1.4864483137119453, 1.4862422693140034
# alpha, M, predM  1.52587890625E-05, 1.4864939571043767, 1.4862422693140034
# alpha, M, predM  7.62939453125E-06, 1.4865167025411188, 1.4862422693140034
# alpha, M, predM  3.814697265625E-06, 1.4865280562206782, 1.4862422693140034
# alpha, M, predM  1.9073486328125E-06, 1.4865337283040039, 1.4862422693140034
# alpha, M, predM  9.5367431640625E-07, 1.4865365631569658, 1.4862422693140034
# alpha, M, predM  4.76837158203125E-07, 1.4865379802863141, 1.4862422693140034
# alpha, M, predM  2.384185791015625E-07, 1.4865386887767154, 1.4862422693140034
# alpha, M, predM  1.1920928955078125E-07, 1.486539043003348, 1.4862422693140034
# alpha, M, predM  5.960464477539063E-08, 1.4865392201120209, 1.4862422693140034
# alpha, M, predM  2.9802322387695312E-08, 1.4865393086651975, 1.4862422693140034
# alpha, M, predM  1.4901161193847656E-08, 1.4865393529414976, 1.4862422693140034
# l2: ||R0||= 6.413105E-01, f_err=1.723612E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 5.45E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4558722906486
#     L2 Norm of Solution:    28.844034024191345
#     L2 Norm of Residual:    1.5028413295477034
#     Relative Residual norm: 1.1555072010305012E-06
#     Matrix Inf norm:        1300590.1894920636
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.4558722906486
#     L2 Norm of Solution:    28.84402901341212
#     L2 Norm of Residual:    1.111950431651337
#     Relative Residual norm: 8.549583417091601E-07
#     Matrix Inf norm:        1300590.1894920636
# alpha, M, predM  1, 3.5983309053306027, 1.4862089567173988
# alpha, M, predM  0.5, 4.249237265472562, 1.4862089567173988
# alpha, M, predM  0.25, 3.6369112416089346, 1.4862089567173988
# alpha, M, predM  0.125, 2.82927849804937, 1.4862089567173988
# alpha, M, predM  0.0625, 3.611220578349875, 1.4862089567173988
# alpha, M, predM  0.03125, 2.7988211345485383, 1.4862089567173988
# alpha, M, predM  0.015625, 2.1160819399867736, 1.4862089567173988
# alpha, M, predM  0.0078125, 1.7797810305435051, 1.4862089567173988
# alpha, M, predM  0.00390625, 1.6442468826305032, 1.4862089567173988
# alpha, M, predM  0.001953125, 1.5903346472502284, 1.4862089567173988
# alpha, M, predM  0.0009765625, 1.553724134250886, 1.4862089567173988
# alpha, M, predM  0.00048828125, 1.5532713578108772, 1.4862089567173988
# alpha, M, predM  0.000244140625, 1.591622575018856, 1.4862089567173988
# alpha, M, predM  0.0001220703125, 1.664550333770238, 1.4862089567173988
# alpha, M, predM  6.103515625E-05, 1.96443458132014, 1.4862089567173988
# alpha, M, predM  3.0517578125E-05, 1.486414996855845, 1.4862089567173988
# alpha, M, predM  1.52587890625E-05, 1.4864606427428644, 1.4862089567173988
# alpha, M, predM  7.62939453125E-06, 1.4864833887629476, 1.4862089567173988
# alpha, M, predM  3.814697265625E-06, 1.4864947425684916, 1.4862089567173988
# alpha, M, predM  1.9073486328125E-06, 1.4865004146734297, 1.4862089567173988
# alpha, M, predM  9.5367431640625E-07, 1.4865032495268495, 1.4862089567173988
# alpha, M, predM  4.76837158203125E-07, 1.4865046666538497, 1.4862089567173988
# alpha, M, predM  2.384185791015625E-07, 1.4865053751424266, 1.4862089567173988
# alpha, M, predM  1.1920928955078125E-07, 1.486505729367989, 1.4862089567173988
# alpha, M, predM  5.960464477539063E-08, 1.4865059064760846, 1.4862089567173988
# alpha, M, predM  2.9802322387695312E-08, 1.4865059950289634, 1.4862089567173988
# alpha, M, predM  1.4901161193847656E-08, 1.4865060393051104, 1.4862089567173988
# l2: ||R0||= 6.4131264E-01, f_err=1.723621E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 5.21E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.479730967722
#     L2 Norm of Solution:    29.552627085607792
#     L2 Norm of Residual:    3.0532604436319675
#     Relative Residual norm: 2.3475418911524807E-06
#     Matrix Inf norm:        1300620.2168912215
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.479730967722
#     L2 Norm of Solution:    29.55246967753754
#     L2 Norm of Residual:    1.6731434709418296
#     Relative Residual norm: 1.286419701318363E-06
#     Matrix Inf norm:        1300620.2168912215
# alpha, M, predM  1, 3.6167355269901797, 1.48619160366315
# alpha, M, predM  0.5, 4.26468153582285, 1.48619160366315
# alpha, M, predM  0.25, 3.5030840129908776, 1.48619160366315
# alpha, M, predM  0.125, 2.834172713011421, 1.48619160366315
# alpha, M, predM  0.0625, 3.616093070741914, 1.48619160366315
# alpha, M, predM  0.03125, 2.802813968540008, 1.48619160366315
# alpha, M, predM  0.015625, 2.1186903237843326, 1.48619160366315
# alpha, M, predM  0.0078125, 1.7806606579049271, 1.48619160366315
# alpha, M, predM  0.00390625, 1.6446320757361852, 1.48619160366315
# alpha, M, predM  0.001953125, 1.590531309464783, 1.48619160366315
# alpha, M, predM  0.0009765625, 1.5537819600154763, 1.48619160366315
# alpha, M, predM  0.00048828125, 1.5531572497320203, 1.48619160366315
# alpha, M, predM  0.000244140625, 1.5914368883429006, 1.48619160366315
# alpha, M, predM  0.0001220703125, 1.6641292805361838, 1.48619160366315
# alpha, M, predM  6.103515625E-05, 1.96047810704491, 1.48619160366315
# alpha, M, predM  3.0517578125E-05, 1.4863976416359839, 1.48619160366315
# alpha, M, predM  1.52587890625E-05, 1.4864432893538415, 1.48619160366315
# alpha, M, predM  7.62939453125E-06, 1.4864660358425654, 1.48619160366315
# alpha, M, predM  3.814697265625E-06, 1.48647738977094, 1.48619160366315
# alpha, M, predM  1.9073486328125E-06, 1.486483061909446, 1.48619160366315
# alpha, M, predM  9.5367431640625E-07, 1.4864858967726953, 1.48619160366315
# alpha, M, predM  4.76837158203125E-07, 1.486487313902868, 1.48619160366315
# alpha, M, predM  2.384185791015625E-07, 1.4864880223925976, 1.48619160366315
# alpha, M, predM  1.1920928955078125E-07, 1.486488376618625, 1.48619160366315
# alpha, M, predM  5.960464477539063E-08, 1.4864885537269308, 1.48619160366315
# alpha, M, predM  2.9802322387695312E-08, 1.486488642279905, 1.48619160366315
# alpha, M, predM  1.4901161193847656E-08, 1.4864886865560978, 1.48619160366315
# l2: ||R0||= 6.4131477E-01, f_err=1.72363E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 3.43E-03, Kappa = 1E+03, Mu =
# alpha, M, predM  0.0625, 3.621354942825958, 1.4861857433426213
# alpha, M, predM  0.03125, 2.8072271821198744, 1.4861857433426213
# alpha, M, predM  0.015625, 2.1216285718704992, 1.4861857433426213
# alpha, M, predM  0.0078125, 1.781663608980862, 1.4861857433426213
# alpha, M, predM  0.00390625, 1.6450815838575694, 1.4861857433426213
# alpha, M, predM  0.001953125, 1.5907711045082171, 1.4861857433426213
# alpha, M, predM  0.0009765625, 1.5538630655333103, 1.4861857433426213
# alpha, M, predM  0.00048828125, 1.553037418169507, 1.4861857433426213
# alpha, M, predM  0.000244140625, 1.5912277917417263, 1.4861857433426213
# alpha, M, predM  0.0001220703125, 1.6636151025048487, 1.4861857433426213
# alpha, M, predM  6.103515625E-05, 1.9552621417051328, 1.4861857433426213
# alpha, M, predM  3.0517578125E-05, 1.4863917807960352, 1.4861857433426213
# alpha, M, predM  1.52587890625E-05, 1.4864374309627337, 1.4861857433426213
# alpha, M, predM  7.62939453125E-06, 1.4864601781790794, 1.4861857433426213
# alpha, M, predM  3.814697265625E-06, 1.4864715323473112, 1.4861857433426213
# alpha, M, predM  1.9073486328125E-06, 1.4864772045747803, 1.4861857433426213
# alpha, M, predM  9.5367431640625E-07, 1.4864800394747713, 1.4861857433426213
# alpha, M, predM  4.76837158203125E-07, 1.4864814566213853, 1.4861857433426213
# alpha, M, predM  2.384185791015625E-07, 1.486482165118855, 1.4861857433426213
# alpha, M, predM  1.1920928955078125E-07, 1.4864825193486257, 1.4861857433426213
# alpha, M, predM  5.960464477539063E-08, 1.4864826964587752, 1.4861857433426213
# alpha, M, predM  2.9802322387695312E-08, 1.486482785012667, 1.4861857433426213
# alpha, M, predM  1.4901161193847656E-08, 1.4864828292893153, 1.4861857433426213
# l2: ||R0||= 6.4131904E-01, f_err=1.723647E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 4.88E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5513072129804
#     L2 Norm of Solution:    1872.4127053121722
#     L2 Norm of Residual:    45.68154345890718
#     Relative Residual norm: 3.512045957088394E-05
#     Matrix Inf norm:        1300710.2986994719
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5513072129804
#     L2 Norm of Solution:    1872.412702090663
#     L2 Norm of Residual:    36.40923169435973
#     Relative Residual norm: 2.7991807038634095E-05
#     Matrix Inf norm:        1300710.2986994719
# alpha, M, predM  1, 3.6969881083683127, 1.4861913292520499
# alpha, M, predM  0.5, 4.300158512214545, 1.4861913292520499
# alpha, M, predM  0.25, 3.5423588100451444, 1.4861913292520499
# alpha, M, predM  0.125, 2.839951426643286, 1.4861913292520499
# alpha, M, predM  0.0625, 3.6225968154731425, 1.4861913292520499
# alpha, M, predM  0.03125, 2.8083562495386696, 1.4861913292520499
# alpha, M, predM  0.015625, 2.1224290633239895, 1.4861913292520499
# alpha, M, predM  0.0078125, 1.7819432163905082, 1.4861913292520499
# alpha, M, predM  0.00390625, 1.6452126673996776, 1.4861913292520499
# alpha, M, predM  0.001953125, 1.5908470946057243, 1.4861913292520499
# alpha, M, predM  0.0009765625, 1.5538936322042056, 1.4861913292520499
# alpha, M, predM  0.00048828125, 1.5530080491733855, 1.4861913292520499
# alpha, M, predM  0.000244140625, 1.5911686773604343, 1.4861913292520499
# alpha, M, predM  0.0001220703125, 1.6634490812972225, 1.4861913292520499
# alpha, M, predM  6.103515625E-05, 1.9533861914896733, 1.4861913292520499
# alpha, M, predM  3.0517578125E-05, 1.4863973675931244, 1.4861913292520499
# alpha, M, predM  1.52587890625E-05, 1.486443018614716, 1.4861913292520499
# alpha, M, predM  7.62939453125E-06, 1.4864657661295146, 1.4861913292520499
# alpha, M, predM  3.814697265625E-06, 1.486477120414783, 1.4861913292520499
# alpha, M, predM  1.9073486328125E-06, 1.4864827926927362, 1.4861913292520499
# alpha, M, predM  9.5367431640625E-07, 1.486485627615958, 1.4861913292520499
# alpha, M, predM  4.76837158203125E-07, 1.486487044773689, 1.4861913292520499
# alpha, M, predM  2.384185791015625E-07, 1.4864877532765857, 1.4861913292520499
# alpha, M, predM  1.1920928955078125E-07, 1.4864881075090426, 1.4861913292520499
# alpha, M, predM  5.960464477539063E-08, 1.4864882846205232, 1.4861913292520499
# alpha, M, predM  2.9802322387695312E-08, 1.4864883731750815, 1.4861913292520499
# alpha, M, predM  1.4901161193847656E-08, 1.4864884174520614, 1.4861913292520499
# l2: ||R0||= 6.4132118E-01, f_err=1.723656E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 4.83E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5751671605703
#     L2 Norm of Solution:    33.91193395868574
#     L2 Norm of Residual:    1.994351460933384
#     Relative Residual norm: 1.5332433521945945E-06
#     Matrix Inf norm:        1300740.3280625911
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.5751671605703
#     L2 Norm of Solution:    33.911942748795276
#     L2 Norm of Residual:    1.235439529433324
#     Relative Residual norm: 9.497972060829924E-07
#     Matrix Inf norm:        1300740.3280625911
# alpha, M, predM  1, 3.8028529882030693, 1.4862001976441446
# alpha, M, predM  0.5, 4.328265567198729, 1.4862001976441446
# alpha, M, predM  0.25, 3.5570673182085835, 1.4862001976441446
# alpha, M, predM  0.125, 2.8429159650108833, 1.4862001976441446
# alpha, M, predM  0.0625, 3.623230682809767, 1.4862001976441446
# alpha, M, predM  0.03125, 2.8090442034592695, 1.4862001976441446
# alpha, M, predM  0.015625, 2.1229758883694587, 1.4862001976441446
# alpha, M, predM  0.0078125, 1.782138933148765, 1.4862001976441446
# alpha, M, predM  0.00390625, 1.6453089459431636, 1.4862001976441446
# alpha, M, predM  0.001953125, 1.5909077935440668, 1.4862001976441446
# alpha, M, predM  0.0009765625, 1.5539206615795058, 1.4862001976441446
# alpha, M, predM  0.00048828125, 1.5529889464508528, 1.4862001976441446
# alpha, M, predM  0.000244140625, 1.5911245382496388, 1.4862001976441446
# alpha, M, predM  0.0001220703125, 1.6633124776456247, 1.4862001976441446
# alpha, M, predM  6.103515625E-05, 1.9517431015948439, 1.4862001976441446
# alpha, M, predM  3.0517578125E-05, 1.486406237328461, 1.4862001976441446
# alpha, M, predM  1.52587890625E-05, 1.4864518890549432, 1.4862001976441446
# alpha, M, predM  7.62939453125E-06, 1.4864746368415767, 1.4862001976441446
# alpha, M, predM  3.814697265625E-06, 1.4864859912426531, 1.4862001976441446
# alpha, M, predM  1.9073486328125E-06, 1.486491663573489, 1.4862001976441446
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         1241.8377140762375
#     L2 Norm of Solution:    21.16782979438389
#     L2 Norm of Residual:    0.1280186737302753
#     Relative Residual norm: 9.839485597359274E-08
#     Matrix Inf norm:        1301070.7974879604
# alpha, M, predM  1, 9.863214422111938, 1.4863590435250016
# alpha, M, predM  0.5, 5.886550830554435, 1.4863590435250016
# alpha, M, predM  0.25, 4.318106148965892, 1.4863590435250016
# alpha, M, predM  0.125, 3.0608836024914616, 1.4863590435250016
# alpha, M, predM  0.0625, 3.6740327059259417, 1.4863590435250016
# alpha, M, predM  0.03125, 2.8182907398165646, 1.4863590435250016
# alpha, M, predM  0.015625, 2.124344796512783, 1.4863590435250016
# alpha, M, predM  0.0078125, 1.7827459902387257, 1.4863590435250016
# alpha, M, predM  0.00390625, 1.6457226780677252, 1.4863590435250016
# alpha, M, predM  0.001953125, 1.5912908764133662, 1.4863590435250016
# alpha, M, predM  0.0009765625, 1.5541520127868136, 1.4863590435250016
# alpha, M, predM  0.00048828125, 1.5529705421780289, 1.4863590435250016
# alpha, M, predM  0.000244140625, 1.5909188394120657, 1.4863590435250016
# alpha, M, predM  0.0001220703125, 1.6623623347493826, 1.4863590435250016
# alpha, M, predM  6.103515625E-05, 1.9383023806201216, 1.4863590435250016
# alpha, M, predM  3.0517578125E-05, 1.4865651068818333, 1.4863590435250016
# alpha, M, predM  1.52587890625E-05, 1.4866107632863645, 1.4863590435250016
# alpha, M, predM  7.62939453125E-06, 1.486633513488651, 1.4863590435250016
# alpha, M, predM  3.814697265625E-06, 1.4866448691167784, 1.4863590435250016
# alpha, M, predM  1.9073486328125E-06, 1.4866505420659575, 1.4863590435250016
# alpha, M, predM  9.5367431640625E-07, 1.4866533773247457, 1.4863590435250016
# alpha, M, predM  4.76837158203125E-07, 1.4866547946502424, 1.4863590435250016
# alpha, M, predM  2.384185791015625E-07, 1.4866555032370192, 1.4863590435250016
# alpha, M, predM  1.1920928955078125E-07, 1.4866558575114226, 1.4863590435250016
# alpha, M, predM  5.960464477539063E-08, 1.4866560346438749, 1.4863590435250016
# alpha, M, predM  2.9802322387695312E-08, 1.4866561232089122, 1.4863590435250016
# alpha, M, predM  1.4901161193847656E-08, 1.4866561674911345, 1.4863590435250016
# l2: ||R0||= 6.4134679E-01, f_err=1.723763E+00, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.75E-03, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.ResNorms.SaveToTextFile(pSAIDT.Control.ProjectName+"_ResPlot.txt");
pSAIDT.obj_f_vals.SaveToTextFile(pSAIDT.Control.ProjectName+"_EnResPlot.txt");
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:600,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="600" height="500"
#  viewBox="0 0 600 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="600" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,381.2 L50.1,381.2 M550.1,381.2 L545.6,381.2 M45.6,345.5 L50.1,345.5 M550.1,345.5 L545.6,345.5
# 		M45.6,320.1 L50.1,320.1 M550.1,320.1 L545.6,320.1 M45.6,300.4 L50.1,300.4 M550.1,300.4 L545.6,300.4
# 		M45.6,284.3 L50.1,284.3 M550.1,284.3 L545.6,284.3 M45.6,270.7 L50.1,270.7 M550.1,270.7 L545.6,270.7
# 		M45.6,258.9 L50.1,258.9 M550.1,258.9 L545.6,258.9 M45.6,248.5 L50.1,248.5 M550.1,248.5 L545.6,248.5
# 		M45.6,239.2 L54.6,239.2 M550.1,239.2 L541.1,239.2  '/>	<g transform="translate(37.3,245.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,178.1 L50.1,178.1 M550.1,178.1 L545.6,178.1 M45.6,142.3 L50.1,142.3 M550.1,142.3 L545.6,142.3
# 		M45.6,116.9 L50.1,116.9 M550.1,116.9 L545.6,116.9 M45.6,97.3 L50.1,97.3 M550.1,97.3 L545.6,97.3
# 		M45.6,81.2 L50.1,81.2 M550.1,81.2 L545.6,81.2 M45.6,67.6 L50.1,67.6 M550.1,67.6 L545.6,67.6
# 		M45.6,55.8 L50.1,55.8 M550.1,55.8 L545.6,55.8 M45.6,45.4 L50.1,45.4 M550.1,45.4 L545.6,45.4
# 		M45.6,36.1 L54.6,36.1 M550.1,36.1 L541.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M129.7,442.4 L129.7,433.4 M129.7,36.1 L129.7,45.1  '/>	<g transform="translate(129.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M213.8,442.4 L213.8,433.4 M213.8,36.1 L213.8,45.1  '/>	<g transform="translate(213.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M297.8,442.4 L297.8,433.4 M297.8,36.1 L297.8,45.1  '/>	<g transform="translate(297.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 15</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M381.9,442.4 L381.9,433.4 M381.9,36.1 L381.9,45.1  '/>	<g transform="translate(381.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M466.0,442.4 L466.0,433.4 M466.0,36.1 L466.0,45.1  '/>	<g transform="translate(466.0,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 25</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M550.1,442.4 L550.1,433.4 M550.1,36.1 L550.1,45.1  '/>	<g transform="translate(550.1,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 30</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(558.4,446.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="start">
# 		<text><tspan font-family="Arial" > </tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M550.1,384.4 L541.1,

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm SAIDT_DGLevelSet_0.plt SAIDT_DGLevelSet_10.plt SAIDT_DGLevelSet_15.plt SAIDT_DGLevelSet_20.plt SAIDT_DGLevelSet_25.plt SAIDT_DGLevelSet_30.plt SAIDT_DGLevelSet_5.plt;

# %% [markdown]
# ## Spline level set

# %%
BoSSS.Solution.Application.InitMPI();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SplineLevelSet,
                    LSDegree: 3,
                    isFarConfig:true
                    );
CSAIDT.SessionName="SAIDT_SplineLevelSet";
CSAIDT.ProjectName="SAIDT_SplineLevelSet";
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SplineLevelSet",pSAIDT.LevelSetOpti.GetLength());
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# Session ID: c6ac8b89-17e7-4b7f-98c7-0b26d38597c6, DB path: 'SAIDT_db_22032024'
# Session directory 'SAIDT_db_22032024\sessions\c6ac8b89-17e7-4b7f-98c7-0b26d38597c6'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Initial Value : l2: |r|= 1.4635787E+00, |f_err|=2.8278013E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 3.7516671689706986, 7.053612935037218
# l2: ||R0||= 9.9767071E-01, f_err=2.198114E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.68E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 1.3718138192652538, 7.076137197616945
# l2: ||R0||= 4.617505E-01, f_err=1.573093E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.26E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1,
-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 8.48E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 5.765062636629772E-06, 1.1602173271617257E-05
# l2: ||R0||= 7.8790788E-04, f_err=3.394901E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 7.69E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 9.458568007739529E-07, 5.762640412962434E-06
# l2: ||R0||= 2.6613746E-04, f_err=1.375331E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 2.5E-03, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
# ALNR=1.5278566941869889 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 1.2801608177961704E-07, 9.456914077001377E-07
# l2: ||R0||= 5.425681E-05, f_err=5.059921E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.42E-03, QuadOrder=4
# ALNR=1.2645608630566982 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 9.167520539396881E-09, 1.2799408545986413E-07
# l2: ||R0||= 3.0356634E-05, f_err=1.354063E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 2E-04, QuadOrder=4
# ALNR=1.3770341620635276 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 1.3796669658026161E-09, 9.166029609562389E-09
# l2: ||R0||= 1.9839155E-05, f_err=5.252909E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 7.25E-05, QuadOrder=4
# ALNR=1.452768087938249 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 1.3508256026868709E-11, 1.3794576418757397E-09
# l2: ||R0||= 8.6492775E-07, f_err=5.19774E-06, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 9.96E-06, QuadOrder=4
# ALNR=4.5866759134752755 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 1.4247048555087662E-13, 1.3513095717091888E-11
# l2: ||R0||= 8.3420104E-08, f_err=5.337986E-07, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 1.41E-06, QuadOrder=4
# ALNR=5.925009775783481 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 9.288688239557013E-16, 1.4290803072477761E-13
# l2: ||R0||= 1.8676423E-08, f_err=4.310148E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 5.79E-08, QuadOrder=4
# ALNR=6.420238286662034 > 1.005 so we continue
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 6.972280565802749E-17, 1.0659974215283668E-15
# l2: ||R0||= 7.9518309E-09, f_err=1.180871E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 8.57E-09, QuadOrder=4
# ALNR=6.6129089587536125 > 1.005 so we continue
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 1.0354674357019392E-16, 1.2902956571057724E-16
# l2: ||R0||= 9.7763161E-09, f_err=1.439074E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 1.33E-09, QuadOrder=4
# ALNR=6.348348095696914 > 1.005 so we continue
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 1.1915247854417714E-16, 1.8362101605157757E-16
# l2: ||R0||= 1.0676298E-08, f_err=1.543713E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 3.73E-10, QuadOrder=4
# ALNR=6.2358747966900845 > 1.005 so we continue
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 1.2465458583730912E-16, 2.0447240332085324E-16
# l2: ||R0||= 1.0940004E-08, f_err=1.578953E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 3.91E-10, QuadOrder=4
# ALNR=6.160140870815363 > 1.005 so we continue
#
#
# Starting Opt-Iter No.41:
# alpha, M, predM  1, 1.2111351959158486E-16, 2.1166664182778587E-16
# l2: ||R0||= 1.0800596E-08, f_err=1.556364E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 3E-10, QuadOrder=4
# ALNR=3.0262330452783357 > 1.005 so we continue
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 1.1135285895749502E-16, 2.070511232265111E-16
# l2: ||R0||= 1.0370045E-08, f_err=1.492333E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.77E-04, Kappa = 1E+03, Mu = 2.31E-10, QuadOrder=4
# ALNR=1.6878991829701302 > 1.005 so we continue
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 9.87558147953071E-17, 1.9423035773564965E-16
# l2: ||R0||= 9.77616E-09, f_err=1.405388E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.51E-04, Kappa = 1E+03, Mu = 1.76E-10, QuadOrder=4
# ALNR=1.192670672091578 > 1.005 so we continue
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 8.66755144071314E-17, 1.7747480352399818E-16
# l2: ||R0||= 9.1666288E-09, f_err=1.316628E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.01E-04, Kappa = 1E+03, Mu = 1.31E-10, QuadOrder=4
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.ResNorms.SaveToTextFile(pSAIDT.Control.ProjectName+"_ResPlot.txt");
pSAIDT.obj_f_vals.SaveToTextFile(pSAIDT.Control.ProjectName+"_EnResPlot.txt");
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:600,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="600" height="500"
#  viewBox="0 0 600 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="600" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-9</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,401.8 L54.6,401.8 M550.1,401.8 L541.1,401.8  '/>	<g transform="translate(37.3,407.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,361.1 L54.6,361.1 M550.1,361.1 L541.1,361.1  '/>	<g transform="translate(37.3,367.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-7</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,320.5 L54.6,320.5 M550.1,320.5 L541.1,320.5  '/>	<g transform="translate(37.3,326.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,279.9 L54.6,279.9 M550.1,279.9 L541.1,279.9  '/>	<g transform="translate(37.3,285.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-5</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,239.2 L54.6,239.2 M550.1,239.2 L541.1,239.2  '/>	<g transform="translate(37.3,245.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,198.6 L54.6,198.6 M550.1,198.6 L541.1,198.6  '/>	<g transform="translate(37.3,204.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,158.0 L54.6,158.0 M550.1,158.0 L541.1,158.0  '/>	<g transform="translate(37.3,164.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,117.4 L54.6,117.4 M550.1,117.4 L541.1,117.4  '/>	<g transform="translate(37.3,123.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,76.7 L54.6,76.7 M550.1,76.7 L541.1,76.7  '/>	<g transform="translate(37.3,82.7)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,36.1 L54.6,36.1 M550.1,36.1 L541.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter

# %%
var si= database.Sessions.Pick(0);
pSAIDT.PlotShadowFields(si);

# %% [markdown]
# ## SpecFemField

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 50,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: 5,
                    optiLevelSetType: OptiLevelSetType.SpecFemField,
                    LSDegree: 3,
                    isFarConfig:true
                    );
CSAIDT.SessionName="SAIDT_CGLevelSet";
CSAIDT.ProjectName="SAIDT_CGLevelSet";
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
DOFS.Add("SpecFemField",pSAIDT.LevelSetOpti.GetLength());
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# Session ID: f546f217-c5a5-4d04-898c-695085ac0f1c, DB path: 'SAIDT_db_22032024'
# Session directory 'SAIDT_db_22032024\sessions\f546f217-c5a5-4d04-898c-695085ac0f1c'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Initial Value : l2: |r|= 1.448461E+00, |f_err|=2.8259626E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         123.05190701970221
#     L2 Norm of Solution:    59.72795755148653
#     L2 Norm of Residual:    536.256694053051
#     Relative Residual norm: 7.319551960117271E-05
#     Matrix Inf norm:        7326359.5500790635
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         123.05190701970221
#     L2 Norm of Solution:    234.7896521386764
#     L2 Norm of Residual:    1967.2965457851872
#     Relative Residual norm: 0.0002685230682903021
#     Matrix Inf norm:        7326359.5500790635
# alpha, M, predM  1, 2.205859659771457, 7.068239261167508
# l2: ||R0||= 6.3580551E-01, f_err=1.822502E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.7E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         13.675799950796316
#     L2 Norm of Solution:    2.0614234949479004
#     L2 Norm of Residual:    11.223311060811426
#     Relative Residual norm: 0.012154273756982897
#     Matrix Inf norm:        923.4044983036018
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         13.675799950796316
#     L2 Norm of Solution:    2.0298753949011124
#     L2 Norm of Residual:    10.811103101015238
#     Relative Residual norm: 0.011707873549323676
#     Matrix Inf norm:        923.4044983036018
# alpha, M, predM  1, 1.0769128859078096, 1.8868538378858224
# l2: ||R0||= 3.9584677E-01, f_err=1.40667E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.12E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 1.169160114874318, 1.1821041993524875
# l2: ||R0||= 4.4486763E-01, f_err=1.430887E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.47E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 0.7966462117757903, 1.91399502698826
# l2: ||R0||= 2.7479321E-01, f_err=1.221145E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.35E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.592848431346022, 0.8116730642632569
# l2: ||R0||= 1.2569551E-01, f_err=1.076099E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.75E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 1.3195305648260214, 0.7960117290832006
# alpha, M, predM  0.5, 0.8347757670782215, 0.7960117290832006
# alpha, M, predM  0.25, 0.7299571631377704, 0.7960117290832006
# l2: ||R0||= 1.3890074E-01, f_err=1.197296E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.37E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.517853951116061, 0.7298772898519084
# l2: ||R0||= 5.1473559E-02, f_err=1.01592E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.36E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.4859553648932934, 0.5182413952343167
# l2: ||R0||= 1.9690624E-01, f_err=9.559292E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.5E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.7357437357853757, 0.4711465829152267
# alpha, M, predM  0.5, 0.5059171056966403, 0.4711465829152267
# alpha, M, predM  0.25, 0.4437470009941843, 0.4711465829152267
# l2: ||R0||= 1.8116266E-01, f_err=9.143279E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.57E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.3963912986740612, 0.44354727341073413
# l2: ||R0||= 2.0152396E-01, f_err=8.552058E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.51E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.5298285175278814, 0.3934110267509917
# alpha, M, predM  0.5, 0.3787969639450274, 0.3934110267509917
# l2: ||R0||= 2.046802E-01, f_err=8.368646E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.37E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.3046777984425722, 0.40340489762908344
# l2: ||R0||= 1.4958856E-01, f_err=7.597201E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.44E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.6432803090315756, 0.5128468432497083
# alpha, M, predM  0.5, 0.4872265633912842, 0.5128468432497083
# l2: ||R0||= 1.9228228E-01, f_err=9.702881E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.92E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.31879290352901823, 0.4869663074838253
# l2: ||R0||= 1.2906913E-01, f_err=7.892479E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.81E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.604369318158049, 0.3211085301992908
# alpha, M, predM  0.5, 0.3623896254767141, 0.3211085301992908
# alpha, M, predM  0.25, 0.3090000202189042, 0.3211085301992908
# l2: ||R0||= 1.3911775E-01, f_err=7.723103E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.11E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# Solve_Direct fail in fallback seq (#0): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         5.029859583960838
#     L2 Norm of Solution:    15.165692923267185
#     L2 Norm of Residual:    80.29229289398249
#     Relative Residual norm: 0.07252246515102322
#     Matrix Inf norm:        1107.1368399678518
#
# Solve_Direct fail in fallback seq (#1): Linear Solver: High residual from direct solver ilPSP.LinSolvers.PARDISO.PARDISOSolver.
#     L2 Norm of RHS:         5.029859583960838
#     L2 Norm of Solution:    5.146489933569984
#     L2 Norm of Residual:    18.625354319017273
#     Relative Residual norm: 0.01682299210597861
#     Matrix Inf norm:        1107.1368399678518
# alpha, M, predM  1, 0.2973043791659021, 0.3266032222847744
# l2: ||R0||= 1.7000312E-01, f_err=7.477528E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.23E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.36439357758679625, 0.2902599653587722
# alpha, M, predM  0.5, 0.24852918267256624, 0.2902599653587722
# l2: ||R0||= 1.4641131E-01, f_err=6.932009E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.71E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.33357343658171645, 0.2523893518223888
# alpha, M, predM  0.5, 0.25712124276660386, 0.2523893518223888
# alpha, M, predM  0.25, 0.250791592315163, 0.2523893518223888
# l2: ||R0||= 1.2730088E-01, f_err=6.951475E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.13E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.26003501764996895, 0.2497027793241036
# alpha, M, predM  0.5, 0.21495178078767485, 0.2497027793241036
# l2: ||R0||= 7.4690998E-02, f_err=6.514041E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 0.27045109087546, 0.21508794806913348
# alpha, M, predM  0.5, 0.2178358611890331, 0.21508794806913348
# alpha, M, predM  0.25, 0.21139602025881438, 0.21508794806913348
# l2: ||R0||= 7.9915066E-02, f_err=6.450426E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.05E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 0.29169302619969995, 0.21122585036098043
# alpha, M, predM  0.5, 0.22172535847150301, 0.21122585036098043
# alpha, M, predM  0.25, 0.1985097379210873, 0.21122585036098043
# l2: ||R0||= 7.2484442E-02, f_err=6.259116E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1E+00, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 0.314788348016906, 0.19820574219663756
# alpha, M, predM  0.5, 0.23960245283209358, 0.19820574219663756
# alpha, M, predM  0.25, 0.21660116398208876, 0.19820574219663756
# alpha, M, predM  0.125, 0.19388338023499038, 0.19820574219663756
# l2: ||R0||= 6.5246918E-02, f_err=6.196725E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.86E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 0.2778201692308239, 0.19383765989350477
# alpha, M, predM  0.5, 0.21169058552010991, 0.19383765989350477
# alpha, M, predM  0.25, 0.1959994537664955, 0.19383765989350477
# alpha, M, predM  0.125, 0.19313880092676133, 0.19383765989350477
# l2: ||R0||= 6.7530224E-02, f_err=6.183213E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.68E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 0.20109977134640797, 0.19334677806671188
# alpha, M, predM  0.5, 0.18701169097176917, 0.19334677806671188
# l2: ||R0||= 5.7005807E-02, f_err=6.090168E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.61E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 0.5007468519894424, 0.18673651504780625
# alpha, M, predM  0.5, 0.26867470765381557, 0.18673651504780625
# alpha, M, predM  0.25, 0.19121070163985948, 0.18673651504780625
# alpha, M, predM  0.125, 0.1824169757691465, 0.18673651504780625
# l2: ||R0||= 6.8564796E-02, f_err=6.008997E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.98E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 0.31687403011082943, 0.18246737768851942
# alpha, M, predM  0.5, 0.23157936152578978, 0.18246737768851942
# alpha, M, predM  0.25, 0.20254871901464283, 0.18246737768851942
# alpha, M, predM  0.125, 0.17782875940194043, 0.18246737768851942
# l2: ||R0||= 6.1549189E-02, f_err=5.937539E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.22E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 0.6183978053676179, 0.17782133825112922
# alpha, M, predM  0.5, 0.17477989308836323, 0.17782133825112922
# l2: ||R0||= 5.1644836E-02, f_err=5.893839E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.2E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 1.0682785689985812, 0.17471066034069052
# alpha, M, predM  0.5, 0.28790202239983426, 0.17471066034069052
# alpha, M, predM  0.25, 0.20254457772458373, 0.17471066034069052
# alpha, M, predM  0.125, 0.1911894554851587, 0.17471066034069052
# alpha, M, predM  0.0625, 0.18951398383599635, 0.17471066034069052
# alpha, M, predM  0.03125, 0.17103324445746718, 0.17471066034069052
# l2: ||R0||= 5.1122336E-02, f_err=5.831257E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.77E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 0.9653645268684096, 0.17092222768184656
# alpha, M, predM  0.5, 0.2910601918853832, 0.17092222768184656
# alpha, M, predM  0.25, 0.2079857872764347, 0.17092222768184656
# alpha, M, predM  0.125, 0.19392000536125642, 0.17092222768184656
# alpha, M, predM  0.0625, 0.18856327265462675, 0.17092222768184656
# alpha, M, predM  0.03125, 0.16675696661958428, 0.17092222768184656
# l2: ||R0||= 4.9504717E-02, f_err=5.760144E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 7.02E-01, QuadOrder=5
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 1.06775617051869, 0.1666295630706602
# alpha, M, predM  0.5, 0.34608857904109414, 0.1666295630706602
# alpha, M, predM  0.25, 0.22220517925048272, 0.1666295630706602
# alpha, M, predM  0.125, 0.19829112401628607, 0.1666295630706602
# alpha, M, predM  0.0625, 0.1902596999471398, 0.1666295630706602
# alpha, M, predM  0.03125, 0.1880143094926143, 0.1666295630706602
# alpha, M, predM  0.015625, 0.18719830277738558, 0.1666295630706602
# alpha, M, predM  0.0078125, 0.18703891033756415, 0.1666295630706602
# alpha, M, predM  0.00390625, 0.16603386277050974, 0.1666295630706602
# l2: ||R0||= 4.9314321E-02, f_err=5.749617E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 6.11E-01, QuadOrder=5
# ALNR=1.0062010236077363 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 1.0939787047890437, 0.1659775159737082
# alpha, M, predM  0.5, 0.5427618111051242, 0.1659775159737082
# alpha, M, predM  0.25, 0.21470230621030656, 0.1659775159737082
# alpha, M, predM  0.125, 0.1898122415026338, 0.1659775159737082
# alpha, M, predM  0.0625, 0.18952088000507822, 0.1659775159737082
# alpha, M, predM  0.03125, 0.18778793478801217, 0.1659775159737082
# alpha, M, predM  0.015625, 0.18715389465761212, 0.1659775159737082
# alpha, M, predM  0.0078125, 0.18687438610660353, 0.1659775159737082
# alpha, M, predM  0.00390625, 0.18689944581166107, 0.1659775159737082
# alpha, M, predM  0.001953125, 0.1870286978827784, 0.1659775159737082
# alpha, M, predM  0.0009765625, 0.18709367735457688, 0.1659775159737082
# alpha, M, predM  0.00048828125, 0.1871266304694, 0.1659775159737082
# alpha, M, predM  0.000244140625, 0.18714312333878225, 0.1659775159737082
# alpha, M, predM  0.0001220703125, 0.16597507914406034, 0.1659775159737082
# l2: ||R0||= 4.9308308E-02, f_err=5.749386E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 5.74E-01, QuadOrder=5
# ALNR=1.006218444698986 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 1.3296990771453072, 0.165876119794115
# alpha, M, predM  0.5, 0.6259394673070224, 0.165876119794115
# alpha, M, predM  0.25, 0.3612305008287582, 0.165876119794115
# alpha, M, predM  0.125, 0.19603663097485502, 0.165876119794115
# alpha, M, predM  0.0625, 0.18908199932634412, 0.165876119794115
# alpha, M, predM  0.03125, 0.1873367206368357, 0.165876119794115
# alpha, M, predM  1.9073486328125E-06, 0.1657991212809984, 0.1657839244027463
# alpha, M, predM  9.5367431640625E-07, 0.16579926902740497, 0.1657839244027463
# alpha, M, predM  4.76837158203125E-07, 0.1657993429006999, 0.1657839244027463
# alpha, M, predM  2.384185791015625E-07, 0.16579937983737017, 0.1657839244027463
# alpha, M, predM  1.1920928955078125E-07, 0.16579939830571083, 0.1657839244027463
# alpha, M, predM  5.960464477539063E-08, 0.1657994075398829, 0.1657839244027463
# alpha, M, predM  2.9802322387695312E-08, 0.1657994121569693, 0.1657839244027463
# alpha, M, predM  1.4901161193847656E-08, 0.16579941446551247, 0.1657839244027463
# l2: ||R0||= 4.9308318E-02, f_err=5.749386E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 4.3E-01, QuadOrder=5
# ALNR=1.006218444698986 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 1.8856628959566293, 0.1657134857962494
# alpha, M, predM  0.5, 0.7981354201003924, 0.1657134857962494
# alpha, M, predM  0.25, 0.4472108035898373, 0.1657134857962494
# alpha, M, predM  0.125, 0.19546489865430985, 0.1657134857962494
# alpha, M, predM  0.0625, 0.18760598926888136, 0.1657134857962494
# alpha, M, predM  0.03125, 0.18613553168104408, 0.1657134857962494
# alpha, M, predM  0.015625, 0.18601125741010383, 0.1657134857962494
# alpha, M, predM  0.0078125, 0.18603134262482746, 0.1657134857962494
# alpha, M, predM  0.00390625, 0.18606267672388865, 0.1657134857962494
# alpha, M, predM  0.001953125, 0.18631222685347762, 0.1657134857962494
# alpha, M, predM  0.0009765625, 0.18646905373230085, 0.1657134857962494
# alpha, M, predM  0.00048828125, 0.18654799091154556, 0.1657134857962494
# alpha, M, predM  0.000244140625, 0.1865875182577431, 0.1657134857962494
# alpha, M, predM  0.0001220703125, 0.18660728960320616, 0.1657134857962494
# alpha, M, predM  6.103515625E-05, 0.1657204061735457, 0.1657134857962494
# alpha, M, predM  3.0517578125E-05, 0.1657258253035821, 0.1657134857962494
# alpha, M, predM  1.52587890625E-05, 0.1657285349867118, 0.1657134857962494
# alpha, M, predM  7.62939453125E-06, 0.1657298898578048, 0.1657134857962494
# alpha, M, predM  3.814697265625E-06, 0.16573056730073452, 0.1657134857962494
# alpha, M, predM  1.9073486328125E-06, 0.16573090602404458, 0.1657134857962494
# alpha, M, predM  9.5367431640625E-07, 0.16573107538616105, 0.1657134857962494
# alpha, M, predM  4.76837158203125E-07, 0.16573116006733465, 0.1657134857962494
# alpha, M, predM  2.384185791015625E-07, 0.16573120240795028, 0.1657134857962494
# alpha, M, predM  1.1920928955078125E-07, 0.1657312235782652, 0.1657134857962494
# alpha, M, predM  5.960464477539063E-08, 0.16573123416342464, 0.1657134857962494
# alpha, M, predM  2.9802322387695312E-08, 0.16573123945600457, 0.1657134857962494
# alpha, M, predM  1.4901161193847656E-08, 0.16573124210229492, 0.1657134857962494
# l2: ||R0||= 4.9308322E-02, f_err=5.749386E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 3.74E-01, QuadOrder=5
# ALNR=1.006218444698986 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 3.5237274678872055, 0.16568355986857758
# alpha, M, predM  0.5, 0.8995918482158264, 0.16568355986857758
# alpha, M, predM  0.25, 0.4959350100957568, 0.16568355986857758
# alpha, M, predM  0.125, 0.3308425111158744, 0.16568355986857758
# alpha, M, predM  0.0625, 0.18656789813753422, 0.16568355986857758
# alpha, M, predM  0.03125, 0.18551953827758141, 0.16568355986857758
# alpha, M, predM  0.015625, 0.1856575283657476, 0.16568355986857758
# alpha, M, predM  0.0078125, 0.18582121138547145, 0.16568355986857758
# alpha, M, predM  0.00390625, 0.18592753466443723, 0.16568355986857758
# alpha, M, predM  0.001953125, 0.18619219756447733, 0.16568355986857758
# alpha, M, predM  0.0009765625, 0.1863792022995904, 0.16568355986857758
# alpha, M, predM  0.00048828125, 0.1864731897869724, 0.16568355986857758
# alpha, M, predM  0.000244140625, 0.1865203025658446, 0.16568355986857758
# alpha, M, predM  0.0001220703125, 0.18654386767560577, 0.16568355986857758
# alpha, M, predM  6.103515625E-05, 0.1656913364717796, 0.16568355986857758
# alpha, M, predM  3.0517578125E-05, 0.16569742604366616, 0.16568355986857758
# alpha, M, predM  1.52587890625E-05, 0.1657004709672926, 0.16568355986857758
# alpha, M, predM  7.62939453125E-06, 0.165701993463528, 0.16568355986857758
# alpha, M, predM  3.814697265625E-06, 0.16570275472025128, 0.16568355986857758
# alpha, M, predM  1.9073486328125E-06, 0.1657031353507645, 0.16568355986857758
# alpha, M, predM  9.5367431640625E-07, 0.16570332566655882, 0.16568355986857758
# alpha, M, predM  4.76837158203125E-07, 0.1657034208245906, 0.16568355986857758
# alpha, M, predM  2.384185791015625E-07, 0.16570346840364025, 0.16568355986857758
# alpha, M, predM  1.1920928955078125E-07, 0.16570349219317332, 0.16568355986857758
# alpha, M, predM  5.960464477539063E-08, 0.1657035040879418, 0.16568355986857758
# alpha, M, predM  2.9802322387695312E-08, 0.16570351003532674, 0.16568355986857758
# alpha, M, predM  1.4901161193847656E-08, 0.16570351300901937, 0.16568355986857758
# l2: ||R0||= 4.9308327E-02, f_err=5.749386E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 3.51E-01, QuadOrder=5
# ALNR=1.0052369807664656 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 5.4476492947661175, 0.16564401768576484
# alpha, M, predM  0.5, 1.0206276027352066, 0.16564401768576484
# alpha, M, predM  0.25, 0.546009771168146, 0.16564401768576484
# alpha, M, predM  0.125, 0.35915689199643186, 0.16564401768576484
# alpha, M, predM  0.0625, 0.18528287728002374, 0.16564401768576484
# alpha, M, predM  0.03125, 0.18483753705318842, 0.16564401768576484
# alpha, M, predM  0.015625, 0.1852680798923833, 0.16564401768576484
# alpha, M, predM  0.0078125, 0.1855832071515129, 0.16564401768576484
# alpha, M, predM  0.00390625, 0.185768467027768, 0.16564401768576484
# alpha, M, predM  0.001953125, 0.18605542975081557, 0.16564401768576484
# alpha, M, predM  0.0009765625, 0.18627050386719274, 0.16564401768576484
# alpha, M, predM  0.00048828125, 0.18637845531314476, 0.16564401768576484
# alpha, M, predM  0.000244140625, 0.18643263675110036, 0.16564401768576484
# alpha, M, predM  0.0001220703125, 0.1864597369305106, 0.16564401768576484
# alpha, M, predM  6.103515625E-05, 0.18647328938634633, 0.16564401768576484
# alpha, M, predM  3.0517578125E-05, 0.16565931640641218, 0.16564401768576484
# alpha, M, predM  1.52587890625E-05, 0.16566267591071185, 0.16564401768576484
# alpha, M, predM  7.62939453125E-06, 0.16566435570042637, 0.16564401768576484
# alpha, M, predM  3.814697265625E-06, 0.1656651956046753, 0.16564401768576484
# alpha, M, predM  1.9073486328125E-06, 0.16566561555914705, 0.16564401768576484
# alpha, M, predM  9.5367431640625E-07, 0.16566582553697032, 0.16564401768576484
# alpha, M, predM  4.76837158203125E-07, 0.16566593052602843, 0.16564401768576484
# alpha, M, predM  2.384185791015625E-07, 0.16566598302059438, 0.16564401768576484
# alpha, M, predM  1.1920928955078125E-07, 0.16566600926788633, 0.16564401768576484
# alpha, M, predM  5.960464477539063E-08, 0.16566602239153483, 0.16564401768576484
# alpha, M, predM  2.9802322387695312E-08, 0.16566602895335933, 0.16564401768576484
# alpha, M, predM  1.4901161193847656E-08, 0.16566603223427231, 0.16564401768576484
# l2: ||R0||= 4.9308332E-02, f_err=5.749386E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 3.2E-01, QuadOrder=5
#
# ALNR=1.0005689729667766 <= 1.005 so we terminate/increase degree
#
# ALNR=1.0002673058954674 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.ResNorms.SaveToTextFile(pSAIDT.Control.ProjectName+"_ResPlot.txt");
pSAIDT.obj_f_vals.SaveToTextFile(pSAIDT.Control.ProjectName+"_EnResPlot.txt");
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:600,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="600" height="500"
#  viewBox="0 0 600 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="600" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M550.1,442.4 L541.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,401.6 L50.1,401.6 M550.1,401.6 L545.6,401.6 M45.6,377.8 L50.1,377.8 M550.1,377.8 L545.6,377.8
# 		M45.6,360.9 L50.1,360.9 M550.1,360.9 L545.6,360.9 M45.6,347.7 L50.1,347.7 M550.1,347.7 L545.6,347.7
# 		M45.6,337.0 L50.1,337.0 M550.1,337.0 L545.6,337.0 M45.6,327.9 L50.1,327.9 M550.1,327.9 L545.6,327.9
# 		M45.6,320.1 L50.1,320.1 M550.1,320.1 L545.6,320.1 M45.6,313.2 L50.1,313.2 M550.1,313.2 L545.6,313.2
# 		M45.6,307.0 L54.6,307.0 M550.1,307.0 L541.1,307.0  '/>	<g transform="translate(37.3,313.0)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,266.2 L50.1,266.2 M550.1,266.2 L545.6,266.2 M45.6,242.3 L50.1,242.3 M550.1,242.3 L545.6,242.3
# 		M45.6,225.4 L50.1,225.4 M550.1,225.4 L545.6,225.4 M45.6,212.3 L50.1,212.3 M550.1,212.3 L545.6,212.3
# 		M45.6,201.6 L50.1,201.6 M550.1,201.6 L545.6,201.6 M45.6,192.5 L50.1,192.5 M550.1,192.5 L545.6,192.5
# 		M45.6,184.7 L50.1,184.7 M550.1,184.7 L545.6,184.7 M45.6,177.7 L50.1,177.7 M550.1,177.7 L545.6,177.7
# 		M45.6,171.5 L54.6,171.5 M550.1,171.5 L541.1,171.5  '/>	<g transform="translate(37.3,177.5)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,130.8 L50.1,130.8 M550.1,130.8 L545.6,130.8 M45.6,106.9 L50.1,106.9 M550.1,106.9 L545.6,106.9
# 		M45.6,90.0 L50.1,90.0 M550.1,90.0 L545.6,90.0 M45.6,76.9 L50.1,76.9 M550.1,76.9 L545.6,76.9
# 		M45.6,66.1 L50.1,66.1 M550.1,66.1 L545.6,66.1 M45.6,57.1 L50.1,57.1 M550.1,57.1 L545.6,57.1
# 		M45.6,49.2 L50.1,49.2 M550.1,49.2 L545.6,49.2 M45.6,42.3 L50.1,42.3 M550.1,42.3 L545.6,42.3
# 		M45.6,36.1 L54.6,36.1 M550.1,36.1 L541.1,36.1  '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M108.7,442.4 L108.7,433.4 M108.7,36.1 L108.7,45.1  '/>	<g transform="translate(108.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M171.7,442.4 L171.7,433.4 M171.7,36.1 L171.7,45.1  '/>	<g transform="translate(171.7,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M234.8,442.4 L234.8,433.4 M234.8,36.1 L234.8,45.1  '/>	<g transform="translate(234.8,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 15</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M297.9,442.4 L297.9,433.4 M297.9,36.1 L297.9,45.1  '/>	<g transform="translate(297.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M360.9,442.4 L360.9,433.4 M360.9,36.1 L360.9,45.1  '/>	<g transform="translate(360.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 25</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="

# %%
var si= database.Sessions.Pick(0);
pSAIDT.PlotShadowFields(si);

# %%
using System.IO;
static void AppendRowToCSV(string filePath, double[] rowData)
    {
        // Create a StreamWriter in append mode to append rows to the CSV file
        using (StreamWriter writer = new StreamWriter(filePath, true))
        {
            int cols = rowData.Length;

            // Write double values of the new row to the file
            for (int i = 0; i < cols; i++)
            {
                writer.Write(rowData[i]);

                // Add a comma after each value except for the last one in a row
                if (i < cols - 1)
                {
                    writer.Write(";");
                }
            }

            // Move to the next line after writing the row
            writer.WriteLine();
        }
    }
    static void WriteCSV(string filePath, string[] data)
    {
        // Create a StreamWriter to write to the CSV file
        using (StreamWriter writer = new StreamWriter(filePath))
        {
            int cols = data.Length;

            // Loop through the data array and write to the file
                for (int j = 0; j < cols; j++)
                {
                    // Write each cell value to the file
                    writer.Write(data[ j]);

                    // Add a comma after each cell value except for the last one in a row
                    if (j < cols - 1)
                    {
                        writer.Write(";");
                    }
                }

                // Move to the next line after each row
                writer.WriteLine();
            
        }
    }
    static void DeleteCSVFiles()
    {
        try
        {
            // Get all CSV files in the specified directory
            string[] csvFiles = Directory.GetFiles("*.csv");

            // Delete each CSV file
            foreach (string file in csvFiles)
            {
                File.Delete(file);
                Console.WriteLine($"Deleted: {file}");
            }
        }
        catch (Exception ex)
        {
            Console.WriteLine($"Error deleting CSV files: {ex.Message}");
        }
    }

# %% [markdown]
# ## Measure wall-clock time for computation of sensitivities and residuals

# %%
using System.Diagnostics;
BoSSS.Solution.Application.InitMPI();
DeleteCSVFiles();

int nRefs=4;
var optLsTypes=new OptiLevelSetType[] {OptiLevelSetType.SinglePhaseField,OptiLevelSetType.SplineLevelSet,OptiLevelSetType.SpecFemField};
var CellsVsRuntime_dRdPhi = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
var CellsVsRuntime_Residuals = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
var CellsVsRuntime_dRdU = MultidimensionalArray.Create(nRefs,optLsTypes.Length +1);
string[] stringArray = new string[] { "nCells" }.Concat(optLsTypes.Select(x => x.ToString())).ToArray();

//Create files for results
string filePathdRdPhi = "TimeDRdPhi.csv";
string filePathdRdU = "TimedRdU.csv";
string filePathResiduals = "TimeResiduals.csv";
string filePathDOFs = "DOFs.csv";
WriteCSV(filePathdRdPhi,stringArray);
WriteCSV(filePathdRdU,stringArray);
WriteCSV(filePathResiduals,stringArray);
WriteCSV(filePathDOFs,stringArray);

for(int n =0; n< nRefs;n++){
    //counter for level set type
    int iLS=1;
    //save cell resolution
    int reso= (int) Math.Pow(2,n+1);
    CellsVsRuntime_dRdPhi[n,0]=reso*reso;
    double[] dRdPhiResults= new double[optLsTypes.Length +1];
    dRdPhiResults[0]=reso*reso;
    double[] dRdUResults=dRdPhiResults.CloneAs();
    double[] resiudalResults=dRdPhiResults.CloneAs();
    double[] DOFs=dRdPhiResults.CloneAs();
    foreach(OptiLevelSetType lstype in optLsTypes){
        var pSAIDT = new SAIDTMain();
        var CSAIDT = SAIDTHardCodedControl.StraightShock(
                            dbPath: null,
                            MaxIterations: 1,
                            dgDegree: 0,
                            numOfCellsX: reso,
                            numOfCellsY: reso,
                            OptiNumOfCellsX: reso,
                            OptiNumOfCellsY: reso,
                            agg: 0.4,
                            ImmediatePlotPeriod: -1,
                            optiLevelSetType: lstype,
                            LSDegree: 3,
                            isFarConfig:true);

        pSAIDT.Init(CSAIDT);    
        pSAIDT.InitializeEverything();
        //pSAIDT.RunSolverMode();

        //Measure time for creation of Jacobians dRdPhi
        Stopwatch stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.FD_LevelSet();
        stopwatch.Stop();
        CellsVsRuntime_dRdPhi[n,iLS] =stopwatch.ElapsedMilliseconds;
        dRdPhiResults[iLS]=stopwatch.ElapsedMilliseconds;

        //Measure time for creation of Jacobians dRdU
        stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.Oproblem.GetJacobians(pSAIDT.ConservativeFields, pSAIDT.XSpatialOperator.LinearizationHint);
        stopwatch.Stop(); 
        CellsVsRuntime_dRdU[n,iLS] =stopwatch.ElapsedMilliseconds;
        dRdUResults[iLS]=stopwatch.ElapsedMilliseconds;

        //Measure time for evaluation of the Residuals
        stopwatch = new Stopwatch();stopwatch.Start();
        pSAIDT.ComputeResiduals();
        stopwatch.Stop(); Console.WriteLine("Elapsed Time: " + stopwatch.ElapsedMilliseconds + "ms");
        CellsVsRuntime_Residuals[n,iLS] =stopwatch.ElapsedMilliseconds;
        resiudalResults[iLS]=stopwatch.ElapsedMilliseconds;

        DOFs[iLS]=pSAIDT.LevelSetOpti.GetLength();

        iLS++;
    }
    // Append the new row to the existing CSV file
    AppendRowToCSV(filePathdRdPhi, dRdPhiResults);
    AppendRowToCSV(filePathdRdU, dRdUResults);
    AppendRowToCSV(filePathResiduals, resiudalResults);
    AppendRowToCSV(filePathDOFs, DOFs);
}
# Out:
# Affinity reported from Win32 API: 0, 1, 2, 3, 4, 5, 6, 7;
# Error deleting CSV files: The filename, directory name, or volume label syntax is incorrect. : 'c:\experimental\public\examples\ShockFitting\Studies\LevelSetComparison Advection\*.csv'
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 15ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 11ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 11ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 15ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 17ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 17ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 17ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 22ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 32ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 30ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 26ms
# Session ID: 00000000-0000-0000-0000-000000000000, DB path: 'EMPTY'
# Session directory 'EMPTY\sessions\00000000-0000-0000-0000-000000000000'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
# Elapsed Time: 43ms

# %%
public PlotFormat GetFormat(int count){
    
    var allPT = new BoSSS.Solution.Gnuplot.PointTypes[] { PointTypes.Diamond, PointTypes.LowerTriangle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle,PointTypes.Diamond, PointTypes.LowerTriangle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle, PointTypes.Circle, PointTypes.OpenDiamond, PointTypes.OpenLowerTriangle, PointTypes.OpenCircle};
    var allC = new BoSSS.Solution.Gnuplot.LineColors[] { LineColors.Blue, LineColors.Black, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red, LineColors.Red, LineColors.Red,LineColors.Blue, LineColors.Black, LineColors.Red};
    var Fmt = new PlotFormat();
    Fmt.PointSize = 0.8;
    Fmt.LineWidth = 1;    
    Fmt.Style     = Styles.LinesPoints;

    Fmt.LineColor = allC[count];
    Fmt.PointType =  allPT[count];
    return Fmt;
}

# %%
CellsVsRuntime_dRdPhi
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>4 868 153 611\r\n16 5135 348 3223\r\n64 31403 918 20564\r\n256 271013 3848 178649</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Dimension</td><td>2</td></tr><tr><td>Lengths</td><td>[ 4, 4 ]</td></tr><tr><td>Storage</td><td>[ 4, 868, 153, 611, 16, 5135, 348, 3223, 64, 31403, 918, 20564, 256, 271013, 3848, 178649 ]</td></tr><tr><td>IsContinuous</td><td>True</td></tr><tr><td>StructureType</td><td>General</td></tr><tr><td>Length</td><td>16</td></tr><tr><td>NoOfCols</td><td>4</td></tr><tr><td>NoOfRows</td><td>4</td></tr><tr><td>IsLocked</td><td>False</td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
var plot = new Plot2Ddata();
int count=0;
for(int iLS=0;iLS<CellsVsRuntime_dRdPhi.Lengths[1]-1; iLS ++){
    plot.AddDataGroup(optLsTypes[iLS].ToString(),CellsVsRuntime_dRdPhi.ExtractSubArrayShallow(-1,0).To1DArray(),CellsVsRuntime_dRdPhi.ExtractSubArrayShallow(-1,iLS+1).To1DArray(), GetFormat(count));
    count++;
}
plot.Xlabel="number of Cells";
plot.LogY = true;
plot.LogX = true;
plot.ShowXtics = true;
plot.ToGnuplot().PlotSVG(xRes:1200,yRes:600)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="600"
#  viewBox="0 0 1200 600"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="600" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M37.3,542.4 L46.3,542.4 M1150.1,542.4 L1141.1,542.4  '/>	<g transform="translate(29.0,548.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M37.3,504.3 L41.8,504.3 M1150.1,504.3 L1145.6,504.3 M37.3,482.0 L41.8,482.0 M1150.1,482.0 L1145.6,482.0
# 		M37.3,466.2 L41.8,466.2 M1150.1,466.2 L1145.6,466.2 M37.3,453.9 L41.8,453.9 M1150.1,453.9 L1145.6,453.9
# 		M37.3,443.9 L41.8,443.9 M1150.1,443.9 L1145.6,443.9 M37.3,435.4 L41.8,435.4 M1150.1,435.4 L1145.6,435.4
# 		M37.3,428.1 L41.8,428.1 M1150.1,428.1 L1145.6,428.1 M37.3,421.6 L41.8,421.6 M1150.1,421.6 L1145.6,421.6
# 		M37.3,415.8 L46.3,415.8 M1150.1,415.8 L1141.1,415.8  '/>	<g transform="translate(29.0,421.8)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='