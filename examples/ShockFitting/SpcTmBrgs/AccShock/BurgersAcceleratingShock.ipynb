# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\BUIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using BUIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %%
var date = DateTime.Now.ToString("ddMMyyyy");
date
# Out:
# 01092023

# %% [markdown]
# open a database

# %%
string dbPath = @"BUIDT_db_" + date ;
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Creating database 'BUIDT_db_01092023'.

# %% [markdown]
# ## Curved Shock Burgers

# %%
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pCSB = new BUIDTMain();
var CCSB = BUIDTHardCodedControl.AccShock(
dbPath: dbPath,
MaxIterations: 100,
dgDegree: 3,
numOfCellsX: 10,
numOfCellsY: 10,
OptiNumOfCellsX: 10,
OptiNumOfCellsY: 10,
linearization: Linearization.FD,
agg: 0.4,
optiLevelSetType: OptiLevelSetType.SplineLevelSet,
getLevelSet: GetLevelSet.FromFunction,
applyReInit: true,
solverRunType: SolverRunType.Staggerd
) ;
CCSB.ProjectName= "CSB";
pCSB.Init(CCSB);
pCSB.RunSolverMode();
# Out:
# rm CSB_SP_0.plt CSB_SP_1.plt CSB_SP_10.plt CSB_SP_11.plt CSB_SP_12.plt CSB_SP_13.plt CSB_SP_14.plt CSB_SP_15.plt CSB_SP_16.plt CSB_SP_17.plt CSB_SP_18.plt CSB_SP_19.plt CSB_SP_2.plt CSB_SP_20.plt CSB_SP_21.plt CSB_SP_22.plt CSB_SP_23.plt CSB_SP_24.plt CSB_SP_25.plt CSB_SP_26.plt CSB_SP_27.plt CSB_SP_28.plt CSB_SP_29.plt CSB_SP_3.plt CSB_SP_30.plt CSB_SP_31.plt CSB_SP_32.plt CSB_SP_33.plt CSB_SP_34.plt CSB_SP_35.plt CSB_SP_36.plt CSB_SP_37.plt CSB_SP_38.plt CSB_SP_39.plt CSB_SP_4.plt CSB_SP_40.plt CSB_SP_41.plt CSB_SP_42.plt CSB_SP_43.plt CSB_SP_44.plt CSB_SP_45.plt CSB_SP_46.plt CSB_SP_47.plt CSB_SP_48.plt CSB_SP_49.plt CSB_SP_5.plt CSB_SP_50.plt CSB_SP_51.plt CSB_SP_52.plt CSB_SP_53.plt CSB_SP_54.plt CSB_SP_55.plt CSB_SP_56.plt CSB_SP_57.plt CSB_SP_58.plt CSB_SP_59.plt CSB_SP_6.plt CSB_SP_60.plt CSB_SP_61.plt CSB_SP_62.plt CSB_SP_63.plt CSB_SP_64.plt CSB_SP_65.plt CSB_SP_66.plt CSB_SP_67.plt CSB_SP_68.plt CSB_SP_7.plt CSB_SP_8.plt CSB_SP_9.plt;
# Session ID: 4d4fef4a-be3c-46c0-86ae-f94d30d5c0ca, DB path: 'BUIDT_db_01092023'
# Session directory 'BUIDT_db_01092023\sessions\4d4fef4a-be3c-46c0-86ae-f94d30d5c0ca'.
# Initial Value : l2: |r|= 1.6093236E+01, |f_err|=3.5312493E+01, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 11651.616305051237, 6312.3569952212765
# alpha, M, predM  0.5, 1924.4418035120523, 6312.3569952212765
# l2: ||R0||= 7.884778E+00, f_err=2.652779E+01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.06E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 349.0384571820367, 829.0738704205602
# l2: ||R0||= 5.4288012E+00, f_err=1.567605E+01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.53E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 179.9653114246378, 426.316248007953
# l2: ||R0||= 3.9156708E+00, f_err=9.136524E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.8E+01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 36.987374960137466, 149.78444243158862
# l2: ||R0||= 1.9191619E+00, f_err=6.844164E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.37E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 12.848570528792782, 33.31043443601368
# l2: ||R0||= 9.1680265E-01, f_err=4.793617E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.23E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 13.436588887015773, 16.65077792571797
# l2: ||R0||= 1.1744333E+00, f_err=4.46752E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.01E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 13.479521484341786, 12.575763415889226
# alpha, M, predM  0.5, 10.062689251853485, 12.575763415889226
# l2: ||R0||= 7.8852706E-01, f_err=4.230538E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.58E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 10.261061667770482, 13.321332166313336
# l2: ||R0||= 1.9616172E-01, f_err=4.499299E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.24E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 11.26205826988223, 10.259050740133306
# alpha, M, predM  0.5, 10.227935944976274, 10.259050740133306
# l2: ||R0||= 1.7588186E-01, f_err=4.498333E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.14E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 10.4032508583973, 10.226588834250935
# alpha, M, predM  0.5, 10.111777344335453, 10.226588834250935
# l2: ||R0||= 9.2342973E-02, f_err=4.490366E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.06E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 10.40169014008212, 10.111222128001966
# alpha, M, predM  0.5, 10.160188949117217, 10.111222128001966
# alpha, M, predM  0.25, 10.10997839690575, 10.111222128001966
# l2: ||R0||= 7.0162965E-02, f_err=4.492868E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.93E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 10.393506045850224, 10.110031008813253
# alpha, M, predM  0.5, 10.20684009206998, 10.110031008813253
# alpha, M, predM  0.25, 10.127057318325091, 10.110031008813253
# alpha, M, predM  0.125, 10.11264839301521, 10.110031008813253
# alpha, M, predM  0.0625, 10.110634664127417, 10.110031008813253
# alpha, M, predM  0.03125, 10.110282043573353, 10.110031008813253
# alpha, M, predM  0.015625, 10.110143584714953, 10.110031008813253
# alpha, M, predM  0.0078125, 10.110083819728509, 10.110031008813253
# alpha, M, predM  0.00390625, 10.110056303544955, 10.110031008813253
# alpha, M, predM  0.001953125, 10.11004313705545, 10.110031008813253
# alpha, M, predM  0.0009765625, 10.110036701714405, 10.110031008813253
# alpha, M, predM  0.00048828125, 10.110033521020249, 10.110031008813253
# alpha, M, predM  0.000244140625, 10.110031939917295, 10.110031008813253
# alpha, M, predM  0.0001220703125, 10.11003115167675, 10.110031008813253
# alpha, M, predM  6.103515625E-05, 10.110030758134334, 10.110031008813253
# l2: ||R0||= 7.0158683E-02, f_err=4.492868E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.95E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 10.400480777407028, 10.109990599008993
# alpha, M, predM  0.5, 10.209823138946415, 10.109990599008993
# alpha, M, predM  0.25, 10.128352795514779, 10.109990599008993
# alpha, M, predM  0.125, 10.112465481114995, 10.109990599008993
# alpha, M, predM  0.0625, 10.110525304395926, 10.109990599008993
# alpha, M, predM  0.03125, 10.110206295839758, 10.109990599008993
# alpha, M, predM  0.015625, 10.110085333853393, 10.109990599008993
# alpha, M, predM  0.0078125, 10.110034490021922, 10.109990599008993
# alpha, M, predM  0.00390625, 10.110011477595744, 10.109990599008993
# alpha, M, predM  0.001953125, 10.110000573779855, 10.109990599008993
# alpha, M, predM  0.0009765625, 10.109995272474382, 10.109990599008993
# alpha, M, predM  0.00048828125, 10.109992659472681, 10.109990599008993
# alpha, M, predM  0.000244140625, 10.109991362384624, 10.109990599008993
# alpha, M, predM  0.0001220703125, 10.109990716193753, 10.109990599008993
# alpha, M, predM  6.103515625E-05, 10.109990393686656, 10.109990599008993
# l2: ||R0||= 7.0154401E-02, f_err=4.492869E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 6.93E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 10.405533969090904, 10.109962910077753
# alpha, M, predM  0.5, 10.211981064200533, 10.109962910077753
# alpha, M, predM  0.25, 10.129289994562923, 10.109962910077753
# alpha, M, predM  0.125, 10.112336421839474, 10.109962910077753
# alpha, M, predM  0.0625, 10.110448566356434, 10.109962910077753
# alpha, M, predM  0.03125, 10.110153447914346, 10.109962910077753
# alpha, M, predM  0.015625, 10.110044937922117, 10.109962910077753
# alpha, M, predM  0.0078125, 10.110000446829003, 10.109962910077753
# alpha, M, predM  0.00390625, 10.109980642458183, 10.109962910077753
# alpha, M, predM  0.001953125, 10.109971350591668, 10.109962910077753
# alpha, M, predM  0.0009765625, 10.109966857241265, 10.109962910077753
# alpha, M, predM  0.00048828125, 10.10996464871223, 10.109962910077753
# alpha, M, predM  0.000244140625, 10.109963553984263, 10.109962910077753
# alpha, M, predM  0.0001220703125, 10.109963009004431, 10.109962910077753
# alpha, M, predM  6.103515625E-05, 10.10996273711055, 10.109962910077753
# l2: ||R0||= 7.0150119E-02, f_err=4.492869E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 6.92E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 10.409112176768717, 10.109944134714148
# alpha, M, predM  0.5, 10.213507598931296, 10.109944134714148
# alpha, M, predM  0.25, 10.129953361762452, 10.109944134714148
# alpha, M, predM  0.125, 10.112246881845712, 10.109944134714148
# alpha, M, predM  0.0625, 10.110395391904074, 10.109944134714148
# alpha, M, predM  0.03125, 10.110117018945814, 10.109944134714148
# alpha, M, predM  0.015625, 10.110017244067402, 10.109944134714148
# alpha, M, predM  0.0078125, 10.10997721113206, 10.109944134714148
# alpha, M, predM  0.00390625, 10.109959658491325, 10.109944134714148
# alpha, M, predM  0.001953125, 10.109951498152864, 10.109944134714148
# alpha, M, predM  0.0009765625, 10.109947571982273, 10.109944134714148
# alpha, M, predM  0.00048828125, 10.109945647397026, 10.109944134714148
# alpha, M, predM  0.000244140625, 10.109944694729457, 10.109944134714148
# alpha, M, predM  0.0001220703125, 10.109944220801951, 10.109944134714148
# alpha, M, predM  6.103515625E-05, 10.109943984439742, 10.109944134714148
# l2: ||R0||= 7.0145837E-02, f_err=4.49287E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 6.91E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 10.411607198756334, 10.109931497694879
# alpha, M, predM  0.5, 10.214571611135726, 10.109931497694879
# alpha, M, predM  0.25, 10.130416550091287, 10.109931497694879
# alpha, M, predM  0.125, 10.112185557657298, 10.109931497694879
# alpha, M, predM  0.0625, 10.110358856635854, 10.109931497694879
# alpha, M, predM  0.03125, 10.110092113029328, 10.109931497694879
# alpha, M, predM  0.015625, 10.10999840781707, 10.109931497694879
# alpha, M, predM  0.0078125, 10.109961473468768, 10.109931497694879
# alpha, M, predM  0.00390625, 10.109945486060802, 10.109931497694879
# alpha, M, predM  0.001953125, 10.109938112323736, 10.109931497694879
# alpha, M, predM  0.0009765625, 10.10993458045011, 10.109931497694879
# alpha, M, predM  0.00048828125, 10.109932853262334, 10.109931497694879
# alpha, M, predM  0.000244140625, 10.109931999355796, 10.109931497694879
# alpha, M, predM  0.0001220703125, 10.109931574824367, 10.109931497694879
# alpha, M, predM  6.103515625E-05, 10.109931363164119, 10.109931497694879
# l2: ||R0||= 7.0141556E-02, f_err=4.49287E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 6.91E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 10.413330929020773, 10.109923040491857
# alpha, M, predM  0.5, 10.215307235982088, 10.109923040491857
# alpha, M, predM  0.25, 10.130738125941656, 10.109923040491857
# alpha, M, predM  0.125, 10.112144008571642, 10.109923040491857
# alpha, M, predM  0.0625, 10.110333924885147, 10.109923040491857
# alpha, M, predM  0.03125, 10.11007519530119, 10.109923040491857
# alpha, M, predM  0.015625, 10.109985674995388, 10.109923040491857
# alpha, M, predM  0.0078125, 10.109950877578587, 10.109923040491857
# alpha, M, predM  0.00390625, 10.109935969756593, 10.109923040491857
# alpha, M, predM  0.001953125, 10.109929138592532, 10.109923040491857
# alpha, M, predM  0.0009765625, 10.109925878700372, 10.109923040491857
# alpha, M, predM  0.00048828125, 10.109924287677215, 10.109923040491857
# alpha, M, predM  0.000244140625, 10.109923501896384, 10.109923040491857
# alpha, M, predM  0.0001220703125, 10.10992311143869, 10.109923040491857
# alpha, M, predM  6.103515625E-05, 10.109922916818007, 10.109923040491857
# l2: ||R0||= 7.0137275E-02, f_err=4.492871E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 6.9E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 10.414516333169884, 10.109917408567345
# alpha, M, predM  0.5, 10.215814632301226, 10.109917408567345
# alpha, M, predM  0.25, 10.130961881128334, 10.109917408567345
# alpha, M, predM  0.125, 10.112116151209404, 10.109917408567345
# alpha, M, predM  0.0625, 10.110317017671289, 10.109917408567345
# alpha, M, predM  0.03125, 10.110063770889584, 10.109917408567345
# alpha, M, predM  0.015625, 10.109977115296214, 10.109917408567345
# alpha, M, predM  0.0078125, 10.10994378106617, 10.109917408567345
# alpha, M, predM  0.00390625, 10.10992961254554, 10.109917408567345
# alpha, M, predM  0.001953125, 10.109923152959214, 10.109917408567345
# alpha, M, predM  0.0009765625, 10.109920079337758, 10.109917408567345
# alpha, M, predM  0.00048828125, 10.109918581570318, 10.109917408567345
# alpha, M, predM  0.000244140625, 10.109917842447485, 10.109917408567345
# alpha, M, predM  0.0001220703125, 10.109917475326277, 10.109917408567345
# alpha, M, predM  6.103515625E-05, 10.109917292375734, 10.109917408567345
# l2: ||R0||= 7.0132994E-02, f_err=4.492871E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 6.9E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 10.415322626428317, 10.109913680561297
# alpha, M, predM  0.5, 10.216161880375264, 10.109913680561297
# alpha, M, predM  0.25, 10.131117333573725, 10.109913680561297
# alpha, M, predM  0.125, 10.112097790846311, 10.109913680561297
# alpha, M, predM  0.0625, 10.110305676359104, 10.109913680561297
# alpha, M, predM  0.03125, 10.110056130253374, 10.109913680561297
# alpha, M, predM  0.015625, 10.109971409320066, 10.109913680561297
# alpha, M, predM  0.0078125, 10.109939063502036, 10.109913680561297
# alpha, M, predM  0.00390625, 10.109925394458187, 10.109913680561297
# alpha, M, predM  0.001953125, 10.109919185927904, 10.109913680561297
# alpha, M, predM  0.0009765625, 10.109916238163866, 10.109913680561297
# alpha, M, predM  0.00048828125, 10.109914803407545, 10.109913680561297
# alpha, M, predM  0.000244140625, 10.109914095810842, 10.109913680561297
# alpha, M, predM  0.0001220703125, 10.109913744457886, 10.109913680561297
# alpha, M, predM  6.103515625E-05, 10.109913569392715, 10.109913680561297
# l2: ||R0||= 7.0128713E-02, f_err=4.492872E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 6.9E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 10.415870552278864, 10.10991124621514
# alpha, M, predM  0.5, 10.21640072779195, 10.10991124621514
# alpha, M, predM  0.25, 10.131226995755318, 10.10991124621514
# alpha, M, predM  0.125, 10.112085986753229, 10.10991124621514
# alpha, M, predM  0.0625, 10.110298181763754, 10.10991124621514
# alpha, M, predM  0.03125, 10.110051094334251, 10.10991124621514
# alpha, M, predM  0.015625, 10.10996765955064, 10.10991124621514
# alpha, M, predM  0.0078125, 10.109935971011302, 10.10991124621514
# alpha, M, predM  0.00390625, 10.109922634157796, 10.10991124621514
# alpha, M, predM  0.001953125, 10.109916592610473, 10.10991124621514
# alpha, M, predM  0.0009765625, 10.10991372855993, 10.10991124621514
# alpha, M, predM  0.00048828125, 10.109912335715816, 10.10991124621514
# alpha, M, predM  0.000244140625, 10.109911649089057, 10.10991124621514
# alpha, M, predM  0.0001220703125, 10.109911308224588, 10.10991124621514
# alpha, M, predM  6.103515625E-05, 10.109911138404549, 10.10991124621514
# l2: ||R0||= 7.0124433E-02, f_err=4.492872E+00, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 6.9E+00, QuadOrder=4
#
# ALNR=1.0000610388750162 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 0 to 1              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 5.2971643E+00, f_err=2.160645E+01, f_phi=0E+00,
#  current DGdegree=1, min It.:15, MaxReInit:20, ReInitTol:-0.2, TermN:8, tALNR:1.005
#
# ################################################################################################
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 4207.78142837085, 1107.7613105964713
# alpha, M, predM  0.5, 369.6135151869177, 1107.7613105964713
# l2: ||R0||= 3.3152202E+00, f_err=7.35673E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.23E+01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 103.51846167746669, 185.98288490634457
# l2: ||R0||= 2.918567E+00, f_err=6.829662E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.88E+01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
# Reinitialized Cells:(32 R) ,
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 181.1372656465163, 124.02832751348818
# alpha, M, predM  0.5, 106.5904206587549, 124.02832751348818
# l2: ||R0||= 2.6506894E+00, f_err=6.79593E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.38E+01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 772.7664205282113, 43.4829060559246
# alpha, M, predM  0.5, 38.45702080139071, 43.4829060559246
# l2: ||R0||= 2.7208625E+00, f_err=5.825777E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.8E+00, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 3.4466787726231725, 28.128256912101417
# l2: ||R0||= 9.4805713E-01, f_err=2.25025E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.04E+00, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 0.1849877765486825, 2.2056450010005904
# l2: ||R0||= 2.0083056E-01, f_err=5.989092E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.8E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 6.720121646982957, 0.18536355283674902
# alpha, M, predM  0.5, 4.871897468568055, 0.18536355283674902
# alpha, M, predM  0.25, 0.12675039110892075, 0.18536355283674902
# l2: ||R0||= 1.5290362E-01, f_err=4.96483E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 7.098580783045424, 0.12657998540358328
# alpha, M, predM  0.5, 5.386918836599234, 0.12657998540358328
# alpha, M, predM  0.25, 4.705871932107302, 0.12657998540358328
# alpha, M, predM  0.125, 0.11050876549354627, 0.12657998540358328
# l2: ||R0||= 1.342179E-01, f_err=4.64609E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.86E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 7.546287983210187, 0.11207784965154237
# alpha, M, predM  0.5, 5.712126372547075, 0.11207784965154237
# alpha, M, predM  0.25, 5.003482772657172, 0.11207784965154237
# alpha, M, predM  0.125, 4.6923866286007225, 0.11207784965154237
# alpha, M, predM  0.0625, 4.546363985694166, 0.11207784965154237
# alpha, M, predM  0.03125, 0.1088061408394016, 0.11207784965154237
# l2: ||R0||= 1.3042843E-01, f_err=4.612579E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 2.85E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 7.972216326055649, 0.10876050992337884
# alpha, M, predM  0.5, 5.875041123979224, 0.10876050992337884
# alpha, M, predM  0.25, 5.109101325705798, 0.10876050992337884
# alpha, M, predM  0.125, 4.774879547852218, 0.10876050992337884
# alpha, M, predM  0.0625, 4.618456880861868, 0.10876050992337884
# alpha, M, predM  0.03125, 4.54276198033002, 0.10876050992337884
# alpha, M, predM  0.015625, 0.10723126735634153, 0.10876050992337884
# l2: ||R0||= 1.284368E-01, f_err=4.580668E-01, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.81E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 8.660215989793755, 0.10724913680124731
# alpha, M, predM  0.5, 6.083025894319514, 0.10724913680124731
# alpha, M, predM  0.25, 5.223594075312755, 0.10724913680124731
# alpha, M, predM  0.125, 4.850829982951606, 0.10724913680124731
# alpha, M, predM  0.0625, 4.67704080529296, 0.10724913680124731
# alpha, M, predM  0.03125, 4.593121316926714, 0.10724913680124731
# alpha, M, predM  0.015625, 4.551883421720364, 0.10724913680124731
# alpha, M, predM  0.0078125, 4.531439049425648, 0.10724913680124731
# alpha, M, predM  0.00390625, 0.10687614741417172, 0.10724913680124731
# l2: ||R0||= 1.2793527E-01, f_err=4.572704E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 2.84E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 8.89572451912571, 0.1069064622878031
# alpha, M, predM  0.5, 6.149512848050505, 0.1069064622878031
# alpha, M, predM  0.25, 5.262004002773377, 0.1069064622878031
# alpha, M, predM  0.125, 4.878350735737716, 0.1069064622878031
# alpha, M, predM  0.0625, 4.6997634951723395, 0.1069064622878031
# alpha, M, predM  0.03125, 4.613593193730174, 0.1069064622878031
# alpha, M, predM  0.015625, 4.571264678118951, 0.1069064622878031
# alpha, M, predM  0.0078125, 4.550287352945328, 0.1069064622878031
# alpha, M, predM  0.00390625, 4.539841603639965, 0.1069064622878031
# alpha, M, predM  0.001953125, 4.534630191585778, 0.1069064622878031
# alpha, M, predM  0.0009765625, 0.10682082629842916, 0.1069064622878031
# l2: ||R0||= 1.2781034E-01, f_err=4.570718E-01, f_phi=0E+00, Alpha = 9.77E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.89E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 9.057622527771768, 0.10683977867668329
# alpha, M, predM  0.5, 6.191333580623427, 0.10683977867668329
# alpha, M, predM  0.25, 5.284273847668605, 0.10683977867668329
# alpha, M, predM  0.125, 4.893114864436155, 0.10683977867668329
# alpha, M, predM  0.0625, 4.711240299380753, 0.10683977867668329
# alpha, M, predM  0.03125, 4.6235324365840125, 0.10683977867668329
# alpha, M, predM  0.015625, 4.58046026204966, 0.10683977867668329
# alpha, M, predM  0.0078125, 4.559117298405373, 0.10683977867668329
# alpha, M, predM  0.00390625, 4.548491270333828, 0.10683977867668329
# alpha, M, predM  0.001953125, 4.543189575284242, 0.10683977867668329
# alpha, M, predM  0.0009765625, 4.540541681241642, 0.10683977867668329
# alpha, M, predM  0.00048828125, 0.10680180861325538, 0.10683977867668329
# l2: ||R0||= 1.2774794E-01, f_err=4.569724E-01, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.93E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 9.17199388936626, 0.10681200768037534
# alpha, M, predM  0.5, 6.220000003577397, 0.10681200768037534
# alpha, M, predM  0.25, 5.299275192519282, 0.10681200768037534
# alpha, M, predM  0.125, 4.902892717170553, 0.10681200768037534
# alpha, M, predM  0.0625, 4.71873573914894, 0.10681200768037534
# alpha, M, predM  0.03125, 4.6299615826823315, 0.10681200768037534
# alpha, M, predM  0.015625, 4.586374015309236, 0.10681200768037534
# alpha, M, predM  0.0078125, 4.564777699849647, 0.10681200768037534
# alpha, M, predM  0.00390625, 4.5540266346470135, 0.10681200768037534
# alpha, M, predM  0.001953125, 4.548662398662471, 0.10681200768037534
# alpha, M, predM  0.0009765625, 4.54598329973651, 0.10681200768037534
# alpha, M, predM  0.00048828125, 4.544644504341791, 0.10681200768037534
# alpha, M, predM  0.000244140625, 4.54397529507429, 0.10681200768037534
# alpha, M, predM  0.0001220703125, 0.10680984729640176, 0.10681200768037534
# l2: ||R0||= 1.2773235E-01, f_err=4.569476E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 2.95E-01, QuadOrder=6
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 9.250620582223533, 0.10681380630899165
# alpha, M, predM  0.5, 6.239090132988385, 0.10681380630899165
# alpha, M, predM  0.25, 5.308978044646118, 0.10681380630899165
# alpha, M, predM  0.125, 4.909021527172419, 0.10681380630899165
# alpha, M, predM  0.0625, 4.723306421329633, 0.10681380630899165
# alpha, M, predM  0.03125, 4.633805170240082, 0.10681380630899165
# alpha, M, predM  0.015625, 4.589866397096489, 0.10681380630899165
# alpha, M, predM  0.0078125, 4.56809749420875, 0.10681380630899165
# alpha, M, predM  0.00390625, 4.557261069307019, 0.10681380630899165
# alpha, M, predM  0.001953125, 4.551854232526506, 0.10681380630899165
# alpha, M, predM  0.0009765625, 4.549153878703384, 0.10681380630899165
# alpha, M, predM  0.00048828125, 4.547804467218153, 0.10681380630899165
# alpha, M, predM  0.000244140625, 4.547129952742756, 0.10681380630899165
# alpha, M, predM  0.0001220703125, 4.546792743310711, 0.10681380630899165
# alpha, M, predM  6.103515625E-05, 4.546624150544692, 0.10681380630899165
# alpha, M, predM  3.0517578125E-05, 0.1068206165974135, 0.10681380630899165
# alpha, M, predM  1.52587890625E-05, 0.1068221121581346, 0.10681380630899165
# alpha, M, predM  7.62939453125E-06, 0.10682285994280244, 0.10681380630899165
# alpha, M, predM  3.814697265625E-06, 0.10682323383622311, 0.10681380630899165
# alpha, M, predM  1.9073486328125E-06, 0.10682342078320252, 0.10681380630899165
# alpha, M, predM  9.5367431640625E-07, 0.10682351425676706, 0.10681380630899165
# alpha, M, predM  4.76837158203125E-07, 0.10682356099354126, 0.10681380630899165
# alpha, M, predM  2.384185791015625E-07, 0.10682358436195442, 0.10681380630899165
# alpha, M, predM  1.1920928955078125E-07, 0.10682359604615292, 0.10681380630899165
# alpha, M, predM  5.960464477539063E-08, 0.10682360188826347, 0.10681380630899165
# alpha, M, predM  2.9802322387695312E-08, 0.10682360480930045, 0.10681380630899165
# alpha, M, predM  1.4901161193847656E-08, 0.10682360626983682, 0.10681380630899165
# l2: ||R0||= 1.2773234E-01, f_err=4.569476E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 2.97E-01, QuadOrder=6
#
# ALNR=1 <= 1.005 so we terminate/increase degree
#
# ALNR=1.002382790011809 <= 1.005 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 1 to 2              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 1.9627283E+00, f_err=3.072869E+00, f_phi=0E+00,
#  current DGdegree=2, min It.:10, MaxReInit:5, ReInitTol:0, TermN:8, tALNR:1.001
#
# ################################################################################################
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 517.3605879853283, 36.77498624213976
# alpha, M, predM  0.5, 157.31952452101797, 36.77498624213976
# alpha, M, predM  0.25, 4.728737721494472, 36.77498624213976
# l2: ||R0||= 6.6421543E-01, f_err=1.453955E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.66E+01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 0.21585301004606341, 1.2481780999240817
# l2: ||R0||= 1.7957118E-01, f_err=6.534047E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.48E-01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 4.5852759873566, 0.21617822283936952
# alpha, M, predM  0.5, 0.052591264310312615, 0.21617822283936952
# l2: ||R0||= 8.8227432E-02, f_err=3.222645E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.71E-01, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 4.71195780505348, 0.03350860793057132
# alpha, M, predM  0.5, 4.288841406159701, 0.03350860793057132
# alpha, M, predM  0.25, 4.097054832635492, 0.03350860793057132
# alpha, M, predM  0.125, 4.006064887532683, 0.03350860793057132
# alpha, M, predM  0.0625, 3.961104919132981, 0.03350860793057132
# alpha, M, predM  0.03125, 0.03166965447031266, 0.03350860793057132
# l2: ||R0||= 6.9938266E-02, f_err=2.507367E-01, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.62E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 4.896749933674767, 0.031631254003635784
# alpha, M, predM  0.5, 4.369114861688909, 0.031631254003635784
# alpha, M, predM  0.25, 4.133785667153141, 0.031631254003635784
# alpha, M, predM  0.125, 4.0227416196695795, 0.031631254003635784
# alpha, M, predM  0.0625, 3.968200981184389, 0.031631254003635784
# alpha, M, predM  0.03125, 3.941301101827893, 0.031631254003635784
# alpha, M, predM  0.015625, 0.03073694342407291, 0.031631254003635784
# l2: ||R0||= 6.8850967E-02, f_err=2.471459E-01, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 8.29E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.41:
# alpha, M, predM  1, 5.0782957881948985, 0.03070194547545451
# alpha, M, predM  0.5, 4.4409949392814685, 0.03070194547545451
# alpha, M, predM  0.25, 4.162315745151367, 0.03070194547545451
# alpha, M, predM  0.125, 4.031634871584099, 0.03070194547545451
# alpha, M, predM  0.0625, 3.967881991739665, 0.03070194547545451
# alpha, M, predM  0.03125, 3.936447184096809, 0.03070194547545451
# alpha, M, predM  0.015625, 3.9208636620674864, 0.03070194547545451
# alpha, M, predM  0.0078125, 3.9131480549512934, 0.03070194547545451
# alpha, M, predM  0.00390625, 3.9093086287471293, 0.03070194547545451
# alpha, M, predM  0.001953125, 0.030596104491218253, 0.03070194547545451
# l2: ||R0||= 6.8716582E-02, f_err=2.466968E-01, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 7.05E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 5.235824554132836, 0.030565032835127116
# alpha, M, predM  0.5, 4.494839317762298, 0.030565032835127116
# alpha, M, predM  0.25, 4.177496561085068, 0.030565032835127116
# alpha, M, predM  0.125, 4.029723431391247, 0.030565032835127116
# alpha, M, predM  0.0625, 3.957901861251466, 0.030565032835127116
# alpha, M, predM  0.03125, 3.9225760662349156, 0.030565032835127116
# alpha, M, predM  0.015625, 3.905074233066572, 0.030565032835127116
# alpha, M, predM  0.0078125, 3.8963936312753473, 0.030565032835127116
# alpha, M, predM  0.00390625, 3.8920782658817124, 0.030565032835127116
# alpha, M, predM  0.001953125, 3.8899232067926124, 0.030565032835127116
# alpha, M, predM  0.0009765625, 3.8888463331729253, 0.030565032835127116
# alpha, M, predM  0.00048828125, 0.03054270296423754, 0.030565032835127116
# l2: ||R0||= 6.8683034E-02, f_err=2.465834E-01, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 5.98E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 5.368580102634509, 0.030516478922661405
# alpha, M, predM  0.5, 4.537908111249927, 0.030516478922661405
# alpha, M, predM  0.25, 4.188710071891503, 0.030516478922661405
# alpha, M, predM  0.125, 4.02709092034375, 0.030516478922661405
# alpha, M, predM  0.0625, 3.9487674656681975, 0.030516478922661405
# alpha, M, predM  0.03125, 3.9103209955179667, 0.030516478922661405
# alpha, M, predM  0.015625, 3.8912832448111923, 0.030516478922661405
# alpha, M, predM  0.0078125, 3.881839454333703, 0.030516478922661405
# alpha, M, predM  0.00390625, 3.8771435723699463, 0.030516478922661405
# alpha, M, predM  0.001953125, 3.874798642110505, 0.030516478922661405
# alpha, M, predM  0.0009765625, 3.873626929524748, 0.030516478922661405
# alpha, M, predM  0.00048828125, 3.87304126135132, 0.030516478922661405
# alpha, M, predM  0.000244140625, 0.03050813268778276, 0.030516478922661405
# l2: ||R0||= 6.8666268E-02, f_err=2.465263E-01, f_phi=0E+00, Alpha = 2.44E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 5.11E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 5.481112264653553, 0.030486543449958624
# alpha, M, predM  0.5, 4.573799447599511, 0.030486543449958624
# alpha, M, predM  0.25, 4.198301040813376, 0.030486543449958624
# alpha, M, predM  0.125, 4.025403307576527, 0.030486543449958624
# alpha, M, predM  0.0625, 3.9418126203417887, 0.030486543449958624
# alpha, M, predM  0.03125, 3.90084285132765, 0.030486543449958624
# alpha, M, predM  0.015625, 3.8805654763473982, 0.030486543449958624
# alpha, M, predM  0.0078125, 3.8705073154025698, 0.030486543449958624
# alpha, M, predM  0.00390625, 3.865504613715059, 0.030486543449958624
# alpha, M, predM  0.001953125, 3.86300660804027, 0.030486543449958624
# alpha, M, predM  0.0009765625, 3.8617584411978774, 0.030486543449958624
# alpha, M, predM  0.00048828125, 3.8611345667388735, 0.030486543449958624
# alpha, M, predM  0.000244140625, 3.8608226817453226, 0.030486543449958624
# alpha, M, predM  0.0001220703125, 0.03048525851865022, 0.030486543449958624
# l2: ||R0||= 6.8657886E-02, f_err=2.464976E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 4.44E-02, QuadOrder=8
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.45:
# alpha, M, predM  1, 5.579687335705386, 0.030478154510071246
# alpha, M, predM  0.5, 4.6106018316886646, 0.030478154510071246
# alpha, M, predM  0.25, 4.214333831514491, 0.030478154510071246
# alpha, M, predM  0.125, 4.032597745292487, 0.030478154510071246
# alpha, M, predM  0.0625, 3.9448903280912933, 0.030478154510071246
# alpha, M, predM  0.03125, 3.9019507663487403, 0.030478154510071246
# alpha, M, predM  0.015625, 3.8807062719636884, 0.030478154510071246
# alpha, M, predM  0.0078125, 3.8701694132403337, 0.030478154510071246
# alpha, M, predM  0.00390625, 3.8649274992742466, 0.030478154510071246
# alpha, M, predM  0.001953125, 3.862310156569076, 0.030478154510071246
# alpha, M, predM  0.0009765625, 3.8610023883457534, 0.030478154510071246
# alpha, M, predM  0.00048828125, 3.8603487299620833, 0.030478154510071246
# alpha, M, predM  0.000244140625, 3.8600219571955328, 0.030478154510071246
# alpha, M, predM  0.0001220703125, 3.8598585849177236, 0.030478154510071246
# alpha, M, predM  6.103515625E-05, 3.8597769023050312, 0.030478154510071246
# alpha, M, predM  3.0517578125E-05, 0.030482221298952828, 0.030478154510071246
# alpha, M, predM  1.52587890625E-05, 0.030483114345197668, 0.030478154510071246
# alpha, M, predM  7.62939453125E-06, 0.030483560877441352, 0.030478154510071246
# alpha, M, predM  3.814697265625E-06, 0.030483784145851497, 0.030478154510071246
# alpha, M, predM  1.9073486328125E-06, 0.030483895780616502, 0.030478154510071246
# alpha, M, predM  9.5367431640625E-07, 0.030483951598154226, 0.030478154510071246
# alpha, M, predM  4.76837158203125E-07, 0.03048397950693578, 0.030478154510071246
# alpha, M, predM  2.384185791015625E-07, 0.0304839934613594, 0.030478154510071246
# alpha, M, predM  1.1920928955078125E-07, 0.0304840004385647, 0.030478154510071246
# alpha, M, predM  5.960464477539063E-08, 0.03048400392715356, 0.030478154510071246
# alpha, M, predM  2.9802322387695312E-08, 0.030484005671466214, 0.030478154510071246
# alpha, M, predM  1.4901161193847656E-08, 0.030484006543616157, 0.030478154510071246
# l2: ||R0||= 6.8657885E-02, f_err=2.464976E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 4.39E-02, QuadOrder=8
# ALNR=1.003037755828668 > 1.001 so we continue
#
#
# Starting Opt-Iter No.46:
# alpha, M, predM  1, 5.654630732560139, 0.030483002135344196
# alpha, M, predM  0.5, 4.641006659255744, 0.030483002135344196
# alpha, M, predM  0.25, 4.229998175328623, 0.030483002135344196
# alpha, M, predM  0.125, 4.0420026626767855, 0.030483002135344196
# alpha, M, predM  0.0625, 3.951412062149305, 0.030483002135344196
# alpha, M, predM  0.03125, 3.9070850488743627, 0.030483002135344196
# alpha, M, predM  0.015625, 3.8851596541183797, 0.030483002135344196
# alpha, M, predM  0.0078125, 3.8742864165205293, 0.030483002135344196
# alpha, M, predM  0.00390625, 3.8688761646759646, 0.030483002135344196
# alpha, M, predM  0.001953125, 3.866174846224567, 0.030483002135344196
# alpha, M, predM  0.0009765625, 3.864825138317312, 0.030483002135344196
# alpha, M, predM  0.00048828125, 3.8641505221253034, 0.030483002135344196
# alpha, M, predM  0.000244140625, 3.86381327346134, 0.030483002135344196
# alpha, M, predM  0.0001220703125, 3.8636446639862845, 0.030483002135344196
# alpha, M, predM  6.103515625E-05, 3.863560362963021, 0.030483002135344196
# alpha, M, predM  3.0517578125E-05, 0.030487083243740817, 0.030483002135344196
# alpha, M, predM  1.52587890625E-05, 0.03048797943487779, 0.030483002135344196
# alpha, M, predM  7.62939453125E-06, 0.030488427539592296, 0.030483002135344196
# alpha, M, predM  3.814697265625E-06, 0.030488651594232436, 0.030483002135344196
# alpha, M, predM  1.9073486328125E-06, 0.030488763622121058, 0.030483002135344196
# alpha, M, predM  9.5367431640625E-07, 0.03048881963621546, 0.030483002135344196
# alpha, M, predM  4.76837158203125E-07, 0.030488847643299632, 0.030483002135344196
# alpha, M, predM  2.384185791015625E-07, 0.030488861646844344, 0.030483002135344196
# alpha, M, predM  1.1920928955078125E-07, 0.03048886864860734, 0.030483002135344196
# alpha, M, predM  5.960464477539063E-08, 0.030488872149511636, 0.030483002135344196
# alpha, M, predM  2.9802322387695312E-08, 0.030488873899946638, 0.030483002135344196
# alpha, M, predM  1.4901161193847656E-08, 0.030488874775181935, 0.030483002135344196
# l2: ||R0||= 6.8657884E-02, f_err=2.464976E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 4.6E-02, QuadOrder=8
# ALNR=1.0026574903771297 > 1.001 so we continue
#
#
# Starting Opt-Iter No.47:
# alpha, M, predM  1, 5.710253491535563, 0.030486528540319306
# alpha, M, predM  0.5, 4.663317068243343, 0.030486528540319306
# alpha, M, predM  0.25, 4.2414481230534316, 0.030486528540319306
# alpha, M, predM  0.125, 4.04886303545508, 0.030486528540319306
# alpha, M, predM  0.0625, 3.956164902643746, 0.030486528540319306
# alpha, M, predM  0.03125, 3.9108240085353088, 0.030486528540319306
# alpha, M, predM  0.015625, 3.8884012761493603, 0.030486528540319306
# alpha, M, predM  0.0078125, 3.8772823950078, 0.030486528540319306
# alpha, M, predM  0.00390625, 3.8717492302471763, 0.030486528540319306
# alpha, M, predM  0.001953125, 3.8689865997289017, 0.030486528540319306
# alpha, M, predM  0.0009765625, 3.8676062718004434, 0.030486528540319306
# alpha, M, predM  0.00048828125, 3.86691635459044, 0.030486528540319306
# alpha, M, predM  0.000244140625, 3.8665714576643504, 0.030486528540319306
# alpha, M, predM  0.0001220703125, 3.8663990246195654, 0.030486528540319306
# alpha, M, predM  6.103515625E-05, 3.8663128119517083, 0.030486528540319306
# alpha, M, predM  3.0517578125E-05, 0.03049062009726548, 0.030486528540319306
# alpha, M, predM  1.52587890625E-05, 0.030491518582176597, 0.030486528540319306
# alpha, M, predM  7.62939453125E-06, 0.030491967833789338, 0.030486528540319306
# alpha, M, predM  3.814697265625E-06, 0.03049219246187072, 0.030486528540319306
# alpha, M, predM  1.9073486328125E-06, 0.03049230477651335, 0.030486528540319306
# alpha, M, predM  9.5367431640625E-07, 0.030492360933966615, 0.030486528540319306
# alpha, M, predM  4.76837158203125E-07, 0.030492389012722526, 0.030486528540319306
# alpha, M, predM  2.384185791015625E-07, 0.030492403052094053, 0.030486528540319306
# alpha, M, predM  1.1920928955078125E-07, 0.03049241007180588, 0.030486528540319306
# alpha, M, predM  5.960464477539063E-08, 0.03049241358164592, 0.030486528540319306
# alpha, M, predM  2.9802322387695312E-08, 0.03049241533658923, 0.030486528540319306
# alpha, M, predM  1.4901161193847656E-08, 0.030492416214033452, 0.030486528540319306
# l2: ||R0||= 6.8657884E-02, f_err=2.464976E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 4.75E-02, QuadOrder=8
#
# ALNR=1.0004014807245376 <= 1.001 so we terminate/increase degree
#
# ALNR=1.0003755051176515 <= 1.001 so we terminate/increase degree
#
# ################################################################################################
# ################################################################################################
# ###########################                                      #####################################################################
# ###########################      Changing polynomial degree      #########################################
# ###########################                                      #####################################################################
# ###########################             From 2 to 3              #########################################
# ###########################                                      #####################################################################
# ################################################################################################
# ################################################################################################
#
# OpEval after change:l2: ||R0||= 2.0004363E+00, f_err=2.741443E+00, f_phi=0E+00,
#  current DGdegree=3, min It.:10, MaxReInit:5, ReInitTol:0, TermN:8, tALNR:1.01
#
# ################################################################################################
#
#
# Starting Opt-Iter No.48:
# alpha, M, predM  1, 2806.9911022572305, 40.21687435107328
# alpha, M, predM  0.5, 752.6994907347007, 40.21687435107328
# alpha, M, predM  0.25, 4.5217790757822085, 40.21687435107328
# l2: ||R0||= 6.2157862E-01, f_err=1.414894E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.82E+01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.49:
# alpha, M, predM  1, 2.270370802773292, 2.1888675605130485
# alpha, M, predM  0.5, 2.5332849549647856, 2.1888675605130485
# alpha, M, predM  0.25, 2.2615823984847987, 2.1888675605130485
# alpha, M, predM  0.125, 2.1878756207868535, 2.1888675605130485
# l2: ||R0||= 6.5525448E-01, f_err=1.950602E+00, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.33E+00, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.50:
# alpha, M, predM  1, 0.035346126244916155, 1.9456051086321235
# l2: ||R0||= 8.1752235E-02, f_err=2.63317E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.03E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.51:
# alpha, M, predM  1, 0.002728339679798541, 0.03681588266116288
# l2: ||R0||= 1.8772553E-02, f_err=7.231452E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.45E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
#
# Starting Opt-Iter No.52:
# alpha, M, predM  1, 0.0032451064042165263, 0.002707290996193108
# alpha, M, predM  0.5, 0.001421628055706245, 0.002707290996193108
# l2: ||R0||= 1.243577E-02, f_err=5.255054E-02, f_phi=0E+00, Alpha = 5E-01, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 5.28E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.53:
# alpha, M, predM  1, 0.00039530069038443827, 0.0013967054090509843
# l2: ||R0||= 5.7775349E-03, f_err=2.799338E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.09E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.54:
# alpha, M, predM  1, 215.0731472738966, 0.0004081479011912534
# alpha, M, predM  0.5, 200.79462885069734, 0.0004081479011912534
# alpha, M, predM  0.25, 193.97102834642425, 0.0004081479011912534
# alpha, M, predM  0.125, 0.0003661755674860049, 0.0004081479011912534
# l2: ||R0||= 5.2954466E-03, f_err=2.654886E-02, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 9.81E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.55:
# alpha, M, predM  1, 0.000483210233133244, 0.00035466881073091295
# alpha, M, predM  0.5, 0.00031732521540311166, 0.00035466881073091295
# l2: ||R0||= 5.2759832E-03, f_err=2.510262E-02, f_phi=0E+00, Alpha = 5E-01, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 1.62E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.56:
# alpha, M, predM  1, 0.0003769609161621798, 0.0003183000629491957
# alpha, M, predM  0.5, 0.0003076084835087617, 0.0003183000629491957
# l2: ||R0||= 3.8672827E-03, f_err=2.473328E-02, f_phi=0E+00, Alpha = 5E-01, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.33E-01, QuadOrder=10
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.57:
# alpha, M, predM  1, 0.00030911027021847924, 0.00030703923837262155
# alpha, M, predM  0.5, 0.000286045183939741, 0.00030703923837262155
# l2: ||R0||= 2.6524056E-03, f_err=2.389519E-02, f_phi=0E+00, Alpha = 5E-01, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 1.58E-01, QuadOrder=10
# ALNR=1.7480525243257612 > 1.01 so we continue
#
#
# Starting Opt-Iter No.58:
# alpha, M, predM  1, 0.00030756187714165486, 0.00028606674655740717
# alpha, M, predM  0.5, 0.0002907032886512427, 0.00028606674655740717
# alpha, M, predM  0.25, 0.0002857242425390907, 0.00028606674655740717
# l2: ||R0||= 2.0554809E-03, f_err=2.389046E-02, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.64E-01, QuadOrder=10
# ALNR=1.409917062953227 > 1.01 so we continue
#
#
# Starting Opt-Iter No.59:
# alpha, M, predM  1, 0.0003200911183676106, 0.0002857215320649429
# alpha, M, predM  0.5, 0.0002943467935825781, 0.0002857215320649429
# alpha, M, predM  0.25, 0.0002886748339313017, 0.0002857215320649429
# alpha, M, predM  0.125, 0.00028613613560930405, 0.0002857215320649429
# alpha, M, predM  0.0625, 0.0002856091034082755, 0.0002857215320649429
# l2: ||R0||= 1.9311522E-03, f_err=2.388743E-02, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 1.63E-01, QuadOrder=10
# ALNR=1.3463198616011591 > 1.01 so we continue
#
#
# Starting Opt-Iter No.60:
# alpha, M, predM  1, 0.00035157086400866393, 0.00028560988103468074
# alpha, M, predM  0.5, 0.00030334388602368327, 0.00028560988103468074
# alpha, M, predM  0.25, 0.00029227321872460615, 0.00028560988103468074
# alpha, M, predM  0.125, 0.00028807669639332507, 0.00028560988103468074
# alpha, M, predM  0.0625, 0.00028641186815768233, 0.00028560988103468074
# alpha, M, predM  0.03125, 0.00028575119518873426, 0.00028560988103468074
# alpha, M, predM  0.015625, 0.0002856631462393585, 0.00028560988103468074
# alpha, M, predM  0.0078125, 0.0002856331075118869, 0.00028560988103468074
# alpha, M, predM  0.00390625, 0.00028562099239704794, 0.00028560988103468074
# alpha, M, predM  0.001953125, 0.000285615205325782, 0.00028560988103468074
# alpha, M, predM  0.0009765625, 0.00028561237941503387, 0.00028560988103468074
# alpha, M, predM  0.00048828125, 0.00028561098336228336, 0.00028560988103468074
# alpha, M, predM  0.000244140625, 0.00028561028956236177, 0.00028560988103468074
# alpha, M, predM  0.0001220703125, 0.0002856099437172221, 0.00028560988103468074
# alpha, M, predM  6.103515625E-05, 0.00028560977105856057, 0.00028560988103468074
# l2: ||R0||= 1.9310344E-03, f_err=2.388744E-02, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 1.63E-01, QuadOrder=10
# ALNR=1.1816949627771567 > 1.01 so we continue
#
#
# Starting Opt-Iter No.61:
# alpha, M, predM  1, 0.00030839354650426666, 0.0002856130187446189
# alpha, M, predM  0.5, 0.00029354480535893023, 0.0002856130187446189
# alpha, M, predM  0.25, 0.0002892127039406924, 0.0002856130187446189
# alpha, M, predM  0.125, 0.0002870048709406947, 0.0002856130187446189
# alpha, M, predM  0.0625, 0.00028600288017822397, 0.0002856130187446189
# alpha, M, predM  0.03125, 0.00028570596085382617, 0.0002856130187446189
# alpha, M, predM  0.015625, 0.00028565450010084733, 0.0002856130187446189
# alpha, M, predM  0.0078125, 0.00028563290939771254, 0.0002856130187446189
# alpha, M, predM  0.00390625, 0.00028562265838224794, 0.0002856130187446189
# alpha, M, predM  0.001953125, 0.0002856176689604054, 0.0002856130187446189
# alpha, M, predM  0.0009765625, 0.0002856152082692172, 0.0002856130187446189
# alpha, M, predM  0.00048828125, 0.00028561398642826816, 0.0002856130187446189
# alpha, M, predM  0.000244140625, 0.0002856133776345919, 0.0002856130187446189
# alpha, M, predM  0.0001220703125, 0.00028561307376711616, 0.0002856130187446189
# alpha, M, predM  6.103515625E-05, 0.00028561292196895423, 0.0002856130187446189
# l2: ||R0||= 1.9309165E-03, f_err=2.388745E-02, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 1.65E-01, QuadOrder=10
# ALNR=1.1686982140070723 > 1.01 so we continue
#
#
# Starting Opt-Iter No.62:
# alpha, M, predM  1, 178.5197093642243, 0.0002856529460743528
# alpha, M, predM  0.5, 0.0002952212526404486, 0.0002856529460743528
# alpha, M, predM  0.25, 0.00028945493155931506, 0.0002856529460743528
# alpha, M, predM  0.125, 0.0002870767430998346, 0.0002856529460743528
# alpha, M, predM  0.0625, 0.0002860745228209166, 0.0002856529460743528
# alpha, M, predM  0.03125, 0.00028582184742104004, 0.0002856529460743528
# alpha, M, predM  0.015625, 0.00028573308478744024, 0.0002856529460743528
# alpha, M, predM  0.0078125, 0.0002856917536233353, 0.0002856529460743528
# alpha, M, predM  0.00390625, 0.00028567185063988013, 0.0002856529460743528
# alpha, M, predM  0.001953125, 0.0002856620898056491, 0.0002856529460743528
# alpha, M, predM  0.0009765625, 0.0002856572570484032, 0.0002856529460743528
# alpha, M, predM  0.00048828125, 0.00028565485259213615, 0.0002856529460743528
# alpha, M, predM  0.000244140625, 0.00028565365334224735, 0.0002856529460743528
# alpha, M, predM  0.0001220703125, 0.000285653054459256, 0.0002856529460743528
# alpha, M, predM  6.103515625E-05, 0.00028565275520576805, 0.0002856529460743528
# l2: ||R0||= 1.9307987E-03, f_err=2.388746E-02, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 1.86E-01, QuadOrder=10
# ALNR=1.1681799265290815 > 1.01 so we continue
#
#
# Starting Opt-Iter No.63:
# alpha, M, predM  1, 5165.490979744913, 0.0002855421376584848
# alpha, M, predM  0.5, 378.0783600009121, 0.0002855421376584848
# alpha, M, predM  0.25, 258.3793998300113, 0.0002855421376584848
# alpha, M, predM  0.125, 212.25085537570203, 0.0002855421376584848
# alpha, M, predM  0.0625, 192.0510660821479, 0.0002855421376584848
# alpha, M, predM  0.03125, 182.60496401513407, 0.0002855421376584848
# alpha, M, predM  0.015625, 178.0380567341041, 0.0002855421376584848
# alpha, M, predM  0.0078125, 0.0002848534858500948, 0.0002855421376584848
# l2: ||R0||= 1.9158062E-03, f_err=2.38584E-02, f_phi=0E+00, Alpha = 7.81E-03, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 1.32E-01, QuadOrder=10
# ALNR=1.1172605874389296 > 1.01 so we continue
#
#
# Starting Opt-Iter No.64:
# alpha, M, predM  1, 5984.04850941561, 0.00028483733054585726
# alpha, M, predM  0.5, 2815.7492970617122, 0.00028483733054585726
# alpha, M, predM  0.25, 272.17354583416545, 0.00028483733054585726
# alpha, M, predM  0.125, 219.29167735695088, 0.00028483733054585726
# alpha, M, predM  0.0625, 196.44037393651402, 0.00028483733054585726
# alpha, M, predM  0.03125, 185.8265111626253, 0.00028483733054585726
# alpha, M, predM  0.015625, 180.71254783487856, 0.00028483733054585726
# alpha, M, predM  0.0078125, 178.20261059623326, 0.00028483733054585726
# alpha, M, predM  0.00390625, 176.95925808573026, 0.00028483733054585726
# alpha, M, predM  0.001953125, 0.0002846557298803524, 0.00028483733054585726
# l2: ||R0||= 1.9120723E-03, f_err=2.385042E-02, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 1.28E-01, QuadOrder=10
# ALNR=1.0521069226443018 > 1.01 so we continue
#
#
# Starting Opt-Iter No.65:
# alpha, M, predM  1, 177.60178334621563, 0.00028472160098123113
# alpha, M, predM  0.5, 177.32677029468252, 0.00028472160098123113
# alpha, M, predM  0.25, 177.18941687665108, 0.00028472160098123113
# alpha, M, predM  0.125, 0.00028621516097493264, 0.00028472160098123113
# alpha, M, predM  0.0625, 0.0002852081073661096, 0.00028472160098123113
# alpha, M, predM  0.03125, 0.000284866954512361, 0.00028472160098123113
# alpha, M, predM  0.015625, 0.0002847796710170059, 0.00028472160098123113
# alpha, M, predM  0.0078125, 0.00028474980637159677, 0.00028472160098123113
# alpha, M, predM  0.00390625, 0.0002847353623036489, 0.00028472160098123113
# alpha, M, predM  0.001953125, 0.00028472826232696775, 0.00028472160098123113
# alpha, M, predM  0.0009765625, 0.00028472474285086153, 0.00028472160098123113
# alpha, M, predM  0.00048828125, 0.0002847229907387706, 0.00028472160098123113
# alpha, M, predM  0.000244140625, 0.00028472211659074764, 0.00028472160098123113
# alpha, M, predM  0.0001220703125, 0.000284721679994784, 0.00028472160098123113
# alpha, M, predM  6.103515625E-05, 0.00028472146181199147, 0.00028472160098123113
# l2: ||R0||= 1.9119556E-03, f_err=2.385043E-02, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 1.64E-01, QuadOrder=10
# ALNR=1.0106290209148268 > 1.01 so we continue
#
#
# Starting Opt-Iter No.66:
# alpha, M, predM  1, 0.0006258831291779728, 0.0002847252088819368
# alpha, M, predM  0.5, 0.0003493212639037512, 0.0002847252088819368
# alpha, M, predM  0.25, 0.00029831716260649097, 0.0002847252088819368
# alpha, M, predM  0.125, 0.0002882009995392957, 0.0002847252088819368
# alpha, M, predM  0.0625, 0.00028561322054869437, 0.0002847252088819368
# alpha, M, predM  0.03125, 0.00028507110226829943, 0.0002847252088819368
# alpha, M, predM  0.015625, 0.00028488370739781626, 0.0002847252088819368
# alpha, M, predM  0.0078125, 0.0002848028315580806, 0.0002847252088819368
# alpha, M, predM  0.00390625, 0.0002847632416482383, 0.0002847252088819368
# alpha, M, predM  0.001953125, 0.00028474365869660546, 0.0002847252088819368
# alpha, M, predM  0.0009765625, 0.0002847339202223755, 0.0002847252088819368
# alpha, M, predM  0.00048828125, 0.0002847290642413583, 0.0002847252088819368
# alpha, M, predM  0.000244140625, 0.00028472663955943044, 0.0002847252088819368
# alpha, M, predM  0.0001220703125, 0.00028472542804834384, 0.0002847252088819368
# alpha, M, predM  6.103515625E-05, 0.0002847248225008677, 0.0002847252088819368
# l2: ||R0||= 1.9118389E-03, f_err=2.385046E-02, f_phi=0E+00, Alpha = 6.1E-05, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 1.66E-01, QuadOrder=10
#
# ALNR=1.0014405194917544 <= 1.01 so we terminate/increase degree
#
# ALNR=1.000221651881335 <= 1.01 so we terminate/increase degree

# %% [markdown]
# the resulting residual plot shows respective residuals corresponding to the polynomial degrees

# %%
pCSB.GetResPlot().ToGnuplot().SaveToSVG("resplotCSB.svg",xRes:1200,yRes:500);
pCSB.GetResPlot().ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,417.9 L50.1,417.9 M1150.1,417.9 L1145.6,417.9 M45.6,385.6 L50.1,385.6 M1150.1,385.6 L1145.6,385.6
# 		M45.6,369.0 L50.1,369.0 M1150.1,369.0 L1145.6,369.0 M45.6,361.1 L54.6,361.1 M1150.1,361.1 L1141.1,361.1
# 		 '/>	<g transform="translate(37.3,367.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,336.7 L50.1,336.7 M1150.1,336.7 L1145.6,336.7 M45.6,304.3 L50.1,304.3 M1150.1,304.3 L1145.6,304.3
# 		M45.6,287.8 L50.1,287.8 M1150.1,287.8 L1145.6,287.8 M45.6,279.9 L54.6,279.9 M1150.1,279.9 L1141.1,279.9
# 		 '/>	<g transform="translate(37.3,285.9)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,255.4 L50.1,255.4 M1150.1,255.4 L1145.6,255.4 M45.6,223.1 L50.1,223.1 M1150.1,223.1 L1145.6,223.1
# 		M45.6,206.5 L50.1,206.5 M1150.1,206.5 L1145.6,206.5 M45.6,198.6 L54.6,198.6 M1150.1,198.6 L1141.1,198.6
# 		 '/>	<g transform="translate(37.3,204.6)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,174.2 L50.1,174.2 M1150.1,174.2 L1145.6,174.2 M45.6,141.8 L50.1,141.8 M1150.1,141.8 L1145.6,141.8
# 		M45.6,125.2 L50.1,125.2 M1150.1,125.2 L1145.6,125.2 M45.6,117.4 L54.6,117.4 M1150.1,117.4 L1141.1,117.4
# 		 '/>	<g transform="translate(37.3,123.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,92.9 L50.1,92.9 M1150.1,92.9 L1145.6,92.9 M45.6,60.6 L50.1,60.6 M1150.1,60.6 L1145.6,60.6
# 		M45.6,44.0 L50.1,44.0 M1150.1,44.0 L1145.6,44.0 M45.6,36.1 L54.6,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M203.4,442.4 L203.4,433.4 M203.4,36.1 L203.4,45.1  '/>	<g transform="translate(203.4,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M361.2,442.4 L361.2,433.4 M361.2,36.1 L361.2,45.1  '/>	<g transform="translate(361.2,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M519.0,442.4 L519.0,433.4 M519.0,36.1 L519.0,45.1  '/>	<g transform="translate(519.0,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 30</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M676.7,442.4 L676.7,433.4 M676.7,36.1 L676.7,45.1  '/>	<g transform="tr

# %% [markdown]
# Resplot using the highest degree

# %%
var siCSB= database.Sessions.Pick(0);
pCSB.GetUniformResPlot(siCSB).ToGnuplot().SaveToSVG("resplotCSBUniorm.svg",xRes:1200,yRes:500);
pCSB.GetUniformResPlot(siCSB).ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L54.6,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(37.3,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,424.9 L50.1,424.9 M1150.1,424.9 L1145.6,424.9 M45.6,401.8 L50.1,401.8 M1150.1,401.8 L1145.6,401.8
# 		M45.6,390.0 L50.1,390.0 M1150.1,390.0 L1145.6,390.0 M45.6,384.4 L54.6,384.4 M1150.1,384.4 L1141.1,384.4
# 		 '/>	<g transform="translate(37.3,390.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,366.9 L50.1,366.9 M1150.1,366.9 L1145.6,366.9 M45.6,343.8 L50.1,343.8 M1150.1,343.8 L1145.6,343.8
# 		M45.6,331.9 L50.1,331.9 M1150.1,331.9 L1145.6,331.9 M45.6,326.3 L54.6,326.3 M1150.1,326.3 L1141.1,326.3
# 		 '/>	<g transform="translate(37.3,332.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,308.8 L50.1,308.8 M1150.1,308.8 L1145.6,308.8 M45.6,285.7 L50.1,285.7 M1150.1,285.7 L1145.6,285.7
# 		M45.6,273.9 L50.1,273.9 M1150.1,273.9 L1145.6,273.9 M45.6,268.3 L54.6,268.3 M1150.1,268.3 L1141.1,268.3
# 		 '/>	<g transform="translate(37.3,274.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,250.8 L50.1,250.8 M1150.1,250.8 L1145.6,250.8 M45.6,227.7 L50.1,227.7 M1150.1,227.7 L1145.6,227.7
# 		M45.6,215.9 L50.1,215.9 M1150.1,215.9 L1145.6,215.9 M45.6,210.2 L54.6,210.2 M1150.1,210.2 L1141.1,210.2
# 		 '/>	<g transform="translate(37.3,216.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">1</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,192.8 L50.1,192.8 M1150.1,192.8 L1145.6,192.8 M45.6,169.7 L50.1,169.7 M1150.1,169.7 L1145.6,169.7
# 		M45.6,157.8 L50.1,157.8 M1150.1,157.8 L1145.6,157.8 M45.6,152.2 L54.6,152.2 M1150.1,152.2 L1141.1,152.2
# 		 '/>	<g transform="translate(37.3,158.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,134.7 L50.1,134.7 M1150.1,134.7 L1145.6,134.7 M45.6,111.6 L50.1,111.6 M1150.1,111.6 L1145.6,111.6
# 		M45.6,99.8 L50.1,99.8 M1150.1,99.8 L1145.6,99.8 M45.6,94.1 L54.6,94.1 M1150.1,94.1 L1141.1,94.1
# 		 '/>	<g transform="translate(37.3,100.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">3</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,76.7 L50.1,76.7 M1150.1,76.7 L1145.6,76.7 M45.6,53.6 L50.1,53.6 M1150.1,53.6 L1145.6,53.6
# 		M45.6,41.7 L50.1,41.7 M1150.1,41.7 L1145.6,41.7 M45.6,36.1 L54.6,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(37.3,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M45.6,442.4 L45.6,433.4 M45.6,36.1 L45.6,45.1  '/>	<g transform="translate(45.6,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="b

# %% [markdown]
# plot shadowfields

# %%
pCSB.PlotShadowFields(siCSB);
