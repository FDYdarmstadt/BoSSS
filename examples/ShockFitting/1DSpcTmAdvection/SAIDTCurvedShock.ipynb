# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\SAIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using SAIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %% [markdown]
# # Run Simulation

# %%
var date = DateTime.Now.ToString("ddMMyyyy");
date
# Out:
# 01092023

# %% [markdown]
# open a database

# %%
string dbPath = @"SAIDT_db_" + date ;
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Opening existing database 'SAIDT_db_01092023'.

# %% [markdown]
# ## Curved Shock Scalar Advection

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.CurvedShock_Eccomas22(
                                        dbPath: dbPath,
                                        MaxIterations: 50,
                                        dgDegree: 0,
                                        numOfCellsX: 10,
                                        numOfCellsY: 10,
                                        agg: 0.4,
                                        optiLevelSetType:OptiLevelSetType.SplineLevelSet
                                        );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
# Out:
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_31.plt ScalarAdvection_SP_32.plt ScalarAdvection_SP_33.plt ScalarAdvection_SP_34.plt ScalarAdvection_SP_35.plt ScalarAdvection_SP_36.plt ScalarAdvection_SP_37.plt ScalarAdvection_SP_38.plt ScalarAdvection_SP_39.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_40.plt ScalarAdvection_SP_41.plt ScalarAdvection_SP_42.plt ScalarAdvection_SP_43.plt ScalarAdvection_SP_44.plt ScalarAdvection_SP_45.plt ScalarAdvection_SP_46.plt ScalarAdvection_SP_47.plt ScalarAdvection_SP_48.plt ScalarAdvection_SP_49.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_50.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Session ID: b0168de5-f95d-4eaf-8a24-95ceb96a93cd, DB path: 'SAIDT_db_01092023'
# Session directory 'SAIDT_db_01092023\sessions\b0168de5-f95d-4eaf-8a24-95ceb96a93cd'.
# Initial Value : l2: |r|= 2.2222222E-01, |f_err|=1.0385227E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 0.9660873349864388, 1.0269049430166421
# l2: ||R0||= 3.3972807E-01, f_err=1.350551E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.37E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 1.281617794724398, 1.2187808477281818
# alpha, M, predM  0.5, 1.107474947546928, 1.2187808477281818
# l2: ||R0||= 3.2042744E-01, f_err=1.453991E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.82E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 0.8698689431117835, 1.5660125018285862
# l2: ||R0||= 3.1958518E-01, f_err=1.281336E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.59E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 3.0468947684028995, 1.2549149702399496
# alpha, M, predM  0.5, 1.595172215761322, 1.2549149702399496
# alpha, M, predM  0.25, 1.2150801859888871, 1.2549149702399496
# l2: ||R0||= 4.3208329E-01, f_err=1.518513E+00, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.66E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.8149201298286505, 1.2039049612189654
# l2: ||R0||= 3.9318061E-01, f_err=1.241955E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.65E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 0.5450187394418908, 1.0984239569383019
# l2: ||R0||= 3.0489832E-01, f_err=1.014828E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.47E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.5133629639554047, 0.5213978077550085
# l2: ||R0||= 2.7217685E-01, f_err=9.883187E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.74E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.18081800873381731, 0.7391881538363388
# l2: ||R0||= 1.5754231E-01, f_err=5.886774E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.08E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.3912953676475513, 0.17940045314708206
# alpha, M, predM  0.5, 0.34701527251363934, 0.17940045314708206
# alpha, M, predM  0.25, 0.1453819877170984, 0.17940045314708206
# l2: ||R0||= 1.16502E-01, f_err=5.329564E-01, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.95E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.42249005658948335, 0.18041248265570037
# alpha, M, predM  0.5, 0.38637614084388405, 0.18041248265570037
# alpha, M, predM  0.25, 0.37741231764299016, 0.18041248265570037
# alpha, M, predM  0.125, 0.16519475942290193, 0.18041248265570037
# l2: ||R0||= 1.2020759E-01, f_err=5.688371E-01, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.72E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.5156990183620801, 0.16578566996214966
# alpha, M, predM  0.5, 0.4192904212721361, 0.16578566996214966
# alpha, M, predM  0.25, 0.392969197178182, 0.16578566996214966
# alpha, M, predM  0.125, 0.38312350525178956, 0.16578566996214966
# alpha, M, predM  0.0625, 0.380098636453531, 0.16578566996214966
# alpha, M, predM  0.03125, 0.3790045834674867, 0.16578566996214966
# alpha, M, predM  0.015625, 0.16360388765819964, 0.16578566996214966
# l2: ||R0||= 1.1833038E-01, f_err=5.651835E-01, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.55E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.5058145457838557, 0.16317089096302848
# alpha, M, predM  0.5, 0.4127392407045371, 0.16317089096302848
# alpha, M, predM  0.25, 0.38933581948849294, 0.16317089096302848
# alpha, M, predM  0.125, 0.381096267649614, 0.16317089096302848
# alpha, M, predM  0.0625, 0.37862223161435987, 0.16317089096302848
# alpha, M, predM  0.03125, 0.3778562197973069, 0.16317089096302848
# alpha, M, predM  0.015625, 0.3776085470974443, 0.16317089096302848
# alpha, M, predM  0.0078125, 0.16197909306303823, 0.16317089096302848
# l2: ||R0||= 1.1740614E-01, f_err=5.631393E-01, f_phi=0E+00, Alpha = 7.81E-03, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 4.96E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.4832119990154147, 0.1614905079582508
# alpha, M, predM  0.5, 0.4004188368588279, 0.1614905079582508
# alpha, M, predM  0.25, 0.3825571542899605, 0.1614905079582508
# alpha, M, predM  0.125, 0.37719430402617016, 0.1614905079582508
# alpha, M, predM  0.0625, 0.3760224294038467, 0.1614905079582508
# alpha, M, predM  0.03125, 0.3759544159843426, 0.1614905079582508
# alpha, M, predM  0.015625, 0.37601629181917023, 0.1614905079582508
# alpha, M, predM  0.0078125, 0.3761060507166443, 0.1614905079582508
# alpha, M, predM  0.00390625, 0.1608368805783674, 0.1614905079582508
# l2: ||R0||= 1.1694757E-01, f_err=5.619876E-01, f_phi=0E+00, Alpha = 3.91E-03, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 4.27E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.4518610171912007, 0.16032650285992486
# alpha, M, predM  0.5, 0.38411605433849527, 0.16032650285992486
# alpha, M, predM  0.25, 0.3736456415928066, 0.16032650285992486
# alpha, M, predM  0.125, 0.3720545412126652, 0.16032650285992486
# alpha, M, predM  0.0625, 0.3727454053582936, 0.16032650285992486
# alpha, M, predM  0.03125, 0.3736100932133941, 0.16032650285992486
# alpha, M, predM  0.015625, 0.3741304592475814, 0.16032650285992486
# alpha, M, predM  0.0078125, 0.3744428310978233, 0.16032650285992486
# alpha, M, predM  0.00390625, 0.37460873009028434, 0.16032650285992486
# alpha, M, predM  0.001953125, 0.1599727471287921, 0.16032650285992486
# l2: ||R0||= 1.1671917E-01, f_err=5.613407E-01, f_phi=0E+00, Alpha = 1.95E-03, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 3.55E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.41582235691339026, 0.1594788853796778
# alpha, M, predM  0.5, 0.36557886965326863, 0.1594788853796778
# alpha, M, predM  0.25, 0.36348558721829494, 0.1594788853796778
# alpha, M, predM  0.125, 0.3662484367955115, 0.1594788853796778
# alpha, M, predM  0.0625, 0.3691678444745089, 0.1594788853796778
# alpha, M, predM  0.03125, 0.3711188901027377, 0.1594788853796778
# alpha, M, predM  0.015625, 0.3721822033370284, 0.1594788853796778
# alpha, M, predM  0.0078125, 0.3727583750137822, 0.1594788853796778
# alpha, M, predM  0.00390625, 0.3730589751443945, 0.1594788853796778
# alpha, M, predM  0.001953125, 0.3732104554633938, 0.1594788853796778
# alpha, M, predM  0.0009765625, 0.3732864906666082, 0.1594788853796778
# alpha, M, predM  0.00048828125, 0.15939704570594726, 0.1594788853796778
# l2: ||R0||= 1.1666218E-01, f_err=5.611607E-01, f_phi=0E+00, Alpha = 4.88E-04, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 2.86E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.38110752543869786, 0.1589520610970963
# alpha, M, predM  0.5, 0.34577254738866553, 0.1589520610970963
# alpha, M, predM  0.25, 0.35285234464387233, 0.1589520610970963
# alpha, M, predM  0.125, 0.36026731499202624, 0.1589520610970963
# alpha, M, predM  0.0625, 0.3656121676134676, 0.1589520610970963
# alpha, M, predM  0.03125, 0.3687296689709696, 0.1589520610970963
# alpha, M, predM  0.015625, 0.3703758902150863, 0.1589520610970963
# alpha, M, predM  0.0078125, 0.3712440811816742, 0.1589520610970963
# alpha, M, predM  0.00390625, 0.371688686862008, 0.1589520610970963
# alpha, M, predM  0.001953125, 0.371912191695705, 0.1589520610970963
# alpha, M, predM  0.0009765625, 0.3720242445611353, 0.1589520610970963
# alpha, M, predM  0.00048828125, 0.37208034609989665, 0.1589520610970963
# alpha, M, predM  0.000244140625, 0.37210841564504293, 0.1589520610970963
# alpha, M, predM  0.0001220703125, 0.3721224551114674, 0.1589520610970963
# alpha, M, predM  6.103515625E-05, 0.3721294760181276, 0.1589520610970963
# alpha, M, predM  3.0517578125E-05, 0.15896805515786516, 0.1589520610970963
# alpha, M, predM  1.52587890625E-05, 0.15897156748101002, 0.1589520610970963
# alpha, M, predM  7.62939453125E-06, 0.15897332365729155, 0.1589520610970963
# alpha, M, predM  3.814697265625E-06, 0.15897420174910898, 0.1589520610970963
# alpha, M, predM  1.9073486328125E-06, 0.15897464079593723, 0.1589520610970963
# alpha, M, predM  9.5367431640625E-07, 0.15897486031958077, 0.1589520610970963
# alpha, M, predM  4.76837158203125E-07, 0.15897497008146075, 0.1589520610970963
# alpha, M, predM  2.384185791015625E-07, 0.15897502496241428, 0.1589520610970963
# alpha, M, predM  1.1920928955078125E-07, 0.15897505240289533, 0.1589520610970963
# alpha, M, predM  5.960464477539063E-08, 0.15897506612313655, 0.1589520610970963
# alpha, M, predM  2.9802322387695312E-08, 0.1589750729832569, 0.1589520610970963
# alpha, M, predM  1.4901161193847656E-08, 0.15897507641331818, 0.1589520610970963
# l2: ||R0||= 1.1666218E-01, f_err=5.611607E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 2.24E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.3482432780678572, 0.1585974808515945
# alpha, M, predM  0.5, 0.32616627724214053, 0.1585974808515945
# alpha, M, predM  0.25, 0.3423011418298186, 0.1585974808515945
# alpha, M, predM  0.125, 0.35448290833055124, 0.1585974808515945
# alpha, M, predM  0.0625, 0.3622557756486398, 0.1585974808515945
# alpha, M, predM  0.03125, 0.36655559260109766, 0.1585974808515945
# alpha, M, predM  0.015625, 0.36879255832879004, 0.1585974808515945
# alpha, M, predM  0.0078125, 0.36995970134832995, 0.1585974808515945
# alpha, M, predM  0.00390625, 0.37054979842124297, 0.1585974808515945
# alpha, M, predM  0.001953125, 0.37084607206955905, 0.1585974808515945
# alpha, M, predM  0.0009765625, 0.3709945150504678, 0.1585974808515945
# alpha, M, predM  0.00048828125, 0.3710688130651316, 0.1585974808515945
# alpha, M, predM  0.000244140625, 0.37110598120166105, 0.1585974808515945
# alpha, M, predM  0.0001220703125, 0.3711245700519936, 0.1585974808515945
# alpha, M, predM  6.103515625E-05, 0.3711338656726474, 0.1585974808515945
# alpha, M, predM  3.0517578125E-05, 0.1586147119860536, 0.1585974808515945
# alpha, M, predM  1.52587890625E-05, 0.15861849597077865, 0.1585974808515945
# alpha, M, predM  7.62939453125E-06, 0.15862038797942704, 0.1585974808515945
# alpha, M, predM  3.814697265625E-06, 0.15862133398782233, 0.1585974808515945
# alpha, M, predM  1.9073486328125E-06, 0.15862180699303857, 0.1585974808515945
# alpha, M, predM  9.5367431640625E-07, 0.15862204349590087, 0.1585974808515945
# alpha, M, predM  4.76837158203125E-07, 0.15862216174739563, 0.1585974808515945
# alpha, M, predM  2.384185791015625E-07, 0.15862222087315875, 0.1585974808515945
# alpha, M, predM  1.1920928955078125E-07, 0.15862225043604433, 0.1585974808515945
# alpha, M, predM  5.960464477539063E-08, 0.15862226521748793, 0.1585974808515945
# alpha, M, predM  2.9802322387695312E-08, 0.15862227260821007, 0.1585974808515945
# alpha, M, predM  1.4901161193847656E-08, 0.15862227630357162, 0.1585974808515945
# l2: ||R0||= 1.1666218E-01, f_err=5.611607E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 1.72E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.3187132012678074, 0.1583167166155326
# alpha, M, predM  0.5, 0.30811397983020195, 0.1583167166155326
# alpha, M, predM  0.25, 0.33224923000020423, 0.1583167166155326
# alpha, M, predM  0.125, 0.3490454861556187, 0.1583167166155326
# alpha, M, predM  0.0625, 0.3591854465454148, 0.1583167166155326
# alpha, M, predM  0.03125, 0.36462814160580753, 0.1583167166155326
# alpha, M, predM  0.015625, 0.36744217925203554, 0.1583167166155326
# alpha, M, predM  0.0078125, 0.3688929310501069, 0.1583167166155326
# alpha, M, predM  0.00390625, 0.3696233063544421, 0.1583167166155326
# alpha, M, predM  0.001953125, 0.3699897420220169, 0.1583167166155326
# alpha, M, predM  0.0009765625, 0.37017327163321306, 0.1583167166155326
# alpha, M, predM  0.00048828125, 0.37026511435503723, 0.1583167166155326
# alpha, M, predM  0.000244140625, 0.37031105519150564, 0.1583167166155326
# alpha, M, predM  0.0001220703125, 0.3703340304781917, 0.1583167166155326
# alpha, M, predM  6.103515625E-05, 0.1583269832404139, 0.1583167166155326
# alpha, M, predM  3.0517578125E-05, 0.15833502356553159, 0.1583167166155326
# alpha, M, predM  1.52587890625E-05, 0.15833904379884917, 0.1583167166155326
# alpha, M, predM  7.62939453125E-06, 0.15834105393319672, 0.1583167166155326
# alpha, M, predM  3.814697265625E-06, 0.1583420590047927, 0.1583167166155326
# alpha, M, predM  1.9073486328125E-06, 0.15834256154169768, 0.1583167166155326
# alpha, M, predM  9.5367431640625E-07, 0.15834281281042567, 0.1583167166155326
# alpha, M, predM  4.76837158203125E-07, 0.1583429384448585, 0.1583167166155326
# alpha, M, predM  2.384185791015625E-07, 0.15834300126209253, 0.1583167166155326
# alpha, M, predM  1.1920928955078125E-07, 0.15834303267071428, 0.1583167166155326
# alpha, M, predM  5.960464477539063E-08, 0.15834304837502586, 0.1583167166155326
# alpha, M, predM  2.9802322387695312E-08, 0.15834305622718137, 0.1583167166155326
# alpha, M, predM  1.4901161193847656E-08, 0.15834306015325977, 0.1583167166155326
# l2: ||R0||= 1.1666218E-01, f_err=5.611607E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 1.31E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.29271506712361683, 0.1581401855135947
# alpha, M, predM  0.5, 0.2914762154828511, 0.1581401855135947
# alpha, M, predM  0.25, 0.3231427835388384, 0.1581401855135947
# alpha, M, predM  0.125, 0.3442673524894072, 0.1581401855135947
# alpha, M, predM  0.0625, 0.3565733866200392, 0.1581401855135947
# alpha, M, predM  0.03125, 0.3630759026438553, 0.1581401855135947
# alpha, M, predM  0.015625, 0.36642942704182324, 0.1581401855135947
# alpha, M, predM  0.0078125, 0.3681397411883376, 0.1581401855135947
# alpha, M, predM  0.00390625, 0.3689999907728013, 0.1581401855135947
# alpha, M, predM  0.001953125, 0.3694313858683964, 0.1581401855135947
# alpha, M, predM  0.0009765625, 0.36964740064171464, 0.1581401855135947
# alpha, M, predM  0.00048828125, 0.36975548729113256, 0.1581401855135947
# alpha, M, predM  0.000244140625, 0.36980955042609026, 0.1581401855135947
# alpha, M, predM  0.0001220703125, 0.3698365869454513, 0.1581401855135947
# alpha, M, predM  6.103515625E-05, 0.15815095756729822, 0.1581401855135947
# alpha, M, predM  3.0517578125E-05, 0.15815939371309817, 0.1581401855135947
# alpha, M, predM  1.52587890625E-05, 0.15816361186135394, 0.1581401855135947
# alpha, M, predM  7.62939453125E-06, 0.15816572095431947, 0.1581401855135947
# alpha, M, predM  3.814697265625E-06, 0.15816677550551272, 0.1581401855135947
# alpha, M, predM  1.9073486328125E-06, 0.15816730278228547, 0.1581401855135947
# alpha, M, predM  9.5367431640625E-07, 0.15816756642096724, 0.1581401855135947
# alpha, M, predM  4.76837158203125E-07, 0.15816769824038102, 0.1581401855135947
# alpha, M, predM  2.384185791015625E-07, 0.15816776415010708, 0.1581401855135947
# alpha, M, predM  1.1920928955078125E-07, 0.15816779710497408, 0.1581401855135947
# alpha, M, predM  5.960464477539063E-08, 0.15816781358240883, 0.1581401855135947
# alpha, M, predM  2.9802322387695312E-08, 0.15816782182112757, 0.1581401855135947
# alpha, M, predM  1.4901161193847656E-08, 0.15816782594048587, 0.1581401855135947
# l2: ||R0||= 1.1666218E-01, f_err=5.611607E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 1.05E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 0.2705089423959761, 0.15803119155082415
# alpha, M, predM  0.5, 0.27692356261836787, 0.15803119155082415
# alpha, M, predM  0.25, 0.31519012820484643, 0.15803119155082415
# alpha, M, predM  0.125, 0.34021174083712424, 0.15803119155082415
# alpha, M, predM  0.0625, 0.3543903800295454, 0.15803119155082415
# alpha, M, predM  0.03125, 0.3618324488141927, 0.15803119155082415
# alpha, M, predM  0.015625, 0.3656654015832558, 0.15803119155082415
# alpha, M, predM  0.0078125, 0.3676056447153859, 0.15803119155082415
# alpha, M, predM  0.00390625, 0.3685809459764903, 0.15803119155082415
# alpha, M, predM  0.001953125, 0.3690698877021092, 0.15803119155082415
# alpha, M, predM  0.0009765625, 0.36931468086245317, 0.15803119155082415
# alpha, M, predM  0.00048828125, 0.36943715795764925, 0.15803119155082415
# alpha, M, predM  0.000244140625, 0.36949841662659355, 0.15803119155082415
# alpha, M, predM  0.0001220703125, 0.3695290509904753, 0.15803119155082415
# alpha, M, predM  6.103515625E-05, 0.1580423703624475, 0.15803119155082415
# alpha, M, predM  3.0517578125E-05, 0.1580511250535628, 0.15803119155082415
# alpha, M, predM  1.52587890625E-05, 0.15805550247790748, 0.15803119155082415
# alpha, M, predM  7.62939453125E-06, 0.1580576912097764, 0.15803119155082415
# alpha, M, predM  3.814697265625E-06, 0.15805878558063477, 0.15803119155082415
# alpha, M, predM  1.9073486328125E-06, 0.15805933276729534, 0.15803119155082415
# alpha, M, predM  9.5367431640625E-07, 0.1580596063609324, 0.15803119155082415
# alpha, M, predM  4.76837158203125E-07, 0.1580597431578289, 0.15803119155082415
# alpha, M, predM  2.384185791015625E-07, 0.15805981155629562, 0.15803119155082415
# alpha, M, predM  1.1920928955078125E-07, 0.15805984575553358, 0.15803119155082415
# alpha, M, predM  5.960464477539063E-08, 0.15805986285515441, 0.15803119155082415
# alpha, M, predM  2.9802322387695312E-08, 0.15805987140496539, 0.15803119155082415
# alpha, M, predM  1.4901161193847656E-08, 0.15805987567987173, 0.15803119155082415
# l2: ||R0||= 1.1666217E-01, f_err=5.611607E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 8.95E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 0.25282063899740237, 0.15792595733080536
# alpha, M, predM  0.5, 0.26488332140387433, 0.15792595733080536
# alpha, M, predM  0.25, 0.3084968867270732, 0.15792595733080536
# alpha, M, predM  0.125, 0.3367562299500209, 0.15792595733080536
# alpha, M, predM  0.0625, 0.35251098045291457, 0.15792595733080536
# alpha, M, predM  0.03125, 0.36075756335850706, 0.15792595733080536
# alpha, M, predM  0.015625, 0.36498342839636194, 0.15792595733080536
# alpha, M, predM  0.0078125, 0.3671175414766548, 0.15792595733080536
# alpha, M, predM  0.00390625, 0.36818985491086337, 0.15792595733080536
# alpha, M, predM  0.001953125, 0.36872732110730666, 0.15792595733080536
# alpha, M, predM  0.0009765625, 0.36899638098461335, 0.15792595733080536
# alpha, M, predM  0.00048828125, 0.36913099254434456, 0.15792595733080536
# alpha, M, predM  0.000244140625, 0.369198318720276, 0.15792595733080536
# alpha, M, predM  0.0001220703125, 0.1579194502077447, 0.15792595733080536
# l2: ||R0||= 1.1664793E-01, f_err=5.610967E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 7.42E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 0.24096048235503073, 0.15779692863367903
# alpha, M, predM  0.5, 0.25524013326245026, 0.15779692863367903
# alpha, M, predM  0.25, 0.30310842803319205, 0.15779692863367903
# alpha, M, predM  0.125, 0.3339289498190078, 0.15779692863367903
# alpha, M, predM  0.0625, 0.3509449977953712, 0.15779692863367903
# alpha, M, predM  0.03125, 0.3598417761553678, 0.15779692863367903
# alpha, M, predM  0.015625, 0.36437817077859047, 0.15779692863367903
# alpha, M, predM  0.0078125, 0.3666678359355707, 0.15779692863367903
# alpha, M, predM  0.00390625, 0.36781799111251723, 0.15779692863367903
# alpha, M, predM  0.001953125, 0.36839439384201594, 0.15779692863367903
# alpha, M, predM  0.0009765625, 0.36868292580574824, 0.15779692863367903
# alpha, M, predM  0.00048828125, 0.3688272743517186, 0.15779692863367903
# alpha, M, predM  0.000244140625, 0.36889946925503525, 0.15779692863367903
# alpha, M, predM  0.0001220703125, 0.368935571862938, 0.15779692863367903
# alpha, M, predM  6.103515625E-05, 0.1578086513619729, 0.15779692863367903
# alpha, M, predM  3.0517578125E-05, 0.15781783202002694, 0.15779692863367903
# alpha, M, predM  1.52587890625E-05, 0.15782242243161865, 0.15779692863367903
# alpha, M, predM  7.62939453125E-06, 0.1578247176580562, 0.15779692863367903
# alpha, M, predM  3.814697265625E-06, 0.15782586527643525, 0.15779692863367903
# alpha, M, predM  1.9073486328125E-06, 0.15782643908691443, 0.15779692863367903
# alpha, M, predM  9.5367431640625E-07, 0.15782672599247632, 0.15779692863367903
# alpha, M, predM  4.76837158203125E-07, 0.15782686944533822, 0.15779692863367903
# alpha, M, predM  2.384185791015625E-07, 0.15782694117178903, 0.15779692863367903
# alpha, M, predM  1.1920928955078125E-07, 0.15782697703501927, 0.15779692863367903
# alpha, M, predM  5.960464477539063E-08, 0.15782699496663696, 0.15779692863367903
# alpha, M, predM  2.9802322387695312E-08, 0.1578270039324449, 0.15779692863367903
# alpha, M, predM  1.4901161193847656E-08, 0.1578270084153498, 0.15779692863367903
# l2: ||R0||= 1.1664793E-01, f_err=5.610967E-01, f_phi=0E+00, Alpha = 1E-08, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 6.06E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 0.2321656246257161, 0.15772060485239614
# alpha, M, predM  0.5, 0.2478906285537857, 0.15772060485239614
# alpha, M, predM  0.25, 0.2989630223159997, 0.15772060485239614
# alpha, M, predM  0.125, 0.33176132374028533, 0.15772060485239614
# alpha, M, predM  0.0625, 0.34977184807827955, 0.15772060485239614
# alpha, M, predM  0.03125, 0.35914762233056774, 0.15772060485239614
# alpha, M, predM  0.015625, 0.36392393220291636, 0.15772060485239614
# alpha, M, predM  0.0078125, 0.36633379434696517, 0.15772060485239614
# alpha, M, predM  0.00390625, 0.3675441030241957, 0.15772060485239614
# alpha, M, predM  0.001953125, 0.3681505956528889, 0.15772060485239614
# alpha, M, predM  0.0009765625, 0.3684541757782748, 0.15772060485239614
# alpha, M, predM  0.00048828125, 0.3686060491986919, 0.15772060485239614
# alpha, M, predM  0.000244140625, 0.3686820067364621, 0.15772060485239614
# alpha, M, predM  0.0001220703125, 0.15771387076929447, 0.15772060485239614
# l2: ||R0||= 1.1663369E-01, f_err=5.610305E-01, f_phi=0E+00, Alpha = 1.22E-04, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 4.94E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 0.028084275896289514, 0.15764151544370603
# l2: ||R0||= 9.1452398E-02, f_err=2.362332E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 4.33E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 0.007721891617547533, 0.024259936160662247
# l2: ||R0||= 5.3054977E-02, f_err=1.239886E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 2.51E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 6.835713285159458E-06, 0.007690554497490025
# l2: ||R0||= 5.5763475E-04, f_err=3.697325E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 3.92E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 4.389739310228832E-09, 6.8337843044411165E-06
# l2: ||R0||= 2.68763E-05, f_err=9.369803E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 2.19E-04, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 8.664168717716189E-12, 4.3888026946332386E-09
# l2: ||R0||= 1.116132E-06, f_err=4.162731E-06, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 6.76E-06, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 4.0976458791086446E-14, 8.66247625859794E-12
# l2: ||R0||= 1.1777225E-07, f_err=2.862742E-07, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 2.83E-07, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 2.0779441418297077E-15, 4.0968462979618056E-14
# l2: ||R0||= 2.8586287E-08, f_err=6.446618E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 3.61E-08, QuadOrder=4
# ALNR=22.36649963693616 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 3.953014539107342E-17, 2.077537808952001E-15
# l2: ||R0||= 3.9589268E-09, f_err=8.891585E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 4.7E-09, QuadOrder=4
# ALNR=23.216043560014068 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 7.18774309073889E-18, 3.9522461750388055E-17
# l2: ||R0||= 1.6965766E-09, f_err=3.791502E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 1.35E-09, QuadOrder=4
# ALNR=23.303150807355753 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 1.039984284011175E-17, 7.186342084877164E-18
# alpha, M, predM  0.5, 9.810934126539907E-19, 7.186342084877164E-18
# l2: ||R0||= 4.8054163E-10, f_err=1.400781E-09, f_phi=0E+00, Alpha = 5E-01, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 1.74E-09, QuadOrder=4
# ALNR=10.215674791217737 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 1.5951674181877202E-17, 9.809520136931178E-19
# alpha, M, predM  0.5, 2.5964935856090394E-18, 9.809520136931178E-19
# alpha, M, predM  0.25, 5.112671821433161E-19, 9.809520136931178E-19
# l2: ||R0||= 2.891903E-10, f_err=1.011204E-09, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 6.77E-04, Kappa = 1E+03, Mu = 1.33E-09, QuadOrder=4
# ALNR=7.489029559889338 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 5.5177066383761654E-17, 5.111832318343035E-19
# alpha, M, predM  0.5, 1.1965772789852176E-17, 5.111832318343035E-19
# alpha, M, predM  0.25, 2.261274491337935E-18, 5.111832318343035E-19
# alpha, M, predM  0.125, 4.007177232899912E-19, 5.111832318343035E-19
# l2: ||R0||= 2.5261436E-10, f_err=8.952293E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 4.51E-04, Kappa = 1E+03, Mu = 6.07E-10, QuadOrder=4
# ALNR=4.212591373986285 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 3.3935235584988714E-17, 4.0064967921039367E-19
# alpha, M, predM  0.5, 7.034813071571095E-18, 4.0064967921039367E-19
# alpha, M, predM  0.25, 1.265309704835293E-18, 4.0064967921039367E-19
# alpha, M, predM  0.125, 2.570643838598393E-19, 4.0064967921039367E-19
# l2: ||R0||= 1.6668019E-10, f_err=7.170277E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 3.01E-04, Kappa = 1E+03, Mu = 2.85E-10, QuadOrder=4
# ALNR=3.075237853227479 > 1.005 so we continue
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 4.502112224549429E-17, 2.570297457966264E-19
# alpha, M, predM  0.5, 1.0225332808708945E-17, 2.570297457966264E-19
# alpha, M, predM  0.25, 2.1337948179895976E-18, 2.570297457966264E-19
# alpha, M, predM  0.125, 4.146176657065768E-19, 2.570297457966264E-19
# alpha, M, predM  0.0625, 1.5534760792733936E-19, 2.570297457966264E-19
# l2: ||R0||= 1.4950502E-10, f_err=5.574004E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 2E-04, Kappa = 1E+03, Mu = 8.83E-10, QuadOrder=4
# ALNR=2.6459512927933075 > 1.005 so we continue
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 2.5859500707291532E-17, 1.553268041268937E-19
# alpha, M, predM  0.5, 6.071636128435715E-18, 1.553268041268937E-19
# alpha, M, predM  0.25, 1.4096312535736067E-18, 1.553268041268937E-19
# alpha, M, predM  0.125, 3.8174134456518297E-19, 1.553268041268937E-19
# alpha, M, predM  0.0625, 1.6617404170102564E-19, 1.553268041268937E-19
# alpha, M, predM  0.03125, 1.362181086907028E-19, 1.553268041268937E-19
# l2: ||R0||= 1.1106001E-10, f_err=5.219542E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1.34E-04, Kappa = 1E+03, Mu = 6.51E-10, QuadOrder=4
# ALNR=1.8067295964879246 > 1.005 so we continue
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 8.264023881939328E-19, 1.3621017768965807E-19
# alpha, M, predM  0.5, 2.54263110415855E-19, 1.3621017768965807E-19
# alpha, M, predM  0.25, 1.371129959729726E-19, 1.3621017768965807E-19
# alpha, M, predM  0.125, 1.2172053615580768E-19, 1.3621017768965807E-19
# l2: ||R0||= 8.7637505E-11, f_err=4.933975E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1E-04, Kappa = 1E+03, Mu = 8.1E-10, QuadOrder=4
# ALNR=1.654413335377411 > 1.005 so we continue
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 8.721066903379127E-18, 1.217142832750076E-19
# alpha, M, predM  0.5, 2.1133077218272462E-18, 1.217142832750076E-19
# alpha, M, predM  0.25, 5.350005932199182E-19, 1.217142832750076E-19
# alpha, M, predM  0.125, 1.8833355120182576E-19, 1.217142832750076E-19
# alpha, M, predM  0.0625, 1.2546100267039773E-19, 1.217142832750076E-19
# alpha, M, predM  0.03125, 1.168182542520517E-19, 1.217142832750076E-19
# l2: ||R0||= 8.7470366E-11, f_err=4.833596E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 6.39E-10, QuadOrder=4
# ALNR=1.2931790793068874 > 1.005 so we continue
#
#
# Starting Opt-Iter No.41:
# alpha, M, predM  1, 1.8489471059385656E-17, 1.168099499760181E-19
# alpha, M, predM  0.5, 4.511924982041482E-18, 1.168099499760181E-19
# alpha, M, predM  0.25, 1.1410764344284686E-18, 1.168099499760181E-19
# alpha, M, predM  0.125, 3.585955174017871E-19, 1.168099499760181E-19
# alpha, M, predM  0.0625, 1.6104593240605913E-19, 1.168099499760181E-19
# alpha, M, predM  0.03125, 1.1973386150675693E-19, 1.168099499760181E-19
# alpha, M, predM  0.015625, 1.1467391496118664E-19, 1.168099499760181E-19
# l2: ||R0||= 8.1310578E-11, f_err=4.789027E-10, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 5.95E-10, QuadOrder=4
# ALNR=1.2094757455421186 > 1.005 so we continue
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 3.143924355341549E-19, 1.146689408893998E-19
# alpha, M, predM  0.5, 1.2440985750163416E-19, 1.146689408893998E-19
# alpha, M, predM  0.25, 1.0228910638066606E-19, 1.146689408893998E-19
# l2: ||R0||= 7.6981551E-11, f_err=4.523032E-10, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E-04, Kappa = 1E+03, Mu = 6.51E-10, QuadOrder=4
# ALNR=1.1968250282918231 > 1.005 so we continue
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 3.0057271319264816E-17, 1.0227637976403508E-19
# alpha, M, predM  0.5, 7.16181120951166E-18, 1.0227637976403508E-19
# alpha, M, predM  0.25, 1.6711013052945142E-18, 1.0227637976403508E-19
# alpha, M, predM  0.125, 4.2082352047243746E-19, 1.0227637976403508E-19
# alpha, M, predM  0.0625, 1.4177704470044343E-19, 1.0227637976403508E-19
# alpha, M, predM  0.03125, 9.354980456701197E-20, 1.0227637976403508E-19
# l2: ||R0||= 5.4717286E-11, f_err=4.325501E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.78E-10, QuadOrder=4
# ALNR=1.1813011901943011 > 1.005 so we continue
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 1.3717113251972298E-17, 9.354446270020823E-20
# alpha, M, predM  0.5, 3.3004054790371687E-18, 9.354446270020823E-20
# alpha, M, predM  0.25, 7.930269013426044E-19, 9.354446270020823E-20
# alpha, M, predM  0.125, 2.179778772119494E-19, 9.354446270020823E-20
# alpha, M, predM  0.0625, 1.0657790897210312E-19, 9.354446270020823E-20
# alpha, M, predM  0.03125, 8.987909305782894E-20, 9.354446270020823E-20
# l2: ||R0||= 6.5898946E-11, f_err=4.23979E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.77E-10, QuadOrder=4
# ALNR=1.1648897292982028 > 1.005 so we continue
#
#
# Starting Opt-Iter No.45:
# alpha, M, predM  1, 1.975931291389838E-17, 8.987108093468163E-20
# alpha, M, predM  0.5, 4.796821747327838E-18, 8.987108093468163E-20
# alpha, M, predM  0.25, 1.1759959710630039E-18, 8.987108093468163E-20
# alpha, M, predM  0.125, 3.336935862460196E-19, 8.987108093468163E-20
# alpha, M, predM  0.0625, 1.321921518197387E-19, 8.987108093468163E-20
# alpha, M, predM  0.03125, 9.175807414560564E-20, 8.987108093468163E-20
# alpha, M, predM  0.015625, 8.687510184019322E-20, 8.987108093468163E-20
# l2: ||R0||= 5.6834654E-11, f_err=4.168335E-10, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.52E-10, QuadOrder=4
# ALNR=1.115437699628085 > 1.005 so we continue
#
#
# Starting Opt-Iter No.46:
# alpha, M, predM  1, 1.5876620083997775E-19, 8.687082639977053E-20
# alpha, M, predM  0.5, 9.273090598248513E-20, 8.687082639977053E-20
# alpha, M, predM  0.25, 8.141669821204635E-20, 8.687082639977053E-20
# l2: ||R0||= 4.2989233E-11, f_err=4.035262E-10, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1E-04, Kappa = 1E+03, Mu = 4.95E-10, QuadOrder=4
# ALNR=1.1162302588748525 > 1.005 so we continue
#
#
# Starting Opt-Iter No.47:
# alpha, M, predM  1, 3.244661768406161E-17, 8.141019473048953E-20
# alpha, M, predM  0.5, 7.782571653353099E-18, 8.141019473048953E-20
# alpha, M, predM  0.25, 1.8113175935275343E-18, 8.141019473048953E-20
# alpha, M, predM  0.125, 4.1588101306734706E-19, 8.141019473048953E-20
# alpha, M, predM  0.0625, 1.2074583570728318E-19, 8.141019473048953E-20
# alpha, M, predM  0.03125, 7.646886516706406E-20, 8.141019473048953E-20
# l2: ||R0||= 6.2857632E-11, f_err=3.910725E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.78E-10, QuadOrder=4
# ALNR=1.1159572861630378 > 1.005 so we continue
#
#
# Starting Opt-Iter No.48:
# alpha, M, predM  1, 2.4689219240174133E-17, 7.646003700594447E-20
# alpha, M, predM  0.5, 5.927840210794652E-18, 7.646003700594447E-20
# alpha, M, predM  0.25, 1.4000470056296614E-18, 7.646003700594447E-20
# alpha, M, predM  0.125, 3.524818369540125E-19, 7.646003700594447E-20
# alpha, M, predM  0.0625, 1.1784393086531154E-19, 7.646003700594447E-20
# alpha, M, predM  0.03125, 7.342770047852046E-20, 7.646003700594447E-20
# l2: ||R0||= 4.138247E-11, f_err=3.832172E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.16E-10, QuadOrder=4
# ALNR=1.110681690977333 > 1.005 so we continue
#
#
# Starting Opt-Iter No.49:
# alpha, M, predM  1, 1.7979401842395995E-17, 7.34231401048037E-20
# alpha, M, predM  0.5, 4.310512932607639E-18, 7.34231401048037E-20
# alpha, M, predM  0.25, 1.012024825465664E-18, 7.34231401048037E-20
# alpha, M, predM  0.125, 2.4677073645407048E-19, 7.34231401048037E-20
# alpha, M, predM  0.0625, 9.191474041693152E-20, 7.34231401048037E-20
# alpha, M, predM  0.03125, 7.011634991259286E-20, 7.34231401048037E-20
# l2: ||R0||= 5.9005184E-11, f_err=3.744766E-10, f_phi=0E+00, Alpha = 3.13E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.89E-10, QuadOrder=4
# ALNR=1.102648176479819 > 1.005 so we continue
#
#
# Starting Opt-Iter No.50:
# alpha, M, predM  1, 1.980011461280532E-17, 7.010924498971931E-20
# alpha, M, predM  0.5, 4.788245590350219E-18, 7.010924498971931E-20
# alpha, M, predM  0.25, 1.1521839769973218E-18, 7.010924498971931E-20
# alpha, M, predM  0.125, 3.0426485605966686E-19, 7.010924498971931E-20
# alpha, M, predM  0.0625, 1.0918189869358422E-19, 7.010924498971931E-20
# alpha, M, predM  0.03125, 7.028630144460538E-20, 7.010924498971931E-20
# alpha, M, predM  0.015625, 6.705852592990466E-20, 7.010924498971931E-20
# l2: ||R0||= 4.8724883E-11, f_err=3.6622E-10, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.36E-10, QuadOrder=4
# ALNR=1.044520122728337 > 1.005 so we continue

# %%
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L62.9,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(45.6,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-12</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,413.4 L58.4,413.4 M1150.1,413.4 L1145.6,413.4 M53.9,384.4 L62.9,384.4 M1150.1,384.4 L1141.1,384.4
# 		 '/>	<g transform="translate(45.6,390.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-10</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,355.3 L58.4,355.3 M1150.1,355.3 L1145.6,355.3 M53.9,326.3 L62.9,326.3 M1150.1,326.3 L1141.1,326.3
# 		 '/>	<g transform="translate(45.6,332.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,297.3 L58.4,297.3 M1150.1,297.3 L1145.6,297.3 M53.9,268.3 L62.9,268.3 M1150.1,268.3 L1141.1,268.3
# 		 '/>	<g transform="translate(45.6,274.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,239.2 L58.4,239.2 M1150.1,239.2 L1145.6,239.2 M53.9,210.2 L62.9,210.2 M1150.1,210.2 L1141.1,210.2
# 		 '/>	<g transform="translate(45.6,216.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,181.2 L58.4,181.2 M1150.1,181.2 L1145.6,181.2 M53.9,152.2 L62.9,152.2 M1150.1,152.2 L1141.1,152.2
# 		 '/>	<g transform="translate(45.6,158.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,123.2 L58.4,123.2 M1150.1,123.2 L1145.6,123.2 M53.9,94.1 L62.9,94.1 M1150.1,94.1 L1141.1,94.1
# 		 '/>	<g transform="translate(45.6,100.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,65.1 L58.4,65.1 M1150.1,65.1 L1145.6,65.1 M53.9,36.1 L62.9,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(45.6,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L53.9,433.4 M53.9,36.1 L53.9,45.1  '/>	<g transform="translate(53.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M273.1,442.4 L273.1,433.4 M273.1,36.1 L273.1,45.1  '/>	<g transform="translate(273.1,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M492.4,442.4 L492.4,433.4 M492.4,36.1 L492.4,45.1  '/>	<g transform="translate(492.4,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 20</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" st

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;
