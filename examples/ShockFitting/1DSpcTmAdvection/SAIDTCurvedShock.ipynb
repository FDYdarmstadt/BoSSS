# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\SAIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using SAIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %% [markdown]
# # Run Simulation

# %% [markdown]
# open a database

# %%
string dbPath = @"SAIDT_db";
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Creating database 'SAIDT_db_03042024'.

# %% [markdown]
# ## Curved Shock Scalar Advection

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.CurvedShock_Eccomas22(
                                        dbPath: dbPath,
                                        MaxIterations: 50,
                                        dgDegree: 0,
                                        numOfCellsX: 10,
                                        numOfCellsY: 10,
                                        agg: 0.4,
                                        optiLevelSetType:OptiLevelSetType.SplineLevelSet
                                        );
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
# Out:
# rm ScalarAdvection_SP_0.plt ScalarAdvection_SP_1.plt ScalarAdvection_SP_10.plt ScalarAdvection_SP_11.plt ScalarAdvection_SP_12.plt ScalarAdvection_SP_13.plt ScalarAdvection_SP_14.plt ScalarAdvection_SP_15.plt ScalarAdvection_SP_16.plt ScalarAdvection_SP_17.plt ScalarAdvection_SP_18.plt ScalarAdvection_SP_19.plt ScalarAdvection_SP_2.plt ScalarAdvection_SP_20.plt ScalarAdvection_SP_21.plt ScalarAdvection_SP_22.plt ScalarAdvection_SP_23.plt ScalarAdvection_SP_24.plt ScalarAdvection_SP_25.plt ScalarAdvection_SP_26.plt ScalarAdvection_SP_27.plt ScalarAdvection_SP_28.plt ScalarAdvection_SP_29.plt ScalarAdvection_SP_3.plt ScalarAdvection_SP_30.plt ScalarAdvection_SP_31.plt ScalarAdvection_SP_32.plt ScalarAdvection_SP_33.plt ScalarAdvection_SP_34.plt ScalarAdvection_SP_35.plt ScalarAdvection_SP_36.plt ScalarAdvection_SP_37.plt ScalarAdvection_SP_38.plt ScalarAdvection_SP_39.plt ScalarAdvection_SP_4.plt ScalarAdvection_SP_40.plt ScalarAdvection_SP_41.plt ScalarAdvection_SP_42.plt ScalarAdvection_SP_43.plt ScalarAdvection_SP_44.plt ScalarAdvection_SP_45.plt ScalarAdvection_SP_5.plt ScalarAdvection_SP_6.plt ScalarAdvection_SP_7.plt ScalarAdvection_SP_8.plt ScalarAdvection_SP_9.plt;
# Session ID: d260e28b-a804-4b9b-abc4-91623bff3258, DB path: 'SAIDT_db_03042024'
# Session directory 'SAIDT_db_03042024\sessions\d260e28b-a804-4b9b-abc4-91623bff3258'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
#
#
# *****************************************************************************************
# *  X   X   DDD   GGG   -   III  SSS  TTTTT  *
# *   X X    D  D G      -    I  S      T     *
# *    X     D  D G  GG  -    I   SSS   T     *      XDG Implicit Shock Tracking Solver
# *   X X    D  D G   G  -    I      S  T     *
# *  X   X   DDD   GGG   -   III  SSS   T     *
# *****************************************************************************************
# *
# *  solver:                             SAIDT.SAIDTMain
# *  project:                            ScalarAdvection
# *  session:                            ScalarAdvection
# *  optimization problem:               FullEnRes
# *  merit function:                     L1Merit
# *  level set type:                     SplineLevelSet
# *  solver type:                        Standard
# *  f_phi type:                         None
# *  globalization strategy:             LineSearch
# *  initial value from:                 FromP0Timestepping
# *
# ******************************* Params ************************************************
# *  Solution Degree:                    0
# *  OptiLevelSet Degree:                3
# *  Level Set Degree:                   3
# *  Level Set Two Degree:               1
# *  Max Iterations:                     200
# *  Agglomeration Threshold:            0.4
# *  Regularization Params:
# *    Gamma Max:                        1
# *    Gamma Min:                        0.0001
# *    Gamma Start:                      1
# *  Globalization Params:
# *    Alpha Min:                        1E-08
# *    Alpha Start:                      1
# *    Mu Start:                         1
# *    Mu Max:                           1000000
# *    Mu Omega:                         1.2
# *    Mu Rho:                           0.95
# *  Level Set penalty Params:
# *    Kappa Xi:                         1
# *    Kappa M:                          100
# *    Kappa Min:                        1E-10
# *    Kappa v:                          0.5
# *  Reinitialization Params:
# *    Apply ReiInit:                    True
# *    c1:                               -0.2
# *    c2:                               0.01
# *    c3:                               0.01
# *  Adaptive Regularization Params:
# *    L:                                1
# *    sigma_1:                          0.01
# *    sigma_2:                          0.1
# *    tauGamma:                         1.5
# Initial Value : l2: |r|= 2.2222222E-01, |f_err|=1.0385227E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 1.9592646888086496, 2.0955928871446985
# l2: ||R0||= 3.3922495E-01, f_err=1.354373E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.37E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 1.9888023360266407, 2.2392458329782094
# l2: ||R0||= 4.0356408E-01, f_err=1.548527E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 9.82E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 6.247499677310241, 3.21319172596816
# alpha, M, predM  0.5, 2.4882650926716923, 3.2132317710752822
# l2: ||R0||= 5.2052581E-01, f_err=1.683331E+00, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.97E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 2.1637532435468785, 2.2962103910257454
# l2: ||R0||= 6.4575574E-01, f_err=1.421293E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.53E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 1.0275802165502224, 2.5630644871449872
# l2: ||R0||= 2.313325E-01, f_err=8.995498E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.43E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 1.0188844739060432, 1.110893058058306
# l2: ||R0||= 2.4425078E-01, f_err=1.00002E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.55E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.7171531008452365, 0.8922007334348736
# l2: ||R0||= 3.44305E-01, f_err=8.368434E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.65E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.9698852387263336, 0.9832986925586502
# l2: ||R0||= 2.719691E-01, f_err=9.081848E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.36E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.36660020452160424, 0.6955294498751063
# l2: ||R0||= 2.7305635E-01, f_err=6.251622E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.23E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.1807979923297134, 0.39911234508459603
# l2: ||R0||= 1.0135751E-01, f_err=3.973154E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.85E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.22561668251339811, 0.22945439846555682
# l2: ||R0||= 2.0295595E-01, f_err=4.729462E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.64E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 0.1377751036148131, 0.24620002619306888
# l2: ||R0||= 9.5302886E-02, f_err=3.666048E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.12E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 0.16051762236520023, 0.1333719528768438
# alpha, M, predM  0.5, 0.0765340851672197, 0.133372338083457
# l2: ||R0||= 5.4627149E-02, f_err=2.366552E-01, f_phi=0E+00, Alpha = 5E-01, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.06E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 0.018288454159963018, 0.06584223486842831
# l2: ||R0||= 1.3037437E-02, f_err=1.413803E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.39E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 0.006886397300878096, 0.015719172593021778
# l2: ||R0||= 5.5536638E-03, f_err=9.661369E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.65E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 0.003399308624347177, 0.00670411404279219
# l2: ||R0||= 6.6772377E-03, f_err=6.972682E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.48E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 0.001482599493724553, 0.0033903238243506977
# l2: ||R0||= 2.2442108E-03, f_err=4.542663E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.41E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 0.0008346346553688723, 0.0013521051161292305
# l2: ||R0||= 2.2273502E-03, f_err=3.257223E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.27E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 0.0007390691296358951, 0.0007726576236860757
# l2: ||R0||= 3.3117343E-03, f_err=2.516517E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.19E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 0.0004929480803388304, 0.0007223767807225173
# l2: ||R0||= 2.7919346E-03, f_err=2.007656E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.03E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 0.0003561642610900637, 0.0004466111891853189
# l2: ||R0||= 2.5062085E-03, f_err=1.689347E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.39E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 0.0002587671567208627, 0.0003338506133112357
# l2: ||R0||= 1.9165565E-03, f_err=1.311384E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 3.03E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 0.00017005731407725226, 0.00022177091908065323
# l2: ||R0||= 1.8637487E-03, f_err=1.088492E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.38E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 0.0001066334764459225, 0.00014503034645915874
# l2: ||R0||= 1.2759445E-03, f_err=7.794769E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 1.84E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 3.6816872598480324E-05, 5.536045619661122E-05
# l2: ||R0||= 1.2178157E-03, f_err=5.363152E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 6.04E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 2.251879373337003E-05, 4.16345091629004E-05
# l2: ||R0||= 6.8324821E-04, f_err=3.411117E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 7.34E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 5.919587489944108E-06, 1.47539066068926E-05
# l2: ||R0||= 3.9383688E-04, f_err=1.664683E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 3.93E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 6.124423774679037E-07, 2.015218574143379E-06
# l2: ||R0||= 1.837004E-04, f_err=7.632052E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 5.46E-04, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 1.4907424594803767E-07, 6.035498731795024E-07
# l2: ||R0||= 7.0461312E-05, f_err=2.548868E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 5.31E-04, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 5.561114420511422E-09, 4.34823993590131E-08
# l2: ||R0||= 1.8135961E-05, f_err=7.046414E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 5.01E-05, QuadOrder=4
# ALNR=2.09454938024223 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 4.262121788098688E-10, 4.088404217043101E-09
# l2: ||R0||= 4.235137E-06, f_err=1.390172E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 2.61E-05, QuadOrder=4
# ALNR=2.4976321117027025 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 3.862300416825275E-12, 1.1288519943596439E-10
# l2: ||R0||= 4.8652117E-07, f_err=1.879222E-06, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 1.29E-06, QuadOrder=4
# ALNR=3.591518802776983 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 6.671738154813709E-14, 2.3148530446861006E-12
# l2: ||R0||= 4.9741617E-08, f_err=1.746827E-07, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 3.38E-07, QuadOrder=4
# ALNR=4.7341726285432495 > 1.005 so we continue
#
#
# Starting Opt-Iter No.34:
# alpha, M, predM  1, 4.2152503526107146E-15, 2.0335199576782705E-14
# l2: ||R0||= 2.3936576E-08, f_err=5.736705E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 3.34E-08, QuadOrder=4
# ALNR=4.783202378997567 > 1.005 so we continue
#
#
# Starting Opt-Iter No.35:
# alpha, M, predM  1, 8.530454935582782E-17, 2.092760385236589E-15
# l2: ||R0||= 2.8203154E-09, f_err=6.497081E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 5.81E-09, QuadOrder=4
# ALNR=5.6893865937912835 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 1.3850521594895599E-17, 3.2658185064682185E-17
# l2: ||R0||= 1.6572615E-09, f_err=3.649359E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 1.05E-09, QuadOrder=4
# ALNR=5.560055522767861 > 1.005 so we continue
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 2.0261164462386358E-17, 1.401344289600674E-17
# alpha, M, predM  0.5, 2.4903536460498596E-18, 1.4013728691706352E-17
# l2: ||R0||= 4.7895595E-10, f_err=1.180106E-09, f_phi=0E+00, Alpha = 5E-01, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 1.07E-09, QuadOrder=4
# ALNR=5.499338853886826 > 1.005 so we continue
#
#
# Starting Opt-Iter No.38:
# alpha, M, predM  1, 1.671888351439102E-17, 2.887583649240901E-18
# alpha, M, predM  0.5, 4.0218391319124276E-18, 2.8875252142200645E-18
# alpha, M, predM  0.25, 7.788197919446326E-19, 2.8874959967096464E-18
# l2: ||R0||= 1.4121303E-10, f_err=5.323853E-10, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 1.31E-09, QuadOrder=4
# ALNR=5.372119648927962 > 1.005 so we continue
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 1.0515644651641555E-17, 4.2884311658982535E-19
# alpha, M, predM  0.5, 3.1939340908024646E-18, 4.288347880237911E-19
# alpha, M, predM  0.25, 9.558399845306297E-19, 4.2883062374077395E-19
# alpha, M, predM  0.125, 2.2537628898978093E-19, 4.288285415992654E-19
# l2: ||R0||= 5.8103786E-11, f_err=4.633651E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 6.77E-04, Kappa = 1E+03, Mu = 5.89E-10, QuadOrder=4
# ALNR=4.475751027982777 > 1.005 so we continue
#
#
# Starting Opt-Iter No.40:
# alpha, M, predM  1, 2.243635261041774E-17, 1.8979183418629056E-19
# alpha, M, predM  0.5, 6.279877932654518E-18, 1.8979309636733682E-19
# alpha, M, predM  0.25, 1.7766310279215986E-18, 1.8979372745785995E-19
# alpha, M, predM  0.125, 4.284423943741257E-19, 1.8979404300312152E-19
# alpha, M, predM  0.0625, 2.5362880445764963E-19, 1.8979420077575232E-19
# alpha, M, predM  0.03125, 1.9977955268886424E-19, 1.897942796620677E-19
# alpha, M, predM  0.015625, 1.660917187995792E-19, 1.897943191052254E-19
# l2: ||R0||= 5.2138153E-11, f_err=4.212467E-10, f_phi=0E+00, Alpha = 1.56E-02, Gamma = 4.51E-04, Kappa = 1E+03, Mu = 4.11E-10, QuadOrder=4
# ALNR=3.237672675014782 > 1.005 so we continue
#
#
# Starting Opt-Iter No.41:
# alpha, M, predM  1, 1.71191706513534E-17, 1.6419169770377618E-19
# alpha, M, predM  0.5, 4.9594518128898184E-18, 1.641919627769051E-19
# alpha, M, predM  0.25, 1.478661722465194E-18, 1.6419209531346959E-19
# alpha, M, predM  0.125, 3.953456357962185E-19, 1.6419216158175184E-19
# alpha, M, predM  0.0625, 2.5399516084462165E-19, 1.6419219471589294E-19
# alpha, M, predM  0.03125, 2.1685422039006714E-19, 1.6419221128296351E-19
# alpha, M, predM  0.015625, 1.9150782640298115E-19, 1.6419221956649878E-19
# alpha, M, predM  0.0078125, 1.7562114746996166E-19, 1.6419222370826642E-19
# alpha, M, predM  0.00390625, 1.6893385827622825E-19, 1.6419222577915025E-19
# alpha, M, predM  0.001953125, 1.6634875208749391E-19, 1.6419222681459216E-19
# alpha, M, predM  0.0009765625, 1.6526339448206104E-19, 1.641922273323131E-19
# alpha, M, predM  0.00048828125, 1.6472805724185216E-19, 1.6419222759117357E-19
# alpha, M, predM  0.000244140625, 1.6445926720045147E-19, 1.6419222772060382E-19
# alpha, M, predM  0.0001220703125, 1.6432674453575291E-19, 1.6419222778531894E-19
# alpha, M, predM  6.103515625E-05, 1.6425810775167491E-19, 1.6419222781767651E-19
# alpha, M, predM  3.0517578125E-05, 1.6422471125352365E-19, 1.641922278338553E-19
# alpha, M, predM  1.52587890625E-05, 1.6420816639250944E-19, 1.6419222784194468E-19
# alpha, M, predM  7.62939453125E-06, 1.6420122709034882E-19, 1.6419222784598937E-19
# alpha, M, predM  3.814697265625E-06, 1.6419818572784066E-19, 1.6419222784801172E-19
# alpha, M, predM  1.9073486328125E-06, 1.6419554281762244E-19, 1.6419222784902288E-19
# alpha, M, predM  9.5367431640625E-07, 1.6419333384397234E-19, 1.6419222784952848E-19
# alpha, M, predM  4.76837158203125E-07, 1.6419330062720085E-19, 1.6419222784978126E-19
# alpha, M, predM  2.384185791015625E-07, 1.641918694332075E-19, 1.6419222784990767E-19
# l2: ||R0||= 5.2137961E-11, f_err=4.212474E-10, f_phi=0E+00, Alpha = 2.38E-07, Gamma = 3.01E-04, Kappa = 1E+03, Mu = 4.01E-10, QuadOrder=4
# ALNR=3.0836647757474056 > 1.005 so we continue
#
#
# Starting Opt-Iter No.42:
# alpha, M, predM  1, 2.4000284260874963E-17, 1.5862714662284238E-19
# alpha, M, predM  0.5, 6.791434279809519E-18, 1.5862818165701612E-19
# alpha, M, predM  0.25, 2.0012967964017386E-18, 1.5862869917410298E-19
# alpha, M, predM  0.125, 5.607893861255593E-19, 1.5862895793264643E-19
# alpha, M, predM  0.0625, 2.527802731808555E-19, 1.5862908731191813E-19
# alpha, M, predM  0.03125, 2.17683088929423E-19, 1.58629152001554E-19
# alpha, M, predM  0.015625, 1.8899087077088854E-19, 1.5862918434637192E-19
# alpha, M, predM  0.0078125, 1.7216649101122258E-19, 1.5862920051878089E-19
# alpha, M, predM  0.00390625, 1.6417186226791142E-19, 1.5862920860498537E-19
# alpha, M, predM  0.001953125, 1.6105482456206112E-19, 1.586292126480876E-19
# alpha, M, predM  0.0009765625, 1.5983256626861258E-19, 1.5862921466963874E-19
# alpha, M, predM  0.00048828125, 1.5923073570421024E-19, 1.586292156804143E-19
# alpha, M, predM  0.000244140625, 1.5892854657403866E-19, 1.5862921618580207E-19
# alpha, M, predM  0.0001220703125, 1.587800895581159E-19, 1.5862921643849595E-19
# alpha, M, predM  6.103515625E-05, 1.5870542812392925E-19, 1.586292165648429E-19
# alpha, M, predM  3.0517578125E-05, 1.5866756248585502E-19, 1.5862921662801639E-19
# alpha, M, predM  1.52587890625E-05, 1.5865058055875468E-19, 1.586292166596031E-19
# alpha, M, predM  7.62939453125E-06, 1.5863925183821233E-19, 1.5862921667539648E-19
# alpha, M, predM  3.814697265625E-06, 1.5863458847463257E-19, 1.5862921668329318E-19
# alpha, M, predM  1.9073486328125E-06, 1.5863329924794947E-19, 1.586292166872415E-19
# alpha, M, predM  9.5367431640625E-07, 1.5863192875310906E-19, 1.5862921668921568E-19
# alpha, M, predM  4.76837158203125E-07, 1.5863059122413119E-19, 1.5862921669020276E-19
# alpha, M, predM  2.384185791015625E-07, 1.5863019685456502E-19, 1.586292166906963E-19
# alpha, M, predM  1.1920928955078125E-07, 1.5863051538353627E-19, 1.586292166909431E-19
# alpha, M, predM  5.960464477539063E-08, 1.5862943996704954E-19, 1.5862921669106647E-19
# alpha, M, predM  2.9802322387695312E-08, 1.586294417931761E-19, 1.5862921669112815E-19
# alpha, M, predM  1.4901161193847656E-08, 1.5862921577812654E-19, 1.58629216691159E-19
# l2: ||R0||= 5.2137961E-11, f_err=4.212474E-10, f_phi=0E+00, Alpha = 1.49E-08, Gamma = 2E-04, Kappa = 1E+03, Mu = 3.72E-10, QuadOrder=4
# ALNR=2.0140650323822524 > 1.005 so we continue
#
#
# Starting Opt-Iter No.43:
# alpha, M, predM  1, 3.158057997563484E-17, 1.5336906031325287E-19
# alpha, M, predM  0.5, 8.75917485020935E-18, 1.5337082314391414E-19
# alpha, M, predM  0.25, 2.5378087726501877E-18, 1.5337170455924478E-19
# alpha, M, predM  0.125, 7.272434855326105E-19, 1.5337214526691012E-19
# alpha, M, predM  0.0625, 2.526306764967757E-19, 1.5337236562074276E-19
# alpha, M, predM  0.03125, 2.1170172564828704E-19, 1.533724757976591E-19
# alpha, M, predM  0.015625, 1.8542948556898607E-19, 1.5337253088611727E-19
# alpha, M, predM  0.0078125, 1.6837294076193265E-19, 1.5337255843034635E-19
# alpha, M, predM  0.00390625, 1.5942100054975656E-19, 1.5337257220246087E-19
# alpha, M, predM  0.001953125, 1.559474819156066E-19, 1.5337257908851816E-19
# alpha, M, predM  0.0009765625, 1.5464730782226964E-19, 1.533725825315468E-19
# alpha, M, predM  0.00048828125, 1.5400680072153044E-19, 1.533725842530611E-19
# alpha, M, predM  0.000244140625, 1.5369041105967342E-19, 1.5337258511381826E-19
# alpha, M, predM  0.0001220703125, 1.5352961851923023E-19, 1.5337258554419684E-19
# alpha, M, predM  6.103515625E-05, 1.5345301580764873E-19, 1.5337258575938615E-19
# alpha, M, predM  3.0517578125E-05, 1.5341377254172643E-19, 1.5337258586698077E-19
# alpha, M, predM  1.52587890625E-05, 1.5339329128888003E-19, 1.5337258592077811E-19
# alpha, M, predM  7.62939453125E-06, 1.5338291933000753E-19, 1.5337258594767676E-19
# alpha, M, predM  3.814697265625E-06, 1.5337863719277092E-19, 1.533725859611261E-19
# alpha, M, predM  1.9073486328125E-06, 1.5337622094506707E-19, 1.5337258596785075E-19
# alpha, M, predM  9.5367431640625E-07, 1.5337619979048898E-19, 1.533725859712131E-19
# alpha, M, predM  4.76837158203125E-07, 1.53374231725436E-19, 1.5337258597289426E-19
# alpha, M, predM  2.384185791015625E-07, 1.5337347231336426E-19, 1.5337258597373485E-19
# alpha, M, predM  1.1920928955078125E-07, 1.5337375337627188E-19, 1.5337258597415514E-19
# alpha, M, predM  5.960464477539063E-08, 1.5337341298740879E-19, 1.5337258597436528E-19
# alpha, M, predM  2.9802322387695312E-08, 1.533731023938299E-19, 1.5337258597447034E-19
# alpha, M, predM  1.4901161193847656E-08, 1.5337258497857847E-19, 1.533725859745229E-19
# l2: ||R0||= 5.213796E-11, f_err=4.212474E-10, f_phi=0E+00, Alpha = 1.49E-08, Gamma = 1.34E-04, Kappa = 1E+03, Mu = 3.44E-10, QuadOrder=4
# ALNR=1.9138089461271606 > 1.005 so we continue
#
#
# Starting Opt-Iter No.44:
# alpha, M, predM  1, 3.7006763585606096E-17, 1.4998955990818463E-19
# alpha, M, predM  0.5, 1.0145267878550101E-17, 1.4999179058473174E-19
# alpha, M, predM  0.25, 2.9052156192885435E-18, 1.4999290592300528E-19
# alpha, M, predM  0.125, 8.353556506756567E-19, 1.4999346359214206E-19
# alpha, M, predM  0.0625, 2.6468745133330777E-19, 1.4999374242671045E-19
# alpha, M, predM  0.03125, 2.1060397609992327E-19, 1.4999388184399464E-19
# alpha, M, predM  0.015625, 1.8224941843867635E-19, 1.4999395155263674E-19
# alpha, M, predM  0.0078125, 1.6565343978123857E-19, 1.499939864069578E-19
# alpha, M, predM  0.00390625, 1.5623726923850643E-19, 1.499940038341183E-19
# alpha, M, predM  0.001953125, 1.5260596889410115E-19, 1.4999401254769858E-19
# alpha, M, predM  0.0009765625, 1.5128331478271338E-19, 1.499940169044887E-19
# alpha, M, predM  0.00048828125, 1.5063454637681963E-19, 1.4999401908288377E-19
# alpha, M, predM  0.000244140625, 1.5031405170968807E-19, 1.4999402017208131E-19
# alpha, M, predM  0.0001220703125, 1.5015443238011297E-19, 1.4999402071668006E-19
# alpha, M, predM  6.103515625E-05, 1.5007545177864554E-19, 1.4999402098897945E-19
# alpha, M, predM  3.0517578125E-05, 1.5003506835995265E-19, 1.4999402112512914E-19
# alpha, M, predM  1.52587890625E-05, 1.5001615616770697E-19, 1.49994021193204E-19
# alpha, M, predM  7.62939453125E-06, 1.5000599226974775E-19, 1.4999402122724142E-19
# alpha, M, predM  3.814697265625E-06, 1.500001475180094E-19, 1.4999402124426012E-19
# alpha, M, predM  1.9073486328125E-06, 1.4999847425902472E-19, 1.4999402125276948E-19
# alpha, M, predM  9.5367431640625E-07, 1.499968290226293E-19, 1.4999402125702417E-19
# alpha, M, predM  4.76837158203125E-07, 1.499955086718685E-19, 1.499940212591515E-19
# alpha, M, predM  2.384185791015625E-07, 1.4999525423339112E-19, 1.4999402126021517E-19
# alpha, M, predM  1.1920928955078125E-07, 1.4999484641227118E-19, 1.49994021260747E-19
# alpha, M, predM  5.960464477539063E-08, 1.499946531814184E-19, 1.4999402126101291E-19
# alpha, M, predM  2.9802322387695312E-08, 1.499944991981704E-19, 1.4999402126114588E-19
# alpha, M, predM  1.4901161193847656E-08, 1.4999450024201598E-19, 1.4999402126121237E-19
# l2: ||R0||= 5.2138146E-11, f_err=4.21247E-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.26E-10, QuadOrder=4
# ALNR=1.5623583201924958 > 1.005 so we continue
#
#
# Starting Opt-Iter No.45:
# alpha, M, predM  1, 3.7006702604576404E-17, 1.4998975564362538E-19
# alpha, M, predM  0.5, 1.0145261214588198E-17, 1.4999198629222155E-19
# alpha, M, predM  0.25, 2.9052181266932013E-18, 1.4999310161651962E-19
# alpha, M, predM  0.125, 8.353568598813664E-19, 1.4999365927866864E-19
# alpha, M, predM  0.0625, 2.64687866344456E-19, 1.4999393810974318E-19
# alpha, M, predM  0.03125, 2.1060587520799045E-19, 1.4999407752528044E-19
# alpha, M, predM  0.015625, 1.822487503358502E-19, 1.4999414723304905E-19
# alpha, M, predM  0.0078125, 1.65655942142534E-19, 1.4999418208693338E-19
# alpha, M, predM  0.00390625, 1.5623741632271638E-19, 1.4999419951387554E-19
# alpha, M, predM  0.001953125, 1.5260581470161686E-19, 1.4999420822734661E-19
# alpha, M, predM  0.0009765625, 1.512833938987855E-19, 1.4999421258408215E-19
# alpha, M, predM  0.00048828125, 1.506345405166305E-19, 1.4999421476244992E-19
# alpha, M, predM  0.000244140625, 1.5031416007418755E-19, 1.499942158516338E-19
# alpha, M, predM  0.0001220703125, 1.5015532303797662E-19, 1.4999421639622576E-19
# alpha, M, predM  6.103515625E-05, 1.5007511032002972E-19, 1.4999421666852172E-19
# alpha, M, predM  3.0517578125E-05, 1.5003508207818033E-19, 1.499942168046697E-19
# alpha, M, predM  1.52587890625E-05, 1.5001626363067732E-19, 1.499942168727437E-19
# alpha, M, predM  7.62939453125E-06, 1.500065880476803E-19, 1.4999421690678068E-19
# alpha, M, predM  3.814697265625E-06, 1.5000025493370216E-19, 1.4999421692379919E-19
# alpha, M, predM  1.9073486328125E-06, 1.4999858166959165E-19, 1.4999421693230845E-19
# alpha, M, predM  9.5367431640625E-07, 1.4999693642765282E-19, 1.4999421693656307E-19
# alpha, M, predM  4.76837158203125E-07, 1.4999561607489367E-19, 1.4999421693869038E-19
# alpha, M, predM  2.384185791015625E-07, 1.4999524131064732E-19, 1.4999421693975402E-19
# alpha, M, predM  1.1920928955078125E-07, 1.4999522344949649E-19, 1.4999421694028587E-19
# alpha, M, predM  5.960464477539063E-08, 1.4999521589960466E-19, 1.4999421694055177E-19
# alpha, M, predM  2.9802322387695312E-08, 1.4999476266958825E-19, 1.4999421694068473E-19
# alpha, M, predM  1.4901161193847656E-08, 1.499946076418718E-19, 1.4999421694075122E-19
# l2: ||R0||= 5.2138234E-11, f_err=4.212467E-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.26E-10, QuadOrder=4
# ALNR=1.2206831244618748 > 1.005 so we continue
#
#
# Starting Opt-Iter No.46:
# alpha, M, predM  1, 3.700656207937902E-17, 1.499899332544726E-19
# alpha, M, predM  0.5, 1.0145216780919129E-17, 1.4999216388682383E-19
# alpha, M, predM  0.25, 2.9052051333920966E-18, 1.4999327920299946E-19
# alpha, M, predM  0.125, 8.353534536489784E-19, 1.4999383686108727E-19
# alpha, M, predM  0.0625, 2.6468679355106615E-19, 1.4999411569013118E-19
# alpha, M, predM  0.03125, 2.106049648202839E-19, 1.4999425510465313E-19
# alpha, M, predM  0.015625, 1.8224886794392328E-19, 1.4999432481191412E-19
# alpha, M, predM  0.0078125, 1.6565520808494546E-19, 1.499943596655446E-19
# alpha, M, predM  0.00390625, 1.5623703245543764E-19, 1.4999437709235985E-19
# alpha, M, predM  0.001953125, 1.5260653292233235E-19, 1.4999438580576747E-19
# alpha, M, predM  0.0009765625, 1.5128353177275431E-19, 1.4999439016247128E-19
# alpha, M, predM  0.00048828125, 1.5063453797479543E-19, 1.4999439234082318E-19
# alpha, M, predM  0.000244140625, 1.5031424859434988E-19, 1.4999439342999914E-19
# alpha, M, predM  0.0001220703125, 1.501551330537021E-19, 1.499943939745871E-19
# alpha, M, predM  6.103515625E-05, 1.5007514041754928E-19, 1.499943942468811E-19
# alpha, M, predM  3.0517578125E-05, 1.5003517761155277E-19, 1.499943943830281E-19
# alpha, M, predM  1.52587890625E-05, 1.500161052755122E-19, 1.499943944511016E-19
# alpha, M, predM  7.62939453125E-06, 1.5000609721869982E-19, 1.4999439448513834E-19
# alpha, M, predM  3.814697265625E-06, 1.500002637575987E-19, 1.499943945021567E-19
# alpha, M, predM  1.9073486328125E-06, 1.4999857918726507E-19, 1.499943945106659E-19
# alpha, M, predM  9.5367431640625E-07, 1.499970866234285E-19, 1.499943945149205E-19
# alpha, M, predM  4.76837158203125E-07, 1.49995445668864E-19, 1.499943945170478E-19
# alpha, M, predM  2.384185791015625E-07, 1.4999506706318242E-19, 1.4999439451811144E-19
# alpha, M, predM  1.1920928955078125E-07, 1.4999522096742767E-19, 1.4999439451864327E-19
# alpha, M, predM  5.960464477539063E-08, 1.499952134175385E-19, 1.4999439451890916E-19
# alpha, M, predM  2.9802322387695312E-08, 1.4999488639835245E-19, 1.4999439451904213E-19
# alpha, M, predM  1.4901161193847656E-08, 1.4999469344073151E-19, 1.4999439451910862E-19
# l2: ||R0||= 5.2138282E-11, f_err=4.212465E-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.26E-10, QuadOrder=4
# ALNR=1.0163462024741365 > 1.005 so we continue
#
#
# Starting Opt-Iter No.47:
# alpha, M, predM  1, 3.700655190931153E-17, 1.4999013184506852E-19
# alpha, M, predM  0.5, 1.0145216174645358E-17, 1.499923624706077E-19
# alpha, M, predM  0.25, 2.905201838821404E-18, 1.499934777833773E-19
# alpha, M, predM  0.125, 8.353527156343889E-19, 1.499940354397621E-19
# alpha, M, predM  0.0625, 2.6468595967560637E-19, 1.4999431426795449E-19
# alpha, M, predM  0.03125, 2.1060510039494617E-19, 1.499944536820507E-19
# alpha, M, predM  0.015625, 1.8224770950850337E-19, 1.499945233890988E-19
# alpha, M, predM  0.0078125, 1.6565447415744626E-19, 1.4999455824262285E-19
# alpha, M, predM  0.00390625, 1.5623600310463456E-19, 1.4999457566938486E-19
# alpha, M, predM  0.001953125, 1.526063065988321E-19, 1.4999458438276588E-19
# alpha, M, predM  0.0009765625, 1.512839265159207E-19, 1.499945887394564E-19
# alpha, M, predM  0.00048828125, 1.506341250440287E-19, 1.4999459091780163E-19
# alpha, M, predM  0.000244140625, 1.5031400509643577E-19, 1.4999459200697426E-19
# alpha, M, predM  0.0001220703125, 1.5015496040244411E-19, 1.499945925515606E-19
# alpha, M, predM  6.103515625E-05, 1.5007527919825086E-19, 1.4999459282385374E-19
# alpha, M, predM  3.0517578125E-05, 1.5003499845964713E-19, 1.499945929600003E-19
# alpha, M, predM  1.52587890625E-05, 1.5001563247469936E-19, 1.499945930280736E-19
# alpha, M, predM  7.62939453125E-06, 1.5000617074270437E-19, 1.4999459306211024E-19
# alpha, M, predM  3.814697265625E-06, 1.5000030862539282E-19, 1.4999459307912858E-19
# alpha, M, predM  1.9073486328125E-06, 1.499984777881852E-19, 1.4999459308763772E-19
# alpha, M, predM  9.5367431640625E-07, 1.4999716173935942E-19, 1.4999459309189232E-19
# alpha, M, predM  4.76837158203125E-07, 1.4999551220150735E-19, 1.499945930940196E-19
# alpha, M, predM  2.384185791015625E-07, 1.4999472716246854E-19, 1.4999459309508325E-19
# alpha, M, predM  1.1920928955078125E-07, 1.4999484604680766E-19, 1.4999459309561507E-19
# alpha, M, predM  5.960464477539063E-08, 1.4999511202811432E-19, 1.4999459309588097E-19
# alpha, M, predM  2.9802322387695312E-08, 1.4999458620901592E-19, 1.4999459309601393E-19
# l2: ||R0||= 5.2138289E-11, f_err=4.212464E-10, f_phi=0E+00, Alpha = 2.98E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 3.26E-10, QuadOrder=4
#
# ALNR=1.0000005292233958 <= 1.005 so we terminate/increase degree
#
# ALNR=1.0000000987005941 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L62.9,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(45.6,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-12</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,413.4 L58.4,413.4 M1150.1,413.4 L1145.6,413.4 M53.9,384.4 L62.9,384.4 M1150.1,384.4 L1141.1,384.4
# 		 '/>	<g transform="translate(45.6,390.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-10</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,355.3 L58.4,355.3 M1150.1,355.3 L1145.6,355.3 M53.9,326.3 L62.9,326.3 M1150.1,326.3 L1141.1,326.3
# 		 '/>	<g transform="translate(45.6,332.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,297.3 L58.4,297.3 M1150.1,297.3 L1145.6,297.3 M53.9,268.3 L62.9,268.3 M1150.1,268.3 L1141.1,268.3
# 		 '/>	<g transform="translate(45.6,274.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,239.2 L58.4,239.2 M1150.1,239.2 L1145.6,239.2 M53.9,210.2 L62.9,210.2 M1150.1,210.2 L1141.1,210.2
# 		 '/>	<g transform="translate(45.6,216.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,181.2 L58.4,181.2 M1150.1,181.2 L1145.6,181.2 M53.9,152.2 L62.9,152.2 M1150.1,152.2 L1141.1,152.2
# 		 '/>	<g transform="translate(45.6,158.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,123.2 L58.4,123.2 M1150.1,123.2 L1145.6,123.2 M53.9,94.1 L62.9,94.1 M1150.1,94.1 L1141.1,94.1
# 		 '/>	<g transform="translate(45.6,100.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,65.1 L58.4,65.1 M1150.1,65.1 L1145.6,65.1 M53.9,36.1 L62.9,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(45.6,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L53.9,433.4 M53.9,36.1 L53.9,45.1  '/>	<g transform="translate(53.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M163.5,442.4 L163.5,433.4 M163.5,36.1 L163.5,45.1  '/>	<g transform="translate(163.5,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M273.1,442.4 L273.1,433.4 M273.1,36.1 L273.1,45.1  '/>	<g transform="translate(273.1,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" str

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;
