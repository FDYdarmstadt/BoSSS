# %%
#r ".\binaries\BoSSSpad.dll"
#r ".\binaries\SAIDT.dll"
#r ".\binaries\ApplicationWithIDT.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Platform.LinAlg;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using ApplicationWithIDT;
using SAIDT;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

# %% [markdown]
# # Run Simulation

# %% [markdown]
# open a database

# %%
string dbPath = @"SAIDT_db";
var database = OpenOrCreateDatabase(dbPath);
# Out:
# Creating database 'SAIDT_db'.

# %% [markdown]
# ## Straight Shock Scalar Advection

# %%
using SAIDT;
BoSSS.Solution.Application.InitMPI();
BoSSS.Solution.Application.DeleteOldPlotFiles();
var pSAIDT = new SAIDTMain();
var CSAIDT = SAIDTHardCodedControl.StraightShock(
                    dbPath: dbPath,
                    MaxIterations: 100,
                    dgDegree: 0,
                    numOfCellsX: 5,
                    numOfCellsY: 5,
                    OptiNumOfCellsX: 5,
                    OptiNumOfCellsY: 5,
                    agg: 0.4,
                    ImmediatePlotPeriod: -1,
                    optiLevelSetType: OptiLevelSetType.SplineLevelSet,
                    LSDegree: 3,
                    isFarConfig:false
                    );
CSAIDT.OptiLevelSetDegree=3;
CSAIDT.SessionName="SAIDT_StraightShock";
pSAIDT.Init(CSAIDT);
pSAIDT.RunSolverMode();
# Out:
# rm;
# Session ID: 7b13e22f-e10a-492d-b295-c85a574c3e87, DB path: 'SAIDT_db'
# Session directory 'SAIDT_db\sessions\7b13e22f-e10a-492d-b295-c85a574c3e87'.
# Grid repartitioning method: METIS
# Grid repartitioning options:
# Number of cell Weights: 0
#
#
# *****************************************************************************************
# *  X   X   DDD   GGG   -   III  SSS  TTTTT  *
# *   X X    D  D G      -    I  S      T     *
# *    X     D  D G  GG  -    I   SSS   T     *      XDG Implicit Shock Tracking Solver
# *   X X    D  D G   G  -    I      S  T     *
# *  X   X   DDD   GGG   -   III  SSS   T     *
# *****************************************************************************************
# *
# *  solver:                             SAIDT.SAIDTMain
# *  project:                            ScalarAdvection
# *  session:                            SAIDT_StraightShock
# *  optimization problem:               FullEnRes
# *  merit function:                     L1Merit
# *  level set type:                     SplineLevelSet
# *  solver type:                        Standard
# *  f_phi type:                         None
# *  globalization strategy:             LineSearch
# *  initial value from:                 FromFunctionPerSpecies
# *
# ******************************* Params ************************************************
# *  Solution Degree:                    0
# *  OptiLevelSet Degree:                3
# *  Level Set Degree:                   3
# *  Level Set Two Degree:               1
# *  Max Iterations:                     200
# *  Agglomeration Threshold:            0.4
# *  Regularization Params:
# *    Gamma Max:                        1
# *    Gamma Min:                        0.0001
# *    Gamma Start:                      1
# *  Globalization Params:
# *    Alpha Min:                        1E-08
# *    Alpha Start:                      1
# *    Mu Start:                         1
# *    Mu Max:                           1000000
# *    Mu Omega:                         1.2
# *    Mu Rho:                           0.95
# *  Level Set penalty Params:
# *    Kappa Xi:                         1
# *    Kappa M:                          100
# *    Kappa Min:                        1E-10
# *    Kappa v:                          0.5
# *  Reinitialization Params:
# *    Apply ReiInit:                    True
# *    c1:                               -0.2
# *    c2:                               0.01
# *    c3:                               0.01
# *  Adaptive Regularization Params:
# *    L:                                1
# *    sigma_1:                          0.01
# *    sigma_2:                          0.1
# *    tauGamma:                         1.5
# Initial Value : l2: |r|= 6.8470954E-01, |f_err|=2.1500261E+00, | f_phi |=0E+00,
#
# Starting Opt-Iter No.1:
# alpha, M, predM  1, 6.124565405809477, 8.53841971072482
# l2: ||R0||= 9.0160584E-01, f_err=1.568063E+00, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.32E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.2:
# alpha, M, predM  1, 0.8929266355547376, 2.3812815690353744
# l2: ||R0||= 3.1768542E-01, f_err=7.102243E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 1.01E+00, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.3:
# alpha, M, predM  1, 0.30920383844359584, 0.5048013514042314
# l2: ||R0||= 2.8858798E-01, f_err=6.315804E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 2.44E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.4:
# alpha, M, predM  1, 0.28773226242995137, 0.3429636735009698
# l2: ||R0||= 1.8024548E-01, f_err=5.608908E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 3.59E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.5:
# alpha, M, predM  1, 0.10394407157058883, 0.28752078002715653
# l2: ||R0||= 7.3899045E-02, f_err=2.483791E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.36E-01, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.6:
# alpha, M, predM  1, 0.014512632115499162, 0.028865617986513905
# l2: ||R0||= 4.5892898E-02, f_err=1.285721E-01, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 8.61E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.7:
# alpha, M, predM  1, 0.001639917837107603, 0.013833655050836056
# l2: ||R0||= 5.8256956E-03, f_err=3.737287E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 7.68E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.8:
# alpha, M, predM  1, 0.0006677935861270123, 0.0014710337982259314
# l2: ||R0||= 2.154761E-03, f_err=3.057547E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 6.3E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.9:
# alpha, M, predM  1, 0.00031837449766414705, 0.0006323986354360569
# l2: ||R0||= 5.204767E-04, f_err=2.357608E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 5.19E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.10:
# alpha, M, predM  1, 0.00017315459074910354, 0.0003111431587718006
# l2: ||R0||= 2.6170261E-05, f_err=1.849217E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 1E+00, Kappa = 1E+03, Mu = 4.26E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.11:
# alpha, M, predM  1, 0.00010529864164870409, 0.00017260685408051013
# l2: ||R0||= 1.9746023E-04, f_err=1.341741E-02, f_phi=0E+00, Alpha = 1E+00, Gamma = 6.67E-01, Kappa = 1E+03, Mu = 3.21E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.12:
# alpha, M, predM  1, 6.99964750249854E-05, 0.00010011998268634414
# l2: ||R0||= 1.0043287E-03, f_err=8.864866E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 4.44E-01, Kappa = 1E+03, Mu = 2.12E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.13:
# alpha, M, predM  1, 1.6873305986043167E-05, 5.663560266492258E-05
# l2: ||R0||= 1.3206167E-04, f_err=5.193435E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.96E-01, Kappa = 1E+03, Mu = 1.2E-02, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.14:
# alpha, M, predM  1, 9.076594543208876E-06, 1.5035847474950718E-05
# l2: ||R0||= 4.5867511E-04, f_err=2.731012E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.98E-01, Kappa = 1E+03, Mu = 5.49E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.15:
# alpha, M, predM  1, 2.858059831062957E-06, 5.6432593388791155E-06
# l2: ||R0||= 5.9167397E-04, f_err=1.285803E-03, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.32E-01, Kappa = 1E+03, Mu = 1.96E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.16:
# alpha, M, predM  1, 3.59434033490618E-07, 2.4963643026541037E-06
# l2: ||R0||= 4.3717867E-05, f_err=6.169101E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 8.78E-02, Kappa = 1E+03, Mu = 1.61E-03, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.17:
# alpha, M, predM  1, 7.397208809925789E-08, 2.2612466242865692E-07
# l2: ||R0||= 5.8844116E-05, f_err=2.229527E-04, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.85E-02, Kappa = 1E+03, Mu = 3.42E-04, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.18:
# alpha, M, predM  1, 9.194703984709569E-09, 4.6840929925816484E-08
# l2: ||R0||= 2.0992202E-05, f_err=7.223853E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.9E-02, Kappa = 1E+03, Mu = 1.53E-04, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.19:
# alpha, M, predM  1, 4.94268423786924E-10, 3.6046550113267404E-09
# l2: ||R0||= 5.5213664E-06, f_err=1.788084E-05, f_phi=0E+00, Alpha = 1E+00, Gamma = 2.6E-02, Kappa = 1E+03, Mu = 2.32E-05, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.20:
# alpha, M, predM  1, 1.623307171151338E-11, 2.4060078452194374E-10
# l2: ||R0||= 1.0187829E-06, f_err=2.94802E-06, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.73E-02, Kappa = 1E+03, Mu = 5.6E-06, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.21:
# alpha, M, predM  1, 7.490141732127496E-14, 5.467784984264969E-12
# l2: ||R0||= 3.2692471E-08, f_err=2.503109E-07, f_phi=0E+00, Alpha = 1E+00, Gamma = 1.16E-02, Kappa = 1E+03, Mu = 5.29E-07, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.22:
# alpha, M, predM  1, 1.5304094208350036E-15, 3.502474838007036E-14
# l2: ||R0||= 1.0407986E-08, f_err=2.783325E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 7.71E-03, Kappa = 1E+03, Mu = 4.49E-08, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.23:
# alpha, M, predM  1, 1.8855837366189735E-16, 6.119561710857723E-16
# l2: ||R0||= 7.4376511E-09, f_err=1.002617E-08, f_phi=0E+00, Alpha = 1E+00, Gamma = 5.14E-03, Kappa = 1E+03, Mu = 8.83E-09, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.24:
# alpha, M, predM  1, 6.411829958447157E-18, 7.387736787437043E-17
# l2: ||R0||= 1.0621598E-09, f_err=2.122281E-09, f_phi=0E+00, Alpha = 1E+00, Gamma = 3.43E-03, Kappa = 1E+03, Mu = 1.51E-09, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.25:
# alpha, M, predM  1, 5.627137381856401E-18, 4.297037362103834E-18
# alpha, M, predM  0.5, 8.400008333592377E-19, 4.297149916126808E-18
# l2: ||R0||= 3.0987154E-10, f_err=7.622715E-10, f_phi=0E+00, Alpha = 5E-01, Gamma = 2.28E-03, Kappa = 1E+03, Mu = 7.42E-10, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.26:
# alpha, M, predM  1, 8.883765595203048E-18, 6.006267944263774E-19
# alpha, M, predM  0.5, 2.2734195760332327E-18, 6.006337411006169E-19
# alpha, M, predM  0.25, 5.3135115434507E-19, 6.006372144377366E-19
# l2: ||R0||= 2.6431448E-10, f_err=7.090115E-10, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 1.52E-03, Kappa = 1E+03, Mu = 4.19E-10, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.27:
# alpha, M, predM  1, 1.1150285921454471E-17, 4.7097677978066525E-19
# alpha, M, predM  0.5, 2.7283189755392725E-18, 4.709848011698183E-19
# alpha, M, predM  0.25, 5.5571076845500655E-19, 4.709888118643949E-19
# alpha, M, predM  0.125, 1.5514365528600091E-19, 4.709908172116831E-19
# l2: ||R0||= 7.6228495E-11, f_err=4.016565E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 1.01E-03, Kappa = 1E+03, Mu = 3.28E-10, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.28:
# alpha, M, predM  1, 2.6933726016244216E-18, 1.8103454419650284E-19
# alpha, M, predM  0.5, 8.89279704496702E-19, 1.8103282422857053E-19
# alpha, M, predM  0.25, 2.816007242370088E-19, 1.8103196424460434E-19
# alpha, M, predM  0.125, 1.7999598525254662E-19, 1.8103153425262128E-19
# l2: ||R0||= 7.8739628E-11, f_err=4.16651E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 6.77E-04, Kappa = 1E+03, Mu = 4.42E-10, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.29:
# alpha, M, predM  1, 6.0773651409682126E-18, 1.7243730670994809E-19
# alpha, M, predM  0.5, 1.850158488114682E-18, 1.7243744316980796E-19
# alpha, M, predM  0.25, 5.4869964050866E-19, 1.7243751139973792E-19
# alpha, M, predM  0.125, 1.6826669550617657E-19, 1.7243754551470288E-19
# l2: ||R0||= 9.4843531E-11, f_err=3.649765E-10, f_phi=0E+00, Alpha = 1.25E-01, Gamma = 4.51E-04, Kappa = 1E+03, Mu = 4.07E-10, QuadOrder=4
# **NOT** terminating now, minimal number of iterations not reached
#
#
# Starting Opt-Iter No.30:
# alpha, M, predM  1, 1.0088874461229521E-17, 1.4937444712454356E-19
# alpha, M, predM  0.5, 2.8193401753317277E-18, 1.4937474823827874E-19
# alpha, M, predM  0.25, 7.865666235483594E-19, 1.4937489879514634E-19
# alpha, M, predM  0.125, 1.7534852387267396E-19, 1.4937497407358014E-19
# alpha, M, predM  0.0625, 1.1779382834476307E-19, 1.4937501171279703E-19
# l2: ||R0||= 7.2856056E-11, f_err=3.363584E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 3.01E-04, Kappa = 1E+03, Mu = 3.31E-10, QuadOrder=4
# ALNR=2.5880246172798596 > 1.005 so we continue
#
#
# Starting Opt-Iter No.31:
# alpha, M, predM  1, 5.659570354939961E-19, 1.150055012517255E-19
# alpha, M, predM  0.5, 1.7355455570052645E-19, 1.1500546254705513E-19
# alpha, M, predM  0.25, 9.582458089475623E-20, 1.1500544319471996E-19
# l2: ||R0||= 6.4541315E-11, f_err=2.791955E-10, f_phi=0E+00, Alpha = 2.5E-01, Gamma = 2E-04, Kappa = 1E+03, Mu = 3.16E-10, QuadOrder=4
# ALNR=1.748945192022352 > 1.005 so we continue
#
#
# Starting Opt-Iter No.32:
# alpha, M, predM  1, 8.201920830371087E-18, 8.226142418098009E-20
# alpha, M, predM  0.5, 2.2869881977179637E-18, 8.226189245614595E-20
# alpha, M, predM  0.25, 6.55681629938905E-19, 8.226212659372888E-20
# alpha, M, predM  0.125, 1.7156585431829408E-19, 8.226224366252034E-20
# alpha, M, predM  0.0625, 6.721126620635453E-20, 8.226230219691608E-20
# l2: ||R0||= 4.5002971E-11, f_err=2.829284E-10, f_phi=0E+00, Alpha = 6.25E-02, Gamma = 1.34E-04, Kappa = 1E+03, Mu = 2.41E-10, QuadOrder=4
# ALNR=1.4641472464879548 > 1.005 so we continue
#
#
# Starting Opt-Iter No.33:
# alpha, M, predM  1, 8.448772072908065E-18, 6.294512860981418E-20
# alpha, M, predM  0.5, 2.3377590344903723E-18, 6.294643459931268E-20
# alpha, M, predM  0.25, 6.736589295827077E-19, 6.294708759406192E-20
# alpha, M, predM  0.125, 1.8946184478313118E-19, 6.294741409143655E-20
# alpha, M, predM  0.0625, 6.397532210346916E-20, 6.294757734012385E-20
# alpha, M, predM  0.03125, 7.253586489829135E-20, 6.294765896446752E-20
# alpha, M, predM  0.015625, 6.949789843974959E-20, 6.294769977663934E-20
# alpha, M, predM  0.0078125, 6.596299606081357E-20, 6.294772018272525E-20
# alpha, M, predM  0.00390625, 6.381167041049423E-20, 6.294773038576822E-20
# alpha, M, predM  0.001953125, 6.325416640421788E-20, 6.294773548728969E-20
# alpha, M, predM  0.0009765625, 6.30955442888893E-20, 6.294773803805043E-20
# alpha, M, predM  0.00048828125, 6.302104862926943E-20, 6.29477393134308E-20
-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 2.03E-10, QuadOrder=4
# ALNR=1.0870391615105712 > 1.005 so we continue
#
#
# Starting Opt-Iter No.36:
# alpha, M, predM  1, 8.448766773857703E-18, 6.29451339068829E-20
# alpha, M, predM  0.5, 2.337760141371507E-18, 6.294643989388199E-20
# alpha, M, predM  0.25, 6.736587431448707E-19, 6.294709288738153E-20
# alpha, M, predM  0.125, 1.8946202891213192E-19, 6.29474193841313E-20
# alpha, M, predM  0.0625, 6.397506252688584E-20, 6.294758263250619E-20
# alpha, M, predM  0.03125, 7.253630812669722E-20, 6.294766425669363E-20
# alpha, M, predM  0.015625, 6.949803813602962E-20, 6.294770506878736E-20
# alpha, M, predM  0.0078125, 6.596294621955041E-20, 6.294772547483422E-20
# alpha, M, predM  0.00390625, 6.38114843551468E-20, 6.294773567785764E-20
# alpha, M, predM  0.001953125, 6.325419241911632E-20, 6.294774077936936E-20
# alpha, M, predM  0.0009765625, 6.309595556541647E-20, 6.294774333012522E-20
# alpha, M, predM  0.00048828125, 6.302106931677914E-20, 6.294774460550315E-20
# alpha, M, predM  0.000244140625, 6.298491767121193E-20, 6.29477452431921E-20
# alpha, M, predM  0.0001220703125, 6.296630422411191E-20, 6.29477455620366E-20
# alpha, M, predM  6.103515625E-05, 6.295706083247623E-20, 6.294774572145883E-20
# alpha, M, predM  3.0517578125E-05, 6.295291877045593E-20, 6.294774580116995E-20
# alpha, M, predM  1.52587890625E-05, 6.295053678182826E-20, 6.294774584102552E-20
# alpha, M, predM  7.62939453125E-06, 6.294950490142586E-20, 6.29477458609533E-20
# alpha, M, predM  3.814697265625E-06, 6.29483299915764E-20, 6.294774587091718E-20
# alpha, M, predM  1.9073486328125E-06, 6.294854779747156E-20, 6.294774587589913E-20
# alpha, M, predM  9.5367431640625E-07, 6.294793271803118E-20, 6.29477458783901E-20
# alpha, M, predM  4.76837158203125E-07, 6.294802532707225E-20, 6.294774587963559E-20
# alpha, M, predM  2.384185791015625E-07, 6.294791259160694E-20, 6.294774588025834E-20
# alpha, M, predM  1.1920928955078125E-07, 6.294807673818588E-20, 6.29477458805697E-20
# alpha, M, predM  5.960464477539063E-08, 6.294807928965077E-20, 6.294774588072539E-20
# alpha, M, predM  2.9802322387695312E-08, 6.294803853560365E-20, 6.294774588080323E-20
# alpha, M, predM  1.4901161193847656E-08, 6.294810372572533E-20, 6.294774588084216E-20
# l2: ||R0||= 4.5002969E-11, f_err=2.829284E-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 2.03E-10, QuadOrder=4
# ALNR=1.0870391615105712 > 1.005 so we continue
#
#
# Starting Opt-Iter No.37:
# alpha, M, predM  1, 8.448771327649156E-18, 6.294513777148438E-20
# alpha, M, predM  0.5, 2.337760886563719E-18, 6.294644375769282E-20
# alpha, M, predM  0.25, 6.73659025060376E-19, 6.294709675079704E-20
# alpha, M, predM  0.125, 1.8946115676034435E-19, 6.294742324734914E-20
# alpha, M, predM  0.0625, 6.39750498600743E-20, 6.29475864956252E-20
# alpha, M, predM  0.03125, 7.253539217981182E-20, 6.294766811976323E-20
# alpha, M, predM  0.015625, 6.949779202427529E-20, 6.294770893183224E-20
# alpha, M, predM  0.0078125, 6.596285623334268E-20, 6.294772933786675E-20
# alpha, M, predM  0.00390625, 6.381156554353954E-20, 6.2947739540884E-20
# alpha, M, predM  0.001953125, 6.325414799223359E-20, 6.294774464239264E-20
# alpha, M, predM  1.9073486328125E-06, 6.294857073022015E-20, 6.294774098648904E-20
# alpha, M, predM  9.5367431640625E-07, 6.294794839122218E-20, 6.294774098898002E-20
# alpha, M, predM  4.76837158203125E-07, 6.294800809383141E-20, 6.29477409902255E-20
# alpha, M, predM  2.384185791015625E-07, 6.294801692171982E-20, 6.294774099084825E-20
# alpha, M, predM  1.1920928955078125E-07, 6.294807714843313E-20, 6.294774099115961E-20
# alpha, M, predM  5.960464477539063E-08, 6.294810543622907E-20, 6.29477409913153E-20
# alpha, M, predM  2.9802322387695312E-08, 6.294808627526295E-20, 6.294774099139315E-20
# alpha, M, predM  1.4901161193847656E-08, 6.294803656860485E-20, 6.294774099143207E-20
# l2: ||R0||= 4.5002965E-11, f_err=2.829284E-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 2.03E-10, QuadOrder=4
# ALNR=1.0620224141147987 > 1.005 so we continue
#
#
# Starting Opt-Iter No.39:
# alpha, M, predM  1, 8.448769301662518E-18, 6.294508703329295E-20
# alpha, M, predM  0.5, 2.337756826546021E-18, 6.294639302547182E-20
# alpha, M, predM  0.25, 6.736596309241546E-19, 6.294704602156127E-20
# alpha, M, predM  0.125, 1.8946187344974945E-19, 6.294737251960598E-20
# alpha, M, predM  0.0625, 6.397547000272375E-20, 6.294753576862835E-20
# alpha, M, predM  0.03125, 7.253574326609483E-20, 6.294761739313952E-20
# alpha, M, predM  0.015625, 6.949782434619569E-20, 6.294765820539512E-20
# alpha, M, predM  0.0078125, 6.596298319118928E-20, 6.294767861152291E-20
# alpha, M, predM  0.00390625, 6.381166418111254E-20, 6.294768881458681E-20
# alpha, M, predM  0.001953125, 6.325405211496114E-20, 6.294769391611876E-20
# alpha, M, predM  0.0009765625, 6.309590615714308E-20, 6.294769646688474E-20
# alpha, M, predM  0.00048828125, 6.302107186236922E-20, 6.294769774226772E-20
# alpha, M, predM  0.000244140625, 6.298474787291674E-20, 6.294769837995921E-20
# alpha, M, predM  0.0001220703125, 6.296627598553891E-20, 6.294769869880496E-20
# alpha, M, predM  6.103515625E-05, 6.295721807230353E-20, 6.294769885822784E-20
# alpha, M, predM  3.0517578125E-05, 6.295275926184298E-20, 6.294769893793927E-20
# alpha, M, predM  1.52587890625E-05, 6.295046737902268E-20, 6.294769897779498E-20
# alpha, M, predM  7.62939453125E-06, 6.294913581233741E-20, 6.294769899772285E-20
# alpha, M, predM  3.814697265625E-06, 6.294831821739763E-20, 6.294769900768678E-20
# alpha, M, predM  1.9073486328125E-06, 6.294845588686672E-20, 6.294769901266875E-20
# alpha, M, predM  9.5367431640625E-07, 6.294787859454958E-20, 6.294769901515972E-20
# alpha, M, predM  4.76837158203125E-07, 6.29482248748658E-20, 6.294769901640522E-20
# alpha, M, predM  2.384185791015625E-07, 6.294798522784563E-20, 6.294769901702796E-20
# alpha, M, predM  1.1920928955078125E-07, 6.294799323854769E-20, 6.294769901733933E-20
# alpha, M, predM  5.960464477539063E-08, 6.294796485803303E-20, 6.294769901749502E-20
# alpha, M, predM  2.9802322387695312E-08, 6.294805642214802E-20, 6.294769901757286E-20
# alpha, M, predM  1.4901161193847656E-08, 6.294803735395126E-20, 6.294769901761179E-20
# l2: ||R0||= 4.5002968E-11, f_err=2.829284E-10, f_phi=0E+00, Alpha = 1E-08, Gamma = 1E-04, Kappa = 1E+03, Mu = 2.03E-10, QuadOrder=4
#
# ALNR=1.000000018282971 <= 1.005 so we terminate/increase degree
#
# ALNR=1 <= 1.005 so we terminate/increase degree

# %%
pSAIDT.GetResPlot().ToGnuplot().PlotSVG(xRes:1200,yRes:500)
# Out:
# Using gnuplot: C:\Program Files (x86)\FDY\BoSSS\bin\native\win\gnuplot-gp510-20160418-win32-mingw\gnuplot\bin\gnuplot.exe
# Note: In a Jupyter Worksheet, you must NOT have a trailing semicolon in order to see the plot on screen; otherwise, the output migth be surpressed.!
# <?xml version="1.0" encoding="utf-8"  standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg
#  width="1200" height="500"
#  viewBox="0 0 1200 500"
#  xmlns="http://www.w3.org/2000/svg"
#  xmlns:xlink="http://www.w3.org/1999/xlink"
# >
#
# <title>Gnuplot</title>
# <desc>Produced by GNUPLOT 5.1 patchlevel 0 </desc>
#
# <g id="gnuplot_canvas">
#
# <rect x="0" y="0" width="1200" height="500" fill="#ffffff"/>
# <defs>
#
# 	<circle id='gpDot' r='0.5' stroke-width='0.5'/>
# 	<path id='gpPt0' stroke-width='0.222' stroke='currentColor' d='M-1,0 h2 M0,-1 v2'/>
# 	<path id='gpPt1' stroke-width='0.222' stroke='currentColor' d='M-1,-1 L1,1 M1,-1 L-1,1'/>
# 	<path id='gpPt2' stroke-width='0.222' stroke='currentColor' d='M-1,0 L1,0 M0,-1 L0,1 M-1,-1 L1,1 M-1,1 L1,-1'/>
# 	<rect id='gpPt3' stroke-width='0.222' stroke='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<rect id='gpPt4' stroke-width='0.222' stroke='currentColor' fill='currentColor' x='-1' y='-1' width='2' height='2'/>
# 	<circle id='gpPt5' stroke-width='0.222' stroke='currentColor' cx='0' cy='0' r='1'/>
# 	<use xlink:href='#gpPt5' id='gpPt6' fill='currentColor' stroke='none'/>
# 	<path id='gpPt7' stroke-width='0.222' stroke='currentColor' d='M0,-1.33 L-1.33,0.67 L1.33,0.67 z'/>
# 	<use xlink:href='#gpPt7' id='gpPt8' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt7' id='gpPt9' stroke='currentColor' transform='rotate(180)'/>
# 	<use xlink:href='#gpPt9' id='gpPt10' fill='currentColor' stroke='none'/>
# 	<use xlink:href='#gpPt3' id='gpPt11' stroke='currentColor' transform='rotate(45)'/>
# 	<use xlink:href='#gpPt11' id='gpPt12' fill='currentColor' stroke='none'/>
# 	<path id='gpPt13' stroke-width='0.222' stroke='currentColor' d='M0,1.330 L1.265,0.411 L0.782,-1.067 L-0.782,-1.076 L-1.265,0.411 z'/>
# 	<use xlink:href='#gpPt13' id='gpPt14' fill='currentColor' stroke='none'/>
# 	<filter id='textbox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='#FFFFFF' flood-opacity='1' result='bgnd'/>
# 	  <feComposite in='SourceGraphic' in2='bgnd' operator='atop'/>
# 	</filter>
# 	<filter id='greybox' filterUnits='objectBoundingBox' x='0' y='0' height='1' width='1'>
# 	  <feFlood flood-color='lightgrey' flood-opacity='1' result='grey'/>
# 	  <feComposite in='SourceGraphic' in2='grey' operator='atop'/>
# 	</filter>
# </defs>
# <g fill="none" color="#FFFFFF" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L62.9,442.4 M1150.1,442.4 L1141.1,442.4  '/>	<g transform="translate(45.6,448.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-12</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,413.4 L58.4,413.4 M1150.1,413.4 L1145.6,413.4 M53.9,384.4 L62.9,384.4 M1150.1,384.4 L1141.1,384.4
# 		 '/>	<g transform="translate(45.6,390.4)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-10</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,355.3 L58.4,355.3 M1150.1,355.3 L1145.6,355.3 M53.9,326.3 L62.9,326.3 M1150.1,326.3 L1141.1,326.3
# 		 '/>	<g transform="translate(45.6,332.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-8</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,297.3 L58.4,297.3 M1150.1,297.3 L1145.6,297.3 M53.9,268.3 L62.9,268.3 M1150.1,268.3 L1141.1,268.3
# 		 '/>	<g transform="translate(45.6,274.3)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-6</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,239.2 L58.4,239.2 M1150.1,239.2 L1145.6,239.2 M53.9,210.2 L62.9,210.2 M1150.1,210.2 L1141.1,210.2
# 		 '/>	<g transform="translate(45.6,216.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-4</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,181.2 L58.4,181.2 M1150.1,181.2 L1145.6,181.2 M53.9,152.2 L62.9,152.2 M1150.1,152.2 L1141.1,152.2
# 		 '/>	<g transform="translate(45.6,158.2)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">-2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,123.2 L58.4,123.2 M1150.1,123.2 L1145.6,123.2 M53.9,94.1 L62.9,94.1 M1150.1,94.1 L1141.1,94.1
# 		 '/>	<g transform="translate(45.6,100.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">0</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,65.1 L58.4,65.1 M1150.1,65.1 L1145.6,65.1 M53.9,36.1 L62.9,36.1 M1150.1,36.1 L1141.1,36.1
# 		 '/>	<g transform="translate(45.6,42.1)" stroke="none" fill="black" font-family="sans" font-size="16.00"  text-anchor="end">
# 		<text><tspan font-family="sans" >10</tspan><tspan font-family="sans"  font-size="12.8" dy="-8.00px">2</tspan><tspan font-size="16.0" dy="8.00"></tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M53.9,442.4 L53.9,433.4 M53.9,36.1 L53.9,45.1  '/>	<g transform="translate(53.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 0</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M190.9,442.4 L190.9,433.4 M190.9,36.1 L190.9,45.1  '/>	<g transform="translate(190.9,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 5</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" stroke="currentColor" stroke-width="1.00" stroke-linecap="butt" stroke-linejoin="miter">
# 	<path stroke='black'  d='M328.0,442.4 L328.0,433.4 M328.0,36.1 L328.0,45.1  '/>	<g transform="translate(328.0,464.9)" stroke="none" fill="black" font-family="Arial" font-size="12.00"  text-anchor="middle">
# 		<text><tspan font-family="Arial" > 10</tspan></text>
# 	</g>
# </g>
# <g fill="none" color="black" str

# %%
var si= database.Sessions.Pick(1);
si
# Out:
# System.ArgumentOutOfRangeException: Index was out of range. Must be non-negative and less than the size of the collection. (Parameter 'index')
#
#    at System.Collections.Generic.List`1.get_Item(Int32 index)
#
#    at System.Linq.Enumerable.ElementAt[TSource](IEnumerable`1 source, Int32 index)
#
#    at BoSSS.Foundation.IO.IEnumerableExtensions.Pick[T](IEnumerable`1 entities, Int32 index) in C:\experimental\public\src\L4-application\BoSSSpad\IEnumerableExtensions.cs:line 131
#
#    at Submission#6.<<Initialize>>d__0.MoveNext()
#
# --- End of stack trace from previous location ---
#
#    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

# %%
var si= database.Sessions.Pick(0);
BoSSS.Solution.Application.DeleteOldPlotFiles();
pSAIDT.PlotShadowFields(si);
# Out:
# rm;
