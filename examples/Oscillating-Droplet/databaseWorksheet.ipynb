// %%
//#r "../../src/L4-application/BoSSSpad/bin/Release/net5.0/BoSSSpad.dll"
//#r "../../src/L4-application/BoSSSpad/bin/Debug/net5.0/BoSSSpad.dll"
#r "BoSSSpad.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Foundation;
using BoSSS.Foundation.XDG;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.AdvancedSolvers;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
using BoSSS.Application.XNSE_Solver;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
Init();

// %%
OpenOrCreateDatabase(@"\\hpccluster\hpccluster-scratch\smuda\XNSE_studyDB");
OpenOrCreateDatabase(@"D:\Database_backups\hpccluster\XNSE_studyDB_backup");

// %%
databases
// Out:
// #0: { Session Count = 814; Grid Count = 23491; Path = \\hpccluster\hpccluster-scratch\smuda\XNSE_studyDB }
// #1: { Session Count = 650; Grid Count = 2789; Path = D:\Database_backups\hpccluster\XNSE_studyDB_backup }

// %%
var origin = databases.Pick(0);
origin
// Out:
// { Session Count = 814; Grid Count = 23491; Path = \\hpccluster\hpccluster-scratch\smuda\XNSE_studyDB }

// %%
var backup = databases.Pick(1);
backup
// Out:
// { Session Count = 650; Grid Count = 2789; Path = D:\Database_backups\hpccluster\XNSE_studyDB_backup }

// %%
var workSess = origin.Sessions.Skip(65);
workSess
// Out:
// Loading session 097e1b7d-e16c-4525-a5dc-1c47cd35a00a failed with message 'Unexpected end when deserializing object. Path 'm_KeysAndQueries.Timestepper_Scheme'.'
// Loading session 097e1b7d-e16c-4525-a5dc-1c47cd35a00a failed with message 'Unexpected end when deserializing object. Path 'm_KeysAndQueries.Timestepper_Scheme'.'
// #0: TwoPhaseCouetteFlow	CouetteGNBC_compDOFstudy_k4_mesh0_AMR1cL_restart2*	10/08/2020 09:51:08	8916f4e6...
// #1: TwoPhaseCouetteFlow	CouetteGNBC_compDOFstudy_k4_mesh0_AMR1cL_restart*	10/07/2020 18:01:46	0953d866...
// #2: TwoPhaseCouetteFlow	CouetteGNBC_compDOFstudy_symmetric_k4_mesh0_AMR1cL_restart*	10/07/2020 13:28:03	3f677722...
// #3: RisingBubble	RisingBubble_tc2_k2_mesh20_newAMR4_restart2*	09/30/2020 17:39:49	29984a49...
// #4: RisingBubble	RisingBubble_tc1_k2_mesh40_noPenalty_AR_int01	09/23/2020 15:21:14	bf558975...
// #5: RisingBubble	RisingBubble_tc2_k2_mesh20_newAMR4_restart*	09/23/2020 15:21:14	b1fba22a...
// ...

// %%
var procSess = workSess.Skip(700).Take(50);

// %%
foreach(var sess in procSess) {
    Console.WriteLine("copying session: {0}", sess.Name);
    sess.Copy(backup); 
}
// Out:
// copying session: StaticDropletOnWall_ConvStudy_k2_mesh4
// copying session: StaticDropletOnWall_ConvStudy_k3_mesh3
// copying session: StaticDropletOnWall_ConvStudy_k3_mesh2
// copying session: StaticDropletOnWall_ConvStudy_k2_mesh3
// copying session: StaticDropletOnWall_ConvStudy_k3_mesh1
// copying session: StaticDropletOnWall_ConvStudy_k2_mesh6
// copying session: StaticDropletOnWall_ConvStudy_k3_mesh0
// copying session: StaticDropletOnWall_ConvStudy_k2_mesh2
// copying session: StaticDropletOnWall_ConvStudy_k2_mesh1
// copying session: StaticDropletOnWall_ConvStudy_k2_mesh0
// copying session: StaticDropletOnWall_test2
// copying session: CouetteFlow_test3
// copying session: CouetteFlow_test2
// copying session: CouetteFlow_test
// copying session: CouetteGNBC_testNewGrid2_k2_mesh02
// copying session: RisingBubble_Fourier_k2_mesh1_parallelTest
// copying session: CouetteGNBC_testNewGrid2_k2_mesh0
// copying session: RisingBubble_ExtVelCurv2_k2_mesh1
// ...
