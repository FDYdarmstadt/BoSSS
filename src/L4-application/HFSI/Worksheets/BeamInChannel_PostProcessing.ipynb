// %%
#r "BoSSSpad/BoSSSpad.dll"
using System;
using System.Collections.Generic;
using System.Linq;
using System.IO;
using System.Data;
using System.Globalization;
using System.Threading;
using ilPSP;
using ilPSP.Utils;
using BoSSS.Platform;
using BoSSS.Foundation;
using BoSSS.Foundation.Grid;
using BoSSS.Foundation.Grid.Classic;
using BoSSS.Foundation.IO;
using BoSSS.Solution;
using BoSSS.Solution.Control;
using BoSSS.Solution.GridImport;
using BoSSS.Solution.Statistic;
using BoSSS.Solution.Utils;
using BoSSS.Solution.Gnuplot;
using BoSSS.Application.BoSSSpad;
//using BoSSS.Application.XNSE_Solver;
using static BoSSS.Application.BoSSSpad.BoSSSshell;
using BoSSS.Foundation.Grid.RefElements;
using BoSSS.Platform.LinAlg;
using BoSSS.Solution.NSECommon;
using BoSSS.Solution.XdgTimestepping;
Init();

// %%
static var myBatch = ExecutionQueues[0];
myBatch.CreateOrOpenCompatibleDatabase("BeamInChannel");
myBatch.CreateOrOpenCompatibleDatabase("Beam");
// Out:
// Opening existing database 'C:\Users\miao\Documents\Database\BeamInChannel'.
// Opening existing database 'C:\Users\miao\Documents\Database\Beam'.

// %%
databases
// Out:
// #0: { Session Count = 25; Grid Count = 3561; Path = C:\Users\miao\Documents\Database\BeamInChannel }
// #1: { Session Count = 25; Grid Count = 35; Path = C:\Users\miao\Documents\Database\Beam }

// %% [markdown]
// ## Create grid

// %% [markdown]
// ## Create Control file

// %% [markdown]
// ## Send and run jobs

// %% [markdown]
// ## Post processing

// %%
databases
// Out:
// #0: { Session Count = 25; Grid Count = 3561; Path = C:\Users\miao\Documents\Database\BeamInChannel }
// #1: { Session Count = 25; Grid Count = 35; Path = C:\Users\miao\Documents\Database\Beam }

// %%
databases[0].Sessions
// Out:
// #0: BeamInChannel-Density10-Sliplength10	BeamInChannel-Density10-Sliplength10	1/9/2024 9:52:35 PM	a80e0205...
// #1: BeamInChannel-Density10-Sliplength0.1	BeamInChannel-Density10-Sliplength0.1	1/9/2024 9:51:12 PM	1bff947f...
// #2: BeamInChannel-Density10-Sliplength1	BeamInChannel-Density10-Sliplength1	1/9/2024 9:52:23 PM	b8b27ec3...
// #3: BeamInChannel-Density10-Sliplength0	BeamInChannel-Density10-Sliplength0	1/9/2024 9:48:11 PM	e97aab7e...
// #4: BeamInChannel-Density100	BeamInChannel-Density100	1/8/2024 9:06:25 PM	bcc3f154...
// #5: BeamInChannel-Density50	BeamInChannel-Density50	1/8/2024 9:06:19 PM	b07953c4...
// #6: BeamInChannel-Density5	BeamInChannel-Density5	1/8/2024 9:06:07 PM	9de6bc94...
// #7: BeamInChannel-Density10	BeamInChannel-Density10	1/8/2024 11:46:29 AM	cdb89f20...
// #8: BeamInChannel-Density10	BeamInChannel-Density10*	1/8/2024 11:44:37 AM	35e9c21c...
// #9: BeamInChannel-Density10	BeamInChannel-Density10-check	9/8/2023 3:37:50 PM	99cc62ca...
// ...

// %%
databases[1].Sessions
// Out:
// #0: Beam-Density10-sliplength10	Beam-Density10-sliplength10*	1/9/2024 9:52:39 PM	e7b3bae2...
// #1: Beam-Density10-sliplength1	Beam-Density10-sliplength1*	1/9/2024 9:52:26 PM	0a93872a...
// #2: Beam-Density10-sliplength0.1	Beam-Density10-sliplength0.1*	1/9/2024 9:51:16 PM	f27414c8...
// #3: Beam-Density10-sliplength0	Beam-Density10-sliplength0*	1/9/2024 9:48:15 PM	e8d229fa...
// #4: Beam-Density100	Beam-Density100*	1/8/2024 9:06:29 PM	105b92c2...
// #5: Beam-Density50	Beam-Density50*	1/8/2024 9:06:22 PM	13d4b8d5...
// #6: Beam-Density5	Beam-Density5*	1/8/2024 9:06:11 PM	5d57ece3...
// #7: Beam-Density10	Beam-Density10*	1/8/2024 11:46:33 AM	050e9ea9...
// #8: Beam-Density10	Beam-Density10*	1/8/2024 11:44:41 AM	0fc87b83...
// #9: Beam-Density5	Beam-Density5-check*	9/8/2023 3:38:52 PM	880ead9d...
// #10: Beam-Density10	Beam-Density10-check*	9/8/2023 3:37:54 PM	f60bc0ee...
// #11: Beam-Density50	Beam-Density50-check*	9/8/2023 3:37:07 PM	756dbae2...
// ...

// %%
//var outPath = databases[0].Sessions[0].Timesteps.Skip(395).Export().WithSupersampling(3).Do();

// %% [markdown]
// ## Results for different Sliplength

// %%
var sessionSL10 = databases[1].Sessions[0];
var sessionSL1 = databases[1].Sessions[1];
var sessionSL0d1 = databases[1].Sessions[2];
var sessionSL0 = databases[1].Sessions[3];

// %%
var mydatasetSL10 = sessionSL10.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Sliplength 10"
        );
mydatasetSL10.SaveTextFileToPublish(@"C:\tmp\Sliplength10_DisplacementX.txt");

var mydatasetSL1 = sessionSL1.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Sliplength 1"
        );
mydatasetSL1.SaveTextFileToPublish(@"C:\tmp\Sliplength1_DisplacementX.txt");

var mydatasetSL0d1 = sessionSL0d1.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Sliplength 0.1"
        );
mydatasetSL0d1.SaveTextFileToPublish(@"C:\tmp\Sliplength0.1_DisplacementX.txt");

var mydatasetSL0 = sessionSL0.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Sliplength 0"
        );
mydatasetSL0.SaveTextFileToPublish(@"C:\tmp\Sliplength0_DisplacementX.txt");

// %%
var mydatasetSL10 = sessionSL10.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Sliplength 10"
        );
mydatasetSL10.SaveTextFileToPublish(@"C:\tmp\Sliplength10_VelocityX.txt");

var mydatasetSL1 = sessionSL1.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Sliplength 1"
        );
mydatasetSL1.SaveTextFileToPublish(@"C:\tmp\Sliplength1_VelocityX.txt");

var mydatasetSL0d1 = sessionSL0d1.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Sliplength 0.1"
        );
mydatasetSL0d1.SaveTextFileToPublish(@"C:\tmp\Sliplength0.1_VelocityX.txt");

var mydatasetSL0 = sessionSL0.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Sliplength 0"
        );
mydatasetSL0.SaveTextFileToPublish(@"C:\tmp\Sliplength0_VelocityX.txt");

// %%
mydatasetSL10.PlotNow()

// %% [markdown]
// ## Results for different Density

// %%
//var outPath = databases[0].Sessions[2].Timesteps.Skip(0).Export().WithSupersampling(4).Do();

// %%
//var outPath = databases[1].Sessions[3].Timesteps.Skip(0).Export().WithSupersampling(4).Do();

// %%
var session100 = databases[1].Sessions[0 + 4];
var session50 = databases[1].Sessions[1 + 4];
var session10 = databases[1].Sessions[3 + 4];
var session5 = databases[1].Sessions[2 + 4];

// %%
//session5.Timesteps.Count

// %%
var mydataset100 = session100.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Density 100"
        );
mydataset100.SaveTextFileToPublish(@"C:\tmp\Density100DisplacementX.txt");

var mydataset50 = session50.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Density 50"
        );
mydataset50.SaveTextFileToPublish(@"C:\tmp\Density50DisplacementX.txt");

var mydataset10 = session10.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Density 10"
        );
mydataset10.SaveTextFileToPublish(@"C:\tmp\Density10DisplacementX.txt");

var mydataset5 = session5.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("DisplacementX").ProbeAt(0.0, 0.90),
        t => "Density 5"
        );
mydataset5.SaveTextFileToPublish(@"C:\tmp\Density5DisplacementX.txt");

// %%
var mydataset100 = session100.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Density 100"
        );
mydataset100.SaveTextFileToPublish(@"C:\tmp\Density100VelocityX.txt");

var mydataset50 = session50.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Density 50"
        );
mydataset50.SaveTextFileToPublish(@"C:\tmp\Density50VelocityX.txt");

var mydataset10 = session10.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Density 10"
        );
mydataset10.SaveTextFileToPublish(@"C:\tmp\Density10VelocityX.txt");

var mydataset5 = session5.Timesteps.ToDataSet(
        t => t.PhysicalTime,
        t => t.Fields.Find("VelocityX").ProbeAt(0.0, 0.90),
        t => "Density 5"
        );
mydataset5.SaveTextFileToPublish(@"C:\tmp\Density5VelocityX.txt");

// %%
mydataset5.PlotNow()
